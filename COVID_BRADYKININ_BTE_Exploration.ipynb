# %% [markdown]
# # Addressing COVID-19 Patient RAS-mediated Bradykinin Storm Hypothesis with  Biothings Explorer
#
# &emsp;
#
# SLIDES LINK: https://docs.google.com/presentation/d/1cL0Y-2FECPP5rWlJGI_ZWsvBysZVUGU-oDq75VexFrA/edit?usp=sharing

# %% [markdown]
# # Table of Contents
#
# ## &emsp; 0 Imports
# ## &emsp; 1 Overview of Background and BTE Approach
# ### &emsp; &emsp; 1.1 Article: Summary and Background
# ### &emsp; &emsp; 1.2 Overview of BTE Approach
# ## &emsp; 2 Determining Related Genes
# ### &emsp; &emsp; 2.1 Load COVID-19, Hypotension, and Vasodilation Nodes
# ### &emsp; &emsp; 2.2 COVID -> Genes <- Hypotension
# ### &emsp; &emsp; 2.3 COVID -> Genes <- Vasodilation
# ### &emsp; &emsp; 2.4 Create Gene Nodes
# ## &emsp; 3 Analyzing and Exploring Gene Results
# ### &emsp; &emsp; 3.1 Genes -> Pathways
# ### &emsp; &emsp; 3.2 Genes -> Biological Processes
# ### &emsp; &emsp; 3.3 Genes -> Chemical Substances
# ### &emsp; &emsp; 3.4 Genes -> Anatomical Entities
# ### &emsp; &emsp; 3.5 Genes -> Chemical Substances <- Vasodilation
# ## &emsp; 4 Exploring COVID-19 to Hyaluronic Acid Connection
# ### &emsp; &emsp; 4.1 COVID-19 -> Genes <- Hyaluronic Acid Explain Query
# ### &emsp; &emsp; 4.2 COVID/HYA Genes -> Pathways
# ## &emsp; 5 Summary
# ### &emsp; &emsp; 5.1 Summary
# ### &emsp; &emsp; 5.2 Future Directions

# %% [markdown]
# ## 0 Imports

# %%
# Import pandas and biothings explorers modules
import pandas as pandas
from biothings_explorer.query.predict import Predict
from biothings_explorer.query.visualize import display_graph
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
import nest_asyncio
nest_asyncio.apply()
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore") 
ht = Hint()


## predict_many -> functionality to be fully incorporated into BTE soon, will no longer need following
def predict_many(input_object_list, output_type_list, intermediate_node_list = ''):
    df_list = []
    for input_object in input_object_list: 
        if('name' in input_object):
            for output_type in output_type_list: 
                if(len(intermediate_node_list) > 0):
                    for inter in intermediate_node_list:
                        try: 
#                             print("Running: " + input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type )
                            fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
                            fc.connect(verbose=False)
                            df = fc.display_table_view()
                            rows = df.shape[0]
                            if(rows > 0):
                                df_list.append(df)
                        except:
                            pass
#                             print(input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type + ' FAILED')
                else:
                    try:
#                         print("Running: " + input_object['name'] + ' --> output type ' + output_type )
                        fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=None)
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        rows = df.shape[0]
                        if(rows > 0):
                            df_list.append(df)
                    except:
                        pass
#                         print(input_object['name'] + ' --> output type ' + output_type + ' FAILED')

    if(len(df_list) > 0):
        return pandas.concat(df_list)
    else:
        return None

# %% [markdown]
# ## 1 Overview of Background and BTE Approach
# &emsp;
# ### 1.1 Article: Summary and Background
#
# Article Reference:
#
# Garvin, Michael R., et al. "A mechanistic model and therapeutic interventions for COVID-19 involving a RAS-mediated bradykinin storm." Elife 9 (2020): e59177.
#
#
# Article Link:
#
# https://elifesciences.org/articles/59177
#
#
#
# Article Main Points:
#
# - RAS Pathway Imbalance implicated through gene expression analysis from cells in bronchoalveolar lavage fluid (BALF) from COVID-19 patients
#
# - Predicted RAS pathway imbalance to be cause of bradykinin-driven vascular dilation, vascular permeability and hypotension
#
# - Leaky membranes -> allows Hyaluronic Acid (HYA) to permeate into lungs
#
# - Analyses found that production of HYA was increased and the enzymes that could degrade it greatly decreased
#
#
# ### 1.2 Overview of BTE Approach
#
# As described in the article, vasodilation and hypotension are two distinctive signs and symptoms in severe COVID-19 cases that are predicted to lead to leaky membranes in the lung. Therefore, the following approach to determine whether or not this may be RAS-pathway linked is by looking at Genes that are both related to COVID and vasoconstriction or hypotension, and then analyzing this genes by looking at what pathways or processes they may be involved in, what chemical substances they may produce, and in what tissues or anatomical entities the genes are linked to.
#
# Also, starting in Section 4, a brief exploration of genes related to both COVID and Hyaluronic acid is done - HYA being a chemical found in the lungs of COVID patients that is hyper-absorbant and forms a gelatenous substance that blocks oxygen absorption by the lungs
#
# ## 2 Determining Related Genes
# &emsp;
# ### 2.1 Load COVID-19, Hypotension, and Vasodilation Nodes
# &emsp;

# %%
covid = ht.query('COVID-19')['Disease'][0]
covid
# Out:
# {'MONDO': 'MONDO:0100096',
#  'DOID': 'DOID:0080600',
#  'name': 'COVID-19',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0100096'},
#  'display': 'MONDO(MONDO:0100096) DOID(DOID:0080600) name(COVID-19)',
#  'type': 'Disease'}

# %%
hypotension = ht.query('hypotension')['PhenotypicFeature'][0]
hypotension
# Out:
# {'UMLS': 'C0020649',
#  'HP': 'HP:0002615',
#  'MESH': 'D007022',
#  'name': 'Hypotension',
#  'primary': {'identifier': 'UMLS',
#   'cls': 'PhenotypicFeature',
#   'value': 'C0020649'},
#  'display': 'UMLS(C0020649) HP(HP:0002615) MESH(D007022) name(Hypotension)',
#  'type': 'PhenotypicFeature'}

# %%
vasodilation = ht.query('vasodilation')['BiologicalProcess'][0]
vasodilation
# Out:
# {'GO': 'GO:0042311',
#  'name': 'vasodilation',
#  'primary': {'identifier': 'GO',
#   'cls': 'BiologicalProcess',
#   'value': 'GO:0042311'},
#  'display': 'GO(GO:0042311) name(vasodilation)',
#  'type': 'BiologicalProcess'}

# %% [markdown]
# ### 2.2 COVID -> Genes <- Hypotension
# Use explain query to determine genes related to both COVID and Hypotension

# %%
fc = FindConnection(input_obj=covid, output_obj=hypotension, intermediate_nodes=['Gene'])
fc.connect(verbose=False)
df = fc.display_table_view()
df
# Out:
#                     input input_type       pred1 pred1_source     pred1_api  \
# 0  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 1  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 2  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 3  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
#
#   pred1_pubmed node1_type node1_name       node1_id       pred2 pred2_source  \
# 0         None       Gene      AGTR1   NCBIGene:185  related_to         None
# 1         None       Gene        ALB   NCBIGene:213  related_to         None
# 2         None       Gene        REN  NCBIGene:5972  related_to         None
# 3         None       Gene        ACE  NCBIGene:1636  related_to         None
#
#      pred2_api pred2_pubmed output_type           output_name      output_id
# 0  BioLink API         None        Gene  ARTERIAL HYPOTENSION  UMLS:C0020649
# 1  BioLink API         None        Gene  ARTERIAL HYPOTENSION  UMLS:C0020649
# 2  BioLink API         None        Gene  ARTERIAL HYPOTENSION  UMLS:C0020649
# 3  BioLink API         None        Gene  ARTERIAL HYPOTENSION  UMLS:C0020649

# %%
df.to_csv("covid_to_hyptension.csv", index = False)

# %% [markdown]
# ### 2.3 COVID -> Genes <- Vasodilation
# Use explain query to determine genes related to both COVID and Vasodilation

# %%
fc2 = FindConnection(input_obj=covid, output_obj=vasodilation, intermediate_nodes=['Gene'])
fc2.connect(verbose=False)
df2 = fc2.display_table_view()
df2
# Out:
#                     input input_type       pred1 pred1_source  \
# 0  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 1  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 2  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 3  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 4  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 5  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 6  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
#
#                      pred1_api pred1_pubmed node1_type node1_name  \
# 0                 DISEASES API         None       Gene         MB
# 1                 DISEASES API         None       Gene        CRP
# 2  Automat CORD19 Scigraph API         None       Gene        CRP
# 3                 DISEASES API         None       Gene        ACE
# 4                 DISEASES API         None       Gene       DPP4
# 5  Automat CORD19 Scigraph API         None       Gene         TH
# 6                 DISEASES API         None       Gene        REN
#
#         node1_id       pred2                     pred2_source  \
# 0  NCBIGene:4151  related_to  Translator Text Mining Provider
# 1  NCBIGene:1401  related_to  Translator Text Mining Provider
# 2  NCBIGene:1401  related_to  Translator Text Mining Provider
# 3  NCBIGene:1636  related_to  Translator Text Mining Provider
# 4  NCBIGene:1803  related_to  Translator Text Mining Provider
# 5  NCBIGene:7054  related_to  Translator Text Mining Provider
# 6  NCBIGene:5972  related_to  Translator Text Mining Provider
#
#                      pred2_api pred2_pubmed output_type  \
# 0  CORD Biological Process API         None        Gene
# 1  CORD Biological Process API         None        Gene
# 2  CORD Biological Process API         None        Gene
# 3  CORD Biological Process API         None        Gene
# 4  CORD Biological Process API         None        Gene
# 5  CORD Biological Process API         None        Gene
# 6  CORD Biological Process API         None        Gene
#
#                                 output_name      output_id
# 0  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 1  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 2  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 3  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 4  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 5  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 6  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311

# %%
df2.to_csv("covid_to_vasodilation.csv", index = False)

# %% [markdown]
# ### 2.4 Create Gene Nodes

# %%
## create Gene list
genes_related_to_syptoms = list(df["node1_name"]) + list(df2["node1_name"])
genes_related_to_syptoms
# Out:
# ['AGTR1', 'ALB', 'REN', 'ACE', 'MB', 'CRP', 'CRP', 'ACE', 'DPP4', 'TH', 'REN']

# %%
# get gene inputs through hint module
gene_inputs = []
for gene in genes_related_to_syptoms: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        gene_inputs.append(gene_input)
    except: 
        print(gene + ' Failed')

# %% [markdown]
# ## 3 Analyzing and Exploring Gene Results
#
# Look at the determined genes (from explain queries above) to analyze what pathways, biological processes, chemical substances, and anatomical entities the genes are related to.

# %% [markdown]
# ### 3.1 Genes -> Pathways
#
# Look at pathways related to the genes, and then display top pathway occurrences in results (and which genes related to each pathway).

# %%
gene_to_pathways = predict_many(gene_inputs, ['Pathway'])

# %%
# pathways
gene_to_pathway_results = {}
gene_to_pathway_genes = list(gene_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'pathway_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_pathways.iterrows():
    gene_to_pathway_results[row['output_name']]['pathway_count'] = gene_to_pathway_results[row['output_name']]['pathway_count'] + 1
    gene_to_pathway_results[row['output_name']]['genes_related'].append(row['input'])
    

gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['pathway_count'], reverse = True))

# gene_to_pathway_results
pandas.DataFrame.from_dict(gene_to_pathway_results, orient='index').iloc[0:50]
# Out:
#                                                     pathway_count  \
# METABOLISM OF PROTEINS                                          6
# ACE INHIBITOR PATHWAY                                           5
# PEPTIDE HORMONE METABOLISM                                      5
# METABOLISM OF ANGIOTENSINOGEN TO ANGIOTENSINS                   4
# SELENIUM MICRONUTRIENT NETWORK                                  3
# VITAMIN B12 METABOLISM                                          3
# FOLATE METABOLISM                                               3
# HUMAN COMPLEMENT SYSTEM                                         3
# VESICLE-MEDIATED TRANSPORT                                      2
# METABOLISM                                                      2
# TRANSPORT OF SMALL MOLECULES                                    2
# COMPLEMENT CASCADE                                              2
# INITIAL TRIGGERING OF COMPLEMENT                                2
# CREATION OF C4 AND C2 ACTIVATORS                                2
# INNATE IMMUNE SYSTEM                                            2
# IMMUNE SYSTEM                                                   2
# CLASSICAL ANTIBODY-MEDIATED COMPLEMENT ACTIVATION               2
# OVERVIEW OF NANOPARTICLE EFFECTS                                2
# IL-6 SIGNALING PATHWAY                                          2
# SIGNAL TRANSDUCTION                                             1
# MEMBRANE TRAFFICKING                                            1
# SIGNALING BY GPCR                                               1
# CLASS A/1 (RHODOPSIN-LIKE RECEPTORS)                            1
# PEPTIDE LIGAND-BINDING RECEPTORS                                1
# GPCR DOWNSTREAM SIGNALLING                                      1
# G ALPHA (Q) SIGNALLING EVENTS                                   1
# GPCR LIGAND BINDING                                             1
# CARGO RECOGNITION FOR CLATHRIN-MEDIATED ENDOCYT...              1
# CLATHRIN-MEDIATED ENDOCYTOSIS                                   1
# ALLOGRAFT REJECTION                                             1
# PEPTIDE GPCRS                                                   1
# HYPOTHESIZED PATHWAYS IN PATHOGENESIS OF CARDIO...              1
# GPCRS, CLASS A RHODOPSIN-LIKE                                   1
# HEMOSTASIS                                                      1
# PLATELET DEGRANULATION                                          1
# RECYCLING OF BILE ACIDS AND SALTS                               1
# PLASMA LIPOPROTEIN ASSEMBLY, REMODELING, AND CL...              1
# METABOLISM OF PORPHYRINS                                        1
# HEME BIOSYNTHESIS                                               1
# HEME DEGRADATION                                                1
# BILE ACID AND BILE SALT METABOLISM                              1
# SCAVENGING OF HEME FROM PLASMA                                  1
# BINDING AND UPTAKE OF LIGANDS BY SCAVENGER RECE...              1
# REGULATION OF INSULIN-LIKE GROWTH FACTOR (IGF) ...              1
# TRANSPORT OF VITAMINS, NUCLEOSIDES, AND RELATED...              1
# SLC-MEDIATED TRANSMEMBRANE TRANSPORT                            1
# METABOLISM OF LIPIDS                                            1
# POST-TRANSLATIONAL PROTEIN MODIFICATION                         1
# PLATELET ACTIVATION, SIGNALING AND AGGREGATION                  1
# RESPONSE TO ELEVATED PLATELET CYTOSOLIC CA2+                    1
#
#                                                                       genes_related
# METABOLISM OF PROTEINS                              [ALB, REN, ACE, ACE, DPP4, REN]
# ACE INHIBITOR PATHWAY                                   [AGTR1, REN, ACE, ACE, REN]
# PEPTIDE HORMONE METABOLISM                               [REN, ACE, ACE, DPP4, REN]
# METABOLISM OF ANGIOTENSINOGEN TO ANGIOTENSINS                  [REN, ACE, ACE, REN]
# SELENIUM MICRONUTRIENT NETWORK                                      [ALB, CRP, CRP]
# VITAMIN B12 METABOLISM                                              [ALB, CRP, CRP]
# FOLATE METABOLISM                                                   [ALB, CRP, CRP]
# HUMAN COMPLEMENT SYSTEM                                             [ALB, CRP, CRP]
# VESICLE-MEDIATED TRANSPORT                                             [AGTR1, ALB]
# METABOLISM                                                                [ALB, TH]
# TRANSPORT OF SMALL MOLECULES                                              [ALB, MB]
# COMPLEMENT CASCADE                                                       [CRP, CRP]
# INITIAL TRIGGERING OF COMPLEMENT                                         [CRP, CRP]
# CREATION OF C4 AND C2 ACTIVATORS                                         [CRP, CRP]
# INNATE IMMUNE SYSTEM                                                     [CRP, CRP]
# IMMUNE SYSTEM                                                            [CRP, CRP]
# CLASSICAL ANTIBODY-MEDIATED COMPLEMENT ACTIVATION                        [CRP, CRP]
# OVERVIEW OF NANOPARTICLE EFFECTS                                         [CRP, CRP]
# IL-6 SIGNALING PATHWAY                                                   [CRP, CRP]
# SIGNAL TRANSDUCTION                                                         [AGTR1]
# MEMBRANE TRAFFICKING                                                        [AGTR1]
# SIGNALING BY GPCR                                                           [AGTR1]
# CLASS A/1 (RHODOPSIN-LIKE RECEPTORS)                                        [AGTR1]
# PEPTIDE LIGAND-BINDING RECEPTORS                                            [AGTR1]
# GPCR DOWNSTREAM SIGNALLING                                                  [AGTR1]
# G ALPHA (Q) SIGNALLING EVENTS                                               [AGTR1]
# GPCR LIGAND BINDING                                                         [AGTR1]
# CARGO RECOGNITION FOR CLATHRIN-MEDIATED ENDOCYT...                          [AGTR1]
# CLATHRIN-MEDIATED ENDOCYTOSIS                                               [AGTR1]
# ALLOGRAFT REJECTION                                                         [AGTR1]
# PEPTIDE GPCRS                                                               [AGTR1]
# HYPOTHESIZED PATHWAYS IN PATHOGENESIS OF CARDIO...                          [AGTR1]
# GPCRS, CLASS A RHODOPSIN-LIKE                                               [AGTR1]
# HEMOSTASIS                                                                    [ALB]
# PLATELET DEGRANULATION                                                        [ALB]
# RECYCLING OF BILE ACIDS AND SALTS                                             [ALB]
# PLASMA LIPOPROTEIN ASSEMBLY, REMODELING, AND CL...                            [ALB]
# METABOLISM OF PORPHYRINS                                                      [ALB]
# HEME BIOSYNTHESIS                                                             [ALB]
# HEME DEGRADATION                                                              [ALB]
# BILE ACID AND BILE SALT METABOLISM                                            [ALB]
# SCAVENGING OF HEME FROM PLASMA                                                [ALB]
# BINDING AND UPTAKE OF LIGANDS BY SCAVENGER RECE...                            [ALB]
# REGULATION OF INSULIN-LIKE GROWTH FACTOR (IGF) ...                            [ALB]
# TRANSPORT OF VITAMINS, NUCLEOSIDES, AND RELATED...                            [ALB]
# SLC-MEDIATED TRANSMEMBRANE TRANSPORT                                          [ALB]
# METABOLISM OF LIPIDS                                                          [ALB]
# POST-TRANSLATIONAL PROTEIN MODIFICATION                                       [ALB]
# PLATELET ACTIVATION, SIGNALING AND AGGREGATION                                [ALB]
# RESPONSE TO ELEVATED PLATELET CYTOSOLIC CA2+                                  [ALB]

# %% [markdown]
# Result table interpretation: In agreement with argument made in article, top ranking results of "ACE Inhibitor Pathway" and "Metabolism of Angiotensinogen to Angiotensins" are both components of the RAS pathway.

# %% [markdown]
# ### 3.2 Genes -> Biological Processes
#
# Look at bbiological processes related to the genes, and then display top biological process occurrences in results (and which genes related to each biological processes).

# %%
# bioprocesss
gene_to_bioprocesses = predict_many(gene_inputs, ['BiologicalProcess'])
gene_to_bioprocess_results = {}
gene_to_bioprocess_genes = list(gene_to_bioprocesses["output_name"]) # create list of genes
gene_to_bioprocess_genes = list(dict.fromkeys(gene_to_bioprocess_genes))  # remove duplicates

for gene in gene_to_bioprocess_genes: 
    gene_to_bioprocess_results[gene] = {
        'bioprocess_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_bioprocesses.iterrows():
    gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] = gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] + 1
    gene_to_bioprocess_results[row['output_name']]['genes_related'].append(row['input'])

# %%
## extra step needed to analyze biological processes because many are returned as UMLS id instead of name

gene_to_bioprocess_results = dict(sorted(gene_to_bioprocess_results.items(), key = lambda x: x[1]['bioprocess_count'], reverse = True))
counter = 0 
gene_to_bioprocess_results_copy = gene_to_bioprocess_results
for key in gene_to_bioprocess_results_copy.keys(): 
    if counter < 100: 
        if(('C0' in key) or ('C1' in key)): 
            try: 
                name = ht.query(key)['BiologicalProcess'][0]['name']
                gene_to_bioprocess_results[name] = gene_to_bioprocess_results[key]
                del gene_to_bioprocess_results[key]
            except: 
                pass
    counter = counter + 1

# %%
# gene_to_bioprocess_results
pandas.DataFrame.from_dict(gene_to_bioprocess_results, orient='index').iloc[0:50]
# Out:
#                                                 bioprocess_count  \
# Growth                                                        25
# enzyme activity                                               25
# Apoptosis                                                     22
# Up-Regulation (Physiology)                                    21
# Transcription, Genetic                                        20
# Signal Transduction                                           18
# Water consumption                                             17
# Cell Proliferation                                            17
# renin activity                                                17
# Down-Regulation                                               17
# Exocytosis                                                    16
# Homeostasis                                                   15
# blood pressure regulation                                     14
# Vasodilation                                                  13
# Signal Transduction Pathways                                  13
# Cytokinesis of the fertilized ovum                            13
# Hemodynamics                                                  12
# cell growth                                                   11
# Biological Evolution                                          11
# Mutation                                                      11
# Angiogenic Process                                            11
# GENE EXPRESSION                                               10
# PEPTIDOLYSIS                                                  10
# ANGIOTENSIN MATURATION                                        10
# Renal function                                                10
# Phosphorylation                                               10
# Cessation of life                                             10
# Arterial pulse pressure                                       10
# GROWTH                                                         9
# INFLAMMATION                                                   9
# CELL ADHESION                                                  9
# BLOOD PRESSURE HOMEOSTASIS                                     9
# POSITIVE REGULATION OF BLOOD VESSEL SIZE                       9
# Gene Expression                                                9
# Baresthesia                                                    9
# Pregnancy                                                      9
# METABOLIC PROCESS                                              8
# PATHOGENESIS                                                   8
# Aging                                                          8
# Cardiovascular Physiological Phenomena                         8
# Protein Biosynthesis                                           8
# immunoreactivity                                               8
# Cell Death                                                     8
# Natriuresis                                                    8
# angiotensin I-converting enzyme activity                       8
# ALVEOLARIZATION                                                7
# BLOOD PRESSURE REGULATION BY RENIN-ANGIOTENSIN                 7
# GLOMERULAR FILTRATION                                          7
# EXCRETION                                                      7
# PROTEIN ANABOLISM                                              7
#
#                                                                                     genes_related
# Growth                                          [AGTR1, AGTR1, ALB, ALB, ALB, REN, REN, REN, A...
# enzyme activity                                 [ALB, ALB, ALB, REN, REN, REN, REN, REN, REN, ...
# Apoptosis                                       [AGTR1, AGTR1, AGTR1, ALB, ALB, ALB, ALB, REN,...
# Up-Regulation (Physiology)                      [AGTR1, AGTR1, ALB, ALB, REN, REN, REN, ACE, A...
# Transcription, Genetic                          [AGTR1, ALB, ALB, REN, REN, REN, REN, ACE, ACE...
# Signal Transduction                             [AGTR1, AGTR1, AGTR1, ALB, ALB, REN, REN, REN,...
# Water consumption                               [AGTR1, REN, REN, REN, REN, REN, REN, ACE, ACE...
# Cell Proliferation                              [AGTR1, AGTR1, ALB, ALB, ALB, REN, REN, ACE, A...
# renin activity                                  [AGTR1, REN, REN, REN, REN, REN, REN, ACE, ACE...
# Down-Regulation                                 [AGTR1, ALB, ALB, REN, REN, ACE, MB, CRP, CRP,...
# Exocytosis                                      [ALB, ALB, ALB, REN, REN, REN, REN, REN, DPP4,...
# Homeostasis                                     [AGTR1, AGTR1, ALB, ALB, REN, REN, ACE, ACE, M...
# blood pressure regulation                       [AGTR1, REN, REN, REN, REN, ACE, ACE, ACE, ACE...
# Vasodilation                                    [AGTR1, AGTR1, AGTR1, ALB, REN, REN, ACE, ACE,...
# Signal Transduction Pathways                    [AGTR1, ALB, ALB, REN, ACE, ACE, ACE, ACE, DPP...
# Cytokinesis of the fertilized ovum              [ALB, ALB, ALB, REN, REN, ACE, ACE, MB, ACE, A...
# Hemodynamics                                    [ALB, REN, REN, REN, ACE, ACE, ACE, ACE, TH, R...
# cell growth                                     [AGTR1, ALB, ALB, REN, ACE, ACE, DPP4, DPP4, T...
# Biological Evolution                            [ALB, REN, REN, ACE, ACE, MB, ACE, ACE, DPP4, ...
# Mutation                                        [ALB, REN, ACE, ACE, MB, MB, ACE, ACE, TH, TH,...
# Angiogenic Process                              [ALB, REN, REN, ACE, MB, MB, ACE, DPP4, TH, RE...
# GENE EXPRESSION                                 [AGTR1, REN, ACE, MB, CRP, CRP, ACE, DPP4, TH,...
# PEPTIDOLYSIS                                    [REN, REN, ACE, ACE, ACE, ACE, DPP4, TH, REN, ...
# ANGIOTENSIN MATURATION                          [REN, REN, REN, ACE, ACE, ACE, ACE, REN, REN, ...
# Renal function                                  [AGTR1, ALB, REN, REN, REN, ACE, ACE, REN, REN...
# Phosphorylation                                 [AGTR1, AGTR1, ALB, ALB, ALB, DPP4, DPP4, TH, ...
# Cessation of life                                [ALB, ALB, REN, ACE, ACE, MB, ACE, ACE, TH, REN]
# Arterial pulse pressure                         [REN, REN, REN, REN, ACE, ACE, REN, REN, REN, ...
# GROWTH                                             [AGTR1, ALB, REN, MB, CRP, CRP, DPP4, TH, REN]
# INFLAMMATION                                      [AGTR1, REN, CRP, CRP, CRP, CRP, DPP4, TH, REN]
# CELL ADHESION                                       [ALB, REN, MB, CRP, CRP, DPP4, DPP4, TH, REN]
# BLOOD PRESSURE HOMEOSTASIS                         [REN, REN, ACE, ACE, ACE, ACE, DPP4, REN, REN]
# POSITIVE REGULATION OF BLOOD VESSEL SIZE             [REN, ACE, MB, CRP, CRP, ACE, DPP4, TH, REN]
# Gene Expression                                     [AGTR1, ALB, ALB, ACE, ACE, DPP4, TH, TH, TH]
# Baresthesia                                         [ALB, REN, REN, REN, REN, REN, REN, REN, REN]
# Pregnancy                                            [REN, REN, ACE, ACE, DPP4, TH, TH, REN, REN]
# METABOLIC PROCESS                                      [AGTR1, ALB, REN, CRP, CRP, DPP4, TH, REN]
# PATHOGENESIS                                              [ALB, REN, ACE, CRP, CRP, ACE, TH, REN]
# Aging                                                   [AGTR1, REN, REN, ACE, ACE, TH, REN, REN]
# Cardiovascular Physiological Phenomena                  [AGTR1, REN, REN, ACE, ACE, TH, REN, REN]
# Protein Biosynthesis                                     [AGTR1, ALB, ALB, ALB, REN, TH, TH, REN]
# immunoreactivity                                            [ALB, REN, REN, TH, TH, TH, REN, REN]
# Cell Death                                                  [ALB, ACE, ACE, MB, ACE, ACE, TH, TH]
# Natriuresis                                              [REN, REN, REN, REN, REN, REN, REN, REN]
# angiotensin I-converting enzyme activity                 [REN, ACE, ACE, ACE, ACE, ACE, ACE, REN]
# ALVEOLARIZATION                                              [AGTR1, ALB, ACE, CRP, CRP, ACE, TH]
# BLOOD PRESSURE REGULATION BY RENIN-ANGIOTENSIN              [AGTR1, ACE, ACE, ACE, ACE, ACE, ACE]
# GLOMERULAR FILTRATION                                         [ALB, REN, ACE, CRP, CRP, ACE, REN]
# EXCRETION                                                     [ALB, REN, CRP, CRP, DPP4, TH, REN]
# PROTEIN ANABOLISM                                               [ALB, REN, MB, CRP, CRP, TH, REN]

# %% [markdown]
# Result table interpretation: In agreement with argument made in article, top ranking results of "renin activity," "Angiogenic Process," and "ANGIOTENSIN MATURATIONs" are components of the RAS pathway / bioprocesses.

# %% [markdown]
# ### 3.3 Genes -> Chemical Substances
#
# Look at chemical substances related to the genes, and then display top chemical substance occurrences in results (and which genes related to each chemical substances).

# %%
# chemical_substances
gene_to_chemical_substance = predict_many(gene_inputs, ['ChemicalSubstance'])
gene_to_chemical_substance_results = {}
gene_to_chemical_substance_genes = list(gene_to_chemical_substance["output_name"]) # create list of genes
gene_to_chemical_substance_genes = list(dict.fromkeys(gene_to_chemical_substance_genes))  # remove duplicates

for gene in gene_to_chemical_substance_genes: 
    gene_to_chemical_substance_results[gene] = {
        'chemical_substance_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_chemical_substance.iterrows():
    gene_to_chemical_substance_results[row['output_name']]['chemical_substance_count'] = gene_to_chemical_substance_results[row['output_name']]['chemical_substance_count'] + 1
    gene_to_chemical_substance_results[row['output_name']]['genes_related'].append(row['input'])

# %%
gene_to_chemical_substance_results = dict(sorted(gene_to_chemical_substance_results.items(), key = lambda x: x[1]['chemical_substance_count'], reverse = True))
pandas.DataFrame.from_dict(gene_to_chemical_substance_results, orient='index').iloc[0:20]
# Out:
#                                                     chemical_substance_count  \
# (+)-ALDOSTERONE                                                           45
# (+)-GLUCOSE                                                               45
# (2-BUTYL-4-CHLORO-1-{[2'-(1H-TETRAZOL-5-YL)BIPH...                        35
# EDRF                                                                      32
# (2S-(1(R*(R*)),2ALPHA,3ABETA,6ABETA))-1-(2-((1-...                        32
# PHARMACEUTICAL PREPARATIONS                                               31
# AMIAS                                                                     30
# 10% SODIUM CHLORIDE INJECTION                                             30
# ALISKIREN                                                                 29
# POTASSIUM                                                                 28
# MESSENGER RNA                                                             27
# ANGIOTENSIN CONVERTING ENZYME INHIBITORS                                  27
# CALCIO                                                                    26
# (-)-NORADRENALINE                                                         25
# 2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE                                         25
# LIPOPOLYSACCHARIDES                                                       24
# 3-(2-AMINOETHYL)-1H-INDOL-5-OL                                            24
# AGUA                                                                      23
# 3',5'-CYCLIC AMP                                                          23
# PGA                                                                       23
#
#                                                                                         genes_related
# (+)-ALDOSTERONE                                     [AGTR1, AGTR1, AGTR1, AGTR1, AGTR1, REN, REN, ...
# (+)-GLUCOSE                                         [AGTR1, AGTR1, ALB, ALB, ALB, ALB, ALB, REN, R...
# (2-BUTYL-4-CHLORO-1-{[2'-(1H-TETRAZOL-5-YL)BIPH...  [AGTR1, AGTR1, AGTR1, AGTR1, AGTR1, AGTR1, AGT...
# EDRF                                                [AGTR1, AGTR1, AGTR1, ALB, REN, REN, REN, REN,...
# (2S-(1(R*(R*)),2ALPHA,3ABETA,6ABETA))-1-(2-((1-...  [AGTR1, ALB, REN, REN, REN, ACE, ACE, ACE, ACE...
# PHARMACEUTICAL PREPARATIONS                         [AGTR1, ALB, ALB, ALB, ALB, ALB, REN, REN, REN...
# AMIAS                                               [AGTR1, AGTR1, AGTR1, AGTR1, AGTR1, AGTR1, AGT...
# 10% SODIUM CHLORIDE INJECTION                       [AGTR1, AGTR1, ALB, ALB, ALB, ALB, ALB, REN, R...
# ALISKIREN                                           [AGTR1, REN, REN, REN, REN, REN, REN, REN, REN...
# POTASSIUM                                           [ALB, ALB, REN, REN, REN, REN, REN, REN, REN, ...
# MESSENGER RNA                                       [AGTR1, AGTR1, AGTR1, AGTR1, ALB, ALB, ALB, AL...
# ANGIOTENSIN CONVERTING ENZYME INHIBITORS            [AGTR1, AGTR1, ALB, ALB, REN, REN, REN, REN, R...
# CALCIO                                              [AGTR1, AGTR1, ALB, ALB, REN, REN, REN, REN, R...
# (-)-NORADRENALINE                                   [AGTR1, ALB, REN, REN, REN, REN, REN, ACE, ACE...
# 2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE                   [AGTR1, ALB, ALB, REN, REN, REN, REN, REN, ACE...
# LIPOPOLYSACCHARIDES                                 [AGTR1, ALB, ALB, ALB, ALB, REN, REN, REN, ACE...
# 3-(2-AMINOETHYL)-1H-INDOL-5-OL                      [AGTR1, AGTR1, ALB, ALB, REN, REN, REN, REN, A...
# AGUA                                                [AGTR1, AGTR1, ALB, ALB, ALB, REN, REN, REN, R...
# 3',5'-CYCLIC AMP                                    [ALB, ALB, REN, REN, REN, REN, REN, REN, CRP, ...
# PGA                                                 [ALB, ALB, REN, REN, REN, REN, REN, REN, REN, ...

# %% [markdown]
# In agreement with article, (+)-ALDOSTERONE (top occurring result) is a critical component in the RAS pathway, as well as ANGIOTENSIN CONVERTING ENZYME INHIBITORS.

# %% [markdown]
# ### 3.4 Genes -> Anatomical Entities
#
# Look at anatomical entities related to the genes, and then display top anatomical entity occurrences in results (and which genes related to each anatomical entities).

# %%
ints_to_anatomical_entity = predict_many(gene_inputs, ['AnatomicalEntity'])
list(dict.fromkeys(list(ints_to_anatomical_entity["output_name"])))
# anatomical_entity
int_to_anatomical_entity_results = {}
int_to_anatomical_entity_ints = list(ints_to_anatomical_entity["output_name"]) # create list of ints
int_to_anatomical_entity_ints = list(dict.fromkeys(int_to_anatomical_entity_ints))  # remove duplicates

for int in int_to_anatomical_entity_ints: 
    int_to_anatomical_entity_results[int] = {
        'anatomical_entity_count' : 0,
        "ints_related" : []
    }

for index, row in ints_to_anatomical_entity.iterrows():
    int_to_anatomical_entity_results[row['output_name']]['anatomical_entity_count'] = int_to_anatomical_entity_results[row['output_name']]['anatomical_entity_count'] + 1
    int_to_anatomical_entity_results[row['output_name']]['ints_related'].append(row['input'])
    

int_to_anatomical_entity_results = dict(sorted(int_to_anatomical_entity_results.items(), key = lambda x: x[1]['anatomical_entity_count'], reverse = True))

    
# int_to_anatomical_entity_results
pandas.DataFrame.from_dict(int_to_anatomical_entity_results, orient='index').iloc[0:50]
# Out:
#                                  anatomical_entity_count  \
# LUNG                                                  17
# BLOOD                                                 16
# PORTION OF SKIN                                       15
# BRAIN                                                 14
# ADIPOSE                                               14
# KIDNEY                                                13
# PORTION OF TISSUE                                     11
# CARDIUM                                               11
# MATERIAL ANATOMICAL ENTITY                            10
# IECUR                                                 10
# FORELIMB AUTOPOD                                       9
# CORONARY ARTERIAL TREE                                 9
# BLOOD SERUM                                            9
# CARDIAC LEFT VENTRICLE                                 9
# ANATOMICAL UNIT                                        8
# ENTIRE LIFE CYCLE                                      8
# GLANDULA THYROIDEA                                     8
# BOWEL                                                  8
# ARTERIAL SUBTREE                                       8
# ENDOMETRIUM                                            7
# BRAIN CORTEX                                           7
# BREAST                                                 7
# ENDOTHELIUM                                            7
# SCALE                                                  7
# ARM                                                    7
# BONE MARROW                                            6
# VESSEL                                                 6
# ORGANISMAL SEGMENT                                     6
# CAROTID                                                6
# CEREBRAL SPINAL FLUID                                  6
# LUNGS                                                  5
# INVOLUNTARY MUSCLE                                     5
# ANTERIOR INTESTINE                                     5
# AORTA                                                  5
# ANIMAL OVARY                                           5
# MUSCULUS QUADRICEPS FEMORIS                            5
# FOOT                                                   5
# AMMON GYRUS                                            5
# LIEN                                                   5
# BLOOD VESSEL INVOLUNTARY MUSCLE                        5
# BLOOD CAPILLARY                                        5
# PAD                                                    5
# EXTREMITIES                                            5
# IMMUNE SYSTEM                                          5
# SKELETAL MUSCLE ORGAN                                  4
# CARDIAC MUSCLE                                         4
# ADRENAL                                                4
# MESENCHYMA                                             4
# LAMINA PROPRIA                                         4
# EPITHELIAL TISSUE                                      4
#
#                                                                       ints_related
# LUNG                             [AGTR1, ALB, REN, REN, ACE, MB, MB, CRP, CRP, ...
# BLOOD                            [AGTR1, ALB, ALB, REN, REN, ACE, MB, CRP, CRP,...
# PORTION OF SKIN                  [AGTR1, ALB, ALB, REN, ACE, ACE, CRP, CRP, CRP...
# BRAIN                            [AGTR1, ALB, REN, ACE, MB, MB, CRP, CRP, CRP, ...
# ADIPOSE                          [ALB, ALB, REN, REN, MB, MB, CRP, CRP, CRP, CR...
# KIDNEY                           [AGTR1, ALB, REN, ACE, MB, MB, CRP, CRP, ACE, ...
# PORTION OF TISSUE                [AGTR1, ALB, REN, ACE, MB, CRP, CRP, ACE, DPP4...
# CARDIUM                          [AGTR1, ALB, REN, ACE, MB, CRP, CRP, ACE, DPP4...
# MATERIAL ANATOMICAL ENTITY       [AGTR1, REN, ACE, MB, CRP, CRP, ACE, DPP4, TH,...
# IECUR                            [ALB, REN, ACE, MB, CRP, CRP, ACE, DPP4, TH, REN]
# FORELIMB AUTOPOD                    [AGTR1, ALB, REN, MB, CRP, CRP, DPP4, TH, REN]
# CORONARY ARTERIAL TREE            [AGTR1, ALB, ACE, ACE, CRP, CRP, ACE, ACE, DPP4]
# BLOOD SERUM                            [ALB, REN, ACE, MB, CRP, CRP, ACE, TH, REN]
# CARDIAC LEFT VENTRICLE              [REN, REN, ACE, CRP, CRP, ACE, DPP4, REN, REN]
# ANATOMICAL UNIT                            [ALB, REN, ACE, CRP, CRP, ACE, TH, REN]
# ENTIRE LIFE CYCLE                          [ALB, REN, MB, CRP, CRP, DPP4, TH, REN]
# GLANDULA THYROIDEA                           [ALB, ACE, MB, CRP, CRP, ACE, TH, TH]
# BOWEL                                       [REN, ACE, MB, CRP, CRP, ACE, TH, REN]
# ARTERIAL SUBTREE                          [REN, ACE, CRP, CRP, ACE, DPP4, TH, REN]
# ENDOMETRIUM                                   [AGTR1, ALB, REN, MB, CRP, CRP, REN]
# BRAIN CORTEX                                  [AGTR1, ALB, ACE, CRP, CRP, ACE, TH]
# BREAST                                           [ALB, REN, MB, CRP, CRP, TH, REN]
# ENDOTHELIUM                                    [ALB, REN, ACE, ACE, DPP4, TH, REN]
# SCALE                                            [ALB, REN, MB, CRP, CRP, TH, REN]
# ARM                                             [REN, ACE, CRP, CRP, ACE, TH, REN]
# BONE MARROW                                       [AGTR1, ALB, CRP, CRP, DPP4, TH]
# VESSEL                                             [ALB, ACE, CRP, CRP, ACE, DPP4]
# ORGANISMAL SEGMENT                                   [ALB, ACE, MB, CRP, CRP, ACE]
# CAROTID                                              [ALB, REN, CRP, CRP, TH, REN]
# CEREBRAL SPINAL FLUID                                [ALB, MB, CRP, CRP, DPP4, TH]
# LUNGS                                                   [AGTR1, ALB, ACE, ACE, TH]
# INVOLUNTARY MUSCLE                                     [AGTR1, REN, DPP4, TH, REN]
# ANTERIOR INTESTINE                                          [ALB, ALB, MB, MB, TH]
# AORTA                                                    [ALB, ACE, ACE, ACE, ACE]
# ANIMAL OVARY                                               [ALB, MB, CRP, CRP, TH]
# MUSCULUS QUADRICEPS FEMORIS                            [ALB, CRP, CRP, DPP4, DPP4]
# FOOT                                                     [ALB, CRP, CRP, DPP4, TH]
# AMMON GYRUS                                             [REN, CRP, CRP, DPP4, REN]
# LIEN                                                      [REN, REN, TH, REN, REN]
# BLOOD VESSEL INVOLUNTARY MUSCLE                         [REN, CRP, CRP, DPP4, REN]
# BLOOD CAPILLARY                                           [ACE, CRP, CRP, ACE, TH]
# PAD                                                       [ACE, MB, CRP, CRP, ACE]
# EXTREMITIES                                               [MB, CRP, CRP, DPP4, TH]
# IMMUNE SYSTEM                                             [MB, CRP, CRP, DPP4, TH]
# SKELETAL MUSCLE ORGAN                                      [AGTR1, CRP, CRP, DPP4]
# CARDIAC MUSCLE                                              [AGTR1, AGTR1, MB, TH]
# ADRENAL                                                      [AGTR1, REN, MB, REN]
# MESENCHYMA                                                    [AGTR1, ALB, MB, TH]
# LAMINA PROPRIA                                               [AGTR1, ACE, ACE, TH]
# EPITHELIAL TISSUE                                            [AGTR1, ACE, ACE, TH]

# %% [markdown]
# In agreement with article, which states “...the Bradykinin-Storm is likely to affect major organs that are regulated by angiotensin derivatives. These include altered electrolyte balance from affected kidney and heart tissue, arrhythmia in dysregulated cardiac tissue, neurological disruptions in the brain, myalgia in muscles and severe alterations in oxygen uptake in the lung itself.” as well as “Finally, COVID-19 patients also frequently display skin rashes including ‘covid-toe’ that appear to be related to dysfunction of the underlying vasculature,” Lung, blood, portion of skin, brain, kidney, and cardium (heart) are all top ranking results related to genes.
#
# Of note: adipose tissue is an iteresting top ranking result, and the connection between obesity being a risk-factor for severe COVID illness and symptom related genes being prevalent in adipose tissue may want to be investigated.

# %% [markdown]
# ### 3.5 Genes -> Chemical Substances <- Vasodilation
#
# Look at determined Gene inputs (related to both COVID and vasodilation/hypotension) and determine chemical substances related to these genes that are also related to vasodilation symptom

# %%
genes_to_chem_to_vasodilation = predict_many(gene_inputs, [vasodilation], ['ChemicalSubstance'])

# %%
genes_to_chem_to_vasodilation_list = list(genes_to_chem_to_vasodilation["node1_name"])

# %%
d = {x:genes_to_chem_to_vasodilation.count(x) for x in genes_to_chem_to_vasodilation}

# %%
## display counts for occurrence of each chemical in results
genes_to_chem_to_vasodilation_df = pandas.DataFrame.from_dict({k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse = True)}, orient='index').iloc[0:20]
genes_to_chem_to_vasodilation_df.columns = ["count"]
genes_to_chem_to_vasodilation_df
# Out:
#                                      count
# (+)-ALDOSTERONE                         45
# (+)-GLUCOSE                             45
# (-)-NORADRENALINE                       25
# 2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE       25
# 3-(2-AMINOETHYL)-1H-INDOL-5-OL          24
# 17BETA-HYDROXY-4-ANDROSTEN-3-ONE        22
# (15S)-PROSTAGLANDIN E2                  22
# (-)-CAPTOPRIL                           22
# LEAD                                    15
# CHEBI:35222                             14
# ANGIOTENSIN                             14
# CA(0)                                   14
# ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG     13
# A-101                                   13
# CHEBI:25212                             12
# ACETYLCHOLINE                           12
# (.)NO                                   12
# CHEBI:24433                             11
# 1H-IMIDAZOLE-4-ETHANAMINE               11
# CHEBI:36357                             10

# %% [markdown]
# In agreement with article, (+)-ALDOSTERONE ranks most highly, and other top results include ANGIOTENSIN and Bradykinin (ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG).

# %% [markdown]
# ## 4 Exploring COVID-19 to Hyaluronic Acid Connection
#
# Look at genes connected to both COVID and HYA, and hypotehsize what pathways may be involved in the HYA production

# %% [markdown]
# ### 4.1 COVID-19 -> Genes <- Hyaluronic Acid Explain Query

# %%
## Get Hayluronic Acid node
HYA = ht.query('hyaluronic acid')['ChemicalSubstance'][0]
HYA
# Out:
# {'CHEBI': 'CHEBI:16336',
#  'name': 'hyaluronic acid',
#  'CAS': '9004-61-9',
#  'formula': '(C14H21NO12)n',
#  'primary': {'identifier': 'CHEBI',
#   'cls': 'ChemicalSubstance',
#   'value': 'CHEBI:16336'},
#  'display': 'CHEBI(CHEBI:16336) name(hyaluronic acid) CAS(9004-61-9) formula((C14H21NO12)n)',
#  'type': 'ChemicalSubstance'}

# %%
fc3 = FindConnection(input_obj=covid, output_obj=HYA, intermediate_nodes=['Gene'])
fc3.connect(verbose=False)
df3 = fc3.display_table_view()
df3
# Out:
#                      input input_type       pred1 pred1_source     pred1_api  \
# 0   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 1   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 2   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 3   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 4   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 5   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 6   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 7   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 8   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 9   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 10  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 11  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 12  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 13  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 14  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 15  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 16  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 17  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 18  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 19  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 20  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 21  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 22  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 23  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 24  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 25  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
#
#    pred1_pubmed node1_type node1_name       node1_id  \
# 0          None       Gene        ALB   NCBIGene:213
# 1          None       Gene        ALB   NCBIGene:213
# 2          None       Gene      IL2RA  NCBIGene:3559
# 3          None       Gene        TNF  NCBIGene:7124
# 4          None       Gene        TNF  NCBIGene:7124
# 5          None       Gene        TNF  NCBIGene:7124
# 6          None       Gene        TNF  NCBIGene:7124
# 7          None       Gene        TNF  NCBIGene:7124
# 8          None       Gene        TNF  NCBIGene:7124
# 9          None       Gene        TNF  NCBIGene:7124
# 10         None       Gene        TNF  NCBIGene:7124
# 11         None       Gene        TNF  NCBIGene:7124
# 12         None       Gene        TNF  NCBIGene:7124
# 13         None       Gene        CD4   NCBIGene:920
# 14         None       Gene      IFNA1  NCBIGene:3439
# 15         None       Gene      IFNA1  NCBIGene:3439
# 16         None       Gene        IL6  NCBIGene:3569
# 17         None       Gene        IL6  NCBIGene:3569
# 18         None       Gene        IL6  NCBIGene:3569
# 19         None       Gene         MB  NCBIGene:4151
# 20         None       Gene         F3  NCBIGene:2152
# 21         None       Gene      CXCL8  NCBIGene:3576
# 22         None       Gene       IFNG  NCBIGene:3458
# 23         None       Gene       IL1B  NCBIGene:3553
# 24         None       Gene       IL1B  NCBIGene:3553
# 25         None       Gene     PPP1CA  NCBIGene:5499
#
#                         pred2                     pred2_source  \
# 0   physically_interacts_with                           SEMMED
# 1                  related_to                              CTD
# 2   physically_interacts_with                           SEMMED
# 3   physically_interacts_with                           SEMMED
# 4        positively_regulates                           SEMMED
# 5     negatively_regulated_by                           SEMMED
# 6               coexists_with                           SEMMED
# 7                 produced_by                           SEMMED
# 8        negatively_regulates                           SEMMED
# 9     positively_regulated_by                           SEMMED
# 10                 related_to                              CTD
# 11                 related_to                              CTD
# 12                 related_to                              CTD
# 13  physically_interacts_with                           SEMMED
# 14  physically_interacts_with                           SEMMED
# 15    positively_regulated_by                           SEMMED
# 16  physically_interacts_with                           SEMMED
# 17       positively_regulates                           SEMMED
# 18                 related_to                              CTD
# 19                 related_to                         scigraph
# 20                 related_to  Translator Text Mining Provider
# 21                 related_to                              CTD
# 22                 related_to                              CTD
# 23                 related_to                              CTD
# 24                 related_to                              CTD
# 25                 related_to                              CTD
#
#                       pred2_api  \
# 0           SEMMED Chemical API
# 1                       CTD API
# 2           SEMMED Chemical API
# 3           SEMMED Chemical API
# 4           SEMMED Chemical API
# 5           SEMMED Chemical API
# 6           SEMMED Chemical API
# 7           SEMMED Chemical API
# 8           SEMMED Chemical API
# 9           SEMMED Chemical API
# 10                      CTD API
# 11                      CTD API
# 12                      CTD API
# 13          SEMMED Chemical API
# 14          SEMMED Chemical API
# 15          SEMMED Chemical API
# 16          SEMMED Chemical API
# 17          SEMMED Chemical API
# 18                      CTD API
# 19  Automat CORD19 Scigraph API
# 20            CORD Chemical API
# 21                      CTD API
# 22                      CTD API
# 23                      CTD API
# 24                      CTD API
# 25                      CTD API
#
#                                          pred2_pubmed output_type  \
# 0                                             7152761        Gene
# 1                                            16642209        Gene
# 2                                            12090468        Gene
# 3   20601239,2171539,23765644,23903893,27837681,85...        Gene
# 4                           11341374,24058413,8514850        Gene
# 5                                             1401082        Gene
# 6                          10616001,17666321,27027581        Gene
# 7                                             1401082        Gene
# 8                                            20398644        Gene
# 9                                             1401082        Gene
# 10                                           25053413        Gene
# 11                                  23692848,25106431        Gene
# 12                                           14697411        Gene
# 13                                           12090468        Gene
# 14                                           28003146        Gene
# 15                                            6207974        Gene
# 16                                           10364906        Gene
# 17                                           11369659        Gene
# 18                                           25053413        Gene
# 19                                               None        Gene
# 20                                               None        Gene
# 21                                           25053413        Gene
# 22                                           18237725        Gene
# 23                                  11318944,25053413        Gene
# 24                                  23595953,23692848        Gene
# 25                                           23178681        Gene
#
#            output_name                output_id
# 0   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 1   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 2   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 3   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 4   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 5   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 6   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 7   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 8   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 9   ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 10  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 11  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 12  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 13  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 14  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 15  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 16  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 17  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 18  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 19  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 20  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 21  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 22  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 23  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 24  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE
# 25  ACIDE HYALURONIQUE  name:ACIDE HYALURONIQUE

# %% [markdown]
# ### 4.2 COVID/HYA Genes -> Pathways

# %%
## get related genes and turn them into nodes
genes_related_to_HYA = list(df3["node1_name"])
# get gene inputs through hint module
gene_inputs_2 = []
for gene in genes_related_to_HYA: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        gene_inputs_2.append(gene_input)
    except: 
        print(gene + ' Failed')

# %%
## Query Genes -> Pathways
HYA_gene_to_pathways = predict_many(gene_inputs_2, ['Pathway'])

# %%
# Display Pathway Counts and Genes related to each pathway 
gene_to_pathway_results = {}
gene_to_pathway_genes = list(HYA_gene_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'pathway_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_pathways_2.iterrows():
    gene_to_pathway_results[row['output_name']]['pathway_count'] = gene_to_pathway_results[row['output_name']]['pathway_count'] + 1
    gene_to_pathway_results[row['output_name']]['genes_related'].append(row['input'])
    

gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['pathway_count'], reverse = True))

# gene_to_pathway_results
pandas.DataFrame.from_dict(gene_to_pathway_results, orient='index').iloc[0:50]
# Out:
#                                                     pathway_count  \
# CYTOKINE SIGNALING IN IMMUNE SYSTEM                            21
# IMMUNE SYSTEM                                                  21
# SIGNALING BY INTERLEUKINS                                      19
# SELENIUM MICRONUTRIENT NETWORK                                 18
# VITAMIN B12 METABOLISM                                         18
# FOLATE METABOLISM                                              18
# REGULATION OF TOLL-LIKE RECEPTOR SIGNALING PATHWAY             18
# LTF DANGER SIGNAL RESPONSE PATHWAY                             18
# TOLL-LIKE RECEPTOR SIGNALING PATHWAY                           18
# SIGNAL TRANSDUCTION                                            17
# SPINAL CORD INJURY                                             17
# CYTOKINES AND INFLAMMATORY RESPONSE                            17
# INTERLEUKIN-10 SIGNALING                                       16
# INTERLEUKIN-4 AND INTERLEUKIN-13 SIGNALING                     16
# PHOTODYNAMIC THERAPY-INDUCED NF-KB SURVIVAL SIG...             16
# LUNG FIBROSIS                                                  16
# DEVELOPMENT AND HETEROGENEITY OF THE ILC FAMILY                16
# NONALCOHOLIC FATTY LIVER DISEASE                               16
# SUDDEN INFANT DEATH SYNDROME (SIDS) SUSCEPTIBIL...             16
# ALLOGRAFT REJECTION                                            15
# VIRAL ACUTE MYOCARDITIS                                        15
# OVERVIEW OF NANOPARTICLE EFFECTS                               14
# PHOTODYNAMIC THERAPY-INDUCED AP-1 SURVIVAL SIGN...             14
# RIG-I-LIKE RECEPTOR SIGNALING                                  14
# PROTEIN ALKYLATION LEADING TO LIVER FIBROSIS                   14
# MIRNAS INVOLVEMENT IN THE IMMUNE RESPONSE IN SE...             14
# NON-GENOMIC ACTIONS OF 1,25 DIHYDROXYVITAMIN D3                14
# RESISTIN AS A REGULATOR OF INFLAMMATION                        14
# TNF RELATED WEAK INDUCER OF APOPTOSIS (TWEAK) S...             13
# TNF ALPHA SIGNALING PATHWAY                                    13
# ADIPOGENESIS                                                   13
# ARYL HYDROCARBON RECEPTOR PATHWAY                              13
# NUCLEAR RECEPTORS META-PATHWAY                                 13
# TRANSCRIPTION FACTOR REGULATION IN ADIPOGENESIS                13
# NO-CGMP-PKG MEDIATED NEUROPROTECTION                           13
# FIBRIN COMPLEMENT RECEPTOR 3 SIGNALING PATHWAY                 13
# ROLE ALTERED GLYCOLYSATION OF MUC1 IN TUMOUR MI...             13
# VITAMIN D IN INFLAMMATORY DISEASES                             13
# ALZHEIMERS DISEASE                                             12
# MAPK SIGNALING PATHWAY                                         12
# T-CELL ANTIGEN RECEPTOR (TCR) PATHWAY DURING ST...             12
# MONOAMINE TRANSPORT                                            12
# EBV LMP1 SIGNALING                                             11
# TGF-BETA RECEPTOR SIGNALING                                    11
# DEVELOPMENTAL BIOLOGY                                          10
# TRANSCRIPTIONAL REGULATION OF WHITE ADIPOCYTE D...             10
# TNFR1-INDUCED PROAPOPTOTIC SIGNALING                           10
# REGULATION OF TNFR1 SIGNALING                                  10
# TNFR1-INDUCED NFKAPPAB SIGNALING PATHWAY                       10
# TNFR1-MEDIATED CERAMIDE PRODUCTION                             10
#
#                                                                                         genes_related
# CYTOKINE SIGNALING IN IMMUNE SYSTEM                 [IL2RA, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF...
# IMMUNE SYSTEM                                       [IL2RA, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF...
# SIGNALING BY INTERLEUKINS                           [IL2RA, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF...
# SELENIUM MICRONUTRIENT NETWORK                      [ALB, ALB, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# VITAMIN B12 METABOLISM                              [ALB, ALB, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# FOLATE METABOLISM                                   [ALB, ALB, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# REGULATION OF TOLL-LIKE RECEPTOR SIGNALING PATHWAY  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# LTF DANGER SIGNAL RESPONSE PATHWAY                  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# TOLL-LIKE RECEPTOR SIGNALING PATHWAY                [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# SIGNAL TRANSDUCTION                                 [IL2RA, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF...
# SPINAL CORD INJURY                                  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# CYTOKINES AND INFLAMMATORY RESPONSE                 [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# INTERLEUKIN-10 SIGNALING                            [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# INTERLEUKIN-4 AND INTERLEUKIN-13 SIGNALING          [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# PHOTODYNAMIC THERAPY-INDUCED NF-KB SURVIVAL SIG...  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# LUNG FIBROSIS                                       [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# DEVELOPMENT AND HETEROGENEITY OF THE ILC FAMILY     [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# NONALCOHOLIC FATTY LIVER DISEASE                    [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# SUDDEN INFANT DEATH SYNDROME (SIDS) SUSCEPTIBIL...  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# ALLOGRAFT REJECTION                                 [IL2RA, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF...
# VIRAL ACUTE MYOCARDITIS                             [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# OVERVIEW OF NANOPARTICLE EFFECTS                    [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# PHOTODYNAMIC THERAPY-INDUCED AP-1 SURVIVAL SIGN...  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# RIG-I-LIKE RECEPTOR SIGNALING                       [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# PROTEIN ALKYLATION LEADING TO LIVER FIBROSIS        [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# MIRNAS INVOLVEMENT IN THE IMMUNE RESPONSE IN SE...  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# NON-GENOMIC ACTIONS OF 1,25 DIHYDROXYVITAMIN D3     [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# RESISTIN AS A REGULATOR OF INFLAMMATION             [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# TNF RELATED WEAK INDUCER OF APOPTOSIS (TWEAK) S...  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# TNF ALPHA SIGNALING PATHWAY                         [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# ADIPOGENESIS                                        [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# ARYL HYDROCARBON RECEPTOR PATHWAY                   [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# NUCLEAR RECEPTORS META-PATHWAY                      [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# TRANSCRIPTION FACTOR REGULATION IN ADIPOGENESIS     [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# NO-CGMP-PKG MEDIATED NEUROPROTECTION                [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# FIBRIN COMPLEMENT RECEPTOR 3 SIGNALING PATHWAY      [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# ROLE ALTERED GLYCOLYSATION OF MUC1 IN TUMOUR MI...  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# VITAMIN D IN INFLAMMATORY DISEASES                  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# ALZHEIMERS DISEASE                                  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# MAPK SIGNALING PATHWAY                              [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# T-CELL ANTIGEN RECEPTOR (TCR) PATHWAY DURING ST...  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# MONOAMINE TRANSPORT                                 [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# EBV LMP1 SIGNALING                                  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# TGF-BETA RECEPTOR SIGNALING                         [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# DEVELOPMENTAL BIOLOGY                               [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# TRANSCRIPTIONAL REGULATION OF WHITE ADIPOCYTE D...  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# TNFR1-INDUCED PROAPOPTOTIC SIGNALING                [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# REGULATION OF TNFR1 SIGNALING                       [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# TNFR1-INDUCED NFKAPPAB SIGNALING PATHWAY            [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...
# TNFR1-MEDIATED CERAMIDE PRODUCTION                  [TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, TNF, ...

# %% [markdown]
# Interestingly, cytokine signaling is the pathway most indicated as being related to genes that are related to both COVID and HYA. This may be in agreement with a large amount of research indicating cytokine concentration elevation to be correlated with severe COVID cases:
#
#
# - Cao, Xuetao. "COVID-19: immunopathology and its implications for therapy." Nature reviews immunology 20.5 (2020): 269-270.
#
# - Mangalmurti, Nilam, and Christopher A. Hunter. "Cytokine storms: understanding COVID-19." Immunity (2020).
#
# - Wu, Dandan, and Xuexian O. Yang. "TH17 responses in cytokine storm of COVID-19: An emerging target of JAK2 inhibitor Fedratinib." Journal of Microbiology, Immunology and Infection (2020).
#
#
#
# Additionally, and interestingly, past research has indicated a role of cytokines in hyaluronic acid production / degredation:
#
# - Sampson, Phyllis M., et al. "Cytokine regulation of human lung fibroblast hyaluronan (hyaluronic acid) production. Evidence for cytokine-regulated hyaluronan (hyaluronic acid) degradation and human lung fibroblast-derived hyaluronidase." The Journal of clinical investigation 90.4 (1992): 1492-1503.

# %% [markdown]
# ## 5 Summary
# ### 5.1 Summary
#
#
# - RAS Pathway and corresponding proteins, pathways, and processes, and chemicals were highly implicated through genes derived from COVID -> Genes <- Vasodilation / Hypotension query
#
# - Anatomical Entities related to genes were very representative of areas where symptoms in COVID patients often occur
#
# - Cytokine pathways may be relevant to different COVID symptoms (Hyaluronic Acid Production) than initially proposed
#
#
# ### 5.2 Future Directions
#
# - Investigate COVID & Hyaluronic Acid connection further
