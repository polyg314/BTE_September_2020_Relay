# %% [markdown]
# # Addressing COVID-19 Patient RAS-mediated Bradykinin Storm Hypothesis with  Biothings Explorer

# %% [markdown]
# # Table of Contents
#
# ## &emsp; 0 Imports
# ## &emsp; 1 Overview of Background and BTE Approach
# ### &emsp; &emsp; 1.1 Article: Summary and Background
# ### &emsp; &emsp; 1.2 Overview of BTE Approach
# ## &emsp; 2 Determining Related Genes
# ### &emsp; &emsp; 2.1 Load COVID-19, ACE2, and SARS
# ### &emsp; &emsp; 2.2 COVID -> Genes
# ### &emsp; &emsp; 2.3 COVID -> Genes -> Genes
# ### &emsp; &emsp; 2.4 Filter Top Genes by those also related to 5+ of the Anatomical Entities from "ACE2 -> Anatomical Entities"
# ### &emsp; &emsp; 2.5 Filter Top Genes by those also related to 1+ of the SARS phenotypes or biological processes
# ## &emsp; 3 Investigating Top Genes
# ### &emsp; &emsp; 3.1 Top Genes -> Pathways
# ### &emsp; &emsp; 3.2 Top Genes -> Phenotypic Feature

# %% [markdown]
# ## 0 Imports

# %%
# Import pandas and biothings explorers modules
import pandas as pandas
from biothings_explorer.query.predict import Predict
from biothings_explorer.query.visualize import display_graph
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
import nest_asyncio
nest_asyncio.apply()
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore") 
ht = Hint()
import math
from IPython.display import Image
import json
import scipy.stats as stats
import itertools
import requests
## predict_many -> functionality to be fully incorporated into BTE soon, will no longer need following
def predict_many(input_object_list, output_type_list, intermediate_node_list = ''):
    df_list = []
    for input_object in input_object_list: 
        if('name' in input_object):
            for output_type in output_type_list: 
                if(len(intermediate_node_list) > 0):
                    for inter in intermediate_node_list:
                        try: 
#                             print("Running: " + input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type )
                            fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
                            fc.connect(verbose=False)
                            df = fc.display_table_view()
                            rows = df.shape[0]
                            if(rows > 0):
                                df_list.append(df)
                        except:
                            pass
#                             print(input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type + ' FAILED')
                else:
                    try:
#                         print("Running: " + input_object['name'] + ' --> output type ' + output_type )
                        fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=None)
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        rows = df.shape[0]
                        if(rows > 0):
                            df_list.append(df)
                    except:
                        pass
#                         print(input_object['name'] + ' --> output type ' + output_type + ' FAILED')

    if(len(df_list) > 0):
        return pandas.concat(df_list)
    else:
        return None
    
    

def create_gene_inputs(gene_list):
    # get gene inputs through hint module
    gene_inputs = []
    for gene in gene_list: 
        try: 
            gene_input = ht.query(gene)["Gene"][0]
            gene_inputs.append(gene_input)
        except: 
            print(gene + ' Failed')
    return(gene_inputs)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# ## 1 Overview of Background and BTE Approach
# &emsp;
# ### 1.1 Article: Summary and Background
#
# Article Reference:
#
# Garvin, Michael R., et al. "A mechanistic model and therapeutic interventions for COVID-19 involving a RAS-mediated bradykinin storm." Elife 9 (2020): e59177.
#
#
# Article Link:
#
# https://elifesciences.org/articles/59177
#
#
#
# Article Main Points:
#
# - RAS Pathway Imbalance implicated through gene expression analysis from cells in bronchoalveolar lavage fluid (BALF) from COVID-19 patients
#
# - Predicted RAS pathway imbalance to be cause of bradykinin-driven vascular dilation, vascular permeability and hypotension
#
# - Leaky membranes -> allows Hyaluronic Acid (HYA) to permeate into lungs
#
# - Analyses found that production of HYA was increased and the enzymes that could degrade it greatly decreased
#
#
# ### 1.2 Overview of BTE Approach
#
# Slides:
#
# https://docs.google.com/presentation/d/1dQbU-lG2j4oGNyHilCiWlAPUqP6s-Mc-XLk8FUIJ3UY/edit?usp=sharing

# %%
from IPython.display import Image
Image("img/covid_bk_top_gene_workflow.png")

# %% [markdown]
# ## 2 Determining Related Genes
# &emsp;
# ### 2.1 Load COVID-19, ACE2, and SARS nodes
# &emsp;

# %%
covid = ht.query('COVID-19')['Disease'][0]
covid
# Out:
# {'MONDO': 'MONDO:0100096',
#  'DOID': 'DOID:0080600',
#  'name': 'COVID-19',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0100096'},
#  'display': 'MONDO(MONDO:0100096) DOID(DOID:0080600) name(COVID-19)',
#  'type': 'Disease'}

# %%
SARS = ht.query("severe acute respiratory syndrome")["Disease"][0]
SARS
# Out:
# {'MONDO': 'MONDO:0005091',
#  'DOID': 'DOID:2945',
#  'UMLS': 'C1175175',
#  'name': 'severe acute respiratory syndrome',
#  'MESH': 'D045169',
#  'ORPHANET': '140896',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0005091'},
#  'display': 'MONDO(MONDO:0005091) DOID(DOID:2945) ORPHANET(140896) UMLS(C1175175) MESH(D045169) name(severe acute respiratory syndrome)',
#  'type': 'Disease'}

# %%
ACE2 = ht.query("ACE2")["Gene"][0]
ACE2
# Out:
# {'NCBIGene': '59272',
#  'name': 'angiotensin I converting enzyme 2',
#  'SYMBOL': 'ACE2',
#  'UMLS': 'C1422064',
#  'HGNC': '13557',
#  'UNIPROTKB': 'Q9BYF1',
#  'ENSEMBL': 'ENSG00000130234',
#  'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#  'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#  'type': 'Gene'}

# %% [markdown]
# ## 2.2 COVID -> Genes

# %%
pd1 = Predict(
    input_objs=[covid],
    intermediate_nodes=[], 
    output_types =['Gene'], 
    config= {"expand": False}
)
pd1.connect(verbose=False)
df1 = pd1.display_table_view()
# fc1 = FindConnection(input_obj=covid, output_obj='Gene', intermediate_nodes=None)
# fc1.connect(verbose=False)
# df1 = fc1.display_table_view()

# %%
df1
# Out:
#          input_id input_label input_type       pred1 pred1_source  \
# 0   MONDO:0100096    COVID-19    Disease  related_to     scigraph
# 1   MONDO:0100096    COVID-19    Disease  related_to     scigraph
# 2   MONDO:0100096    COVID-19    Disease  related_to     scigraph
# 3   MONDO:0100096    COVID-19    Disease  related_to     scigraph
# 4   MONDO:0100096    COVID-19    Disease  related_to     scigraph
# 5   MONDO:0100096    COVID-19    Disease  related_to     scigraph
# 6   MONDO:0100096    COVID-19    Disease  related_to     scigraph
# 7   MONDO:0100096    COVID-19    Disease  related_to  gwascatalog
# 8   MONDO:0100096    COVID-19    Disease  related_to  gwascatalog
# 9   MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 10  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 11  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 12  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 13  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 14  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 15  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 16  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 17  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 18  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 19  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 20  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 21  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 22  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 23  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 24  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 25  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 26  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 27  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 28  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 29  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 30  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 31  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 32  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 33  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 34  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 35  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 36  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 37  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 38  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 39  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 40  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 41  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 42  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 43  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 44  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 45  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 46  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 47  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 48  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 49  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 50  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 51  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 52  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 53  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 54  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 55  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 56  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 57  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
#
#                       pred1_api pred1_publications        output_id  \
# 0   Automat CORD19 Scigraph API               None    NCBIGene:4141
# 1   Automat CORD19 Scigraph API               None    NCBIGene:6651
# 2   Automat CORD19 Scigraph API               None    NCBIGene:1401
# 3   Automat CORD19 Scigraph API               None   NCBIGene:59272
# 4   Automat CORD19 Scigraph API               None    NCBIGene:7054
# 5   Automat CORD19 Scigraph API               None    NCBIGene:5447
# 6   Automat CORD19 Scigraph API               None    NCBIGene:7113
# 7                   BioLink API      PMID:32558485      NCBIGene:28
# 8                   BioLink API      PMID:32558485   NCBIGene:54585
# 9                  DISEASES API               None     NCBIGene:920
# 10                 DISEASES API               None    NCBIGene:6347
# 11                 DISEASES API               None    NCBIGene:3558
# 12                 DISEASES API               None    NCBIGene:3458
# 13                 DISEASES API               None   NCBIGene:10045
# 14                 DISEASES API               None    NCBIGene:1401
# 15                 DISEASES API               None   NCBIGene:92521
# 16                 DISEASES API               None    NCBIGene:3553
# 17                 DISEASES API               None    NCBIGene:3574
# 18                 DISEASES API               None    NCBIGene:5972
# 19                 DISEASES API               None    NCBIGene:3439
# 20                 DISEASES API               None    NCBIGene:1636
# 21                 DISEASES API               None     NCBIGene:213
# 22                 DISEASES API               None  NCBIGene:340024
# 23                 DISEASES API               None    NCBIGene:3627
# 24                 DISEASES API               None    NCBIGene:3576
# 25                 DISEASES API               None    NCBIGene:2147
# 26                 DISEASES API               None    NCBIGene:6868
# 27                 DISEASES API               None    NCBIGene:2580
# 28                 DISEASES API               None   NCBIGene:10332
# 29                 DISEASES API               None   NCBIGene:10044
# 30                 DISEASES API               None    NCBIGene:5499
# 31                 DISEASES API               None     NCBIGene:682
# 32                 DISEASES API               None    NCBIGene:2152
# 33                 DISEASES API               None  NCBIGene:339967
# 34                 DISEASES API               None    NCBIGene:7137
# 35                 DISEASES API               None    NCBIGene:3605
# 36                 DISEASES API               None    NCBIGene:1514
# 37                 DISEASES API               None    NCBIGene:1803
# 38                 DISEASES API               None     NCBIGene:186
# 39                 DISEASES API               None   NCBIGene:10473
# 40                 DISEASES API               None    NCBIGene:3559
# 41                 DISEASES API               None    NCBIGene:3456
# 42                 DISEASES API               None    SYMBOL:TMEM27
# 43                 DISEASES API               None    NCBIGene:2875
# 44                 DISEASES API               None    NCBIGene:4151
# 45                 DISEASES API               None    NCBIGene:7113
# 46                 DISEASES API               None   NCBIGene:10410
# 47                 DISEASES API               None    NCBIGene:3569
# 48                 DISEASES API               None   NCBIGene:22848
# 49                 DISEASES API               None     NCBIGene:925
# 50                 DISEASES API               None   NCBIGene:59272
# 51                 DISEASES API               None    NCBIGene:7124
# 52                 DISEASES API               None    NCBIGene:3586
# 53                 DISEASES API               None     NCBIGene:185
# 54                 DISEASES API               None    NCBIGene:1506
# 55                 DISEASES API               None   NCBIGene:54938
# 56                 DISEASES API               None    NCBIGene:6348
# 57                 DISEASES API               None    NCBIGene:5045
#
#      output_label output_type output_degree
# 0           MARS1        Gene          None
# 1             SON        Gene          None
# 2             CRP        Gene          None
# 3            ACE2        Gene          None
# 4              TH        Gene          None
# 5             POR        Gene          None
# 6         TMPRSS2        Gene          None
# 7             ABO        Gene          None
# 8          LZTFL1        Gene          None
# 9             CD4        Gene          None
# 10           CCL2        Gene          None
# 11            IL2        Gene          None
# 12           IFNG        Gene          None
# 13         SH2D3A        Gene          None
# 14            CRP        Gene          None
# 15         SPECC1        Gene          None
# 16           IL1B        Gene          None
# 17            IL7        Gene          None
# 18            REN        Gene          None
# 19          IFNA1        Gene          None
# 20            ACE        Gene          None
# 21            ALB        Gene          None
# 22        SLC6A19        Gene          None
# 23         CXCL10        Gene          None
# 24          CXCL8        Gene          None
# 25             F2        Gene          None
# 26         ADAM17        Gene          None
# 27            GAK        Gene          None
# 28         CLEC4M        Gene          None
# 29         SH2D3C        Gene          None
# 30         PPP1CA        Gene          None
# 31            BSG        Gene          None
# 32             F3        Gene          None
# 33      TMPRSS11A        Gene          None
# 34          TNNI3        Gene          None
# 35          IL17A        Gene          None
# 36           CTSL        Gene          None
# 37           DPP4        Gene          None
# 38          AGTR2        Gene          None
# 39          HMGN4        Gene          None
# 40          IL2RA        Gene          None
# 41          IFNB1        Gene          None
# 42  SYMBOL:TMEM27        Gene          None
# 43            GPT        Gene          None
# 44             MB        Gene          None
# 45        TMPRSS2        Gene          None
# 46         IFITM3        Gene          None
# 47            IL6        Gene          None
# 48           AAK1        Gene          None
# 49           CD8A        Gene          None
# 50           ACE2        Gene          None
# 51            TNF        Gene          None
# 52           IL10        Gene          None
# 53          AGTR1        Gene          None
# 54           CTRL        Gene          None
# 55          SARS2        Gene          None
# 56           CCL3        Gene          None
# 57          FURIN        Gene          None

# %% [markdown]
# ## 2.3 COVID -> Genes -> Genes

# %%
query_config = {
    "annotate": ["nodeDegree"],
    "expand": False
}
## way to filter at the gene step for top x number of genes? 
pd2 = Predict(
    input_objs=[covid],
    intermediate_nodes =['Gene'], 
    output_types =['Gene'], 
    config= query_config 
)
pd2.connect(verbose=False)

# %%
df2 = pd2.display_table_view(extra_fields=["nodeDegree"]).sort_values(by="output_degree")
df2 = df2[df2["output_degree"] > 15]
genes_related_to_cov_w_int = list(dict.fromkeys(list(df2["output_label"])))
genes_related_to_cov_w_int = [x for x in genes_related_to_cov_w_int if not x.startswith('UMLS')]
print(genes_related_to_cov_w_int)
print(len(genes_related_to_cov_w_int))
# Out:
# ['FGF2', 'PSMD9', 'CX3CL1', 'IFNG', 'NOTCH1', 'PPIG', 'STAT4', 'VIP', 'IFIT1', 'CCR6', 'TH', 'RAF1', 'EGR1', 'SOD1', 'FOXP3', 'CBL', 'RHOA', 'LPL', 'PTGS2', 'MSC', 'BAX', 'SOAT1', 'ACE2', 'KLRK1', 'CXCL9', 'LCK', 'TNFRSF1A', 'TLR8', 'REL', 'TLR5', 'TF', 'JAG1', 'IFNAR1', 'FCGR3A', 'LIF', 'CCR2', 'CCR1', 'GPI', 'IL4', 'IFI27', 'MTOR', 'CXCL10', 'STAT1', 'ITGAX', 'H3P16', 'TCEAL1', 'REG1A', 'SELL', 'GRK2', 'C5AR1', 'ADRA1D', 'TIMP1', 'CXCL2', 'DPP4', 'LOX', 'NCAM1', 'IL7', 'CD19', 'IRF1', 'SGSM3', 'PTH', 'CD79A', 'IFNB1', 'SP1', 'CCL20', 'TLR7', 'ITIH4', 'LBR', 'PTPN11', 'MYD88', 'CD14', 'STAT6', 'PIK3CB', 'SERPINE1', 'CDKN1A', 'HSPA4', 'MPO', 'IL9', 'CD44', 'PPARA', 'SOCS3', 'TNFRSF10B', 'TNFSF11', 'ESR1', 'ERCC8', 'IRF3', 'HSPA9', 'CSH1', 'MAPK3', 'TRBV20OR9-2', 'TLR3', 'TAT', 'ICAM1', 'PLAT', 'CD2', 'ACE', 'TFRC', 'ADA', 'SYK', 'EGF', 'HLA-E', 'GORASP1', 'ERVK-10', 'AGTR1', 'CCL3', 'ISG20', 'IL3', 'CD69', 'CREB1', 'PTPRC', 'SYT1', 'LEP', 'AHSA1', 'POLDIP2', 'IGHE', 'CD80', 'CXCR4', 'PIK3CA', 'ALB', 'GRAP2', 'POMC', 'CA2', 'ITGAM', 'FAS', 'APP', 'MMP2', 'CCR5', 'MMP9', 'IL2RA', 'CISH', 'CD28', 'TP53', 'CAT', 'RELA', 'EGFR', 'ATM', 'STAT5A', 'CD40', 'TLR4', 'CCL5', 'INS', 'FOS', 'CCL2', 'ANG', 'IL10', 'REN', 'IL6', 'STAT3', 'MAPK8', 'CRK', 'CD4', 'CAMP', 'IFNA1', 'IL2', 'TGFB1', 'AKT1', 'VEGFA', 'MAPK1', 'TNF']
# 159

# %%
## covert genes from "covid -> genes" and "covid -> genes -> genes" outputs to data node list
genes_related_to_covid = list(dict.fromkeys(list(df1["output_label"]) + genes_related_to_cov_w_int))
genes_related_to_covid
#covid_gene_inputs
# Out:
# ['MARS1',
#  'SON',
#  'CRP',
#  'ACE2',
#  'TH',
#  'POR',
#  'TMPRSS2',
#  'ABO',
#  'LZTFL1',
#  'CD4',
#  'CCL2',
#  'IL2',
#  'IFNG',
#  'SH2D3A',
#  'SPECC1',
#  'IL1B',
#  'IL7',
#  'REN',
#  'IFNA1',
#  'ACE',
#  'ALB',
#  'SLC6A19',
#  'CXCL10',
#  'CXCL8',
#  'F2',
#  'ADAM17',
#  'GAK',
#  'CLEC4M',
#  'SH2D3C',
#  'PPP1CA',
#  'BSG',
#  'F3',
#  'TMPRSS11A',
#  'TNNI3',
#  'IL17A',
#  'CTSL',
#  'DPP4',
#  'AGTR2',
#  'HMGN4',
#  'IL2RA',
#  'IFNB1',
#  'SYMBOL:TMEM27',
#  'GPT',
#  'MB',
#  'IFITM3',
#  'IL6',
#  'AAK1',
#  'CD8A',
#  'TNF',
#  'IL10',
#  'AGTR1',
#  'CTRL',
#  'SARS2',
#  'CCL3',
#  'FURIN',
#  'FGF2',
#  'PSMD9',
#  'CX3CL1',
#  'NOTCH1',
#  'PPIG',
#  'STAT4',
#  'VIP',
#  'IFIT1',
#  'CCR6',
#  'RAF1',
#  'EGR1',
#  'SOD1',
#  'FOXP3',
#  'CBL',
#  'RHOA',
#  'LPL',
#  'PTGS2',
#  'MSC',
#  'BAX',
#  'SOAT1',
#  'KLRK1',
#  'CXCL9',
#  'LCK',
#  'TNFRSF1A',
#  'TLR8',
#  'REL',
#  'TLR5',
#  'TF',
#  'JAG1',
#  'IFNAR1',
#  'FCGR3A',
#  'LIF',
#  'CCR2',
#  'CCR1',
#  'GPI',
#  'IL4',
#  'IFI27',
#  'MTOR',
#  'STAT1',
#  'ITGAX',
#  'H3P16',
#  'TCEAL1',
#  'REG1A',
#  'SELL',
#  'GRK2',
#  'C5AR1',
#  'ADRA1D',
#  'TIMP1',
#  'CXCL2',
#  'LOX',
#  'NCAM1',
#  'CD19',
#  'IRF1',
#  'SGSM3',
#  'PTH',
#  'CD79A',
#  'SP1',
#  'CCL20',
#  'TLR7',
#  'ITIH4',
#  'LBR',
#  'PTPN11',
#  'MYD88',
#  'CD14',
#  'STAT6',
#  'PIK3CB',
#  'SERPINE1',
#  'CDKN1A',
#  'HSPA4',
#  'MPO',
#  'IL9',
#  'CD44',
#  'PPARA',
#  'SOCS3',
#  'TNFRSF10B',
#  'TNFSF11',
#  'ESR1',
#  'ERCC8',
#  'IRF3',
#  'HSPA9',
#  'CSH1',
#  'MAPK3',
#  'TRBV20OR9-2',
#  'TLR3',
#  'TAT',
#  'ICAM1',
#  'PLAT',
#  'CD2',
#  'TFRC',
#  'ADA',
#  'SYK',
#  'EGF',
#  'HLA-E',
#  'GORASP1',
#  'ERVK-10',
#  'ISG20',
#  'IL3',
#  'CD69',
#  'CREB1',
#  'PTPRC',
#  'SYT1',
#  'LEP',
#  'AHSA1',
#  'POLDIP2',
#  'IGHE',
#  'CD80',
#  'CXCR4',
#  'PIK3CA',
#  'GRAP2',
#  'POMC',
#  'CA2',
#  'ITGAM',
#  'FAS',
#  'APP',
#  'MMP2',
#  'CCR5',
#  'MMP9',
#  'CISH',
#  'CD28',
#  'TP53',
#  'CAT',
#  'RELA',
#  'EGFR',
#  'ATM',
#  'STAT5A',
#  'CD40',
#  'TLR4',
#  'CCL5',
#  'INS',
#  'FOS',
#  'ANG',
#  'STAT3',
#  'MAPK8',
#  'CRK',
#  'CAMP',
#  'TGFB1',
#  'AKT1',
#  'VEGFA',
#  'MAPK1']

# %%
covid_gene_inputs = create_gene_inputs(genes_related_to_covid)
# Out:
# SYMBOL:TMEM27 Failed

# %%
covid_gene_inputs[0]
# Out:
# {'NCBIGene': '4141',
#  'name': 'methionyl-tRNA synthetase 1',
#  'SYMBOL': 'MARS1',
#  'UMLS': 'C1417035',
#  'HGNC': '6898',
#  'UNIPROTKB': 'P56192',
#  'ENSEMBL': 'ENSG00000166986',
#  'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4141'},
#  'display': 'NCBIGene(4141) ENSEMBL(ENSG00000166986) HGNC(6898) UMLS(C1417035) UNIPROTKB(P56192) SYMBOL(MARS1)',
#  'type': 'Gene'}

# %% [markdown]
# ## 2.4 Genes-> Mouse genes -> Mouse Phenotypes -> Human Phenotypes

# %%
df2
# Out:
#             input_id input_label input_type       pred1 pred1_source  \
# 25620  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 3100   MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 17131  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 2945   MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 15287  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# ...              ...         ...        ...         ...          ...
# 17137  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 21907  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 17742  MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 8906   MONDO:0100096    COVID-19    Disease  related_to     DISEASES
# 8654   MONDO:0100096    COVID-19    Disease  related_to     DISEASES
#
#           pred1_api pred1_publications       node1_id node1_label node1_type  \
# 25620  DISEASES API               None  NCBIGene:3586        IL10       Gene
# 3100   DISEASES API               None   NCBIGene:920         CD4       Gene
# 17131  DISEASES API               None  NCBIGene:2875         GPT       Gene
# 2945   DISEASES API               None   NCBIGene:920         CD4       Gene
# 15287  DISEASES API               None  NCBIGene:3605       IL17A       Gene
# ...             ...                ...            ...         ...        ...
# 17137  DISEASES API               None  NCBIGene:2875         GPT       Gene
# 21907  DISEASES API               None  NCBIGene:7124         TNF       Gene
# 17742  DISEASES API               None  NCBIGene:3569         IL6       Gene
# 8906   DISEASES API               None  NCBIGene:5972         REN       Gene
# 8654   DISEASES API               None  NCBIGene:5972         REN       Gene
#
#        node1_degree                      pred2 pred2_source        pred2_api  \
# 25620             1       negatively_regulates       SEMMED  SEMMED Gene API
# 3100              1       negatively_regulates       SEMMED  SEMMED Gene API
# 17131             1    negatively_regulated_by       SEMMED  SEMMED Gene API
# 2945              1    negatively_regulated_by       SEMMED  SEMMED Gene API
# 15287             1  physically_interacts_with       string      BioLink API
# ...             ...                        ...          ...              ...
# 17137             1       negatively_regulates       SEMMED  SEMMED Gene API
# 21907             1  physically_interacts_with       SEMMED  SEMMED Gene API
# 17742             1       negatively_regulates       SEMMED  SEMMED Gene API
# 8906              1       negatively_regulates       SEMMED  SEMMED Gene API
# 8654              1  physically_interacts_with       string      BioLink API
#
#                                       pred2_publications      output_id  \
# 25620                                      PMID:29163498  NCBIGene:2247
# 3100                                       PMID:21078910  NCBIGene:5715
# 17131                                       PMID:7873591  UMLS:C0001899
# 2945                                       PMID:24970890  NCBIGene:6376
# 15287                                               None  NCBIGene:3458
# ...                                                  ...            ...
# 17137                                      PMID:18289853  NCBIGene:7124
# 21907  PMID:10088765,PMID:10201981,PMID:10318823,PMID...  NCBIGene:7124
# 17742  PMID:18942757,PMID:21457706,PMID:26011183,PMID...  NCBIGene:7124
# 8906                                       PMID:19940035  NCBIGene:7124
# 8654                                                None  NCBIGene:7124
#
#         output_label output_type  output_degree
# 25620           FGF2        Gene             16
# 3100           PSMD9        Gene             16
# 17131  UMLS:C0001899        Gene             16
# 2945          CX3CL1        Gene             16
# 15287           IFNG        Gene             16
# ...              ...         ...            ...
# 17137            TNF        Gene            103
# 21907            TNF        Gene            103
# 17742            TNF        Gene            103
# 8906             TNF        Gene            103
# 8654             TNF        Gene            103
#
# [7784 rows x 19 columns]

# %%
#http://www.informatics.jax.org/batch
gene_to_mp = pandas.read_csv("MGIBatchReport_20201029_201300.csv", sep = "\t", error_bad_lines=False)

# %%
gene_to_mp.head()
# Out:
#   Input      Input Type MGI Gene/Marker ID Symbol  \
# 0  ACE2  current symbol        MGI:1917258   Ace2
# 1  ACE2  current symbol        MGI:1917258   Ace2
# 2  ACE2  current symbol        MGI:1917258   Ace2
# 3  ACE2  current symbol        MGI:1917258   Ace2
# 4  ACE2  current symbol        MGI:1917258   Ace2
#
#                                                 Name         Feature Type  \
# 0  angiotensin I converting enzyme (peptidyl-dipe...  protein coding gene
# 1  angiotensin I converting enzyme (peptidyl-dipe...  protein coding gene
# 2  angiotensin I converting enzyme (peptidyl-dipe...  protein coding gene
# 3  angiotensin I converting enzyme (peptidyl-dipe...  protein coding gene
# 4  angiotensin I converting enzyme (peptidyl-dipe...  protein coding gene
#
#         MP ID                                  Term
# 0  MP:0000219      increased neutrophil cell number
# 1  MP:0000231                          hypertension
# 2  MP:0000280                 thin ventricular wall
# 3  MP:0001179  thick pulmonary interalveolar septum
# 4  MP:0001182                       lung hemorrhage

# %%
gene_to_mp_dict = {}
for index, row in gene_to_mp.iterrows(): 
    if row["Input"] in gene_to_mp_dict:
        if(row["MP ID"] not in gene_to_mp_dict[row["Input"]]["MPs"]):
            gene_to_mp_dict[row["Input"]]["MPs"].append(row["MP ID"])
    else: 
        gene_to_mp_dict[row["Input"]] = {}
        gene_to_mp_dict[row["Input"]]["MPs"] = [row["MP ID"]]

# %%
gene_to_mp_dict["CD4"]
# Out:
# {'MPs': ['MP:0000689',
#   'MP:0000921',
#   'MP:0001805',
#   'MP:0001806',
#   'MP:0001847',
#   'MP:0002145',
#   'MP:0002169',
#   'MP:0002347',
#   'MP:0002408',
#   'MP:0002432',
#   'MP:0002460',
#   'MP:0002722',
#   'MP:0003790',
#   'MP:0003944',
#   'MP:0004774',
#   'MP:0004804',
#   'MP:0004946',
#   'MP:0005010',
#   'MP:0005018',
#   'MP:0005027',
#   'MP:0005091',
#   'MP:0005092',
#   'MP:0005095',
#   'MP:0005348',
#   'MP:0005463',
#   'MP:0005466',
#   'MP:0006413',
#   'MP:0008074',
#   'MP:0008075',
#   'MP:0008078',
#   'MP:0008100',
#   'MP:0008698',
#   'MP:0020154',
#   'MP:0020937']}

# %%
pd3 = Predict(
    input_objs=[SARS],
    intermediate_nodes=[], 
    output_types =['PhenotypicFeature'], 
    config= {"expand": False}
)
pd3.connect(verbose=False)
df3 = pd3.display_table_view()
# df3

# %%
HP_IDs = []
symptom_hp_dict = {}
for result in pd3.steps_results[0]:
    HP_IDs.append(result['HP'][0])
    symptom_hp_dict[result['label']] = [result['HP'][0]]
#     print(result['label'])

HP_IDs = list(dict.fromkeys(HP_IDs))
print(HP_IDs)
print(symptom_hp_dict)
# Out:
# ['HP:0012735', 'HP:0001945', 'HP:0002094', 'HP:0002098', 'HP:0002315', 'HP:0002721', 'HP:0003326', 'HP:0000819', 'HP:0001626', 'HP:0002664', 'HP:0004887', 'HP:0006528', 'HP:0011949', 'HP:0012418', 'HP:0025439', 'HP:0001919']
# {'Cough': ['HP:0012735'], 'Fever': ['HP:0001945'], 'Dyspnea': ['HP:0002094'], 'Respiratory distress': ['HP:0002098'], 'Headache': ['HP:0002315'], 'Immunodeficiency': ['HP:0002721'], 'Myalgia': ['HP:0003326'], 'Diabetes mellitus': ['HP:0000819'], 'Abnormality of the cardiovascular system': ['HP:0001626'], 'Neoplasm': ['HP:0002664'], 'Respiratory failure requiring assisted ventilation': ['HP:0004887'], 'Chronic lung disease': ['HP:0006528'], 'Acute infectious pneumonia': ['HP:0011949'], 'Hypoxemia': ['HP:0012418'], 'Pharyngitis': ['HP:0025439'], 'Acute kidney injury': ['HP:0001919']}

# %%
df3
# Out:
#          input_id                        input_label input_type  \
# 0   MONDO:0005091  severe acute respiratory syndrome    Disease
# 1   MONDO:0005091  severe acute respiratory syndrome    Disease
# 2   MONDO:0005091  severe acute respiratory syndrome    Disease
# 3   MONDO:0005091  severe acute respiratory syndrome    Disease
# 4   MONDO:0005091  severe acute respiratory syndrome    Disease
# 5   MONDO:0005091  severe acute respiratory syndrome    Disease
# 6   MONDO:0005091  severe acute respiratory syndrome    Disease
# 7   MONDO:0005091  severe acute respiratory syndrome    Disease
# 8   MONDO:0005091  severe acute respiratory syndrome    Disease
# 9   MONDO:0005091  severe acute respiratory syndrome    Disease
# 10  MONDO:0005091  severe acute respiratory syndrome    Disease
# 11  MONDO:0005091  severe acute respiratory syndrome    Disease
# 12  MONDO:0005091  severe acute respiratory syndrome    Disease
# 13  MONDO:0005091  severe acute respiratory syndrome    Disease
# 14  MONDO:0005091  severe acute respiratory syndrome    Disease
# 15  MONDO:0005091  severe acute respiratory syndrome    Disease
# 16  MONDO:0005091  severe acute respiratory syndrome    Disease
# 17  MONDO:0005091  severe acute respiratory syndrome    Disease
# 18  MONDO:0005091  severe acute respiratory syndrome    Disease
# 19  MONDO:0005091  severe acute respiratory syndrome    Disease
# 20  MONDO:0005091  severe acute respiratory syndrome    Disease
# 21  MONDO:0005091  severe acute respiratory syndrome    Disease
# 22  MONDO:0005091  severe acute respiratory syndrome    Disease
# 23  MONDO:0005091  severe acute respiratory syndrome    Disease
# 24  MONDO:0005091  severe acute respiratory syndrome    Disease
# 25  MONDO:0005091  severe acute respiratory syndrome    Disease
# 26  MONDO:0005091  severe acute respiratory syndrome    Disease
# 27  MONDO:0005091  severe acute respiratory syndrome    Disease
# 28  MONDO:0005091  severe acute respiratory syndrome    Disease
# 29  MONDO:0005091  severe acute respiratory syndrome    Disease
# 30  MONDO:0005091  severe acute respiratory syndrome    Disease
# 31  MONDO:0005091  severe acute respiratory syndrome    Disease
#
#             pred1 pred1_source           pred1_api pred1_publications  \
# 0      related_to         hpoa  mydisease.info API               None
# 1      related_to         hpoa  mydisease.info API               None
# 2      related_to         hpoa  mydisease.info API               None
# 3      related_to         hpoa  mydisease.info API               None
# 4      related_to         hpoa  mydisease.info API               None
# 5      related_to         hpoa  mydisease.info API               None
# 6      related_to         hpoa  mydisease.info API               None
# 7      related_to         hpoa  mydisease.info API               None
# 8      related_to         hpoa  mydisease.info API               None
# 9      related_to         hpoa  mydisease.info API               None
# 10     related_to         hpoa  mydisease.info API               None
# 11     related_to         hpoa  mydisease.info API               None
# 12     related_to         hpoa  mydisease.info API               None
# 13     related_to         hpoa  mydisease.info API               None
# 14     related_to         hpoa  mydisease.info API               None
# 15     related_to         hpoa  mydisease.info API               None
# 16  has_phenotype         hpoa         BioLink API               None
# 17  has_phenotype         hpoa         BioLink API               None
# 18  has_phenotype         hpoa         BioLink API               None
# 19  has_phenotype         hpoa         BioLink API               None
# 20  has_phenotype         hpoa         BioLink API               None
# 21  has_phenotype         hpoa         BioLink API               None
# 22  has_phenotype         hpoa         BioLink API               None
# 23  has_phenotype         hpoa         BioLink API               None
# 24  has_phenotype         hpoa         BioLink API               None
# 25  has_phenotype         hpoa         BioLink API               None
# 26  has_phenotype         hpoa         BioLink API               None
# 27  has_phenotype         hpoa         BioLink API               None
# 28  has_phenotype         hpoa         BioLink API               None
# 29  has_phenotype         hpoa         BioLink API               None
# 30  has_phenotype         hpoa         BioLink API               None
# 31  has_phenotype         hpoa         BioLink API               None
#
#         output_id                                       output_label  \
# 0   UMLS:C0010200                                              Cough
# 1   UMLS:C0015967                                              Fever
# 2   UMLS:C0013404                                            Dyspnea
# 3   UMLS:C0013404                               Respiratory distress
# 4   UMLS:C0018681                                           Headache
# 5   UMLS:C0021051                                   Immunodeficiency
# 6   UMLS:C0231528                                            Myalgia
# 7   UMLS:C0011849                                  Diabetes mellitus
# 8   UMLS:C0243050           Abnormality of the cardiovascular system
# 9   UMLS:C0027651                                           Neoplasm
# 10  UMLS:C4025279  Respiratory failure requiring assisted ventila...
# 11  UMLS:C0746102                               Chronic lung disease
# 12  UMLS:C4023112                         Acute infectious pneumonia
# 13  UMLS:C0700292                                          Hypoxemia
# 14     HP:0025439                                        Pharyngitis
# 15  UMLS:C2609414                                Acute kidney injury
# 16  UMLS:C0021051                                   Immunodeficiency
# 17  UMLS:C0027651                                           Neoplasm
# 18  UMLS:C0010200                                              Cough
# 19  UMLS:C0700292                                          Hypoxemia
# 20  UMLS:C0013404                               Respiratory distress
# 21  UMLS:C0013404                                            Dyspnea
# 22  UMLS:C0011849                                  Diabetes mellitus
# 23  UMLS:C0243050           Abnormality of the cardiovascular system
# 24  UMLS:C0015967                                              Fever
# 25  UMLS:C4025279  Respiratory failure requiring assisted ventila...
# 26     HP:0025439                                        Pharyngitis
# 27  UMLS:C0231528                                            Myalgia
# 28  UMLS:C2609414                                Acute kidney injury
# 29  UMLS:C4023112                         Acute infectious pneumonia
# 30  UMLS:C0746102                               Chronic lung disease
# 31  UMLS:C0018681                                           Headache
#
#           output_type output_degree
# 0   PhenotypicFeature          None
# 1   PhenotypicFeature          None
# 2   PhenotypicFeature          None
# 3   PhenotypicFeature          None
# 4   PhenotypicFeature          None
# 5   PhenotypicFeature          None
# 6   PhenotypicFeature          None
# 7   PhenotypicFeature          None
# 8   PhenotypicFeature          None
# 9   PhenotypicFeature          None
# 10  PhenotypicFeature          None
# 11  PhenotypicFeature          None
# 12  PhenotypicFeature          None
# 13  PhenotypicFeature          None
# 14  PhenotypicFeature          None
# 15  PhenotypicFeature          None
# 16  PhenotypicFeature          None
# 17  PhenotypicFeature          None
# 18  PhenotypicFeature          None
# 19  PhenotypicFeature          None
# 20  PhenotypicFeature          None
# 21  PhenotypicFeature          None
# 22  PhenotypicFeature          None
# 23  PhenotypicFeature          None
# 24  PhenotypicFeature          None
# 25  PhenotypicFeature          None
# 26  PhenotypicFeature          None
# 27  PhenotypicFeature          None
# 28  PhenotypicFeature          None
# 29  PhenotypicFeature          None
# 30  PhenotypicFeature          None
# 31  PhenotypicFeature          None

# %%
sars_symptoms = list(dict.fromkeys(list(df3["output_label"])))
sars_symptoms
# Out:
# ['Cough',
#  'Fever',
#  'Dyspnea',
#  'Respiratory distress',
#  'Headache',
#  'Immunodeficiency',
#  'Myalgia',
#  'Diabetes mellitus',
#  'Abnormality of the cardiovascular system',
#  'Neoplasm',
#  'Respiratory failure requiring assisted ventilation',
#  'Chronic lung disease',
#  'Acute infectious pneumonia',
#  'Hypoxemia',
#  'Pharyngitis',
#  'Acute kidney injury']

# %%
# HP_IDs = [];
# symptom_hp_dict = {}
# for x in sars_symptoms: 
#     q = ht.query(x)["PhenotypicFeature"]
#     for y in q:
#         if(y["name"].lower() == x.lower()):
#             print(x)
#             print(y["HP"])
#             HP_IDs.append(y["HP"])
#             symptom_hp_dict[x] = y["HP"]
# #     hp = q["HP"]
# #     print(x)
# #     print(q["name"])
# symptom_hp_dict

# %%
HP_IDs
# Out:
# ['HP:0012735',
#  'HP:0001945',
#  'HP:0002094',
#  'HP:0002098',
#  'HP:0002315',
#  'HP:0002721',
#  'HP:0003326',
#  'HP:0000819',
#  'HP:0001626',
#  'HP:0002664',
#  'HP:0004887',
#  'HP:0006528',
#  'HP:0011949',
#  'HP:0012418',
#  'HP:0025439',
#  'HP:0001919']

# %%
# https://biothings.ncats.io/upheno_ontology/phenotype/HP:0025038
sars_symptoms_mp_dict = {}

for key in symptom_hp_dict:
    hp = symptom_hp_dict[key][0]
    url = "https://biothings.ncats.io/upheno_ontology/phenotype/" + hp 
    r = requests.get(url)
    json = r.json()
    print(json)
    if('mp_class_id' in json):
        mp = json['mp_class_id']
        sars_symptoms_mp_dict[key] = [mp]

sars_symptoms_mp_dict
# Out:
# {'_id': 'HP:0012735', '_version': 1, 'fuzzy_equivalence_score': 0.875, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Cough', 'mp_class_id': 'MP:0002133', 'mp_ontology_class_label': 'abnormal respiratory system physiology'}
# {'_id': 'HP:0001945', '_version': 1, 'fuzzy_equivalence_score': 0.8888888889, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Fever', 'mp_class_id': 'MP:0001777', 'mp_ontology_class_label': 'abnormal body temperature homeostasis'}
# {'_id': 'HP:0002094', '_version': 1, 'fuzzy_equivalence_score': 0.875, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Dyspnea', 'mp_class_id': 'MP:0002133', 'mp_ontology_class_label': 'abnormal respiratory system physiology'}
# {'_id': 'HP:0002098', '_version': 1, 'fuzzy_equivalence_score': 1.0, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Respiratory distress', 'mp_class_id': 'MP:0001954', 'mp_ontology_class_label': 'respiratory distress'}
# {'_id': 'HP:0002315', '_version': 1, 'fuzzy_equivalence_score': 0.875, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Headache', 'mp_class_id': 'MP:0003633', 'mp_ontology_class_label': 'abnormal nervous system physiology'}
# {'_id': 'HP:0002721', '_version': 1, 'fuzzy_equivalence_score': 0.5833333333, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Immunodeficiency', 'mp_class_id': 'MP:0001790', 'mp_ontology_class_label': 'abnormal immune system physiology'}
# {'code': 404, 'success': False, 'error': "ID 'HP:0003326' not found"}
# {'_id': 'HP:0000819', '_version': 1, 'fuzzy_equivalence_score': 0.8181818181999999, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Diabetes mellitus', 'mp_class_id': 'MP:0005291', 'mp_ontology_class_label': 'abnormal glucose tolerance'}
# {'_id': 'HP:0001626', '_version': 1, 'fuzzy_equivalence_score': 0.5714285714, 'fuzzy_subclass_score': 0.5714285714, 'hp_class_label': 'Abnormality of the cardiovascular system', 'mp_class_id': 'MP:0002127', 'mp_ontology_class_label': 'abnormal cardiovascular system morphology'}
# {'_id': 'HP:0002664', '_version': 1, 'fuzzy_equivalence_score': 1.0, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Neoplasm', 'mp_class_id': 'MP:0002006', 'mp_ontology_class_label': 'neoplasm'}
# {'_id': 'HP:0004887', '_version': 1, 'fuzzy_equivalence_score': 0.8888888889, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Respiratory failure requiring assisted ventilation', 'mp_class_id': 'MP:0001953', 'mp_ontology_class_label': 'respiratory failure'}
# {'_id': 'HP:0006528', '_version': 1, 'fuzzy_equivalence_score': 0.8888888889, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Chronic lung disease', 'mp_class_id': 'MP:0001175', 'mp_ontology_class_label': 'abnormal lung morphology'}
# {'_id': 'HP:0011949', '_version': 1, 'fuzzy_equivalence_score': 0.5789473684, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Acute infectious pneumonia', 'mp_class_id': 'MP:0002406', 'mp_ontology_class_label': 'increased susceptibility to infection'}
# {'_id': 'HP:0012418', '_version': 1, 'fuzzy_equivalence_score': 1.0, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Hypoxemia', 'mp_class_id': 'MP:0012549', 'mp_ontology_class_label': 'hypoxemia'}
# {'_id': 'HP:0025439', '_version': 1, 'fuzzy_equivalence_score': 0.72, 'fuzzy_subclass_score': 0.8181818181999999, 'hp_class_label': 'Pharyngitis', 'mp_class_id': 'MP:0001867', 'mp_ontology_class_label': 'rhinitis'}
# {'_id': 'HP:0001919', '_version': 1, 'fuzzy_equivalence_score': 0.9230769231, 'fuzzy_subclass_score': 1.0, 'hp_class_label': 'Acute kidney injury', 'mp_class_id': 'MP:0003606', 'mp_ontology_class_label': 'kidney failure'}
# {'Cough': ['MP:0002133'],
#  'Fever': ['MP:0001777'],
#  'Dyspnea': ['MP:0002133'],
#  'Respiratory distress': ['MP:0001954'],
#  'Headache': ['MP:0003633'],
#  'Immunodeficiency': ['MP:0001790'],
#  'Diabetes mellitus': ['MP:0005291'],
#  'Abnormality of the cardiovascular system': ['MP:0002127'],
#  'Neoplasm': ['MP:0002006'],
#  'Respiratory failure requiring assisted ventilation': ['MP:0001953'],
#  'Chronic lung disease': ['MP:0001175'],
#  'Acute infectious pneumonia': ['MP:0002406'],
#  'Hypoxemia': ['MP:0012549'],
#  'Pharyngitis': ['MP:0001867'],
#  'Acute kidney injury': ['MP:0003606']}

# %%
# sars_symptoms_mp_dict = {
# 'Cough': ['MP:0031088'],
# 'Dyspnea': ['MP:0001954','MP:0002317'],
# 'Respiratory distress': ['MP:0001954','MP:0002317'],
# 'Abnormality of the cardiovascular system': ['MP:0000177', 'MP:0000302', 'MP:0001623', 'MP:0001626', 'MP:0002130'],
# 'Neoplasm': ['MP:0002006'],
# 'Respiratory failure requiring assisted ventilation': ['MP:0001953'],
# 'Acute infectious pneumonia': ['MP:0001861'],
# 'Hypoxemia': ['MP:0012549'],
# 'Pharyngitis': ['MP:0031095']
#  }

# %%
reverse_dict = {}

for key in sars_symptoms_mp_dict:
    for x in sars_symptoms_mp_dict[key]:
        reverse_dict[x] = key

# %%
reverse_dict
# Out:
# {'MP:0002133': 'Dyspnea',
#  'MP:0001777': 'Fever',
#  'MP:0001954': 'Respiratory distress',
#  'MP:0003633': 'Headache',
#  'MP:0001790': 'Immunodeficiency',
#  'MP:0005291': 'Diabetes mellitus',
#  'MP:0002127': 'Abnormality of the cardiovascular system',
#  'MP:0002006': 'Neoplasm',
#  'MP:0001953': 'Respiratory failure requiring assisted ventilation',
#  'MP:0001175': 'Chronic lung disease',
#  'MP:0002406': 'Acute infectious pneumonia',
#  'MP:0012549': 'Hypoxemia',
#  'MP:0001867': 'Pharyngitis',
#  'MP:0003606': 'Acute kidney injury'}

# %%
MP_list = list(sars_symptoms_mp_dict.values())
MP_list = list(itertools.chain.from_iterable(MP_list))
MP_list
# Out:
# ['MP:0002133',
#  'MP:0001777',
#  'MP:0002133',
#  'MP:0001954',
#  'MP:0003633',
#  'MP:0001790',
#  'MP:0005291',
#  'MP:0002127',
#  'MP:0002006',
#  'MP:0001953',
#  'MP:0001175',
#  'MP:0002406',
#  'MP:0012549',
#  'MP:0001867',
#  'MP:0003606']

# %%
for key in gene_to_mp_dict:
    gene_to_mp_dict[key]["sars_symptom_count"] = (len(set(gene_to_mp_dict[key]['MPs']) 
                                                      & set(MP_list))
                                                 )
    gene_to_mp_dict[key]["sars_symptoms"] = (set(gene_to_mp_dict[key]['MPs']) 
                                                      & set(MP_list))
    gene_to_mp_dict[key]["sars_symptoms_phen"] = []
    for x in gene_to_mp_dict[key]["sars_symptoms"]:
        gene_to_mp_dict[key]["sars_symptoms_phen"].append(reverse_dict[x])

# %%
gene_to_mp_dict['IL2']["sars_symptoms"]
output_dict = gene_to_mp_dict

# %%
 output_df = pandas.DataFrame.from_dict(output_dict, orient='index')

# %%
 output_df =  output_df[output_df["sars_symptom_count"] > 0]

# %%
 output_df.to_csv("MP_phen_table.csv")

# %%
 output_df
# Out:
#                                                         MPs  \
# TMPRSS2   [MP:0001861, MP:0002169, MP:0003009, MP:000360...
# TH        [MP:0000255, MP:0000267, MP:0000279, MP:000074...
# IFNG      [MP:0000218, MP:0000219, MP:0000220, MP:000022...
# IL1B      [MP:0000920, MP:0000953, MP:0001273, MP:000187...
# ADAM17    [MP:0000065, MP:0000066, MP:0000135, MP:000016...
# SH2D3C    [MP:0000837, MP:0000965, MP:0000968, MP:000114...
# BSG       [MP:0000598, MP:0000601, MP:0000715, MP:000115...
# TNNI3     [MP:0000266, MP:0000278, MP:0001544, MP:000162...
# IL17A     [MP:0000208, MP:0000222, MP:0000322, MP:000117...
# DPP4      [MP:0000219, MP:0000220, MP:0000223, MP:000118...
# IL6       [MP:0000063, MP:0000130, MP:0000135, MP:000013...
# TNF       [MP:0000062, MP:0000130, MP:0000136, MP:000016...
# IL10      [MP:0000130, MP:0000199, MP:0000216, MP:000032...
# RAF1      [MP:0000218, MP:0000219, MP:0000220, MP:000027...
# FOXP3     [MP:0000018, MP:0000019, MP:0000020, MP:000020...
# PTGS2     [MP:0000208, MP:0000218, MP:0000242, MP:000036...
# TNFRSF1A  [MP:0000062, MP:0000217, MP:0000218, MP:000069...
# REL       [MP:0000240, MP:0000333, MP:0000470, MP:000059...
# IL4       [MP:0000066, MP:0000135, MP:0000136, MP:000016...
# CCR2      [MP:0000130, MP:0000222, MP:0000223, MP:000034...
# ITGAX     [MP:0000717, MP:0001790, MP:0001793, MP:000182...
# IRF1      [MP:0000685, MP:0001573, MP:0001790, MP:000216...
# CD79A     [MP:0000238, MP:0000716, MP:0001790, MP:000180...
# MYD88     [MP:0000221, MP:0000222, MP:0000223, MP:000047...
# SERPINE1  [MP:0000157, MP:0000322, MP:0000702, MP:000117...
# PPARA     [MP:0000184, MP:0000188, MP:0000189, MP:000027...
# CDKN1A    [MP:0000005, MP:0000223, MP:0000266, MP:000027...
# TNFSF11   [MP:0000061, MP:0000062, MP:0000063, MP:000006...
# ICAM1     [MP:0000218, MP:0000219, MP:0000220, MP:000126...
# TLR3      [MP:0000808, MP:0000812, MP:0001364, MP:000140...
# SYK       [MP:0000219, MP:0000238, MP:0000574, MP:000117...
# PTPRC     [MP:0000133, MP:0000217, MP:0000219, MP:000022...
# CXCR4     [MP:0000219, MP:0000220, MP:0000221, MP:000026...
# FAS       [MP:0000048, MP:0000218, MP:0000219, MP:000042...
# APP       [MP:0000136, MP:0000243, MP:0000604, MP:000074...
# CISH      [MP:0000685, MP:0000693, MP:0000708, MP:000179...
# CCR5      [MP:0000130, MP:0000222, MP:0000223, MP:000034...
# EGFR      [MP:0000088, MP:0000111, MP:0000221, MP:000027...
# TLR4      [MP:0000062, MP:0000188, MP:0000316, MP:000049...
# STAT3     [MP:0000005, MP:0000218, MP:0000219, MP:000022...
# CAMP      [MP:0000219, MP:0001313, MP:0002412, MP:000539...
# TGFB1     [MP:0000120, MP:0000129, MP:0000160, MP:000021...
# VEGFA     [MP:0000065, MP:0000088, MP:0000111, MP:000012...
#
#           sars_symptom_count  \
# TMPRSS2                    1
# TH                         1
# IFNG                       1
# IL1B                       1
# ADAM17                     3
# SH2D3C                     1
# BSG                        1
# TNNI3                      1
# IL17A                      1
# DPP4                       1
# IL6                        2
# TNF                        6
# IL10                       1
# RAF1                       1
# FOXP3                      1
# PTGS2                      1
# TNFRSF1A                   2
# REL                        1
# IL4                        1
# CCR2                       1
# ITGAX                      1
# IRF1                       1
# CD79A                      1
# MYD88                      3
# SERPINE1                   1
# PPARA                      1
# CDKN1A                     2
# TNFSF11                    2
# ICAM1                      1
# TLR3                       1
# SYK                        1
# PTPRC                      2
# CXCR4                      2
# FAS                        2
# APP                        1
# CISH                       1
# CCR5                       1
# EGFR                       2
# TLR4                       1
# STAT3                      3
# CAMP                       1
# TGFB1                      2
# VEGFA                      4
#
#                                               sars_symptoms  \
# TMPRSS2                                        {MP:0005291}
# TH                                             {MP:0001953}
# IFNG                                           {MP:0001175}
# IL1B                                           {MP:0001777}
# ADAM17                 {MP:0001175, MP:0001953, MP:0001954}
# SH2D3C                                         {MP:0003633}
# BSG                                            {MP:0001954}
# TNNI3                                          {MP:0001954}
# IL17A                                          {MP:0001790}
# DPP4                                           {MP:0001954}
# IL6                                {MP:0003633, MP:0001790}
# TNF       {MP:0001175, MP:0003633, MP:0001953, MP:000195...
# IL10                                           {MP:0001790}
# RAF1                                           {MP:0001953}
# FOXP3                                          {MP:0001790}
# PTGS2                                          {MP:0003606}
# TNFRSF1A                           {MP:0003633, MP:0001790}
# REL                                            {MP:0001175}
# IL4                                            {MP:0001790}
# CCR2                                           {MP:0003633}
# ITGAX                                          {MP:0001790}
# IRF1                                           {MP:0001790}
# CD79A                                          {MP:0001790}
# MYD88                  {MP:0002133, MP:0003633, MP:0001790}
# SERPINE1                                       {MP:0001175}
# PPARA                                          {MP:0005291}
# CDKN1A                             {MP:0001175, MP:0003606}
# TNFSF11                            {MP:0001175, MP:0001790}
# ICAM1                                          {MP:0001790}
# TLR3                                           {MP:0002133}
# SYK                                            {MP:0001175}
# PTPRC                              {MP:0003606, MP:0001790}
# CXCR4                              {MP:0003633, MP:0001790}
# FAS                                {MP:0003606, MP:0001790}
# APP                                            {MP:0003633}
# CISH                                           {MP:0001790}
# CCR5                                           {MP:0003633}
# EGFR                               {MP:0001953, MP:0001954}
# TLR4                                           {MP:0002133}
# STAT3                  {MP:0001777, MP:0001953, MP:0001954}
# CAMP                                           {MP:0001953}
# TGFB1                              {MP:0001175, MP:0001790}
# VEGFA      {MP:0001175, MP:0002133, MP:0001954, MP:0003606}
#
#                                          sars_symptoms_phen
# TMPRSS2                                 [Diabetes mellitus]
# TH        [Respiratory failure requiring assisted ventil...
# IFNG                                 [Chronic lung disease]
# IL1B                                                [Fever]
# ADAM17    [Chronic lung disease, Respiratory failure req...
# SH2D3C                                           [Headache]
# BSG                                  [Respiratory distress]
# TNNI3                                [Respiratory distress]
# IL17A                                    [Immunodeficiency]
# DPP4                                 [Respiratory distress]
# IL6                            [Headache, Immunodeficiency]
# TNF       [Chronic lung disease, Headache, Respiratory f...
# IL10                                     [Immunodeficiency]
# RAF1      [Respiratory failure requiring assisted ventil...
# FOXP3                                    [Immunodeficiency]
# PTGS2                                 [Acute kidney injury]
# TNFRSF1A                       [Headache, Immunodeficiency]
# REL                                  [Chronic lung disease]
# IL4                                      [Immunodeficiency]
# CCR2                                             [Headache]
# ITGAX                                    [Immunodeficiency]
# IRF1                                     [Immunodeficiency]
# CD79A                                    [Immunodeficiency]
# MYD88                 [Dyspnea, Headache, Immunodeficiency]
# SERPINE1                             [Chronic lung disease]
# PPARA                                   [Diabetes mellitus]
# CDKN1A          [Chronic lung disease, Acute kidney injury]
# TNFSF11            [Chronic lung disease, Immunodeficiency]
# ICAM1                                    [Immunodeficiency]
# TLR3                                              [Dyspnea]
# SYK                                  [Chronic lung disease]
# PTPRC               [Acute kidney injury, Immunodeficiency]
# CXCR4                          [Headache, Immunodeficiency]
# FAS                 [Acute kidney injury, Immunodeficiency]
# APP                                              [Headache]
# CISH                                     [Immunodeficiency]
# CCR5                                             [Headache]
# EGFR      [Respiratory failure requiring assisted ventil...
# TLR4                                              [Dyspnea]
# STAT3     [Fever, Respiratory failure requiring assisted...
# CAMP      [Respiratory failure requiring assisted ventil...
# TGFB1              [Chronic lung disease, Immunodeficiency]
# VEGFA     [Chronic lung disease, Dyspnea, Respiratory di...

# %%
genes_with_sars_symptoms_MP = []

for key in gene_to_mp_dict:
    if(gene_to_mp_dict[key]["sars_symptom_count"] > 0):
        print(key)
        print(gene_to_mp_dict[key]["sars_symptom_count"])
        genes_with_sars_symptoms_MP.append(key)
# Out:
# TMPRSS2
# 1
# TH
# 1
# IFNG
# 1
# IL1B
# 1
# ADAM17
# 3
# SH2D3C
# 1
# BSG
# 1
# TNNI3
# 1
# IL17A
# 1
# DPP4
# 1
# IL6
# 2
# TNF
# 6
# IL10
# 1
# RAF1
# 1
# FOXP3
# 1
# PTGS2
# 1
# TNFRSF1A
# 2
# REL
# 1
# IL4
# 1
# CCR2
# 1
# ITGAX
# 1
# IRF1
# 1
# CD79A
# 1
# MYD88
# 3
# SERPINE1
# 1
# PPARA
# 1
# CDKN1A
# 2
# TNFSF11
# 2
# ICAM1
# 1
# TLR3
# 1
# SYK
# 1
# PTPRC
# 2
# CXCR4
# 2
# FAS
# 2
# APP
# 1
# CISH
# 1
# CCR5
# 1
# EGFR
# 2
# TLR4
# 1
# STAT3
# 3
# CAMP
# 1
# TGFB1
# 2
# VEGFA
# 4

# %%
genes_with_sars_symptoms_MP
# Out:
# ['TMPRSS2',
#  'TH',
#  'IFNG',
#  'IL1B',
#  'ADAM17',
#  'SH2D3C',
#  'BSG',
#  'TNNI3',
#  'IL17A',
#  'DPP4',
#  'IL6',
#  'TNF',
#  'IL10',
#  'RAF1',
#  'FOXP3',
#  'PTGS2',
#  'TNFRSF1A',
#  'REL',
#  'IL4',
#  'CCR2',
#  'ITGAX',
#  'IRF1',
#  'CD79A',
#  'MYD88',
#  'SERPINE1',
#  'PPARA',
#  'CDKN1A',
#  'TNFSF11',
#  'ICAM1',
#  'TLR3',
#  'SYK',
#  'PTPRC',
#  'CXCR4',
#  'FAS',
#  'APP',
#  'CISH',
#  'CCR5',
#  'EGFR',
#  'TLR4',
#  'STAT3',
#  'CAMP',
#  'TGFB1',
#  'VEGFA']

# %%
covid_sars_mp_gene_inputs = create_gene_inputs(genes_with_sars_symptoms_MP)

# %% [markdown]
# ## 2.4  Filter Top Genes by those also related to 5+ of the Anatomical Entities from "ACE2 -> Anatomical Entities"

# %%
genes_related_to_AE = predict_many([ACE2],covid_gene_inputs,['AnatomicalEntity'])

# pd4 = Predict(
#     input_objs=[covid_gene_inputs],
#     intermediate_nodes=['AnatomicalEntity'], 
#     output_types =[ACE2], 
#     config= {"expand": False}
# )
# pd4.connect(verbose=False)
# df4 = pd4.display_table_view()
# df4
# Out:
# The second query doesn't return any result. So BTE does not find any connection between your input and output

# %%
genes_related_to_AE
# Out:
#    input input_type       pred1                     pred1_source  \
# 0   ACE2       Gene  related_to                             None
# 1   ACE2       Gene  related_to                             None
# 2   ACE2       Gene  related_to                             None
# 3   ACE2       Gene  related_to                             None
# 4   ACE2       Gene  related_to                             None
# ..   ...        ...         ...                              ...
# 1   ACE2       Gene  related_to  Translator Text Mining Provider
# 2   ACE2       Gene  related_to  Translator Text Mining Provider
# 3   ACE2       Gene  related_to  Translator Text Mining Provider
# 4   ACE2       Gene  related_to  Translator Text Mining Provider
# 5   ACE2       Gene  related_to                             None
#
#         pred1_api pred1_pubmed        node1_type  \
# 0     BioLink API         None  AnatomicalEntity
# 1     BioLink API         None  AnatomicalEntity
# 2     BioLink API         None  AnatomicalEntity
# 3     BioLink API         None  AnatomicalEntity
# 4     BioLink API         None  AnatomicalEntity
# ..            ...          ...               ...
# 1   CORD Gene API         None  AnatomicalEntity
# 2   CORD Gene API         None  AnatomicalEntity
# 3   CORD Gene API         None  AnatomicalEntity
# 4   CORD Gene API         None  AnatomicalEntity
# 5     BioLink API         None  AnatomicalEntity
#
#                          node1_name               node1_id       pred2  \
# 0             SKELETAL MUSCLE ORGAN  UBERON:UBERON:0014892  related_to
# 1   EPITHELIUM OF LACTIFEROUS GLAND  UBERON:UBERON:0003244  related_to
# 2                       ENDOMETRIUM  UBERON:UBERON:0001295  related_to
# 3            CORONARY ARTERIAL TREE  UBERON:UBERON:0001621  related_to
# 4                  DUCTUS LACTIFERI  UBERON:UBERON:0001765  related_to
# ..                              ...                    ...         ...
# 1                            KIDNEY  UBERON:UBERON:0002113  related_to
# 2                   ANATOMICAL UNIT  UBERON:UBERON:0000062  related_to
# 3                 PORTION OF TISSUE  UBERON:UBERON:0000479  related_to
# 4                           CARDIUM  UBERON:UBERON:0000948  related_to
# 5                             BRAIN  UBERON:UBERON:0000955  related_to
#
#                        pred2_source      pred2_api pred2_pubmed  \
# 0                              None    BioLink API         None
# 1                              None    BioLink API         None
# 2                              None    BioLink API         None
# 3                              None    BioLink API         None
# 4                              None    BioLink API         None
# ..                              ...            ...          ...
# 1   Translator Text Mining Provider  CORD Gene API         None
# 2   Translator Text Mining Provider  CORD Gene API         None
# 3   Translator Text Mining Provider  CORD Gene API         None
# 4   Translator Text Mining Provider  CORD Gene API         None
# 5   Translator Text Mining Provider  CORD Gene API         None
#
#          output_type output_name       output_id
# 0   AnatomicalEntity        ACE2  NCBIGene:59272
# 1   AnatomicalEntity        ACE2  NCBIGene:59272
# 2   AnatomicalEntity        ACE2  NCBIGene:59272
# 3   AnatomicalEntity        ACE2  NCBIGene:59272
# 4   AnatomicalEntity        ACE2  NCBIGene:59272
# ..               ...         ...             ...
# 1   AnatomicalEntity       MAPK1   NCBIGene:5594
# 2   AnatomicalEntity       MAPK1   NCBIGene:5594
# 3   AnatomicalEntity       MAPK1   NCBIGene:5594
# 4   AnatomicalEntity       MAPK1   NCBIGene:5594
# 5   AnatomicalEntity       MAPK1   NCBIGene:5594
#
# [1144 rows x 16 columns]

# %%
gene_list_2 = list(genes_related_to_AE["output_name"])
d = {x:gene_list_2.count(x) for x in gene_list_2}
d2_gene_df = pandas.DataFrame.from_dict({k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse = True)}, orient='index').iloc[0:50]
d2_gene_df.columns = ["count"]
d2_gene_df
# Out:
#         count
# ACE2       31
# ACE        17
# CRP        16
# TNF        16
# TH         15
# REN        15
# CISH       15
# MSC        14
# IL4        14
# IL2RA      13
# IL10       13
# AGTR1      13
# INS        13
# CD4        12
# POMC       12
# CA2        12
# CD28       12
# CCL2       11
# IFNA1      11
# F3         11
# IL6        11
# PSMD9      11
# CCR2       11
# PTH        11
# LEP        11
# ALB        10
# GPT        10
# CD2        10
# ISG20      10
# GRAP2      10
# FAS        10
# CCR5       10
# CAT        10
# EGFR       10
# AKT1       10
# AGTR2       9
# MB          9
# FOXP3       9
# TF          9
# REG1A       9
# CCL20       9
# ICAM1       9
# PIK3CA      9
# CXCL8       8
# IL17A       8
# DPP4        8
# CX3CL1      8
# CXCL9       8
# LCK         8
# MTOR        8

# %%
v2_genes = list(d2_gene_df[d2_gene_df["count"] >= 1].index)
print(v2_genes)
# Out:
# ['ACE2', 'ACE', 'CRP', 'TNF', 'TH', 'REN', 'CISH', 'MSC', 'IL4', 'IL2RA', 'IL10', 'AGTR1', 'INS', 'CD4', 'POMC', 'CA2', 'CD28', 'CCL2', 'IFNA1', 'F3', 'IL6', 'PSMD9', 'CCR2', 'PTH', 'LEP', 'ALB', 'GPT', 'CD2', 'ISG20', 'GRAP2', 'FAS', 'CCR5', 'CAT', 'EGFR', 'AKT1', 'AGTR2', 'MB', 'FOXP3', 'TF', 'REG1A', 'CCL20', 'ICAM1', 'PIK3CA', 'CXCL8', 'IL17A', 'DPP4', 'CX3CL1', 'CXCL9', 'LCK', 'MTOR']

# %%
v2_gene_inputs = create_gene_inputs(v2_genes)
v2_gene_inputs
# Out:
# [{'NCBIGene': '59272',
#   'name': 'angiotensin I converting enzyme 2',
#   'SYMBOL': 'ACE2',
#   'UMLS': 'C1422064',
#   'HGNC': '13557',
#   'UNIPROTKB': 'Q9BYF1',
#   'ENSEMBL': 'ENSG00000130234',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#   'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#   'type': 'Gene'},
#  {'NCBIGene': '1636',
#   'name': 'angiotensin I converting enzyme',
#   'SYMBOL': 'ACE',
#   'UMLS': 'C1413931',
#   'HGNC': '2707',
#   'UNIPROTKB': 'P12821',
#   'ENSEMBL': 'ENSG00000159640',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1636'},
#   'display': 'NCBIGene(1636) ENSEMBL(ENSG00000159640) HGNC(2707) UMLS(C1413931) UNIPROTKB(P12821) SYMBOL(ACE)',
#   'type': 'Gene'},
#  {'NCBIGene': '1401',
#   'name': 'C-reactive protein',
#   'SYMBOL': 'CRP',
#   'UMLS': 'C1413716',
#   'HGNC': '2367',
#   'UNIPROTKB': 'P02741',
#   'ENSEMBL': 'ENSG00000132693',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1401'},
#   'display': 'NCBIGene(1401) ENSEMBL(ENSG00000132693) HGNC(2367) UMLS(C1413716) UNIPROTKB(P02741) SYMBOL(CRP)',
#   'type': 'Gene'},
#  {'NCBIGene': '7124',
#   'name': 'tumor necrosis factor',
#   'SYMBOL': 'TNF',
#   'UMLS': 'C0812246',
#   'HGNC': '11892',
#   'UNIPROTKB': 'P01375',
#   'ENSEMBL': 'ENSG00000204490',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7124'},
#   'display': 'NCBIGene(7124) ENSEMBL(ENSG00000204490) HGNC(11892) UMLS(C0812246) UNIPROTKB(P01375) SYMBOL(TNF)',
#   'type': 'Gene'},
#  {'NCBIGene': '7054',
#   'name': 'tyrosine hydroxylase',
#   'SYMBOL': 'TH',
#   'UMLS': 'C1420718',
#   'HGNC': '11782',
#   'UNIPROTKB': 'P07101',
#   'ENSEMBL': 'ENSG00000180176',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7054'},
#   'display': 'NCBIGene(7054) ENSEMBL(ENSG00000180176) HGNC(11782) UMLS(C1420718) UNIPROTKB(P07101) SYMBOL(TH)',
#   'type': 'Gene'},
#  {'NCBIGene': '5972',
#   'name': 'renin',
#   'SYMBOL': 'REN',
#   'UMLS': 'C1419338',
#   'HGNC': '9958',
#   'UNIPROTKB': 'P00797',
#   'ENSEMBL': 'ENSG00000143839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5972'},
#   'display': 'NCBIGene(5972) ENSEMBL(ENSG00000143839) HGNC(9958) UMLS(C1419338) UNIPROTKB(P00797) SYMBOL(REN)',
#   'type': 'Gene'},
#  {'NCBIGene': '1154',
#   'name': 'cytokine inducible SH2 containing protein',
#   'SYMBOL': 'CISH',
#   'UMLS': 'C1332762',
#   'HGNC': '1984',
#   'UNIPROTKB': 'Q9NSE2',
#   'ENSEMBL': 'ENSG00000114737',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1154'},
#   'display': 'NCBIGene(1154) ENSEMBL(ENSG00000114737) HGNC(1984) UMLS(C1332762) UNIPROTKB(Q9NSE2) SYMBOL(CISH)',
#   'type': 'Gene'},
#  {'NCBIGene': '9242',
#   'name': 'musculin',
#   'SYMBOL': 'MSC',
#   'UMLS': 'C1334531',
#   'HGNC': '7321',
#   'UNIPROTKB': 'O60682',
#   'ENSEMBL': 'ENSG00000178860',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9242'},
#   'display': 'NCBIGene(9242) ENSEMBL(ENSG00000178860) HGNC(7321) UMLS(C1334531) UNIPROTKB(O60682) SYMBOL(MSC)',
#   'type': 'Gene'},
#  {'NCBIGene': '3565',
#   'name': 'interleukin 4',
#   'SYMBOL': 'IL4',
#   'UMLS': 'C1334119',
#   'HGNC': '6014',
#   'UNIPROTKB': 'P05112',
#   'ENSEMBL': 'ENSG00000113520',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3565'},
#   'display': 'NCBIGene(3565) ENSEMBL(ENSG00000113520) HGNC(6014) UMLS(C1334119) UNIPROTKB(P05112) SYMBOL(IL4)',
#   'type': 'Gene'},
#  {'NCBIGene': '3559',
#   'name': 'interleukin 2 receptor subunit alpha',
#   'SYMBOL': 'IL2RA',
#   'UMLS': 'C1334114',
#   'HGNC': '6008',
#   'UNIPROTKB': 'P01589',
#   'ENSEMBL': 'ENSG00000134460',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3559'},
#   'display': 'NCBIGene(3559) ENSEMBL(ENSG00000134460) HGNC(6008) UMLS(C1334114) UNIPROTKB(P01589) SYMBOL(IL2RA)',
#   'type': 'Gene'},
#  {'NCBIGene': '3586',
#   'name': 'interleukin 10',
#   'SYMBOL': 'IL10',
#   'UMLS': 'C1334098',
#   'HGNC': '5962',
#   'UNIPROTKB': 'P22301',
#   'ENSEMBL': 'ENSG00000136634',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3586'},
#   'display': 'NCBIGene(3586) ENSEMBL(ENSG00000136634) HGNC(5962) UMLS(C1334098) UNIPROTKB(P22301) SYMBOL(IL10)',
#   'type': 'Gene'},
#  {'NCBIGene': '185',
#   'name': 'angiotensin II receptor type 1',
#   'SYMBOL': 'AGTR1',
#   'UMLS': 'C1439284',
#   'HGNC': '336',
#   'UNIPROTKB': 'P30556',
#   'ENSEMBL': 'ENSG00000144891',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '185'},
#   'display': 'NCBIGene(185) ENSEMBL(ENSG00000144891) HGNC(336) UMLS(C1439284) UNIPROTKB(P30556) SYMBOL(AGTR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3630',
#   'name': 'insulin',
#   'SYMBOL': 'INS',
#   'UMLS': 'C1337112',
#   'HGNC': '6081',
#   'UNIPROTKB': 'P01308',
#   'ENSEMBL': 'ENSG00000254647',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3630'},
#   'display': 'NCBIGene(3630) ENSEMBL(ENSG00000254647) HGNC(6081) UMLS(C1337112) UNIPROTKB(P01308) SYMBOL(INS)',
#   'type': 'Gene'},
#  {'NCBIGene': '920',
#   'name': 'CD4 molecule',
#   'SYMBOL': 'CD4',
#   'UMLS': 'C1332714',
#   'HGNC': '1678',
#   'UNIPROTKB': 'P01730',
#   'ENSEMBL': 'ENSG00000010610',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '920'},
#   'display': 'NCBIGene(920) ENSEMBL(ENSG00000010610) HGNC(1678) UMLS(C1332714) UNIPROTKB(P01730) SYMBOL(CD4)',
#   'type': 'Gene'},
#  {'NCBIGene': '5443',
#   'name': 'proopiomelanocortin',
#   'SYMBOL': 'POMC',
#   'UMLS': 'C1337111',
#   'HGNC': '9201',
#   'UNIPROTKB': 'P01189',
#   'ENSEMBL': 'ENSG00000115138',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5443'},
#   'display': 'NCBIGene(5443) ENSEMBL(ENSG00000115138) HGNC(9201) UMLS(C1337111) UNIPROTKB(P01189) SYMBOL(POMC)',
#   'type': 'Gene'},
#  {'NCBIGene': '760',
#   'name': 'carbonic anhydrase 2',
#   'SYMBOL': 'CA2',
#   'UMLS': 'C1413043',
#   'HGNC': '1373',
#   'UNIPROTKB': 'P00918',
#   'ENSEMBL': 'ENSG00000104267',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '760'},
#   'display': 'NCBIGene(760) ENSEMBL(ENSG00000104267) HGNC(1373) UMLS(C1413043) UNIPROTKB(P00918) SYMBOL(CA2)',
#   'type': 'Gene'},
#  {'NCBIGene': '940',
#   'name': 'CD28 molecule',
#   'SYMBOL': 'CD28',
#   'UMLS': 'C1332709',
#   'HGNC': '1653',
#   'UNIPROTKB': 'P10747',
#   'ENSEMBL': 'ENSG00000178562',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '940'},
#   'display': 'NCBIGene(940) ENSEMBL(ENSG00000178562) HGNC(1653) UMLS(C1332709) UNIPROTKB(P10747) SYMBOL(CD28)',
#   'type': 'Gene'},
#  {'NCBIGene': '6347',
#   'name': 'C-C motif chemokine ligand 2',
#   'SYMBOL': 'CCL2',
#   'UMLS': 'C1337092',
#   'HGNC': '10618',
#   'UNIPROTKB': 'P13500',
#   'ENSEMBL': 'ENSG00000108691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6347'},
#   'display': 'NCBIGene(6347) ENSEMBL(ENSG00000108691) HGNC(10618) UMLS(C1337092) UNIPROTKB(P13500) SYMBOL(CCL2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3439',
#   'name': 'interferon alpha 1',
#   'SYMBOL': 'IFNA1',
#   'UMLS': 'C1415900',
#   'HGNC': '5417',
#   'UNIPROTKB': 'P01562',
#   'ENSEMBL': 'ENSG00000197919',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3439'},
#   'display': 'NCBIGene(3439) ENSEMBL(ENSG00000197919) HGNC(5417) UMLS(C1415900) UNIPROTKB(P01562) SYMBOL(IFNA1)',
#   'type': 'Gene'},
#  {'NCBIGene': '2152',
#   'name': 'coagulation factor III, tissue factor',
#   'SYMBOL': 'F3',
#   'UMLS': 'C1333522',
#   'HGNC': '3541',
#   'UNIPROTKB': 'P13726',
#   'ENSEMBL': 'ENSG00000117525',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2152'},
#   'display': 'NCBIGene(2152) ENSEMBL(ENSG00000117525) HGNC(3541) UMLS(C1333522) UNIPROTKB(P13726) SYMBOL(F3)',
#   'type': 'Gene'},
#  {'NCBIGene': '3569',
#   'name': 'interleukin 6',
#   'SYMBOL': 'IL6',
#   'UMLS': 'C1334122',
#   'HGNC': '6018',
#   'UNIPROTKB': 'P05231',
#   'ENSEMBL': 'ENSG00000136244',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3569'},
#   'display': 'NCBIGene(3569) ENSEMBL(ENSG00000136244) HGNC(6018) UMLS(C1334122) UNIPROTKB(P05231) SYMBOL(IL6)',
#   'type': 'Gene'},
#  {'NCBIGene': '5715',
#   'name': 'proteasome 26S subunit, non-ATPase 9',
#   'SYMBOL': 'PSMD9',
#   'UMLS': 'C1419040',
#   'HGNC': '9567',
#   'UNIPROTKB': 'O00233',
#   'ENSEMBL': 'ENSG00000110801',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5715'},
#   'display': 'NCBIGene(5715) ENSEMBL(ENSG00000110801) HGNC(9567) UMLS(C1419040) UNIPROTKB(O00233) SYMBOL(PSMD9)',
#   'type': 'Gene'},
#  {'NCBIGene': '729230',
#   'name': 'C-C motif chemokine receptor 2',
#   'SYMBOL': 'CCR2',
#   'UMLS': 'C1413188',
#   'HGNC': '1603',
#   'UNIPROTKB': 'P41597',
#   'ENSEMBL': 'ENSG00000121807',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '729230'},
#   'display': 'NCBIGene(729230) ENSEMBL(ENSG00000121807) HGNC(1603) UMLS(C1413188) UNIPROTKB(P41597) SYMBOL(CCR2)',
#   'type': 'Gene'},
#  {'NCBIGene': '5741',
#   'name': 'parathyroid hormone',
#   'SYMBOL': 'PTH',
#   'UMLS': 'C1419072',
#   'HGNC': '9606',
#   'UNIPROTKB': 'P01270',
#   'ENSEMBL': 'ENSG00000152266',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5741'},
#   'display': 'NCBIGene(5741) ENSEMBL(ENSG00000152266) HGNC(9606) UMLS(C1419072) UNIPROTKB(P01270) SYMBOL(PTH)',
#   'type': 'Gene'},
#  {'NCBIGene': '3952',
#   'name': 'leptin',
#   'SYMBOL': 'LEP',
#   'UMLS': 'C1416825',
#   'HGNC': '6553',
#   'UNIPROTKB': 'P41159',
#   'ENSEMBL': 'ENSG00000174697',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3952'},
#   'display': 'NCBIGene(3952) ENSEMBL(ENSG00000174697) HGNC(6553) UMLS(C1416825) UNIPROTKB(P41159) SYMBOL(LEP)',
#   'type': 'Gene'},
#  {'NCBIGene': '213',
#   'name': 'albumin',
#   'SYMBOL': 'ALB',
#   'UMLS': 'C1412332',
#   'HGNC': '399',
#   'UNIPROTKB': 'P02768',
#   'ENSEMBL': 'ENSG00000163631',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '213'},
#   'display': 'NCBIGene(213) ENSEMBL(ENSG00000163631) HGNC(399) UMLS(C1412332) UNIPROTKB(P02768) SYMBOL(ALB)',
#   'type': 'Gene'},
#  {'NCBIGene': '2875',
#   'name': 'glutamic--pyruvic transaminase',
#   'SYMBOL': 'GPT',
#   'UMLS': 'C1415274',
#   'HGNC': '4552',
#   'UNIPROTKB': 'P24298',
#   'ENSEMBL': 'ENSG00000167701',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2875'},
#   'display': 'NCBIGene(2875) ENSEMBL(ENSG00000167701) HGNC(4552) UMLS(C1415274) UNIPROTKB(P24298) SYMBOL(GPT)',
#   'type': 'Gene'},
#  {'NCBIGene': '914',
#   'name': 'CD2 molecule',
#   'SYMBOL': 'CD2',
#   'UMLS': 'C1367475',
#   'HGNC': '1639',
#   'UNIPROTKB': 'P06729',
#   'ENSEMBL': 'ENSG00000116824',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '914'},
#   'display': 'NCBIGene(914) ENSEMBL(ENSG00000116824) HGNC(1639) UMLS(C1367475) UNIPROTKB(P06729) SYMBOL(CD2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3669',
#   'name': 'interferon stimulated exonuclease gene 20',
#   'SYMBOL': 'ISG20',
#   'UMLS': 'C1416478',
#   'HGNC': '6130',
#   'UNIPROTKB': 'Q96AZ6',
#   'ENSEMBL': 'ENSG00000172183',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3669'},
#   'display': 'NCBIGene(3669) ENSEMBL(ENSG00000172183) HGNC(6130) UMLS(C1416478) UNIPROTKB(Q96AZ6) SYMBOL(ISG20)',
#   'type': 'Gene'},
#  {'NCBIGene': '9402',
#   'name': 'GRB2 related adaptor protein 2',
#   'SYMBOL': 'GRAP2',
#   'UMLS': 'C1415284',
#   'HGNC': '4563',
#   'UNIPROTKB': 'O75791',
#   'ENSEMBL': 'ENSG00000100351',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9402'},
#   'display': 'NCBIGene(9402) ENSEMBL(ENSG00000100351) HGNC(4563) UMLS(C1415284) UNIPROTKB(O75791) SYMBOL(GRAP2)',
#   'type': 'Gene'},
#  {'NCBIGene': '355',
#   'name': 'Fas cell surface death receptor',
#   'SYMBOL': 'FAS',
#   'UMLS': 'C1539477',
#   'HGNC': '11920',
#   'UNIPROTKB': 'P25445',
#   'ENSEMBL': 'ENSG00000026103',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '355'},
#   'display': 'NCBIGene(355) ENSEMBL(ENSG00000026103) HGNC(11920) UMLS(C1539477) UNIPROTKB(P25445) SYMBOL(FAS)',
#   'type': 'Gene'},
#  {'NCBIGene': '1234',
#   'name': 'C-C motif chemokine receptor 5',
#   'SYMBOL': 'CCR5',
#   'UMLS': 'C1332700',
#   'HGNC': '1606',
#   'UNIPROTKB': 'P51681',
#   'ENSEMBL': 'ENSG00000160791',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1234'},
#   'display': 'NCBIGene(1234) ENSEMBL(ENSG00000160791) HGNC(1606) UMLS(C1332700) UNIPROTKB(P51681) SYMBOL(CCR5)',
#   'type': 'Gene'},
#  {'NCBIGene': '847',
#   'name': 'catalase',
#   'SYMBOL': 'CAT',
#   'UMLS': 'C1413138',
#   'HGNC': '1516',
#   'UNIPROTKB': 'P04040',
#   'ENSEMBL': 'ENSG00000121691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '847'},
#   'display': 'NCBIGene(847) ENSEMBL(ENSG00000121691) HGNC(1516) UMLS(C1413138) UNIPROTKB(P04040) SYMBOL(CAT)',
#   'type': 'Gene'},
#  {'NCBIGene': '1956',
#   'name': 'epidermal growth factor receptor',
#   'SYMBOL': 'EGFR',
#   'UMLS': 'C1414313',
#   'HGNC': '3236',
#   'UNIPROTKB': 'P00533',
#   'ENSEMBL': 'ENSG00000146648',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1956'},
#   'display': 'NCBIGene(1956) ENSEMBL(ENSG00000146648) HGNC(3236) UMLS(C1414313) UNIPROTKB(P00533) SYMBOL(EGFR)',
#   'type': 'Gene'},
#  {'NCBIGene': '207',
#   'name': 'AKT serine/threonine kinase 1',
#   'SYMBOL': 'AKT1',
#   'UMLS': 'C0812228',
#   'HGNC': '391',
#   'UNIPROTKB': 'P31749',
#   'ENSEMBL': 'ENSG00000142208',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '207'},
#   'display': 'NCBIGene(207) ENSEMBL(ENSG00000142208) HGNC(391) UMLS(C0812228) UNIPROTKB(P31749) SYMBOL(AKT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '186',
#   'name': 'angiotensin II receptor type 2',
#   'SYMBOL': 'AGTR2',
#   'UMLS': 'C1332036',
#   'HGNC': '338',
#   'UNIPROTKB': 'P50052',
#   'ENSEMBL': 'ENSG00000180772',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '186'},
#   'display': 'NCBIGene(186) ENSEMBL(ENSG00000180772) HGNC(338) UMLS(C1332036) UNIPROTKB(P50052) SYMBOL(AGTR2)',
#   'type': 'Gene'},
#  {'NCBIGene': '4151',
#   'name': 'myoglobin',
#   'SYMBOL': 'MB',
#   'UMLS': 'C1417048',
#   'HGNC': '6915',
#   'UNIPROTKB': 'P02144',
#   'ENSEMBL': 'ENSG00000198125',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4151'},
#   'display': 'NCBIGene(4151) ENSEMBL(ENSG00000198125) HGNC(6915) UMLS(C1417048) UNIPROTKB(P02144) SYMBOL(MB)',
#   'type': 'Gene'},
#  {'NCBIGene': '50943',
#   'name': 'forkhead box P3',
#   'SYMBOL': 'FOXP3',
#   'UMLS': 'C1416467',
#   'HGNC': '6106',
#   'UNIPROTKB': 'Q9BZS1',
#   'ENSEMBL': 'ENSG00000049768',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '50943'},
#   'display': 'NCBIGene(50943) ENSEMBL(ENSG00000049768) HGNC(6106) UMLS(C1416467) UNIPROTKB(Q9BZS1) SYMBOL(FOXP3)',
#   'type': 'Gene'},
#  {'NCBIGene': '7018',
#   'name': 'transferrin',
#   'SYMBOL': 'TF',
#   'UMLS': 'C1442762',
#   'HGNC': '11740',
#   'UNIPROTKB': 'P02787',
#   'ENSEMBL': 'ENSG00000091513',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7018'},
#   'display': 'NCBIGene(7018) ENSEMBL(ENSG00000091513) HGNC(11740) UMLS(C1442762) UNIPROTKB(P02787) SYMBOL(TF)',
#   'type': 'Gene'},
#  {'NCBIGene': '5967',
#   'name': 'regenerating family member 1 alpha',
#   'SYMBOL': 'REG1A',
#   'UMLS': 'C1419333',
#   'HGNC': '9951',
#   'UNIPROTKB': 'P05451',
#   'ENSEMBL': 'ENSG00000115386',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5967'},
#   'display': 'NCBIGene(5967) ENSEMBL(ENSG00000115386) HGNC(9951) UMLS(C1419333) UNIPROTKB(P05451) SYMBOL(REG1A)',
#   'type': 'Gene'},
#  {'NCBIGene': '6364',
#   'name': 'C-C motif chemokine ligand 20',
#   'SYMBOL': 'CCL20',
#   'UMLS': 'C1366524',
#   'HGNC': '10619',
#   'UNIPROTKB': 'P78556',
#   'ENSEMBL': 'ENSG00000115009',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6364'},
#   'display': 'NCBIGene(6364) ENSEMBL(ENSG00000115009) HGNC(10619) UMLS(C1366524) UNIPROTKB(P78556) SYMBOL(CCL20)',
#   'type': 'Gene'},
#  {'NCBIGene': '3383',
#   'name': 'intercellular adhesion molecule 1',
#   'SYMBOL': 'ICAM1',
#   'UMLS': 'C1334074',
#   'HGNC': '5344',
#   'UNIPROTKB': 'P05362',
#   'ENSEMBL': 'ENSG00000090339',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3383'},
#   'display': 'NCBIGene(3383) ENSEMBL(ENSG00000090339) HGNC(5344) UMLS(C1334074) UNIPROTKB(P05362) SYMBOL(ICAM1)',
#   'type': 'Gene'},
#  {'NCBIGene': '5290',
#   'name': 'phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha',
#   'SYMBOL': 'PIK3CA',
#   'UMLS': 'C1335212',
#   'HGNC': '8975',
#   'UNIPROTKB': 'P42336',
#   'ENSEMBL': 'ENSG00000121879',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5290'},
#   'display': 'NCBIGene(5290) ENSEMBL(ENSG00000121879) HGNC(8975) UMLS(C1335212) UNIPROTKB(P42336) SYMBOL(PIK3CA)',
#   'type': 'Gene'},
#  {'NCBIGene': '3576',
#   'name': 'C-X-C motif chemokine ligand 8',
#   'SYMBOL': 'CXCL8',
#   'UMLS': 'C1366571',
#   'HGNC': '6025',
#   'UNIPROTKB': 'P10145',
#   'ENSEMBL': 'ENSG00000169429',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3576'},
#   'display': 'NCBIGene(3576) ENSEMBL(ENSG00000169429) HGNC(6025) UMLS(C1366571) UNIPROTKB(P10145) SYMBOL(CXCL8)',
#   'type': 'Gene'},
#  {'NCBIGene': '3605',
#   'name': 'interleukin 17A',
#   'SYMBOL': 'IL17A',
#   'UMLS': 'C1825592',
#   'HGNC': '5981',
#   'UNIPROTKB': 'Q16552',
#   'ENSEMBL': 'ENSG00000112115',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3605'},
#   'display': 'NCBIGene(3605) ENSEMBL(ENSG00000112115) HGNC(5981) UMLS(C1825592) UNIPROTKB(Q16552) SYMBOL(IL17A)',
#   'type': 'Gene'},
#  {'NCBIGene': '1803',
#   'name': 'dipeptidyl peptidase 4',
#   'SYMBOL': 'DPP4',
#   'UMLS': 'C1414141',
#   'HGNC': '3009',
#   'UNIPROTKB': 'P27487',
#   'ENSEMBL': 'ENSG00000197635',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1803'},
#   'display': 'NCBIGene(1803) ENSEMBL(ENSG00000197635) HGNC(3009) UMLS(C1414141) UNIPROTKB(P27487) SYMBOL(DPP4)',
#   'type': 'Gene'},
#  {'NCBIGene': '6376',
#   'name': 'C-X3-C motif chemokine ligand 1',
#   'SYMBOL': 'CX3CL1',
#   'UMLS': 'C1332814',
#   'HGNC': '10647',
#   'UNIPROTKB': 'P78423',
#   'ENSEMBL': 'ENSG00000006210',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6376'},
#   'display': 'NCBIGene(6376) ENSEMBL(ENSG00000006210) HGNC(10647) UMLS(C1332814) UNIPROTKB(P78423) SYMBOL(CX3CL1)',
#   'type': 'Gene'},
#  {'NCBIGene': '4283',
#   'name': 'C-X-C motif chemokine ligand 9',
#   'SYMBOL': 'CXCL9',
#   'UMLS': 'C1332821',
#   'HGNC': '7098',
#   'UNIPROTKB': 'Q07325',
#   'ENSEMBL': 'ENSG00000138755',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4283'},
#   'display': 'NCBIGene(4283) ENSEMBL(ENSG00000138755) HGNC(7098) UMLS(C1332821) UNIPROTKB(Q07325) SYMBOL(CXCL9)',
#   'type': 'Gene'},
#  {'NCBIGene': '3932',
#   'name': 'LCK proto-oncogene, Src family tyrosine kinase',
#   'SYMBOL': 'LCK',
#   'UMLS': 'C0919477',
#   'HGNC': '6524',
#   'UNIPROTKB': 'P06239',
#   'ENSEMBL': 'ENSG00000182866',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3932'},
#   'display': 'NCBIGene(3932) ENSEMBL(ENSG00000182866) HGNC(6524) UMLS(C0919477) UNIPROTKB(P06239) SYMBOL(LCK)',
#   'type': 'Gene'},
#  {'NCBIGene': '2475',
#   'name': 'mechanistic target of rapamycin kinase',
#   'SYMBOL': 'MTOR',
#   'UMLS': 'C1414805',
#   'HGNC': '3942',
#   'UNIPROTKB': 'P42345',
#   'ENSEMBL': 'ENSG00000198793',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2475'},
#   'display': 'NCBIGene(2475) ENSEMBL(ENSG00000198793) HGNC(3942) UMLS(C1414805) UNIPROTKB(P42345) SYMBOL(MTOR)',
#   'type': 'Gene'}]

# %% [markdown]
# ## 2.5 Filter Top Genes by those also related to 1+ of the SARS phenotypes or biological processes

# %%
genes_related_to_phens = predict_many(covid_gene_inputs,[SARS],['BiologicalProcess','PhenotypicFeature'])
genes_related_to_phens
# Out:
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
#     input input_type       pred1                     pred1_source  \
# 0    ACE2       Gene     affects                           SEMMED
# 1    ACE2       Gene    disrupts                           SEMMED
# 2    ACE2       Gene     affects                           SEMMED
# 3    ACE2       Gene     affects                           SEMMED
# 4    ACE2       Gene     affects                           SEMMED
# ..    ...        ...         ...                              ...
# 61  MAPK1       Gene  related_to  Translator Text Mining Provider
# 62  MAPK1       Gene  related_to  Translator Text Mining Provider
# 63  MAPK1       Gene  related_to  Translator Text Mining Provider
# 64  MAPK1       Gene  related_to  Translator Text Mining Provider
# 65  MAPK1       Gene  related_to  Translator Text Mining Provider
#
#           pred1_api pred1_pubmed         node1_type             node1_name  \
# 0   SEMMED Gene API     15825152  BiologicalProcess               C0007613
# 1   SEMMED Gene API     27806985  BiologicalProcess               C0007613
# 2   SEMMED Gene API     23013041  BiologicalProcess               C0017262
# 3   SEMMED Gene API     23013041  BiologicalProcess               C0017262
# 4   SEMMED Gene API     23013041  BiologicalProcess               C0017262
# ..              ...          ...                ...                    ...
# 61    CORD Gene API         None  BiologicalProcess        GENE EXPRESSION
# 62    CORD Gene API         None  BiologicalProcess              BREAKDOWN
# 63    CORD Gene API         None  BiologicalProcess         CELL MIGRATION
# 64    CORD Gene API         None  BiologicalProcess  NEURAL TUBE FORMATION
# 65    CORD Gene API         None  BiologicalProcess       HYPERSENSITIVITY
#
#          node1_id        pred2                     pred2_source  \
# 0   UMLS:C0007613      affects                           SEMMED
# 1   UMLS:C0007613      affects                           SEMMED
# 2   UMLS:C0017262      affects                           SEMMED
# 3   UMLS:C0017262   related_to                           SEMMED
# 4   UMLS:C0017262  affected_by                           SEMMED
# ..            ...          ...                              ...
# 61  GO:GO:0010467   related_to  Translator Text Mining Provider
# 62  GO:GO:0009056   related_to  Translator Text Mining Provider
# 63  GO:GO:0016477   related_to  Translator Text Mining Provider
# 64  GO:GO:0001841   related_to  Translator Text Mining Provider
# 65  GO:GO:0002524   related_to  Translator Text Mining Provider
#
#              pred2_api                        pred2_pubmed        output_type  \
# 0   SEMMED Disease API                            19364769  BiologicalProcess
# 1   SEMMED Disease API                            19364769  BiologicalProcess
# 2   SEMMED Disease API  12565954,12650527,12749904,3208739  BiologicalProcess
# 3   SEMMED Disease API                             8049444  BiologicalProcess
# 4   SEMMED Disease API                            16174304  BiologicalProcess
# ..                 ...                                 ...                ...
# 61    CORD Disease API                                None  BiologicalProcess
# 62    CORD Disease API                                None  BiologicalProcess
# 63    CORD Disease API                                None  BiologicalProcess
# 64    CORD Disease API                                None  BiologicalProcess
# 65    CORD Disease API                                None  BiologicalProcess
#
#                                 output_name            output_id
# 0   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 1   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 2   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 3   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 4   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# ..                                      ...                  ...
# 61  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 62  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 63  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 64  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 65  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
#
# [5973 rows x 16 columns]

# %%
v3_genes = list(dict.fromkeys(list(genes_related_to_phens["input"])))
v3_gene_inputs = create_gene_inputs(v3_genes)
v3_gene_inputs
# Out:
# [{'NCBIGene': '59272',
#   'name': 'angiotensin I converting enzyme 2',
#   'SYMBOL': 'ACE2',
#   'UMLS': 'C1422064',
#   'HGNC': '13557',
#   'UNIPROTKB': 'Q9BYF1',
#   'ENSEMBL': 'ENSG00000130234',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#   'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#   'type': 'Gene'},
#  {'NCBIGene': '1401',
#   'name': 'C-reactive protein',
#   'SYMBOL': 'CRP',
#   'UMLS': 'C1413716',
#   'HGNC': '2367',
#   'UNIPROTKB': 'P02741',
#   'ENSEMBL': 'ENSG00000132693',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1401'},
#   'display': 'NCBIGene(1401) ENSEMBL(ENSG00000132693) HGNC(2367) UMLS(C1413716) UNIPROTKB(P02741) SYMBOL(CRP)',
#   'type': 'Gene'},
#  {'NCBIGene': '7054',
#   'name': 'tyrosine hydroxylase',
#   'SYMBOL': 'TH',
#   'UMLS': 'C1420718',
#   'HGNC': '11782',
#   'UNIPROTKB': 'P07101',
#   'ENSEMBL': 'ENSG00000180176',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7054'},
#   'display': 'NCBIGene(7054) ENSEMBL(ENSG00000180176) HGNC(11782) UMLS(C1420718) UNIPROTKB(P07101) SYMBOL(TH)',
#   'type': 'Gene'},
#  {'NCBIGene': '6651',
#   'name': 'SON DNA and RNA binding protein',
#   'SYMBOL': 'SON',
#   'UMLS': 'C1420310',
#   'HGNC': '11183',
#   'UNIPROTKB': 'P18583',
#   'ENSEMBL': 'ENSG00000159140',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6651'},
#   'display': 'NCBIGene(6651) ENSEMBL(ENSG00000159140) HGNC(11183) UMLS(C1420310) UNIPROTKB(P18583) SYMBOL(SON)',
#   'type': 'Gene'},
#  {'NCBIGene': '4141',
#   'name': 'methionyl-tRNA synthetase 1',
#   'SYMBOL': 'MARS1',
#   'UMLS': 'C1417035',
#   'HGNC': '6898',
#   'UNIPROTKB': 'P56192',
#   'ENSEMBL': 'ENSG00000166986',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4141'},
#   'display': 'NCBIGene(4141) ENSEMBL(ENSG00000166986) HGNC(6898) UMLS(C1417035) UNIPROTKB(P56192) SYMBOL(MARS1)',
#   'type': 'Gene'},
#  {'NCBIGene': '5447',
#   'name': 'cytochrome p450 oxidoreductase',
#   'SYMBOL': 'POR',
#   'UMLS': 'C1335232',
#   'HGNC': '9208',
#   'UNIPROTKB': 'P16435',
#   'ENSEMBL': 'ENSG00000127948',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5447'},
#   'display': 'NCBIGene(5447) ENSEMBL(ENSG00000127948) HGNC(9208) UMLS(C1335232) UNIPROTKB(P16435) SYMBOL(POR)',
#   'type': 'Gene'},
#  {'NCBIGene': '920',
#   'name': 'CD4 molecule',
#   'SYMBOL': 'CD4',
#   'UMLS': 'C1332714',
#   'HGNC': '1678',
#   'UNIPROTKB': 'P01730',
#   'ENSEMBL': 'ENSG00000010610',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '920'},
#   'display': 'NCBIGene(920) ENSEMBL(ENSG00000010610) HGNC(1678) UMLS(C1332714) UNIPROTKB(P01730) SYMBOL(CD4)',
#   'type': 'Gene'},
#  {'NCBIGene': '6347',
#   'name': 'C-C motif chemokine ligand 2',
#   'SYMBOL': 'CCL2',
#   'UMLS': 'C1337092',
#   'HGNC': '10618',
#   'UNIPROTKB': 'P13500',
#   'ENSEMBL': 'ENSG00000108691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6347'},
#   'display': 'NCBIGene(6347) ENSEMBL(ENSG00000108691) HGNC(10618) UMLS(C1337092) UNIPROTKB(P13500) SYMBOL(CCL2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3558',
#   'name': 'interleukin 2',
#   'SYMBOL': 'IL2',
#   'UMLS': 'C0879590',
#   'HGNC': '6001',
#   'UNIPROTKB': 'P60568',
#   'ENSEMBL': 'ENSG00000109471',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3558'},
#   'display': 'NCBIGene(3558) ENSEMBL(ENSG00000109471) HGNC(6001) UMLS(C0879590) UNIPROTKB(P60568) SYMBOL(IL2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3458',
#   'name': 'interferon gamma',
#   'SYMBOL': 'IFNG',
#   'UMLS': 'C1334085',
#   'HGNC': '5438',
#   'UNIPROTKB': 'P01579',
#   'ENSEMBL': 'ENSG00000111537',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3458'},
#   'display': 'NCBIGene(3458) ENSEMBL(ENSG00000111537) HGNC(5438) UMLS(C1334085) UNIPROTKB(P01579) SYMBOL(IFNG)',
#   'type': 'Gene'},
#  {'NCBIGene': '10045',
#   'name': 'SH2 domain containing 3A',
#   'SYMBOL': 'SH2D3A',
#   'UMLS': 'C1335817',
#   'HGNC': '16885',
#   'UNIPROTKB': 'Q9BRG2',
#   'ENSEMBL': 'ENSG00000125731',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10045'},
#   'display': 'NCBIGene(10045) ENSEMBL(ENSG00000125731) HGNC(16885) UMLS(C1335817) UNIPROTKB(Q9BRG2) SYMBOL(SH2D3A)',
#   'type': 'Gene'},
#  {'NCBIGene': '3553',
#   'name': 'interleukin 1 beta',
#   'SYMBOL': 'IL1B',
#   'UMLS': 'C1334112',
#   'HGNC': '5992',
#   'UNIPROTKB': 'P01584',
#   'ENSEMBL': 'ENSG00000125538',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3553'},
#   'display': 'NCBIGene(3553) ENSEMBL(ENSG00000125538) HGNC(5992) UMLS(C1334112) UNIPROTKB(P01584) SYMBOL(IL1B)',
#   'type': 'Gene'},
#  {'NCBIGene': '3574',
#   'name': 'interleukin 7',
#   'SYMBOL': 'IL7',
#   'UMLS': 'C1334124',
#   'HGNC': '6023',
#   'UNIPROTKB': 'P13232',
#   'ENSEMBL': 'ENSG00000104432',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3574'},
#   'display': 'NCBIGene(3574) ENSEMBL(ENSG00000104432) HGNC(6023) UMLS(C1334124) UNIPROTKB(P13232) SYMBOL(IL7)',
#   'type': 'Gene'},
#  {'NCBIGene': '5972',
#   'name': 'renin',
#   'SYMBOL': 'REN',
#   'UMLS': 'C1419338',
#   'HGNC': '9958',
#   'UNIPROTKB': 'P00797',
#   'ENSEMBL': 'ENSG00000143839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5972'},
#   'display': 'NCBIGene(5972) ENSEMBL(ENSG00000143839) HGNC(9958) UMLS(C1419338) UNIPROTKB(P00797) SYMBOL(REN)',
#   'type': 'Gene'},
#  {'NCBIGene': '3439',
#   'name': 'interferon alpha 1',
#   'SYMBOL': 'IFNA1',
#   'UMLS': 'C1415900',
#   'HGNC': '5417',
#   'UNIPROTKB': 'P01562',
#   'ENSEMBL': 'ENSG00000197919',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3439'},
#   'display': 'NCBIGene(3439) ENSEMBL(ENSG00000197919) HGNC(5417) UMLS(C1415900) UNIPROTKB(P01562) SYMBOL(IFNA1)',
#   'type': 'Gene'},
#  {'NCBIGene': '1636',
#   'name': 'angiotensin I converting enzyme',
#   'SYMBOL': 'ACE',
#   'UMLS': 'C1413931',
#   'HGNC': '2707',
#   'UNIPROTKB': 'P12821',
#   'ENSEMBL': 'ENSG00000159640',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1636'},
#   'display': 'NCBIGene(1636) ENSEMBL(ENSG00000159640) HGNC(2707) UMLS(C1413931) UNIPROTKB(P12821) SYMBOL(ACE)',
#   'type': 'Gene'},
#  {'NCBIGene': '213',
#   'name': 'albumin',
#   'SYMBOL': 'ALB',
#   'UMLS': 'C1412332',
#   'HGNC': '399',
#   'UNIPROTKB': 'P02768',
#   'ENSEMBL': 'ENSG00000163631',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '213'},
#   'display': 'NCBIGene(213) ENSEMBL(ENSG00000163631) HGNC(399) UMLS(C1412332) UNIPROTKB(P02768) SYMBOL(ALB)',
#   'type': 'Gene'},
#  {'NCBIGene': '3627',
#   'name': 'C-X-C motif chemokine ligand 10',
#   'SYMBOL': 'CXCL10',
#   'UMLS': 'C1367714',
#   'HGNC': '10637',
#   'UNIPROTKB': 'P02778',
#   'ENSEMBL': 'ENSG00000169245',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3627'},
#   'display': 'NCBIGene(3627) ENSEMBL(ENSG00000169245) HGNC(10637) UMLS(C1367714) UNIPROTKB(P02778) SYMBOL(CXCL10)',
#   'type': 'Gene'},
#  {'NCBIGene': '3576',
#   'name': 'C-X-C motif chemokine ligand 8',
#   'SYMBOL': 'CXCL8',
#   'UMLS': 'C1366571',
#   'HGNC': '6025',
#   'UNIPROTKB': 'P10145',
#   'ENSEMBL': 'ENSG00000169429',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3576'},
#   'display': 'NCBIGene(3576) ENSEMBL(ENSG00000169429) HGNC(6025) UMLS(C1366571) UNIPROTKB(P10145) SYMBOL(CXCL8)',
#   'type': 'Gene'},
#  {'NCBIGene': '2147',
#   'name': 'coagulation factor II, thrombin',
#   'SYMBOL': 'F2',
#   'UMLS': 'C1414504',
#   'HGNC': '3535',
#   'UNIPROTKB': 'P00734',
#   'ENSEMBL': 'ENSG00000180210',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2147'},
#   'display': 'NCBIGene(2147) ENSEMBL(ENSG00000180210) HGNC(3535) UMLS(C1414504) UNIPROTKB(P00734) SYMBOL(F2)',
#   'type': 'Gene'},
#  {'NCBIGene': '6868',
#   'name': 'ADAM metallopeptidase domain 17',
#   'SYMBOL': 'ADAM17',
#   'UMLS': 'C1412186',
#   'HGNC': '195',
#   'UNIPROTKB': 'P78536',
#   'ENSEMBL': 'ENSG00000151694',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6868'},
#   'display': 'NCBIGene(6868) ENSEMBL(ENSG00000151694) HGNC(195) UMLS(C1412186) UNIPROTKB(P78536) SYMBOL(ADAM17)',
#   'type': 'Gene'},
#  {'NCBIGene': '10044',
#   'name': 'SH2 domain containing 3C',
#   'SYMBOL': 'SH2D3C',
#   'UMLS': 'C1335818',
#   'HGNC': '16884',
#   'UNIPROTKB': 'Q8N5H7',
#   'ENSEMBL': 'ENSG00000095370',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10044'},
#   'display': 'NCBIGene(10044) ENSEMBL(ENSG00000095370) HGNC(16884) UMLS(C1335818) UNIPROTKB(Q8N5H7) SYMBOL(SH2D3C)',
#   'type': 'Gene'},
#  {'NCBIGene': '682',
#   'name': 'basigin (Ok blood group)',
#   'SYMBOL': 'BSG',
#   'UMLS': 'C1412828',
#   'HGNC': '1116',
#   'UNIPROTKB': 'P35613',
#   'ENSEMBL': 'ENSG00000172270',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '682'},
#   'display': 'NCBIGene(682) ENSEMBL(ENSG00000172270) HGNC(1116) UMLS(C1412828) UNIPROTKB(P35613) SYMBOL(BSG)',
#   'type': 'Gene'},
#  {'NCBIGene': '2152',
#   'name': 'coagulation factor III, tissue factor',
#   'SYMBOL': 'F3',
#   'UMLS': 'C1333522',
#   'HGNC': '3541',
#   'UNIPROTKB': 'P13726',
#   'ENSEMBL': 'ENSG00000117525',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2152'},
#   'display': 'NCBIGene(2152) ENSEMBL(ENSG00000117525) HGNC(3541) UMLS(C1333522) UNIPROTKB(P13726) SYMBOL(F3)',
#   'type': 'Gene'},
#  {'NCBIGene': '7137',
#   'name': 'troponin I3, cardiac type',
#   'SYMBOL': 'TNNI3',
#   'UMLS': 'C1420826',
#   'HGNC': '11947',
#   'UNIPROTKB': 'P19429',
#   'ENSEMBL': 'ENSG00000129991',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7137'},
#   'display': 'NCBIGene(7137) ENSEMBL(ENSG00000129991) HGNC(11947) UMLS(C1420826) UNIPROTKB(P19429) SYMBOL(TNNI3)',
#   'type': 'Gene'},
#  {'NCBIGene': '3605',
#   'name': 'interleukin 17A',
#   'SYMBOL': 'IL17A',
#   'UMLS': 'C1825592',
#   'HGNC': '5981',
#   'UNIPROTKB': 'Q16552',
#   'ENSEMBL': 'ENSG00000112115',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3605'},
#   'display': 'NCBIGene(3605) ENSEMBL(ENSG00000112115) HGNC(5981) UMLS(C1825592) UNIPROTKB(Q16552) SYMBOL(IL17A)',
#   'type': 'Gene'},
#  {'NCBIGene': '1514',
#   'name': 'cathepsin L',
#   'SYMBOL': 'CTSL',
#   'UMLS': 'C1332807',
#   'HGNC': '2537',
#   'UNIPROTKB': 'P07711',
#   'ENSEMBL': 'ENSG00000135047',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1514'},
#   'display': 'NCBIGene(1514) ENSEMBL(ENSG00000135047) HGNC(2537) UMLS(C1332807) UNIPROTKB(P07711) SYMBOL(CTSL)',
#   'type': 'Gene'},
#  {'NCBIGene': '1803',
#   'name': 'dipeptidyl peptidase 4',
#   'SYMBOL': 'DPP4',
#   'UMLS': 'C1414141',
#   'HGNC': '3009',
#   'UNIPROTKB': 'P27487',
#   'ENSEMBL': 'ENSG00000197635',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1803'},
#   'display': 'NCBIGene(1803) ENSEMBL(ENSG00000197635) HGNC(3009) UMLS(C1414141) UNIPROTKB(P27487) SYMBOL(DPP4)',
#   'type': 'Gene'},
#  {'NCBIGene': '186',
#   'name': 'angiotensin II receptor type 2',
#   'SYMBOL': 'AGTR2',
#   'UMLS': 'C1332036',
#   'HGNC': '338',
#   'UNIPROTKB': 'P50052',
#   'ENSEMBL': 'ENSG00000180772',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '186'},
#   'display': 'NCBIGene(186) ENSEMBL(ENSG00000180772) HGNC(338) UMLS(C1332036) UNIPROTKB(P50052) SYMBOL(AGTR2)',
#   'type': 'Gene'},
#  {'NCBIGene': '10473',
#   'name': 'high mobility group nucleosomal binding domain 4',
#   'SYMBOL': 'HMGN4',
#   'UMLS': 'C1333916',
#   'HGNC': '4989',
#   'UNIPROTKB': 'O00479',
#   'ENSEMBL': 'ENSG00000182952',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10473'},
#   'display': 'NCBIGene(10473) ENSEMBL(ENSG00000182952) HGNC(4989) UMLS(C1333916) UNIPROTKB(O00479) SYMBOL(HMGN4)',
#   'type': 'Gene'},
#  {'NCBIGene': '3559',
#   'name': 'interleukin 2 receptor subunit alpha',
#   'SYMBOL': 'IL2RA',
#   'UMLS': 'C1334114',
#   'HGNC': '6008',
#   'UNIPROTKB': 'P01589',
#   'ENSEMBL': 'ENSG00000134460',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3559'},
#   'display': 'NCBIGene(3559) ENSEMBL(ENSG00000134460) HGNC(6008) UMLS(C1334114) UNIPROTKB(P01589) SYMBOL(IL2RA)',
#   'type': 'Gene'},
#  {'NCBIGene': '3456',
#   'name': 'interferon beta 1',
#   'SYMBOL': 'IFNB1',
#   'UMLS': 'C1415912',
#   'HGNC': '5434',
#   'UNIPROTKB': 'P01574',
#   'ENSEMBL': 'ENSG00000171855',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3456'},
#   'display': 'NCBIGene(3456) ENSEMBL(ENSG00000171855) HGNC(5434) UMLS(C1415912) UNIPROTKB(P01574) SYMBOL(IFNB1)',
#   'type': 'Gene'},
#  {'NCBIGene': '2875',
#   'name': 'glutamic--pyruvic transaminase',
#   'SYMBOL': 'GPT',
#   'UMLS': 'C1415274',
#   'HGNC': '4552',
#   'UNIPROTKB': 'P24298',
#   'ENSEMBL': 'ENSG00000167701',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2875'},
#   'display': 'NCBIGene(2875) ENSEMBL(ENSG00000167701) HGNC(4552) UMLS(C1415274) UNIPROTKB(P24298) SYMBOL(GPT)',
#   'type': 'Gene'},
#  {'NCBIGene': '4151',
#   'name': 'myoglobin',
#   'SYMBOL': 'MB',
#   'UMLS': 'C1417048',
#   'HGNC': '6915',
#   'UNIPROTKB': 'P02144',
#   'ENSEMBL': 'ENSG00000198125',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4151'},
#   'display': 'NCBIGene(4151) ENSEMBL(ENSG00000198125) HGNC(6915) UMLS(C1417048) UNIPROTKB(P02144) SYMBOL(MB)',
#   'type': 'Gene'},
#  {'NCBIGene': '10410',
#   'name': 'interferon induced transmembrane protein 3',
#   'SYMBOL': 'IFITM3',
#   'UMLS': 'C1415898',
#   'HGNC': '5414',
#   'UNIPROTKB': 'Q01628',
#   'ENSEMBL': 'ENSG00000142089',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10410'},
#   'display': 'NCBIGene(10410) ENSEMBL(ENSG00000142089) HGNC(5414) UMLS(C1415898) UNIPROTKB(Q01628) SYMBOL(IFITM3)',
#   'type': 'Gene'},
#  {'NCBIGene': '3569',
#   'name': 'interleukin 6',
#   'SYMBOL': 'IL6',
#   'UMLS': 'C1334122',
#   'HGNC': '6018',
#   'UNIPROTKB': 'P05231',
#   'ENSEMBL': 'ENSG00000136244',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3569'},
#   'display': 'NCBIGene(3569) ENSEMBL(ENSG00000136244) HGNC(6018) UMLS(C1334122) UNIPROTKB(P05231) SYMBOL(IL6)',
#   'type': 'Gene'},
#  {'NCBIGene': '925',
#   'name': 'CD8a molecule',
#   'SYMBOL': 'CD8A',
#   'UMLS': 'C1413244',
#   'HGNC': '1706',
#   'UNIPROTKB': 'P01732',
#   'ENSEMBL': 'ENSG00000153563',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '925'},
#   'display': 'NCBIGene(925) ENSEMBL(ENSG00000153563) HGNC(1706) UMLS(C1413244) UNIPROTKB(P01732) SYMBOL(CD8A)',
#   'type': 'Gene'},
#  {'NCBIGene': '7124',
#   'name': 'tumor necrosis factor',
#   'SYMBOL': 'TNF',
#   'UMLS': 'C0812246',
#   'HGNC': '11892',
#   'UNIPROTKB': 'P01375',
#   'ENSEMBL': 'ENSG00000204490',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7124'},
#   'display': 'NCBIGene(7124) ENSEMBL(ENSG00000204490) HGNC(11892) UMLS(C0812246) UNIPROTKB(P01375) SYMBOL(TNF)',
#   'type': 'Gene'},
#  {'NCBIGene': '3586',
#   'name': 'interleukin 10',
#   'SYMBOL': 'IL10',
#   'UMLS': 'C1334098',
#   'HGNC': '5962',
#   'UNIPROTKB': 'P22301',
#   'ENSEMBL': 'ENSG00000136634',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3586'},
#   'display': 'NCBIGene(3586) ENSEMBL(ENSG00000136634) HGNC(5962) UMLS(C1334098) UNIPROTKB(P22301) SYMBOL(IL10)',
#   'type': 'Gene'},
#  {'NCBIGene': '185',
#   'name': 'angiotensin II receptor type 1',
#   'SYMBOL': 'AGTR1',
#   'UMLS': 'C1439284',
#   'HGNC': '336',
#   'UNIPROTKB': 'P30556',
#   'ENSEMBL': 'ENSG00000144891',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '185'},
#   'display': 'NCBIGene(185) ENSEMBL(ENSG00000144891) HGNC(336) UMLS(C1439284) UNIPROTKB(P30556) SYMBOL(AGTR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '1506',
#   'name': 'chymotrypsin like',
#   'SYMBOL': 'CTRL',
#   'UMLS': 'C1413809',
#   'HGNC': '2524',
#   'UNIPROTKB': 'P40313',
#   'ENSEMBL': 'ENSG00000141086',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1506'},
#   'display': 'NCBIGene(1506) ENSEMBL(ENSG00000141086) HGNC(2524) UMLS(C1413809) UNIPROTKB(P40313) SYMBOL(CTRL)',
#   'type': 'Gene'},
#  {'NCBIGene': '54938',
#   'name': 'seryl-tRNA synthetase 2, mitochondrial',
#   'SYMBOL': 'SARS2',
#   'UMLS': 'C1425041',
#   'HGNC': '17697',
#   'UNIPROTKB': 'Q9NP81',
#   'ENSEMBL': 'ENSG00000104835',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '54938'},
#   'display': 'NCBIGene(54938) ENSEMBL(ENSG00000104835) HGNC(17697) UMLS(C1425041) UNIPROTKB(Q9NP81) SYMBOL(SARS2)',
#   'type': 'Gene'},
#  {'NCBIGene': '6348',
#   'name': 'C-C motif chemokine ligand 3',
#   'SYMBOL': 'CCL3',
#   'UMLS': 'C1332690',
#   'HGNC': '10627',
#   'UNIPROTKB': 'P10147',
#   'ENSEMBL': 'ENSG00000274221',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6348'},
#   'display': 'NCBIGene(6348) ENSEMBL(ENSG00000274221) HGNC(10627) UMLS(C1332690) UNIPROTKB(P10147) SYMBOL(CCL3)',
#   'type': 'Gene'},
#  {'NCBIGene': '5045',
#   'name': 'furin, paired basic amino acid cleaving enzyme',
#   'SYMBOL': 'FURIN',
#   'UMLS': 'C0919550',
#   'HGNC': '8568',
#   'UNIPROTKB': 'P09958',
#   'ENSEMBL': 'ENSG00000140564',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5045'},
#   'display': 'NCBIGene(5045) ENSEMBL(ENSG00000140564) HGNC(8568) UMLS(C0919550) UNIPROTKB(P09958) SYMBOL(FURIN)',
#   'type': 'Gene'},
#  {'NCBIGene': '7432',
#   'name': 'vasoactive intestinal peptide',
#   'SYMBOL': 'VIP',
#   'UMLS': 'C1366646',
#   'HGNC': '12693',
#   'UNIPROTKB': 'P01282',
#   'ENSEMBL': 'ENSG00000146469',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7432'},
#   'display': 'NCBIGene(7432) ENSEMBL(ENSG00000146469) HGNC(12693) UMLS(C1366646) UNIPROTKB(P01282) SYMBOL(VIP)',
#   'type': 'Gene'},
#  {'NCBIGene': '6376',
#   'name': 'C-X3-C motif chemokine ligand 1',
#   'SYMBOL': 'CX3CL1',
#   'UMLS': 'C1332814',
#   'HGNC': '10647',
#   'UNIPROTKB': 'P78423',
#   'ENSEMBL': 'ENSG00000006210',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6376'},
#   'display': 'NCBIGene(6376) ENSEMBL(ENSG00000006210) HGNC(10647) UMLS(C1332814) UNIPROTKB(P78423) SYMBOL(CX3CL1)',
#   'type': 'Gene'},
#  {'NCBIGene': '6775',
#   'name': 'signal transducer and activator of transcription 4',
#   'SYMBOL': 'STAT4',
#   'UMLS': 'C1335874',
#   'HGNC': '11365',
#   'UNIPROTKB': 'Q14765',
#   'ENSEMBL': 'ENSG00000138378',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6775'},
#   'display': 'NCBIGene(6775) ENSEMBL(ENSG00000138378) HGNC(11365) UMLS(C1335874) UNIPROTKB(Q14765) SYMBOL(STAT4)',
#   'type': 'Gene'},
#  {'NCBIGene': '6647',
#   'name': 'superoxide dismutase 1',
#   'SYMBOL': 'SOD1',
#   'UMLS': 'C1420306',
#   'HGNC': '11179',
#   'UNIPROTKB': 'P00441',
#   'ENSEMBL': 'ENSG00000142168',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6647'},
#   'display': 'NCBIGene(6647) ENSEMBL(ENSG00000142168) HGNC(11179) UMLS(C1420306) UNIPROTKB(P00441) SYMBOL(SOD1)',
#   'type': 'Gene'},
#  {'NCBIGene': '4851',
#   'name': 'notch receptor 1',
#   'SYMBOL': 'NOTCH1',
#   'UMLS': 'C1334889',
#   'HGNC': '7881',
#   'UNIPROTKB': 'P46531',
#   'ENSEMBL': 'ENSG00000148400',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4851'},
#   'display': 'NCBIGene(4851) ENSEMBL(ENSG00000148400) HGNC(7881) UMLS(C1334889) UNIPROTKB(P46531) SYMBOL(NOTCH1)',
#   'type': 'Gene'},
#  {'NCBIGene': '2247',
#   'name': 'fibroblast growth factor 2',
#   'SYMBOL': 'FGF2',
#   'UMLS': 'C0919506',
#   'HGNC': '3676',
#   'UNIPROTKB': 'P09038',
#   'ENSEMBL': 'ENSG00000138685',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2247'},
#   'display': 'NCBIGene(2247) ENSEMBL(ENSG00000138685) HGNC(3676) UMLS(C0919506) UNIPROTKB(P09038) SYMBOL(FGF2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3434',
#   'name': 'interferon induced protein with tetratricopeptide repeats 1',
#   'SYMBOL': 'IFIT1',
#   'UMLS': 'C1415892',
#   'HGNC': '5407',
#   'UNIPROTKB': 'P09914',
#   'ENSEMBL': 'ENSG00000185745',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3434'},
#   'display': 'NCBIGene(3434) ENSEMBL(ENSG00000185745) HGNC(5407) UMLS(C1415892) UNIPROTKB(P09914) SYMBOL(IFIT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '5715',
#   'name': 'proteasome 26S subunit, non-ATPase 9',
#   'SYMBOL': 'PSMD9',
#   'UMLS': 'C1419040',
#   'HGNC': '9567',
#   'UNIPROTKB': 'O00233',
#   'ENSEMBL': 'ENSG00000110801',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5715'},
#   'display': 'NCBIGene(5715) ENSEMBL(ENSG00000110801) HGNC(9567) UMLS(C1419040) UNIPROTKB(O00233) SYMBOL(PSMD9)',
#   'type': 'Gene'},
#  {'NCBIGene': '1958',
#   'name': 'early growth response 1',
#   'SYMBOL': 'EGR1',
#   'UMLS': 'C1414314',
#   'HGNC': '3238',
#   'UNIPROTKB': 'P18146',
#   'ENSEMBL': 'ENSG00000120738',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1958'},
#   'display': 'NCBIGene(1958) ENSEMBL(ENSG00000120738) HGNC(3238) UMLS(C1414314) UNIPROTKB(P18146) SYMBOL(EGR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '867',
#   'name': 'Cbl proto-oncogene',
#   'SYMBOL': 'CBL',
#   'UMLS': 'C0812242',
#   'HGNC': '1541',
#   'UNIPROTKB': 'P22681',
#   'ENSEMBL': 'ENSG00000110395',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '867'},
#   'display': 'NCBIGene(867) ENSEMBL(ENSG00000110395) HGNC(1541) UMLS(C0812242) UNIPROTKB(P22681) SYMBOL(CBL)',
#   'type': 'Gene'},
#  {'NCBIGene': '5894',
#   'name': 'Raf-1 proto-oncogene, serine/threonine kinase',
#   'SYMBOL': 'RAF1',
#   'UMLS': 'C0812215',
#   'HGNC': '9829',
#   'UNIPROTKB': 'P04049',
#   'ENSEMBL': 'ENSG00000132155',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5894'},
#   'display': 'NCBIGene(5894) ENSEMBL(ENSG00000132155) HGNC(9829) UMLS(C0812215) UNIPROTKB(P04049) SYMBOL(RAF1)',
#   'type': 'Gene'},
#  {'NCBIGene': '50943',
#   'name': 'forkhead box P3',
#   'SYMBOL': 'FOXP3',
#   'UMLS': 'C1416467',
#   'HGNC': '6106',
#   'UNIPROTKB': 'Q9BZS1',
#   'ENSEMBL': 'ENSG00000049768',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '50943'},
#   'display': 'NCBIGene(50943) ENSEMBL(ENSG00000049768) HGNC(6106) UMLS(C1416467) UNIPROTKB(Q9BZS1) SYMBOL(FOXP3)',
#   'type': 'Gene'},
#  {'NCBIGene': '9360',
#   'name': 'peptidylprolyl isomerase G',
#   'SYMBOL': 'PPIG',
#   'UMLS': 'C1422813',
#   'HGNC': '14650',
#   'UNIPROTKB': 'Q13427',
#   'ENSEMBL': 'ENSG00000138398',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9360'},
#   'display': 'NCBIGene(9360) ENSEMBL(ENSG00000138398) HGNC(14650) UMLS(C1422813) UNIPROTKB(Q13427) SYMBOL(PPIG)',
#   'type': 'Gene'},
#  {'NCBIGene': '1235',
#   'name': 'C-C motif chemokine receptor 6',
#   'SYMBOL': 'CCR6',
#   'UMLS': 'C1332701',
#   'HGNC': '1607',
#   'UNIPROTKB': 'P51684',
#   'ENSEMBL': 'ENSG00000112486',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1235'},
#   'display': 'NCBIGene(1235) ENSEMBL(ENSG00000112486) HGNC(1607) UMLS(C1332701) UNIPROTKB(P51684) SYMBOL(CCR6)',
#   'type': 'Gene'},
#  {'NCBIGene': '9242',
#   'name': 'musculin',
#   'SYMBOL': 'MSC',
#   'UMLS': 'C1334531',
#   'HGNC': '7321',
#   'UNIPROTKB': 'O60682',
#   'ENSEMBL': 'ENSG00000178860',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9242'},
#   'display': 'NCBIGene(9242) ENSEMBL(ENSG00000178860) HGNC(7321) UMLS(C1334531) UNIPROTKB(O60682) SYMBOL(MSC)',
#   'type': 'Gene'},
#  {'NCBIGene': '4023',
#   'name': 'lipoprotein lipase',
#   'SYMBOL': 'LPL',
#   'UMLS': 'C1416902',
#   'HGNC': '6677',
#   'UNIPROTKB': 'P06858',
#   'ENSEMBL': 'ENSG00000175445',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4023'},
#   'display': 'NCBIGene(4023) ENSEMBL(ENSG00000175445) HGNC(6677) UMLS(C1416902) UNIPROTKB(P06858) SYMBOL(LPL)',
#   'type': 'Gene'},
#  {'NCBIGene': '5743',
#   'name': 'prostaglandin-endoperoxide synthase 2',
#   'SYMBOL': 'PTGS2',
#   'UMLS': 'C1367485',
#   'HGNC': '9605',
#   'UNIPROTKB': 'P35354',
#   'ENSEMBL': 'ENSG00000073756',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5743'},
#   'display': 'NCBIGene(5743) ENSEMBL(ENSG00000073756) HGNC(9605) UMLS(C1367485) UNIPROTKB(P35354) SYMBOL(PTGS2)',
#   'type': 'Gene'},
#  {'NCBIGene': '22914',
#   'name': 'killer cell lectin like receptor K1',
#   'SYMBOL': 'KLRK1',
#   'UMLS': 'C1425775',
#   'HGNC': '18788',
#   'UNIPROTKB': 'P26718',
#   'ENSEMBL': 'ENSG00000213809',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '22914'},
#   'display': 'NCBIGene(22914) ENSEMBL(ENSG00000213809) HGNC(18788) UMLS(C1425775) UNIPROTKB(P26718) SYMBOL(KLRK1)',
#   'type': 'Gene'},
#  {'NCBIGene': '7132',
#   'name': 'TNF receptor superfamily member 1A',
#   'SYMBOL': 'TNFRSF1A',
#   'UMLS': 'C1363984',
#   'HGNC': '11916',
#   'UNIPROTKB': 'P19438',
#   'ENSEMBL': 'ENSG00000067182',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7132'},
#   'display': 'NCBIGene(7132) ENSEMBL(ENSG00000067182) HGNC(11916) UMLS(C1363984) UNIPROTKB(P19438) SYMBOL(TNFRSF1A)',
#   'type': 'Gene'},
#  {'NCBIGene': '581',
#   'name': 'BCL2 associated X, apoptosis regulator',
#   'SYMBOL': 'BAX',
#   'UMLS': 'C0812198',
#   'HGNC': '959',
#   'UNIPROTKB': 'Q07812',
#   'ENSEMBL': 'ENSG00000087088',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '581'},
#   'display': 'NCBIGene(581) ENSEMBL(ENSG00000087088) HGNC(959) UMLS(C0812198) UNIPROTKB(Q07812) SYMBOL(BAX)',
#   'type': 'Gene'},
#  {'NCBIGene': '7100',
#   'name': 'toll like receptor 5',
#   'SYMBOL': 'TLR5',
#   'UMLS': 'C1336637',
#   'HGNC': '11851',
#   'UNIPROTKB': 'O60602',
#   'ENSEMBL': 'ENSG00000187554',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7100'},
#   'display': 'NCBIGene(7100) ENSEMBL(ENSG00000187554) HGNC(11851) UMLS(C1336637) UNIPROTKB(O60602) SYMBOL(TLR5)',
#   'type': 'Gene'},
#  {'NCBIGene': '51311',
#   'name': 'toll like receptor 8',
#   'SYMBOL': 'TLR8',
#   'UMLS': 'C1336640',
#   'HGNC': '15632',
#   'UNIPROTKB': 'Q9NR97',
#   'ENSEMBL': 'ENSG00000101916',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '51311'},
#   'display': 'NCBIGene(51311) ENSEMBL(ENSG00000101916) HGNC(15632) UMLS(C1336640) UNIPROTKB(Q9NR97) SYMBOL(TLR8)',
#   'type': 'Gene'},
#  {'NCBIGene': '6646',
#   'name': 'sterol O-acyltransferase 1',
#   'SYMBOL': 'SOAT1',
#   'UMLS': 'C1420304',
#   'HGNC': '11177',
#   'UNIPROTKB': 'P35610',
#   'ENSEMBL': 'ENSG00000057252',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6646'},
#   'display': 'NCBIGene(6646) ENSEMBL(ENSG00000057252) HGNC(11177) UMLS(C1420304) UNIPROTKB(P35610) SYMBOL(SOAT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '387',
#   'name': 'ras homolog family member A',
#   'SYMBOL': 'RHOA',
#   'UMLS': 'C0812234',
#   'HGNC': '667',
#   'UNIPROTKB': 'P61586',
#   'ENSEMBL': 'ENSG00000067560',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '387'},
#   'display': 'NCBIGene(387) ENSEMBL(ENSG00000067560) HGNC(667) UMLS(C0812234) UNIPROTKB(P61586) SYMBOL(RHOA)',
#   'type': 'Gene'},
#  {'NCBIGene': '4283',
#   'name': 'C-X-C motif chemokine ligand 9',
#   'SYMBOL': 'CXCL9',
#   'UMLS': 'C1332821',
#   'HGNC': '7098',
#   'UNIPROTKB': 'Q07325',
#   'ENSEMBL': 'ENSG00000138755',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4283'},
#   'display': 'NCBIGene(4283) ENSEMBL(ENSG00000138755) HGNC(7098) UMLS(C1332821) UNIPROTKB(Q07325) SYMBOL(CXCL9)',
#   'type': 'Gene'},
#  {'NCBIGene': '3932',
#   'name': 'LCK proto-oncogene, Src family tyrosine kinase',
#   'SYMBOL': 'LCK',
#   'UMLS': 'C0919477',
#   'HGNC': '6524',
#   'UNIPROTKB': 'P06239',
#   'ENSEMBL': 'ENSG00000182866',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3932'},
#   'display': 'NCBIGene(3932) ENSEMBL(ENSG00000182866) HGNC(6524) UMLS(C0919477) UNIPROTKB(P06239) SYMBOL(LCK)',
#   'type': 'Gene'},
#  {'NCBIGene': '7018',
#   'name': 'transferrin',
#   'SYMBOL': 'TF',
#   'UMLS': 'C1442762',
#   'HGNC': '11740',
#   'UNIPROTKB': 'P02787',
#   'ENSEMBL': 'ENSG00000091513',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7018'},
#   'display': 'NCBIGene(7018) ENSEMBL(ENSG00000091513) HGNC(11740) UMLS(C1442762) UNIPROTKB(P02787) SYMBOL(TF)',
#   'type': 'Gene'},
#  {'NCBIGene': '5966',
#   'name': 'REL proto-oncogene, NF-kB subunit',
#   'SYMBOL': 'REL',
#   'UMLS': 'C0035018',
#   'HGNC': '9954',
#   'UNIPROTKB': 'Q04864',
#   'ENSEMBL': 'ENSG00000162924',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5966'},
#   'display': 'NCBIGene(5966) ENSEMBL(ENSG00000162924) HGNC(9954) UMLS(C0035018) UNIPROTKB(Q04864) SYMBOL(REL)',
#   'type': 'Gene'},
#  {'NCBIGene': '3429',
#   'name': 'interferon alpha inducible protein 27',
#   'SYMBOL': 'IFI27',
#   'UMLS': 'C1415887',
#   'HGNC': '5397',
#   'UNIPROTKB': 'P40305',
#   'ENSEMBL': 'ENSG00000165949',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3429'},
#   'display': 'NCBIGene(3429) ENSEMBL(ENSG00000165949) HGNC(5397) UMLS(C1415887) UNIPROTKB(P40305) SYMBOL(IFI27)',
#   'type': 'Gene'},
#  {'NCBIGene': '3565',
#   'name': 'interleukin 4',
#   'SYMBOL': 'IL4',
#   'UMLS': 'C1334119',
#   'HGNC': '6014',
#   'UNIPROTKB': 'P05112',
#   'ENSEMBL': 'ENSG00000113520',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3565'},
#   'display': 'NCBIGene(3565) ENSEMBL(ENSG00000113520) HGNC(6014) UMLS(C1334119) UNIPROTKB(P05112) SYMBOL(IL4)',
#   'type': 'Gene'},
#  {'NCBIGene': '3976',
#   'name': 'LIF interleukin 6 family cytokine',
#   'SYMBOL': 'LIF',
#   'UMLS': 'C1366463',
#   'HGNC': '6596',
#   'UNIPROTKB': 'P15018',
#   'ENSEMBL': 'ENSG00000128342',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3976'},
#   'display': 'NCBIGene(3976) ENSEMBL(ENSG00000128342) HGNC(6596) UMLS(C1366463) UNIPROTKB(P15018) SYMBOL(LIF)',
#   'type': 'Gene'},
#  {'NCBIGene': '729230',
#   'name': 'C-C motif chemokine receptor 2',
#   'SYMBOL': 'CCR2',
#   'UMLS': 'C1413188',
#   'HGNC': '1603',
#   'UNIPROTKB': 'P41597',
#   'ENSEMBL': 'ENSG00000121807',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '729230'},
#   'display': 'NCBIGene(729230) ENSEMBL(ENSG00000121807) HGNC(1603) UMLS(C1413188) UNIPROTKB(P41597) SYMBOL(CCR2)',
#   'type': 'Gene'},
#  {'NCBIGene': '2821',
#   'name': 'glucose-6-phosphate isomerase',
#   'SYMBOL': 'GPI',
#   'UMLS': 'C1333690',
#   'HGNC': '4458',
#   'UNIPROTKB': 'P06744',
#   'ENSEMBL': 'ENSG00000105220',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2821'},
#   'display': 'NCBIGene(2821) ENSEMBL(ENSG00000105220) HGNC(4458) UMLS(C1333690) UNIPROTKB(P06744) SYMBOL(GPI)',
#   'type': 'Gene'},
#  {'NCBIGene': '182',
#   'name': 'jagged canonical Notch ligand 1',
#   'SYMBOL': 'JAG1',
#   'UMLS': 'C1416525',
#   'HGNC': '6188',
#   'UNIPROTKB': 'P78504',
#   'ENSEMBL': 'ENSG00000101384',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '182'},
#   'display': 'NCBIGene(182) ENSEMBL(ENSG00000101384) HGNC(6188) UMLS(C1416525) UNIPROTKB(P78504) SYMBOL(JAG1)',
#   'type': 'Gene'},
#  {'NCBIGene': '2214',
#   'name': 'Fc fragment of IgG receptor IIIa',
#   'SYMBOL': 'FCGR3A',
#   'UMLS': 'C1414555',
#   'HGNC': '3619',
#   'UNIPROTKB': 'P08637',
#   'ENSEMBL': 'ENSG00000203747',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2214'},
#   'display': 'NCBIGene(2214) ENSEMBL(ENSG00000203747) HGNC(3619) UMLS(C1414555) UNIPROTKB(P08637) SYMBOL(FCGR3A)',
#   'type': 'Gene'},
#  {'NCBIGene': '1230',
#   'name': 'C-C motif chemokine receptor 1',
#   'SYMBOL': 'CCR1',
#   'UMLS': 'C1332699',
#   'HGNC': '1602',
#   'UNIPROTKB': 'P32246',
#   'ENSEMBL': 'ENSG00000163823',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1230'},
#   'display': 'NCBIGene(1230) ENSEMBL(ENSG00000163823) HGNC(1602) UMLS(C1332699) UNIPROTKB(P32246) SYMBOL(CCR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3454',
#   'name': 'interferon alpha and beta receptor subunit 1',
#   'SYMBOL': 'IFNAR1',
#   'UMLS': 'C1334081',
#   'HGNC': '5432',
#   'UNIPROTKB': 'P17181',
#   'ENSEMBL': 'ENSG00000142166',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3454'},
#   'display': 'NCBIGene(3454) ENSEMBL(ENSG00000142166) HGNC(5432) UMLS(C1334081) UNIPROTKB(P17181) SYMBOL(IFNAR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '156',
#   'name': 'G protein-coupled receptor kinase 2',
#   'SYMBOL': 'GRK2',
#   'UMLS': 'C1366490',
#   'HGNC': '289',
#   'UNIPROTKB': 'P25098',
#   'ENSEMBL': 'ENSG00000173020',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '156'},
#   'display': 'NCBIGene(156) ENSEMBL(ENSG00000173020) HGNC(289) UMLS(C1366490) UNIPROTKB(P25098) SYMBOL(GRK2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3687',
#   'name': 'integrin subunit alpha X',
#   'SYMBOL': 'ITGAX',
#   'UMLS': 'C1334145',
#   'HGNC': '6152',
#   'UNIPROTKB': 'P20702',
#   'ENSEMBL': 'ENSG00000140678',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3687'},
#   'display': 'NCBIGene(3687) ENSEMBL(ENSG00000140678) HGNC(6152) UMLS(C1334145) UNIPROTKB(P20702) SYMBOL(ITGAX)',
#   'type': 'Gene'},
#  {'NCBIGene': '2475',
#   'name': 'mechanistic target of rapamycin kinase',
#   'SYMBOL': 'MTOR',
#   'UMLS': 'C1414805',
#   'HGNC': '3942',
#   'UNIPROTKB': 'P42345',
#   'ENSEMBL': 'ENSG00000198793',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2475'},
#   'display': 'NCBIGene(2475) ENSEMBL(ENSG00000198793) HGNC(3942) UMLS(C1414805) UNIPROTKB(P42345) SYMBOL(MTOR)',
#   'type': 'Gene'},
#  {'NCBIGene': '6402',
#   'name': 'selectin L',
#   'SYMBOL': 'SELL',
#   'UMLS': 'C1335808',
#   'HGNC': '10720',
#   'UNIPROTKB': 'P14151',
#   'ENSEMBL': 'ENSG00000188404',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6402'},
#   'display': 'NCBIGene(6402) ENSEMBL(ENSG00000188404) HGNC(10720) UMLS(C1335808) UNIPROTKB(P14151) SYMBOL(SELL)',
#   'type': 'Gene'},
#  {'NCBIGene': '9338',
#   'name': 'transcription elongation factor A like 1',
#   'SYMBOL': 'TCEAL1',
#   'UMLS': 'C1420626',
#   'HGNC': '11616',
#   'UNIPROTKB': 'Q15170',
#   'ENSEMBL': 'ENSG00000172465',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9338'},
#   'display': 'NCBIGene(9338) ENSEMBL(ENSG00000172465) HGNC(11616) UMLS(C1420626) UNIPROTKB(Q15170) SYMBOL(TCEAL1)',
#   'type': 'Gene'},
#  {'NCBIGene': '6772',
#   'name': 'signal transducer and activator of transcription 1',
#   'SYMBOL': 'STAT1',
#   'UMLS': 'C1335872',
#   'HGNC': '11362',
#   'UNIPROTKB': 'P42224',
#   'ENSEMBL': 'ENSG00000115415',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6772'},
#   'display': 'NCBIGene(6772) ENSEMBL(ENSG00000115415) HGNC(11362) UMLS(C1335872) UNIPROTKB(P42224) SYMBOL(STAT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '146',
#   'name': 'adrenoceptor alpha 1D',
#   'SYMBOL': 'ADRA1D',
#   'UMLS': 'C1412260',
#   'HGNC': '280',
#   'UNIPROTKB': 'P25100',
#   'ENSEMBL': 'ENSG00000171873',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '146'},
#   'display': 'NCBIGene(146) ENSEMBL(ENSG00000171873) HGNC(280) UMLS(C1412260) UNIPROTKB(P25100) SYMBOL(ADRA1D)',
#   'type': 'Gene'},
#  {'NCBIGene': '5967',
#   'name': 'regenerating family member 1 alpha',
#   'SYMBOL': 'REG1A',
#   'UMLS': 'C1419333',
#   'HGNC': '9951',
#   'UNIPROTKB': 'P05451',
#   'ENSEMBL': 'ENSG00000115386',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5967'},
#   'display': 'NCBIGene(5967) ENSEMBL(ENSG00000115386) HGNC(9951) UMLS(C1419333) UNIPROTKB(P05451) SYMBOL(REG1A)',
#   'type': 'Gene'},
#  {'NCBIGene': '728',
#   'name': 'complement C5a receptor 1',
#   'SYMBOL': 'C5AR1',
#   'UMLS': 'C1824180',
#   'HGNC': '1338',
#   'UNIPROTKB': 'P21730',
#   'ENSEMBL': 'ENSG00000197405',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '728'},
#   'display': 'NCBIGene(728) ENSEMBL(ENSG00000197405) HGNC(1338) UMLS(C1824180) UNIPROTKB(P21730) SYMBOL(C5AR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '930',
#   'name': 'CD19 molecule',
#   'SYMBOL': 'CD19',
#   'UMLS': 'C1413206',
#   'HGNC': '1633',
#   'UNIPROTKB': 'P15391',
#   'ENSEMBL': 'ENSG00000177455',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '930'},
#   'display': 'NCBIGene(930) ENSEMBL(ENSG00000177455) HGNC(1633) UMLS(C1413206) UNIPROTKB(P15391) SYMBOL(CD19)',
#   'type': 'Gene'},
#  {'NCBIGene': '7076',
#   'name': 'TIMP metallopeptidase inhibitor 1',
#   'SYMBOL': 'TIMP1',
#   'UMLS': 'C1367459',
#   'HGNC': '11820',
#   'UNIPROTKB': 'P01033',
#   'ENSEMBL': 'ENSG00000102265',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7076'},
#   'display': 'NCBIGene(7076) ENSEMBL(ENSG00000102265) HGNC(11820) UMLS(C1367459) UNIPROTKB(P01033) SYMBOL(TIMP1)',
#   'type': 'Gene'},
#  {'NCBIGene': '2920',
#   'name': 'C-X-C motif chemokine ligand 2',
#   'SYMBOL': 'CXCL2',
#   'UMLS': 'C0812310',
#   'HGNC': '4603',
#   'UNIPROTKB': 'P19875',
#   'ENSEMBL': 'ENSG00000081041',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2920'},
#   'display': 'NCBIGene(2920) ENSEMBL(ENSG00000081041) HGNC(4603) UMLS(C0812310) UNIPROTKB(P19875) SYMBOL(CXCL2)',
#   'type': 'Gene'},
#  {'NCBIGene': '4015',
#   'name': 'lysyl oxidase',
#   'SYMBOL': 'LOX',
#   'UMLS': 'C1334349',
#   'HGNC': '6664',
#   'UNIPROTKB': 'P28300',
#   'ENSEMBL': 'ENSG00000113083',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4015'},
#   'display': 'NCBIGene(4015) ENSEMBL(ENSG00000113083) HGNC(6664) UMLS(C1334349) UNIPROTKB(P28300) SYMBOL(LOX)',
#   'type': 'Gene'},
#  {'NCBIGene': '3659',
#   'name': 'interferon regulatory factor 1',
#   'SYMBOL': 'IRF1',
#   'UMLS': 'C1366516',
#   'HGNC': '6116',
#   'UNIPROTKB': 'P10914',
#   'ENSEMBL': 'ENSG00000125347',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3659'},
#   'display': 'NCBIGene(3659) ENSEMBL(ENSG00000125347) HGNC(6116) UMLS(C1366516) UNIPROTKB(P10914) SYMBOL(IRF1)',
#   'type': 'Gene'},
#  {'NCBIGene': '4684',
#   'name': 'neural cell adhesion molecule 1',
#   'SYMBOL': 'NCAM1',
#   'UMLS': 'C1334863',
#   'HGNC': '7656',
#   'UNIPROTKB': 'P13591',
#   'ENSEMBL': 'ENSG00000149294',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4684'},
#   'display': 'NCBIGene(4684) ENSEMBL(ENSG00000149294) HGNC(7656) UMLS(C1334863) UNIPROTKB(P13591) SYMBOL(NCAM1)',
#   'type': 'Gene'},
#  {'NCBIGene': '6667',
#   'name': 'Sp1 transcription factor',
#   'SYMBOL': 'SP1',
#   'UMLS': 'C1335858',
#   'HGNC': '11205',
#   'UNIPROTKB': 'P08047',
#   'ENSEMBL': 'ENSG00000185591',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6667'},
#   'display': 'NCBIGene(6667) ENSEMBL(ENSG00000185591) HGNC(11205) UMLS(C1335858) UNIPROTKB(P08047) SYMBOL(SP1)',
#   'type': 'Gene'},
#  {'NCBIGene': '973',
#   'name': 'CD79a molecule',
#   'SYMBOL': 'CD79A',
#   'UMLS': 'C1413238',
#   'HGNC': '1698',
#   'UNIPROTKB': 'P11912',
#   'ENSEMBL': 'ENSG00000105369',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '973'},
#   'display': 'NCBIGene(973) ENSEMBL(ENSG00000105369) HGNC(1698) UMLS(C1413238) UNIPROTKB(P11912) SYMBOL(CD79A)',
#   'type': 'Gene'},
#  {'NCBIGene': '51284',
#   'name': 'toll like receptor 7',
#   'SYMBOL': 'TLR7',
#   'UMLS': 'C1336639',
#   'HGNC': '15631',
#   'UNIPROTKB': 'Q9NYK1',
#   'ENSEMBL': 'ENSG00000196664',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '51284'},
#   'display': 'NCBIGene(51284) ENSEMBL(ENSG00000196664) HGNC(15631) UMLS(C1336639) UNIPROTKB(Q9NYK1) SYMBOL(TLR7)',
#   'type': 'Gene'},
#  {'NCBIGene': '6364',
#   'name': 'C-C motif chemokine ligand 20',
#   'SYMBOL': 'CCL20',
#   'UMLS': 'C1366524',
#   'HGNC': '10619',
#   'UNIPROTKB': 'P78556',
#   'ENSEMBL': 'ENSG00000115009',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6364'},
#   'display': 'NCBIGene(6364) ENSEMBL(ENSG00000115009) HGNC(10619) UMLS(C1366524) UNIPROTKB(P78556) SYMBOL(CCL20)',
#   'type': 'Gene'},
#  {'NCBIGene': '3700',
#   'name': 'inter-alpha-trypsin inhibitor heavy chain 4',
#   'SYMBOL': 'ITIH4',
#   'UMLS': 'C1416509',
#   'HGNC': '6169',
#   'UNIPROTKB': 'Q14624',
#   'ENSEMBL': 'ENSG00000055955',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3700'},
#   'display': 'NCBIGene(3700) ENSEMBL(ENSG00000055955) HGNC(6169) UMLS(C1416509) UNIPROTKB(Q14624) SYMBOL(ITIH4)',
#   'type': 'Gene'},
#  {'NCBIGene': '3930',
#   'name': 'lamin B receptor',
#   'SYMBOL': 'LBR',
#   'UMLS': 'C1416802',
#   'HGNC': '6518',
#   'UNIPROTKB': 'Q14739',
#   'ENSEMBL': 'ENSG00000143815',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3930'},
#   'display': 'NCBIGene(3930) ENSEMBL(ENSG00000143815) HGNC(6518) UMLS(C1416802) UNIPROTKB(Q14739) SYMBOL(LBR)',
#   'type': 'Gene'},
#  {'NCBIGene': '5741',
#   'name': 'parathyroid hormone',
#   'SYMBOL': 'PTH',
#   'UMLS': 'C1419072',
#   'HGNC': '9606',
#   'UNIPROTKB': 'P01270',
#   'ENSEMBL': 'ENSG00000152266',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5741'},
#   'display': 'NCBIGene(5741) ENSEMBL(ENSG00000152266) HGNC(9606) UMLS(C1419072) UNIPROTKB(P01270) SYMBOL(PTH)',
#   'type': 'Gene'},
#  {'NCBIGene': '27352',
#   'name': 'small G protein signaling modulator 3',
#   'SYMBOL': 'SGSM3',
#   'UMLS': 'C1428456',
#   'HGNC': '25228',
#   'UNIPROTKB': 'Q96HU1',
#   'ENSEMBL': 'ENSG00000100359',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '27352'},
#   'display': 'NCBIGene(27352) ENSEMBL(ENSG00000100359) HGNC(25228) UMLS(C1428456) UNIPROTKB(Q96HU1) SYMBOL(SGSM3)',
#   'type': 'Gene'},
#  {'NCBIGene': '929',
#   'name': 'CD14 molecule',
#   'SYMBOL': 'CD14',
#   'UMLS': 'C1367477',
#   'HGNC': '1628',
#   'UNIPROTKB': 'P08571',
#   'ENSEMBL': 'ENSG00000170458',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '929'},
#   'display': 'NCBIGene(929) ENSEMBL(ENSG00000170458) HGNC(1628) UMLS(C1367477) UNIPROTKB(P08571) SYMBOL(CD14)',
#   'type': 'Gene'},
#  {'NCBIGene': '5781',
#   'name': 'protein tyrosine phosphatase non-receptor type 11',
#   'SYMBOL': 'PTPN11',
#   'UMLS': 'C1335280',
#   'HGNC': '9644',
#   'UNIPROTKB': 'Q06124',
#   'ENSEMBL': 'ENSG00000179295',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5781'},
#   'display': 'NCBIGene(5781) ENSEMBL(ENSG00000179295) HGNC(9644) UMLS(C1335280) UNIPROTKB(Q06124) SYMBOL(PTPN11)',
#   'type': 'Gene'},
#  {'NCBIGene': '4615',
#   'name': 'MYD88 innate immune signal transduction adaptor',
#   'SYMBOL': 'MYD88',
#   'UMLS': 'C1417530',
#   'HGNC': '7562',
#   'UNIPROTKB': 'Q99836',
#   'ENSEMBL': 'ENSG00000172936',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4615'},
#   'display': 'NCBIGene(4615) ENSEMBL(ENSG00000172936) HGNC(7562) UMLS(C1417530) UNIPROTKB(Q99836) SYMBOL(MYD88)',
#   'type': 'Gene'},
#  {'NCBIGene': '5291',
#   'name': 'phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit beta',
#   'SYMBOL': 'PIK3CB',
#   'UMLS': 'C1335213',
#   'HGNC': '8976',
#   'UNIPROTKB': 'P42338',
#   'ENSEMBL': 'ENSG00000051382',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5291'},
#   'display': 'NCBIGene(5291) ENSEMBL(ENSG00000051382) HGNC(8976) UMLS(C1335213) UNIPROTKB(P42338) SYMBOL(PIK3CB)',
#   'type': 'Gene'},
#  {'NCBIGene': '6778',
#   'name': 'signal transducer and activator of transcription 6',
#   'SYMBOL': 'STAT6',
#   'UMLS': 'C1335877',
#   'HGNC': '11368',
#   'UNIPROTKB': 'P42226',
#   'ENSEMBL': 'ENSG00000166888',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6778'},
#   'display': 'NCBIGene(6778) ENSEMBL(ENSG00000166888) HGNC(11368) UMLS(C1335877) UNIPROTKB(P42226) SYMBOL(STAT6)',
#   'type': 'Gene'},
#  {'NCBIGene': '5054',
#   'name': 'serpin family E member 1',
#   'SYMBOL': 'SERPINE1',
#   'UMLS': 'C1418252',
#   'HGNC': '8583',
#   'UNIPROTKB': 'P05121',
#   'ENSEMBL': 'ENSG00000106366',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5054'},
#   'display': 'NCBIGene(5054) ENSEMBL(ENSG00000106366) HGNC(8583) UMLS(C1418252) UNIPROTKB(P05121) SYMBOL(SERPINE1)',
#   'type': 'Gene'},
#  {'NCBIGene': '960',
#   'name': 'CD44 molecule (Indian blood group)',
#   'SYMBOL': 'CD44',
#   'UMLS': 'C1332712',
#   'HGNC': '1681',
#   'UNIPROTKB': 'P16070',
#   'ENSEMBL': 'ENSG00000026508',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '960'},
#   'display': 'NCBIGene(960) ENSEMBL(ENSG00000026508) HGNC(1681) UMLS(C1332712) UNIPROTKB(P16070) SYMBOL(CD44)',
#   'type': 'Gene'},
#  {'NCBIGene': '4353',
#   'name': 'myeloperoxidase',
#   'SYMBOL': 'MPO',
#   'UMLS': 'C1417245',
#   'HGNC': '7218',
#   'UNIPROTKB': 'P05164',
#   'ENSEMBL': 'ENSG00000005381',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4353'},
#   'display': 'NCBIGene(4353) ENSEMBL(ENSG00000005381) HGNC(7218) UMLS(C1417245) UNIPROTKB(P05164) SYMBOL(MPO)',
#   'type': 'Gene'},
#  {'NCBIGene': '5465',
#   'name': 'peroxisome proliferator activated receptor alpha',
#   'SYMBOL': 'PPARA',
#   'UMLS': 'C1418776',
#   'HGNC': '9232',
#   'UNIPROTKB': 'Q07869',
#   'ENSEMBL': 'ENSG00000186951',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5465'},
#   'display': 'NCBIGene(5465) ENSEMBL(ENSG00000186951) HGNC(9232) UMLS(C1418776) UNIPROTKB(Q07869) SYMBOL(PPARA)',
#   'type': 'Gene'},
#  {'NCBIGene': '1026',
#   'name': 'cyclin dependent kinase inhibitor 1A',
#   'SYMBOL': 'CDKN1A',
#   'UMLS': 'C0249197',
#   'HGNC': '1784',
#   'UNIPROTKB': 'P38936',
#   'ENSEMBL': 'ENSG00000124762',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1026'},
#   'display': 'NCBIGene(1026) ENSEMBL(ENSG00000124762) HGNC(1784) UMLS(C0249197) UNIPROTKB(P38936) SYMBOL(CDKN1A)',
#   'type': 'Gene'},
#  {'NCBIGene': '3578',
#   'name': 'interleukin 9',
#   'SYMBOL': 'IL9',
#   'UMLS': 'C1334127',
#   'HGNC': '6029',
#   'UNIPROTKB': 'P15248',
#   'ENSEMBL': 'ENSG00000145839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3578'},
#   'display': 'NCBIGene(3578) ENSEMBL(ENSG00000145839) HGNC(6029) UMLS(C1334127) UNIPROTKB(P15248) SYMBOL(IL9)',
#   'type': 'Gene'},
#  {'NCBIGene': '3308',
#   'name': 'heat shock protein family A (Hsp70) member 4',
#   'SYMBOL': 'HSPA4',
#   'UMLS': 'C1415760',
#   'HGNC': '5237',
#   'UNIPROTKB': 'P34932',
#   'ENSEMBL': 'ENSG00000170606',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3308'},
#   'display': 'NCBIGene(3308) ENSEMBL(ENSG00000170606) HGNC(5237) UMLS(C1415760) UNIPROTKB(P34932) SYMBOL(HSPA4)',
#   'type': 'Gene'},
#  {'NCBIGene': '8600',
#   'name': 'TNF superfamily member 11',
#   'SYMBOL': 'TNFSF11',
#   'UMLS': 'C1367028',
#   'HGNC': '11926',
#   'UNIPROTKB': 'O14788',
#   'ENSEMBL': 'ENSG00000120659',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '8600'},
#   'display': 'NCBIGene(8600) ENSEMBL(ENSG00000120659) HGNC(11926) UMLS(C1367028) UNIPROTKB(O14788) SYMBOL(TNFSF11)',
#   'type': 'Gene'},
#  {'NCBIGene': '2099',
#   'name': 'estrogen receptor 1',
#   'SYMBOL': 'ESR1',
#   'UMLS': 'C1414461',
#   'HGNC': '3467',
#   'UNIPROTKB': 'P03372',
#   'ENSEMBL': 'ENSG00000091831',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2099'},
#   'display': 'NCBIGene(2099) ENSEMBL(ENSG00000091831) HGNC(3467) UMLS(C1414461) UNIPROTKB(P03372) SYMBOL(ESR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3661',
#   'name': 'interferon regulatory factor 3',
#   'SYMBOL': 'IRF3',
#   'UMLS': 'C1334139',
#   'HGNC': '6118',
#   'UNIPROTKB': 'Q14653',
#   'ENSEMBL': 'ENSG00000126456',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3661'},
#   'display': 'NCBIGene(3661) ENSEMBL(ENSG00000126456) HGNC(6118) UMLS(C1334139) UNIPROTKB(Q14653) SYMBOL(IRF3)',
#   'type': 'Gene'},
#  {'NCBIGene': '9021',
#   'name': 'suppressor of cytokine signaling 3',
#   'SYMBOL': 'SOCS3',
#   'UMLS': 'C1426212',
#   'HGNC': '19391',
#   'UNIPROTKB': 'O14543',
#   'ENSEMBL': 'ENSG00000184557',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9021'},
#   'display': 'NCBIGene(9021) ENSEMBL(ENSG00000184557) HGNC(19391) UMLS(C1426212) UNIPROTKB(O14543) SYMBOL(SOCS3)',
#   'type': 'Gene'},
#  {'NCBIGene': '1161',
#   'name': 'ERCC excision repair 8, CSA ubiquitin ligase complex subunit',
#   'SYMBOL': 'ERCC8',
#   'UMLS': 'C1414440',
#   'HGNC': '3439',
#   'UNIPROTKB': 'Q13216',
#   'ENSEMBL': 'ENSG00000049167',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1161'},
#   'display': 'NCBIGene(1161) ENSEMBL(ENSG00000049167) HGNC(3439) UMLS(C1414440) UNIPROTKB(Q13216) SYMBOL(ERCC8)',
#   'type': 'Gene'},
#  {'NCBIGene': '8795',
#   'name': 'TNF receptor superfamily member 10b',
#   'SYMBOL': 'TNFRSF10B',
#   'UMLS': 'C1336644',
#   'HGNC': '11905',
#   'UNIPROTKB': 'O14763',
#   'ENSEMBL': 'ENSG00000120889',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '8795'},
#   'display': 'NCBIGene(8795) ENSEMBL(ENSG00000120889) HGNC(11905) UMLS(C1336644) UNIPROTKB(O14763) SYMBOL(TNFRSF10B)',
#   'type': 'Gene'},
#  {'NCBIGene': '1442',
#   'name': 'chorionic somatomammotropin hormone 1',
#   'SYMBOL': 'CSH1',
#   'UMLS': 'C1413752',
#   'HGNC': '2440',
#   'UNIPROTKB': 'P0DML2',
#   'ENSEMBL': 'ENSG00000136488',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1442'},
#   'display': 'NCBIGene(1442) ENSEMBL(ENSG00000136488) HGNC(2440) UMLS(C1413752) UNIPROTKB(P0DML2) SYMBOL(CSH1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3313',
#   'name': 'heat shock protein family A (Hsp70) member 9',
#   'SYMBOL': 'HSPA9',
#   'UMLS': 'C1825549',
#   'HGNC': '5244',
#   'UNIPROTKB': 'P38646',
#   'ENSEMBL': 'ENSG00000113013',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3313'},
# ...
#   'UNIPROTKB': 'P08575',
#   'ENSEMBL': 'ENSG00000081237',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5788'},
#   'display': 'NCBIGene(5788) ENSEMBL(ENSG00000081237) HGNC(9666) UMLS(C1335285) UNIPROTKB(P08575) SYMBOL(PTPRC)',
#   'type': 'Gene'},
#  {'NCBIGene': '3562',
#   'name': 'interleukin 3',
#   'SYMBOL': 'IL3',
#   'UMLS': 'C1334117',
#   'HGNC': '6011',
#   'UNIPROTKB': 'P08700',
#   'ENSEMBL': 'ENSG00000164399',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3562'},
#   'display': 'NCBIGene(3562) ENSEMBL(ENSG00000164399) HGNC(6011) UMLS(C1334117) UNIPROTKB(P08700) SYMBOL(IL3)',
#   'type': 'Gene'},
#  {'NCBIGene': '969',
#   'name': 'CD69 molecule',
#   'SYMBOL': 'CD69',
#   'UMLS': 'C1413235',
#   'HGNC': '1694',
#   'UNIPROTKB': 'Q07108',
#   'ENSEMBL': 'ENSG00000110848',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '969'},
#   'display': 'NCBIGene(969) ENSEMBL(ENSG00000110848) HGNC(1694) UMLS(C1413235) UNIPROTKB(Q07108) SYMBOL(CD69)',
#   'type': 'Gene'},
#  {'NCBIGene': '6857',
#   'name': 'synaptotagmin 1',
#   'SYMBOL': 'SYT1',
#   'UMLS': 'C1420556',
#   'HGNC': '11509',
#   'UNIPROTKB': 'P21579',
#   'ENSEMBL': 'ENSG00000067715',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6857'},
#   'display': 'NCBIGene(6857) ENSEMBL(ENSG00000067715) HGNC(11509) UMLS(C1420556) UNIPROTKB(P21579) SYMBOL(SYT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '10598',
#   'name': 'activator of HSP90 ATPase activity 1',
#   'SYMBOL': 'AHSA1',
#   'UMLS': 'C1412886',
#   'HGNC': '1189',
#   'UNIPROTKB': 'O95433',
#   'ENSEMBL': 'ENSG00000100591',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10598'},
#   'display': 'NCBIGene(10598) ENSEMBL(ENSG00000100591) HGNC(1189) UMLS(C1412886) UNIPROTKB(O95433) SYMBOL(AHSA1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3952',
#   'name': 'leptin',
#   'SYMBOL': 'LEP',
#   'UMLS': 'C1416825',
#   'HGNC': '6553',
#   'UNIPROTKB': 'P41159',
#   'ENSEMBL': 'ENSG00000174697',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3952'},
#   'display': 'NCBIGene(3952) ENSEMBL(ENSG00000174697) HGNC(6553) UMLS(C1416825) UNIPROTKB(P41159) SYMBOL(LEP)',
#   'type': 'Gene'},
#  {'NCBIGene': '26073',
#   'name': 'DNA polymerase delta interacting protein 2',
#   'SYMBOL': 'POLDIP2',
#   'UMLS': 'C1428254',
#   'HGNC': '23781',
#   'UNIPROTKB': 'Q9Y2S7',
#   'ENSEMBL': 'ENSG00000004142',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '26073'},
#   'display': 'NCBIGene(26073) ENSEMBL(ENSG00000004142) HGNC(23781) UMLS(C1428254) UNIPROTKB(Q9Y2S7) SYMBOL(POLDIP2)',
#   'type': 'Gene'},
#  {'NCBIGene': '941',
#   'name': 'CD80 molecule',
#   'SYMBOL': 'CD80',
#   'UMLS': 'C1366561',
#   'HGNC': '1700',
#   'UNIPROTKB': 'P33681',
#   'ENSEMBL': 'ENSG00000121594',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '941'},
#   'display': 'NCBIGene(941) ENSEMBL(ENSG00000121594) HGNC(1700) UMLS(C1366561) UNIPROTKB(P33681) SYMBOL(CD80)',
#   'type': 'Gene'},
#  {'NCBIGene': '3497',
#   'name': 'immunoglobulin heavy constant epsilon',
#   'SYMBOL': 'IGHE',
#   'UMLS': 'C1415975',
#   'HGNC': '5522',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3497'},
#   'display': 'NCBIGene(3497) HGNC(5522) UMLS(C1415975) SYMBOL(IGHE)',
#   'type': 'Gene'},
#  {'NCBIGene': '7852',
#   'name': 'C-X-C motif chemokine receptor 4',
#   'SYMBOL': 'CXCR4',
#   'UMLS': 'C1332823',
#   'HGNC': '2561',
#   'UNIPROTKB': 'P61073',
#   'ENSEMBL': 'ENSG00000121966',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7852'},
#   'display': 'NCBIGene(7852) ENSEMBL(ENSG00000121966) HGNC(2561) UMLS(C1332823) UNIPROTKB(P61073) SYMBOL(CXCR4)',
#   'type': 'Gene'},
#  {'NCBIGene': '5290',
#   'name': 'phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha',
#   'SYMBOL': 'PIK3CA',
#   'UMLS': 'C1335212',
#   'HGNC': '8975',
#   'UNIPROTKB': 'P42336',
#   'ENSEMBL': 'ENSG00000121879',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5290'},
#   'display': 'NCBIGene(5290) ENSEMBL(ENSG00000121879) HGNC(8975) UMLS(C1335212) UNIPROTKB(P42336) SYMBOL(PIK3CA)',
#   'type': 'Gene'},
#  {'NCBIGene': '5443',
#   'name': 'proopiomelanocortin',
#   'SYMBOL': 'POMC',
#   'UMLS': 'C1337111',
#   'HGNC': '9201',
#   'UNIPROTKB': 'P01189',
#   'ENSEMBL': 'ENSG00000115138',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5443'},
#   'display': 'NCBIGene(5443) ENSEMBL(ENSG00000115138) HGNC(9201) UMLS(C1337111) UNIPROTKB(P01189) SYMBOL(POMC)',
#   'type': 'Gene'},
#  {'NCBIGene': '9402',
#   'name': 'GRB2 related adaptor protein 2',
#   'SYMBOL': 'GRAP2',
#   'UMLS': 'C1415284',
#   'HGNC': '4563',
#   'UNIPROTKB': 'O75791',
#   'ENSEMBL': 'ENSG00000100351',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9402'},
#   'display': 'NCBIGene(9402) ENSEMBL(ENSG00000100351) HGNC(4563) UMLS(C1415284) UNIPROTKB(O75791) SYMBOL(GRAP2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3684',
#   'name': 'integrin subunit alpha M',
#   'SYMBOL': 'ITGAM',
#   'UMLS': 'C1366562',
#   'HGNC': '6149',
#   'UNIPROTKB': 'P11215',
#   'ENSEMBL': 'ENSG00000169896',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3684'},
#   'display': 'NCBIGene(3684) ENSEMBL(ENSG00000169896) HGNC(6149) UMLS(C1366562) UNIPROTKB(P11215) SYMBOL(ITGAM)',
#   'type': 'Gene'},
#  {'NCBIGene': '355',
#   'name': 'Fas cell surface death receptor',
#   'SYMBOL': 'FAS',
#   'UMLS': 'C1539477',
#   'HGNC': '11920',
#   'UNIPROTKB': 'P25445',
#   'ENSEMBL': 'ENSG00000026103',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '355'},
#   'display': 'NCBIGene(355) ENSEMBL(ENSG00000026103) HGNC(11920) UMLS(C1539477) UNIPROTKB(P25445) SYMBOL(FAS)',
#   'type': 'Gene'},
#  {'NCBIGene': '760',
#   'name': 'carbonic anhydrase 2',
#   'SYMBOL': 'CA2',
#   'UMLS': 'C1413043',
#   'HGNC': '1373',
#   'UNIPROTKB': 'P00918',
#   'ENSEMBL': 'ENSG00000104267',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '760'},
#   'display': 'NCBIGene(760) ENSEMBL(ENSG00000104267) HGNC(1373) UMLS(C1413043) UNIPROTKB(P00918) SYMBOL(CA2)',
#   'type': 'Gene'},
#  {'NCBIGene': '4313',
#   'name': 'matrix metallopeptidase 2',
#   'SYMBOL': 'MMP2',
#   'UMLS': 'C1334522',
#   'HGNC': '7166',
#   'UNIPROTKB': 'P08253',
#   'ENSEMBL': 'ENSG00000087245',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4313'},
#   'display': 'NCBIGene(4313) ENSEMBL(ENSG00000087245) HGNC(7166) UMLS(C1334522) UNIPROTKB(P08253) SYMBOL(MMP2)',
#   'type': 'Gene'},
#  {'NCBIGene': '351',
#   'name': 'amyloid beta precursor protein',
#   'SYMBOL': 'APP',
#   'UMLS': 'C1364818',
#   'HGNC': '620',
#   'UNIPROTKB': 'P05067',
#   'ENSEMBL': 'ENSG00000142192',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '351'},
#   'display': 'NCBIGene(351) ENSEMBL(ENSG00000142192) HGNC(620) UMLS(C1364818) UNIPROTKB(P05067) SYMBOL(APP)',
#   'type': 'Gene'},
#  {'NCBIGene': '4318',
#   'name': 'matrix metallopeptidase 9',
#   'SYMBOL': 'MMP9',
#   'UMLS': 'C1334523',
#   'HGNC': '7176',
#   'UNIPROTKB': 'P14780',
#   'ENSEMBL': 'ENSG00000100985',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4318'},
#   'display': 'NCBIGene(4318) ENSEMBL(ENSG00000100985) HGNC(7176) UMLS(C1334523) UNIPROTKB(P14780) SYMBOL(MMP9)',
#   'type': 'Gene'},
#  {'NCBIGene': '1154',
#   'name': 'cytokine inducible SH2 containing protein',
#   'SYMBOL': 'CISH',
#   'UMLS': 'C1332762',
#   'HGNC': '1984',
#   'UNIPROTKB': 'Q9NSE2',
#   'ENSEMBL': 'ENSG00000114737',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1154'},
#   'display': 'NCBIGene(1154) ENSEMBL(ENSG00000114737) HGNC(1984) UMLS(C1332762) UNIPROTKB(Q9NSE2) SYMBOL(CISH)',
#   'type': 'Gene'},
#  {'NCBIGene': '940',
#   'name': 'CD28 molecule',
#   'SYMBOL': 'CD28',
#   'UMLS': 'C1332709',
#   'HGNC': '1653',
#   'UNIPROTKB': 'P10747',
#   'ENSEMBL': 'ENSG00000178562',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '940'},
#   'display': 'NCBIGene(940) ENSEMBL(ENSG00000178562) HGNC(1653) UMLS(C1332709) UNIPROTKB(P10747) SYMBOL(CD28)',
#   'type': 'Gene'},
#  {'NCBIGene': '1234',
#   'name': 'C-C motif chemokine receptor 5',
#   'SYMBOL': 'CCR5',
#   'UMLS': 'C1332700',
#   'HGNC': '1606',
#   'UNIPROTKB': 'P51681',
#   'ENSEMBL': 'ENSG00000160791',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1234'},
#   'display': 'NCBIGene(1234) ENSEMBL(ENSG00000160791) HGNC(1606) UMLS(C1332700) UNIPROTKB(P51681) SYMBOL(CCR5)',
#   'type': 'Gene'},
#  {'NCBIGene': '847',
#   'name': 'catalase',
#   'SYMBOL': 'CAT',
#   'UMLS': 'C1413138',
#   'HGNC': '1516',
#   'UNIPROTKB': 'P04040',
#   'ENSEMBL': 'ENSG00000121691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '847'},
#   'display': 'NCBIGene(847) ENSEMBL(ENSG00000121691) HGNC(1516) UMLS(C1413138) UNIPROTKB(P04040) SYMBOL(CAT)',
#   'type': 'Gene'},
#  {'NCBIGene': '7157',
#   'name': 'tumor protein p53',
#   'SYMBOL': 'TP53',
#   'UMLS': 'C0079419',
#   'HGNC': '11998',
#   'UNIPROTKB': 'P04637',
#   'ENSEMBL': 'ENSG00000141510',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7157'},
#   'display': 'NCBIGene(7157) ENSEMBL(ENSG00000141510) HGNC(11998) UMLS(C0079419) UNIPROTKB(P04637) SYMBOL(TP53)',
#   'type': 'Gene'},
#  {'NCBIGene': '1956',
#   'name': 'epidermal growth factor receptor',
#   'SYMBOL': 'EGFR',
#   'UMLS': 'C1414313',
#   'HGNC': '3236',
#   'UNIPROTKB': 'P00533',
#   'ENSEMBL': 'ENSG00000146648',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1956'},
#   'display': 'NCBIGene(1956) ENSEMBL(ENSG00000146648) HGNC(3236) UMLS(C1414313) UNIPROTKB(P00533) SYMBOL(EGFR)',
#   'type': 'Gene'},
#  {'NCBIGene': '5970',
#   'name': 'RELA proto-oncogene, NF-kB subunit',
#   'SYMBOL': 'RELA',
#   'UMLS': 'C1335610',
#   'HGNC': '9955',
#   'UNIPROTKB': 'Q04206',
#   'ENSEMBL': 'ENSG00000173039',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5970'},
#   'display': 'NCBIGene(5970) ENSEMBL(ENSG00000173039) HGNC(9955) UMLS(C1335610) UNIPROTKB(Q04206) SYMBOL(RELA)',
#   'type': 'Gene'},
#  {'NCBIGene': '472',
#   'name': 'ATM serine/threonine kinase',
#   'SYMBOL': 'ATM',
#   'UMLS': 'C0919524',
#   'HGNC': '795',
#   'UNIPROTKB': 'Q13315',
#   'ENSEMBL': 'ENSG00000149311',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '472'},
#   'display': 'NCBIGene(472) ENSEMBL(ENSG00000149311) HGNC(795) UMLS(C0919524) UNIPROTKB(Q13315) SYMBOL(ATM)',
#   'type': 'Gene'},
#  {'NCBIGene': '6776',
#   'name': 'signal transducer and activator of transcription 5A',
#   'SYMBOL': 'STAT5A',
#   'UMLS': 'C1335875',
#   'HGNC': '11366',
#   'UNIPROTKB': 'P42229',
#   'ENSEMBL': 'ENSG00000126561',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6776'},
#   'display': 'NCBIGene(6776) ENSEMBL(ENSG00000126561) HGNC(11366) UMLS(C1335875) UNIPROTKB(P42229) SYMBOL(STAT5A)',
#   'type': 'Gene'},
#  {'NCBIGene': '958',
#   'name': 'CD40 molecule',
#   'SYMBOL': 'CD40',
#   'UMLS': 'C1539081',
#   'HGNC': '11919',
#   'UNIPROTKB': 'P25942',
#   'ENSEMBL': 'ENSG00000101017',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '958'},
#   'display': 'NCBIGene(958) ENSEMBL(ENSG00000101017) HGNC(11919) UMLS(C1539081) UNIPROTKB(P25942) SYMBOL(CD40)',
#   'type': 'Gene'},
#  {'NCBIGene': '7099',
#   'name': 'toll like receptor 4',
#   'SYMBOL': 'TLR4',
#   'UMLS': 'C1336636',
#   'HGNC': '11850',
#   'UNIPROTKB': 'O00206',
#   'ENSEMBL': 'ENSG00000136869',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7099'},
#   'display': 'NCBIGene(7099) ENSEMBL(ENSG00000136869) HGNC(11850) UMLS(C1336636) UNIPROTKB(O00206) SYMBOL(TLR4)',
#   'type': 'Gene'},
#  {'NCBIGene': '3630',
#   'name': 'insulin',
#   'SYMBOL': 'INS',
#   'UMLS': 'C1337112',
#   'HGNC': '6081',
#   'UNIPROTKB': 'P01308',
#   'ENSEMBL': 'ENSG00000254647',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3630'},
#   'display': 'NCBIGene(3630) ENSEMBL(ENSG00000254647) HGNC(6081) UMLS(C1337112) UNIPROTKB(P01308) SYMBOL(INS)',
#   'type': 'Gene'},
#  {'NCBIGene': '6352',
#   'name': 'C-C motif chemokine ligand 5',
#   'SYMBOL': 'CCL5',
#   'UMLS': 'C1332691',
#   'HGNC': '10632',
#   'UNIPROTKB': 'P13501',
#   'ENSEMBL': 'ENSG00000271503',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6352'},
#   'display': 'NCBIGene(6352) ENSEMBL(ENSG00000271503) HGNC(10632) UMLS(C1332691) UNIPROTKB(P13501) SYMBOL(CCL5)',
#   'type': 'Gene'},
#  {'NCBIGene': '2353',
#   'name': 'Fos proto-oncogene, AP-1 transcription factor subunit',
#   'SYMBOL': 'FOS',
#   'UMLS': 'C0087140',
#   'HGNC': '3796',
#   'UNIPROTKB': 'P01100',
#   'ENSEMBL': 'ENSG00000170345',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2353'},
#   'display': 'NCBIGene(2353) ENSEMBL(ENSG00000170345) HGNC(3796) UMLS(C0087140) UNIPROTKB(P01100) SYMBOL(FOS)',
#   'type': 'Gene'},
#  {'NCBIGene': '283',
#   'name': 'angiogenin',
#   'SYMBOL': 'ANG',
#   'UMLS': 'C1367482',
#   'HGNC': '483',
#   'UNIPROTKB': 'P03950',
#   'ENSEMBL': 'ENSG00000214274',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '283'},
#   'display': 'NCBIGene(283) ENSEMBL(ENSG00000214274) HGNC(483) UMLS(C1367482) UNIPROTKB(P03950) SYMBOL(ANG)',
#   'type': 'Gene'},
#  {'NCBIGene': '6774',
#   'name': 'signal transducer and activator of transcription 3',
#   'SYMBOL': 'STAT3',
#   'UMLS': 'C1367307',
#   'HGNC': '11364',
#   'UNIPROTKB': 'P40763',
#   'ENSEMBL': 'ENSG00000168610',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6774'},
#   'display': 'NCBIGene(6774) ENSEMBL(ENSG00000168610) HGNC(11364) UMLS(C1367307) UNIPROTKB(P40763) SYMBOL(STAT3)',
#   'type': 'Gene'},
#  {'NCBIGene': '5599',
#   'name': 'mitogen-activated protein kinase 8',
#   'SYMBOL': 'MAPK8',
#   'UMLS': 'C1367731',
#   'HGNC': '6881',
#   'UNIPROTKB': 'P45983',
#   'ENSEMBL': 'ENSG00000107643',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5599'},
#   'display': 'NCBIGene(5599) ENSEMBL(ENSG00000107643) HGNC(6881) UMLS(C1367731) UNIPROTKB(P45983) SYMBOL(MAPK8)',
#   'type': 'Gene'},
#  {'NCBIGene': '1398',
#   'name': 'CRK proto-oncogene, adaptor protein',
#   'SYMBOL': 'CRK',
#   'UMLS': 'C0812252',
#   'HGNC': '2362',
#   'UNIPROTKB': 'P46108',
#   'ENSEMBL': 'ENSG00000167193',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1398'},
#   'display': 'NCBIGene(1398) ENSEMBL(ENSG00000167193) HGNC(2362) UMLS(C0812252) UNIPROTKB(P46108) SYMBOL(CRK)',
#   'type': 'Gene'},
#  {'NCBIGene': '820',
#   'name': 'cathelicidin antimicrobial peptide',
#   'SYMBOL': 'CAMP',
#   'UMLS': 'C1413106',
#   'HGNC': '1472',
#   'UNIPROTKB': 'P49913',
#   'ENSEMBL': 'ENSG00000164047',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '820'},
#   'display': 'NCBIGene(820) ENSEMBL(ENSG00000164047) HGNC(1472) UMLS(C1413106) UNIPROTKB(P49913) SYMBOL(CAMP)',
#   'type': 'Gene'},
#  {'NCBIGene': '7040',
#   'name': 'transforming growth factor beta 1',
#   'SYMBOL': 'TGFB1',
#   'UMLS': 'C1366557',
#   'HGNC': '11766',
#   'UNIPROTKB': 'P01137',
#   'ENSEMBL': 'ENSG00000105329',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7040'},
#   'display': 'NCBIGene(7040) ENSEMBL(ENSG00000105329) HGNC(11766) UMLS(C1366557) UNIPROTKB(P01137) SYMBOL(TGFB1)',
#   'type': 'Gene'},
#  {'NCBIGene': '207',
#   'name': 'AKT serine/threonine kinase 1',
#   'SYMBOL': 'AKT1',
#   'UMLS': 'C0812228',
#   'HGNC': '391',
#   'UNIPROTKB': 'P31749',
#   'ENSEMBL': 'ENSG00000142208',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '207'},
#   'display': 'NCBIGene(207) ENSEMBL(ENSG00000142208) HGNC(391) UMLS(C0812228) UNIPROTKB(P31749) SYMBOL(AKT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '7422',
#   'name': 'vascular endothelial growth factor A',
#   'SYMBOL': 'VEGFA',
#   'UMLS': 'C1823619',
#   'HGNC': '12680',
#   'UNIPROTKB': 'P15692',
#   'ENSEMBL': 'ENSG00000112715',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7422'},
#   'display': 'NCBIGene(7422) ENSEMBL(ENSG00000112715) HGNC(12680) UMLS(C1823619) UNIPROTKB(P15692) SYMBOL(VEGFA)',
#   'type': 'Gene'},
#  {'NCBIGene': '5594',
#   'name': 'mitogen-activated protein kinase 1',
#   'SYMBOL': 'MAPK1',
#   'UMLS': 'C1366882',
#   'HGNC': '6871',
#   'UNIPROTKB': 'P28482',
#   'ENSEMBL': 'ENSG00000100030',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5594'},
#   'display': 'NCBIGene(5594) ENSEMBL(ENSG00000100030) HGNC(6871) UMLS(C1366882) UNIPROTKB(P28482) SYMBOL(MAPK1)',
#   'type': 'Gene'}]

# %%
print(len(v3_genes))
print(v3_genes)
# Out:
# 182
# ['ACE2', 'CRP', 'TH', 'SON', 'MARS1', 'POR', 'CD4', 'CCL2', 'IL2', 'IFNG', 'SH2D3A', 'IL1B', 'IL7', 'REN', 'IFNA1', 'ACE', 'ALB', 'CXCL10', 'CXCL8', 'F2', 'ADAM17', 'SH2D3C', 'BSG', 'F3', 'TNNI3', 'IL17A', 'CTSL', 'DPP4', 'AGTR2', 'HMGN4', 'IL2RA', 'IFNB1', 'GPT', 'MB', 'IFITM3', 'IL6', 'CD8A', 'TNF', 'IL10', 'AGTR1', 'CTRL', 'SARS2', 'CCL3', 'FURIN', 'VIP', 'CX3CL1', 'STAT4', 'SOD1', 'NOTCH1', 'FGF2', 'IFIT1', 'PSMD9', 'EGR1', 'CBL', 'RAF1', 'FOXP3', 'PPIG', 'CCR6', 'MSC', 'LPL', 'PTGS2', 'KLRK1', 'TNFRSF1A', 'BAX', 'TLR5', 'TLR8', 'SOAT1', 'RHOA', 'CXCL9', 'LCK', 'TF', 'REL', 'IFI27', 'IL4', 'LIF', 'CCR2', 'GPI', 'JAG1', 'FCGR3A', 'CCR1', 'IFNAR1', 'GRK2', 'ITGAX', 'MTOR', 'SELL', 'TCEAL1', 'STAT1', 'ADRA1D', 'REG1A', 'C5AR1', 'CD19', 'TIMP1', 'CXCL2', 'LOX', 'IRF1', 'NCAM1', 'SP1', 'CD79A', 'TLR7', 'CCL20', 'ITIH4', 'LBR', 'PTH', 'SGSM3', 'CD14', 'PTPN11', 'MYD88', 'PIK3CB', 'STAT6', 'SERPINE1', 'CD44', 'MPO', 'PPARA', 'CDKN1A', 'IL9', 'HSPA4', 'TNFSF11', 'ESR1', 'IRF3', 'SOCS3', 'ERCC8', 'TNFRSF10B', 'CSH1', 'HSPA9', 'TRBV20OR9-2', 'MAPK3', 'CD2', 'ICAM1', 'PLAT', 'TLR3', 'TAT', 'EGF', 'ADA', 'HLA-E', 'TFRC', 'SYK', 'ERVK-10', 'GORASP1', 'ISG20', 'CREB1', 'PTPRC', 'IL3', 'CD69', 'SYT1', 'AHSA1', 'LEP', 'POLDIP2', 'CD80', 'IGHE', 'CXCR4', 'PIK3CA', 'POMC', 'GRAP2', 'ITGAM', 'FAS', 'CA2', 'MMP2', 'APP', 'MMP9', 'CISH', 'CD28', 'CCR5', 'CAT', 'TP53', 'EGFR', 'RELA', 'ATM', 'STAT5A', 'CD40', 'TLR4', 'INS', 'CCL5', 'FOS', 'ANG', 'STAT3', 'MAPK8', 'CRK', 'CAMP', 'TGFB1', 'AKT1', 'VEGFA', 'MAPK1']

# %% [markdown]
# OK

# %%
final_genes = list(dict.fromkeys(list(genes_with_sars_symptoms_MP + v2_genes + v3_genes)))

# %%
final_genes
# Out:
# ['TMPRSS2',
#  'TH',
#  'IFNG',
#  'IL1B',
#  'ADAM17',
#  'SH2D3C',
#  'BSG',
#  'TNNI3',
#  'IL17A',
#  'DPP4',
#  'IL6',
#  'TNF',
#  'IL10',
#  'RAF1',
#  'FOXP3',
#  'PTGS2',
#  'TNFRSF1A',
#  'REL',
#  'IL4',
#  'CCR2',
#  'ITGAX',
#  'IRF1',
#  'CD79A',
#  'MYD88',
#  'SERPINE1',
#  'PPARA',
#  'CDKN1A',
#  'TNFSF11',
#  'ICAM1',
#  'TLR3',
#  'SYK',
#  'PTPRC',
#  'CXCR4',
#  'FAS',
#  'APP',
#  'CISH',
#  'CCR5',
#  'EGFR',
#  'TLR4',
#  'STAT3',
#  'CAMP',
#  'TGFB1',
#  'VEGFA',
#  'ACE2',
#  'ACE',
#  'CRP',
#  'REN',
#  'MSC',
#  'IL2RA',
#  'AGTR1',
#  'INS',
#  'CD4',
#  'POMC',
#  'CA2',
#  'CD28',
#  'CCL2',
#  'IFNA1',
#  'F3',
#  'PSMD9',
#  'PTH',
#  'LEP',
#  'ALB',
#  'GPT',
#  'CD2',
#  'ISG20',
#  'GRAP2',
#  'CAT',
#  'AKT1',
#  'AGTR2',
#  'MB',
#  'TF',
#  'REG1A',
#  'CCL20',
#  'PIK3CA',
#  'CXCL8',
#  'CX3CL1',
#  'CXCL9',
#  'LCK',
#  'MTOR',
#  'SON',
#  'MARS1',
#  'POR',
#  'IL2',
#  'SH2D3A',
#  'IL7',
#  'CXCL10',
#  'F2',
#  'CTSL',
#  'HMGN4',
#  'IFNB1',
#  'IFITM3',
#  'CD8A',
#  'CTRL',
#  'SARS2',
#  'CCL3',
#  'FURIN',
#  'VIP',
#  'STAT4',
#  'SOD1',
#  'NOTCH1',
#  'FGF2',
#  'IFIT1',
#  'EGR1',
#  'CBL',
#  'PPIG',
#  'CCR6',
#  'LPL',
#  'KLRK1',
#  'BAX',
#  'TLR5',
#  'TLR8',
#  'SOAT1',
#  'RHOA',
#  'IFI27',
#  'LIF',
#  'GPI',
#  'JAG1',
#  'FCGR3A',
#  'CCR1',
#  'IFNAR1',
#  'GRK2',
#  'SELL',
#  'TCEAL1',
#  'STAT1',
#  'ADRA1D',
#  'C5AR1',
#  'CD19',
#  'TIMP1',
#  'CXCL2',
#  'LOX',
#  'NCAM1',
#  'SP1',
#  'TLR7',
#  'ITIH4',
#  'LBR',
#  'SGSM3',
#  'CD14',
#  'PTPN11',
#  'PIK3CB',
#  'STAT6',
#  'CD44',
#  'MPO',
#  'IL9',
#  'HSPA4',
#  'ESR1',
#  'IRF3',
#  'SOCS3',
#  'ERCC8',
#  'TNFRSF10B',
#  'CSH1',
#  'HSPA9',
#  'TRBV20OR9-2',
#  'MAPK3',
#  'PLAT',
#  'TAT',
#  'EGF',
#  'ADA',
#  'HLA-E',
#  'TFRC',
#  'ERVK-10',
#  'GORASP1',
#  'CREB1',
#  'IL3',
#  'CD69',
#  'SYT1',
#  'AHSA1',
#  'POLDIP2',
#  'CD80',
#  'IGHE',
#  'ITGAM',
#  'MMP2',
#  'MMP9',
#  'TP53',
#  'RELA',
#  'ATM',
#  'STAT5A',
#  'CD40',
#  'CCL5',
#  'FOS',
#  'ANG',
#  'MAPK8',
#  'CRK',
#  'MAPK1']

# %%
final_gene_inputs = create_gene_inputs(final_genes)

# %% [markdown]
# ## 3 Investigate Top Genes
# ## 3.1 Top Genes -> Pathways

# %%
pd7 = Predict(
    input_objs=final_gene_inputs,
    intermediate_nodes=[], 
    output_types =['Pathway'], 
    config= {"expand": False}
)
pd7.connect(verbose=False)
df7 = pd7.display_table_view()

# %%
df7
# Out:
#            input_id                          input_label input_type  \
# 0     NCBIGene:2147      coagulation factor II, thrombin       Gene
# 1     NCBIGene:2147      coagulation factor II, thrombin       Gene
# 2     NCBIGene:2147      coagulation factor II, thrombin       Gene
# 3     NCBIGene:2147      coagulation factor II, thrombin       Gene
# 4     NCBIGene:2147      coagulation factor II, thrombin       Gene
# ...             ...                                  ...        ...
# 6706   NCBIGene:156  G protein-coupled receptor kinase 2       Gene
# 6707  NCBIGene:6646           sterol O-acyltransferase 1       Gene
# 6708  NCBIGene:6646           sterol O-acyltransferase 1       Gene
# 6709  NCBIGene:6646           sterol O-acyltransferase 1       Gene
# 6710  NCBIGene:6646           sterol O-acyltransferase 1       Gene
#
#                        pred1 pred1_source        pred1_api pred1_publications  \
# 0     functional_association         CPDB  MyGene.info API               None
# 1     functional_association         CPDB  MyGene.info API               None
# 2     functional_association         CPDB  MyGene.info API               None
# 3     functional_association         CPDB  MyGene.info API               None
# 4     functional_association         CPDB  MyGene.info API               None
# ...                      ...          ...              ...                ...
# 6706  functional_association         CPDB  MyGene.info API               None
# 6707  functional_association         CPDB  MyGene.info API               None
# 6708  functional_association         CPDB  MyGene.info API               None
# 6709  functional_association         CPDB  MyGene.info API               None
# 6710  functional_association         CPDB  MyGene.info API               None
#
#                 output_id                                       output_label  \
# 0       WIKIPATHWAYS:WP15                     Selenium Micronutrient Network
# 1     WIKIPATHWAYS:WP1533                             Vitamin B12 Metabolism
# 2      WIKIPATHWAYS:WP176                                  Folate Metabolism
# 3      WIKIPATHWAYS:WP272                             Blood Clotting Cascade
# 4     WIKIPATHWAYS:WP2865                  IL1 and megakaryocytes in obesity
# ...                   ...                                                ...
# 6706  REACT:R-HSA-9006925       Intracellular signaling by second messengers
# 6707   REACT:R-HSA-174824  Plasma lipoprotein assembly, remodeling, and c...
# 6708   REACT:R-HSA-382551                       Transport of small molecules
# 6709  REACT:R-HSA-8964038                                      LDL clearance
# 6710  REACT:R-HSA-8964043                       Plasma lipoprotein clearance
#
#      output_type output_degree
# 0        Pathway          None
# 1        Pathway          None
# 2        Pathway          None
# 3        Pathway          None
# 4        Pathway          None
# ...          ...           ...
# 6706     Pathway          None
# 6707     Pathway          None
# 6708     Pathway          None
# 6709     Pathway          None
# 6710     Pathway          None
#
# [6711 rows x 11 columns]

# %%
genes_to_pathways = df7
print(genes_to_pathways.shape)
## only use WIKIPATHWAYS AT THE MOMENT - ONLY SOURCE WITH GENE SETS WITH ASSOCIATED PATHWAYS 
genes_to_pathways = genes_to_pathways[genes_to_pathways["output_id"].str.contains('WIKIPATHWAYS')]
print(genes_to_pathways.shape)
# Out:
# (6711, 11)
# (2271, 11)

# %%
## Use custom wikipathway_dict.json - {pathway: pathway_genes, pathway_gene_ids}
import json as json 

with open('wikipathway_dict.json') as f:
    wikipathway_dict = json.load(f)
## example entry: 
print(wikipathway_dict["ACE INHIBITOR PATHWAY"])
# Out:
# {'pathway_genes': ['NOS3', 'AGTR2', 'BDKRB1', 'TFs', 'AGTR1', 'TGFB1', 'CTSG', 'KNG1', 'ACE', 'CMA1', 'REN', 'CYP11B2', 'MAS1', 'ACE2', 'AGT', 'NR3C2', 'ATP6AP2', 'BDKRB2'], 'pathway_gene_ids': ['4846', '186', '623', '', '185', '7040', '1511', '3827', '1636', '1215', '5972', '1585', '4142', '59272', '183', '4306', '10159', '624']}

# %%
all_genes = []
for key in wikipathway_dict:
    all_genes = all_genes + wikipathway_dict[key]['pathway_genes']
## values needed for hyperparametric statistical analysis
genes_in_wiki_pathways = len(list(dict.fromkeys(list(all_genes))))
bf_c = len(list(wikipathway_dict.keys()))

# %%
# wikipathway_dict['Vitamin B12 Metabolism'.upper()]
# Out:
# {'pathway_genes': ['MCP1',
#   'NFkB2',
#   'IF*',
#   'TCN2*',
#   'RELA',
#   'HC',
#   'Megalin',
#   'CUBN',
#   'NFkB1',
#   'MM-CoA-H',
#   'CBR',
#   'MMAB',
#   'MAT',
#   'MTR*',
#   'MCEE',
#   'MSR*',
#   'MUT',
#   'SHMT',
#   'CBS',
#   'MPO',
#   'PAI-1',
#   'tPA',
#   'PLG',
#   'Thrombin',
#   'Factor VII',
#   'SOD3',
#   'CTH',
#   'MTHFR*',
#   'SOD1',
#   'ACT',
#   'LDLR',
#   'APOB',
#   'SRB1',
#   'ABCA1',
#   'SAA4',
#   'SAA3',
#   'APOA1',
#   'SAA1',
#   'APOE',
#   'APOA1-NO2Tyr',
#   'SAA2',
#   'SOD2',
#   'D-dimer',
#   'TNFa',
#   'HbA1c',
#   'Fibrinogen',
#   'IL1B',
#   'INSR',
#   'IL6',
#   'IL10',
#   'ALB',
#   'INS',
#   'RANTES',
#   'HBA1',
#   'sICAM-1',
#   'HBB',
#   'Fibrin',
#   'CRP',
#   'FGA',
#   'FGB',
#   'FGG'],
#  'pathway_gene_ids': ['6347',
#   '4791',
#   '2694',
#   '6948',
#   '5970',
#   '6947',
#   '4036',
#   '8029',
#   '4790',
#   '3.1.2.17',
#   '1.16.1.4',
#   '326625',
#   '4143',
#   '4548',
#   '84693',
#   '4552',
#   '4594',
#   '6472',
#   '875',
#   '4353',
#   '5054',
#   '5327',
#   '5340',
#   '2147',
#   '2155',
#   '6649',
#   '1491',
#   '4524',
#   '6647',
#   '12',
#   '3949',
#   '338',
#   '949',
#   '19',
#   '6291',
#   '6290',
#   '335',
#   '6288',
#   '348',
#   '335',
#   '6289',
#   '6648',
#   'Q2162109',
#   '7124',
#   'Q311213',
#   '',
#   '3553',
#   '3643',
#   '3569',
#   '3458',
#   '213',
#   '3630',
#   '6352',
#   '3039',
#   '3383',
#   '3043',
#   'Q27205',
#   '1401',
#   '',
#   '',
#   '']}

# %%
# pathways
gene_to_pathway_results = {}
gene_to_pathway_pathways = list(genes_to_pathways["output_label"]) # create list of genes
gene_to_pathway_pathways = list(dict.fromkeys(gene_to_pathway_pathways))  # remove duplicates
gene_to_pathway_genes = list(dict.fromkeys(list(genes_to_pathways["input_label"])))

for pathway in gene_to_pathway_pathways: 
    total_pathway_genes = 0
    if(pathway.upper() in wikipathway_dict):
        total_pathway_genes =  len(wikipathway_dict[pathway.upper()]['pathway_genes'])
    gene_to_pathway_results[pathway] = {
        'genes_related_count' : 0,
        "genes_related" : [],
#         "weighted_score" : [],
        "genes_in_pathway": total_pathway_genes,
        "p-value": None
    }

    
for index, row in genes_to_pathways.iterrows():
    gene_to_pathway_results[row['output_label']]['genes_related_count'] = gene_to_pathway_results[row['output_label']]['genes_related_count'] + 1
    gene_to_pathway_results[row['output_label']]['genes_related'].append(row['input_label'])

for index, row in genes_to_pathways.iterrows():
    score = 0 
    gene_to_pathway_results[row['output_label']]['genes_related_count'] = len(list(dict.fromkeys(list( gene_to_pathway_results[row['output_label']]['genes_related']))))
    if(gene_to_pathway_results[row['output_label']]['genes_in_pathway'] > 0):
        n = gene_to_pathway_results[row['output_label']]['genes_in_pathway']
        M = genes_in_wiki_pathways
        x = gene_to_pathway_results[row['output_label']]['genes_related_count']
        N = len(gene_to_pathway_genes)
        bf_c = len(list(wikipathway_dict.keys()))
        pval = stats.hypergeom.sf(x-1, M, n, N)*bf_c
        gene_to_pathway_results[row['output_label']]['p-value'] = pval
#         print(pval)


# sort final output by pvalue
pathways_df = pandas.DataFrame.from_dict(gene_to_pathway_results, orient='index').sort_values(by=['p-value'])

# %%
pathways_df
# Out:
#                                                     genes_related_count  \
# Toll-like Receptor Signaling Pathway                                 30
# Regulation of toll-like receptor signaling pathway                   32
# Thymic Stromal LymphoPoietin (TSLP) Signaling P...                   18
# Spinal Cord Injury                                                   24
# Leptin signaling pathway                                             20
# ...                                                                 ...
# Wnt-beta-catenin Signaling Pathway in Leukemia                        1
# C-type lectin receptors (CLRs)                                        1
# Interleukin-1 family signaling                                        1
# Pilocytic astrocytoma                                                 1
# Demo complete                                                         1
#
#                                                                                         genes_related  \
# Toll-like Receptor Signaling Pathway                [toll like receptor 5, C-C motif chemokine lig...
# Regulation of toll-like receptor signaling pathway  [toll like receptor 5, C-C motif chemokine lig...
# Thymic Stromal LymphoPoietin (TSLP) Signaling P...  [signal transducer and activator of transcript...
# Spinal Cord Injury                                  [tumor necrosis factor, C-X-C motif chemokine ...
# Leptin signaling pathway                            [estrogen receptor 1, signal transducer and ac...
# ...                                                                                               ...
# Wnt-beta-catenin Signaling Pathway in Leukemia                        [AKT serine/threonine kinase 1]
# C-type lectin receptors (CLRs)                                                   [interleukin 1 beta]
# Interleukin-1 family signaling                      [protein tyrosine phosphatase non-receptor typ...
# Pilocytic astrocytoma                               [protein tyrosine phosphatase non-receptor typ...
# Demo complete                                                            [sterol O-acyltransferase 1]
#
#                                                     genes_in_pathway  \
# Toll-like Receptor Signaling Pathway                             103
# Regulation of toll-like receptor signaling pathway               150
# Thymic Stromal LymphoPoietin (TSLP) Signaling P...                40
# Spinal Cord Injury                                               117
# Leptin signaling pathway                                          73
# ...                                                              ...
# Wnt-beta-catenin Signaling Pathway in Leukemia                     0
# C-type lectin receptors (CLRs)                                     0
# Interleukin-1 family signaling                                     0
# Pilocytic astrocytoma                                              0
# Demo complete                                                      0
#
#                                                         p-value
# Toll-like Receptor Signaling Pathway               0.0000000000
# Regulation of toll-like receptor signaling pathway 0.0000000000
# Thymic Stromal LymphoPoietin (TSLP) Signaling P... 0.0000000000
# Spinal Cord Injury                                 0.0000000000
# Leptin signaling pathway                           0.0000000000
# ...                                                         ...
# Wnt-beta-catenin Signaling Pathway in Leukemia              nan
# C-type lectin receptors (CLRs)                              nan
# Interleukin-1 family signaling                              nan
# Pilocytic astrocytoma                                       nan
# Demo complete                                               nan
#
# [387 rows x 4 columns]

# %%
## show more decimal places
pandas.options.display.float_format = "{:,.10f}".format
#include rows with pathway in wikipathway dict, has more than one gene, and has a significant pval
pathways_df = pathways_df[pathways_df["genes_in_pathway"] > 0]
pathways_df = pathways_df[pathways_df["genes_related_count"] > 1]
pathways_df = pathways_df[pathways_df["p-value"] <= 0.05]

list1 = list(map(str,(list(pathways_df["genes_related_count"]))))
list2 = ["/"] * len(list1)
list3 = list(map(str,(list(pathways_df["genes_in_pathway"]))))
pathways_df["count in gene set"] = [list1[i] + list2[i] + list3[i] for i in range(0,len(list1))]
pathways_df
# Out:
#                                                     genes_related_count  \
# Toll-like Receptor Signaling Pathway                                 30
# Regulation of toll-like receptor signaling pathway                   32
# Thymic Stromal LymphoPoietin (TSLP) Signaling P...                   18
# Spinal Cord Injury                                                   24
# Leptin signaling pathway                                             20
# ...                                                                 ...
# Primary Focal Segmental Glomerulosclerosis FSGS                       8
# Angiogenesis                                                          5
# Sudden Infant Death Syndrome (SIDS) Susceptibil...                   11
# Mammary gland development pathway - Puberty (St...                    4
# Androgen receptor signaling pathway                                   8
#
#                                                                                         genes_related  \
# Toll-like Receptor Signaling Pathway                [toll like receptor 5, C-C motif chemokine lig...
# Regulation of toll-like receptor signaling pathway  [toll like receptor 5, C-C motif chemokine lig...
# Thymic Stromal LymphoPoietin (TSLP) Signaling P...  [signal transducer and activator of transcript...
# Spinal Cord Injury                                  [tumor necrosis factor, C-X-C motif chemokine ...
# Leptin signaling pathway                            [estrogen receptor 1, signal transducer and ac...
# ...                                                                                               ...
# Primary Focal Segmental Glomerulosclerosis FSGS     [cathepsin L, toll like receptor 4, notch rece...
# Angiogenesis                                        [mitogen-activated protein kinase 1, phosphati...
# Sudden Infant Death Syndrome (SIDS) Susceptibil...  [transferrin, tumor necrosis factor, vascular ...
# Mammary gland development pathway - Puberty (St...  [signal transducer and activator of transcript...
# Androgen receptor signaling pathway                 [signal transducer and activator of transcript...
#
#                                                     genes_in_pathway  \
# Toll-like Receptor Signaling Pathway                             103
# Regulation of toll-like receptor signaling pathway               150
# Thymic Stromal LymphoPoietin (TSLP) Signaling P...                40
# Spinal Cord Injury                                               117
# Leptin signaling pathway                                          73
# ...                                                              ...
# Primary Focal Segmental Glomerulosclerosis FSGS                   81
# Angiogenesis                                                      26
# Sudden Infant Death Syndrome (SIDS) Susceptibil...               160
# Mammary gland development pathway - Puberty (St...                14
# Androgen receptor signaling pathway                               85
#
#                                                         p-value  \
# Toll-like Receptor Signaling Pathway               0.0000000000
# Regulation of toll-like receptor signaling pathway 0.0000000000
# Thymic Stromal LymphoPoietin (TSLP) Signaling P... 0.0000000000
# Spinal Cord Injury                                 0.0000000000
# Leptin signaling pathway                           0.0000000000
# ...                                                         ...
# Primary Focal Segmental Glomerulosclerosis FSGS    0.0309690091
# Angiogenesis                                       0.0338409830
# Sudden Infant Death Syndrome (SIDS) Susceptibil... 0.0372489623
# Mammary gland development pathway - Puberty (St... 0.0375448947
# Androgen receptor signaling pathway                0.0438475266
#
#                                                    count in gene set
# Toll-like Receptor Signaling Pathway                          30/103
# Regulation of toll-like receptor signaling pathway            32/150
# Thymic Stromal LymphoPoietin (TSLP) Signaling P...             18/40
# Spinal Cord Injury                                            24/117
# Leptin signaling pathway                                       20/73
# ...                                                              ...
# Primary Focal Segmental Glomerulosclerosis FSGS                 8/81
# Angiogenesis                                                    5/26
# Sudden Infant Death Syndrome (SIDS) Susceptibil...            11/160
# Mammary gland development pathway - Puberty (St...              4/14
# Androgen receptor signaling pathway                             8/85
#
# [107 rows x 5 columns]

# %%
pathways_df.to_csv("covid_pathways_results_2020_10_30.csv")

# %% [markdown]
# ### 3.2 Top Genes -> PhenotypicFeatures

# %%
gene_to_phenotypic_features = predict_many(v3_gene_inputs, ['PhenotypicFeature'])

# %%
gene_list_5 = list(gene_to_phenotypic_features["input"])
gene_to_phenotypic_feature_count_dict = {x:gene_list_5.count(x) for x in gene_list_5}
gene_to_phenotypic_feature_count_dict

gene_to_phenotypic_feature_results = {}
gene_to_phenotypic_feature_genes = list(gene_to_phenotypic_features["output_name"]) # create list of genes
gene_to_phenotypic_feature_genes = list(dict.fromkeys(gene_to_phenotypic_feature_genes))  # remove duplicates


for gene in gene_to_phenotypic_feature_genes: 
    gene_to_phenotypic_feature_results[gene] = {
        'phenotypic_feature_count' : 0,
        "genes_related" : [],

    }

for index, row in gene_to_phenotypic_features.iterrows():
    gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] = gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] + 1
    gene_to_phenotypic_feature_results[row['output_name']]['genes_related'].append(row['input'])

for index, row in gene_to_phenotypic_features.iterrows():
    gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] = len(list(dict.fromkeys(list(gene_to_phenotypic_feature_results[row['output_name']]['genes_related']))))
    
for index, row in gene_to_phenotypic_features.iterrows():
    gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] = gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] + 1
    gene_to_phenotypic_feature_results[row['output_name']]['genes_related'].append(row['input'])

# %%
gene_to_phenotypic_feature_results = dict(sorted(gene_to_phenotypic_feature_results.items(), key = lambda x: x[1]['phenotypic_feature_count'], reverse = True))
pandas.DataFrame.from_dict(gene_to_phenotypic_feature_results, orient='index').iloc[0:20]
# Out:
#                                  phenotypic_feature_count  \
# C0034917                                               31
# C0019699                                               18
# EPILEPSY                                               18
# INCREASED SPLEEN SIZE                                  15
# COGNITIVE DELAY                                        15
# FAILURE TO THRIVE                                      14
# ANAEMIA                                                13
# ARTERIAL HYPOTENSION                                   12
# ENLARGED LIVER                                         12
# HAVING TOO MUCH BODY FAT                               12
# DULL INTELLIGENCE                                      12
# PROGRESSIVE RESPIRATORY FAILURE                        10
# ABNORMALLY SMALL CRANIUM                               10
# DIABETES MELLITUS                                      10
# ELEVATED INSULIN LEVEL                                 10
# FATIGUE                                                10
# DECREASED BODY HEIGHT                                   9
# LOW LEVELS OF AMNIOTIC FLUID                            8
# ATAXIA                                                  8
# NEUROPATHY                                              8
#
#                                                                      genes_related
# C0034917                         [TNF, TNF, TNF, TNF, TNF, INS, CD4, CA2, ALB, ...
# C0019699                         [TNF, TNF, IL10, CD4, IFNA1, IFNA1, LEP, FAS, ...
# EPILEPSY                         [INS, PTH, PTH, FAS, AKT1, AGTR2, PIK3CA, PIK3...
# INCREASED SPLEEN SIZE            [IL2RA, CA2, FAS, AKT1, PIK3CA, PIK3CA, FOS, F...
# COGNITIVE DELAY                  [INS, CA2, AKT1, AGTR2, PIK3CA, PIK3CA, EGF, T...
# FAILURE TO THRIVE                [INS, POMC, CA2, AKT1, PIK3CA, FOS, SARS2, INS...
# ANAEMIA                          [REN, CA2, CA2, PIK3CA, TP53, F2, SARS2, REN, ...
# ARTERIAL HYPOTENSION             [ACE, REN, AGTR1, ALB, PIK3CA, TP53, ACE, REN,...
# ENLARGED LIVER                   [IL2RA, CA2, FAS, TP53, FOS, F2, IL2RA, CA2, F...
# HAVING TOO MUCH BODY FAT         [INS, POMC, LEP, ALB, AGTR2, EGF, INS, POMC, L...
# DULL INTELLIGENCE                [INS, CA2, CA2, AKT1, PIK3CA, PIK3CA, FOS, INS...
# PROGRESSIVE RESPIRATORY FAILURE  [ACE, REN, AGTR1, ANG, SARS2, ACE, REN, AGTR1,...
# ABNORMALLY SMALL CRANIUM         [ACE, REN, AGTR1, EGF, TP53, ACE, REN, AGTR1, ...
# DIABETES MELLITUS                [IL2RA, INS, FOS, F2, SARS2, IL2RA, INS, FOS, ...
# ELEVATED INSULIN LEVEL           [INS, POMC, LEP, ESR1, FOS, INS, POMC, LEP, ES...
# FATIGUE                          [ALB, PIK3CA, TP53, ANG, F2, ALB, PIK3CA, TP53...
# DECREASED BODY HEIGHT            [CA2, CA2, AKT1, PIK3CA, TP53, CA2, CA2, AKT1,...
# LOW LEVELS OF AMNIOTIC FLUID          [ACE, REN, AGTR1, ALB, ACE, REN, AGTR1, ALB]
# ATAXIA                              [TH, INS, AKT1, PIK3CA, TH, INS, AKT1, PIK3CA]
# NEUROPATHY                                  [INS, CA2, FOS, F2, INS, CA2, FOS, F2]

# %%
gene_pf_df = pandas.DataFrame.from_dict(gene_to_phenotypic_feature_results, orient='index').iloc[0:20]
gene_pf_df.to_csv("gene_pf_df_2020_10_17.csv")

# %% [markdown]
# Concept: [C0034917]  Reduced Glutathione
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7263077/
#
# Polonikov, Alexey. "Endogenous Deficiency of Glutathione as the Most Likely Cause of Serious Manifestations and Death in COVID-19 Patients." ACS Infectious Diseases (2020).
#
#
# C0019699
# Concept: [C0019699]  HIV Seropositivity

# %% [markdown]
# ## Pathways -> Genes -> ChemicalSubstance <-

# %%
ace_inh_gene_list = wikipathway_dict["ACE INHIBITOR PATHWAY"]["pathway_genes"]

# %%
ace_inh_gene_inputs = create_gene_inputs(ace_inh_gene_list )
# Out:
# TFs Failed

# %%
ace_genes_to_chem = predict_many(ace_inh_gene_inputs,["ChemicalSubstance"])

# %%
ace_genes_to_chem
# Out:
#       input input_type                      pred1 pred1_source  \
# 0      NOS3       Gene  physically_interacts_with       SEMMED
# 1      NOS3       Gene  physically_interacts_with       SEMMED
# 2      NOS3       Gene    positively_regulated_by       SEMMED
# 3      NOS3       Gene    negatively_regulated_by       SEMMED
# 4      NOS3       Gene                 related_to      scibite
# ..      ...        ...                        ...          ...
# 347  BDKRB2       Gene                 related_to       pharos
# 348  BDKRB2       Gene                 related_to       pharos
# 349  BDKRB2       Gene                 related_to       pharos
# 350  BDKRB2       Gene                 related_to      chembio
# 351  BDKRB2       Gene                 related_to         hmdb
#
#                       pred1_api       pred1_pubmed        output_type  \
# 0               SEMMED Gene API           15069547  ChemicalSubstance
# 1               SEMMED Gene API  25239655,25878398  ChemicalSubstance
# 2               SEMMED Gene API           11053770  ChemicalSubstance
# 3               SEMMED Gene API           25681545  ChemicalSubstance
# 4    Automat CORD19 Scibite API               None  ChemicalSubstance
# ..                          ...                ...                ...
# 347          Automat PHAROS API               None  ChemicalSubstance
# 348          Automat PHAROS API               None  ChemicalSubstance
# 349          Automat PHAROS API               None  ChemicalSubstance
# 350         Automat CHEMBIO API               None  ChemicalSubstance
# 351            Automat HMDB API               None  ChemicalSubstance
#
#                       output_name                          output_id
# 0                        C1171350                      UMLS:C1171350
# 1                        C0699857                      UMLS:C0699857
# 2                        C0301871                      UMLS:C0301871
# 3                        C0141729                      UMLS:C0141729
# 4                    CHEMBL265582       CHEMBL.COMPOUND:CHEMBL265582
# ..                            ...                                ...
# 347                     JSM-10292                     name:JSM-10292
# 348                      JMV-1645                      name:JMV-1645
# 349                     MEN-15442                     name:MEN-15442
# 350  (+)-PENTACYCLOANAMMOXIC ACID  name:(+)-PENTACYCLOANAMMOXIC ACID
# 351                        CA(2+)                        name:CA(2+)
#
# [10249 rows x 9 columns]

# %%
chemical_list = list(ace_genes_to_chem["output_name"])
d = {x:chemical_list.count(x) for x in chemical_list}
chemical_df = pandas.DataFrame.from_dict({k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse = True)}, orient='index').iloc[0:50]
chemical_df.columns = ["count"]
chemical_df
# Out:
#                                                     count
# (+)-ALDOSTERONE                                        42
# (2-BUTYL-4-CHLORO-1-{[2'-(1H-TETRAZOL-5-YL)BIPH...     31
# EDRF                                                   27
# (+)-GLUCOSE                                            27
# AMIAS                                                  25
# ANGIOTENSIN                                            22
# ALISKIREN                                              21
# ABBOLACTONE                                            21
# AGONISTS                                               20
# ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG                    20
# 4'-((1,4'-DIMETHYL-2'-PROPYL(2,6'-BI-1H-BENZIMI...     20
# MESSENGER RNA                                          20
# PHARMACEUTICAL PREPARATIONS                            19
# ANGIOTENSIN CONVERTING ENZYME INHIBITORS               19
# (2S-(1(R*(R*)),2ALPHA,3ABETA,6ABETA))-1-(2-((1-...     19
# OXYGEN SPECIES, REACTIVE                               17
# CALCIO                                                 17
# POTASSIUM                                              17
# (+)-EPLERENONE                                         17
# 10% SODIUM CHLORIDE INJECTION                          16
# (15S)-PROSTAGLANDIN E2                                 16
# 3-METHYLADENINE DNA                                    16
# (-)-CAPTOPRIL                                          15
# (11Β)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE        15
# (S)-4-PREGNENE-3,20-DIONE                              15
# MICRORNA                                               14
# (S)-1-(N-(1-(ETHOXYCARBONYL)-3-PHENYLPROPYL)-L-...     14
# SODIUM                                                 14
# 2-BUTYL-3-{[2'-(1H-TETRAZOL-5-YL)BIPHENYL-4-YL]...     14
# INTERFERING RNA, SMALL                                 14
# (S)-N-VALERYL-N-{[2'-(1H-TETRAZOL-5-YL)BIPHENYL...     14
# CHEBI:35222                                            13
# LIPOPOLYSACCHARIDES                                    13
# (-)-NORADRENALINE                                      13
# AGUA                                                   13
# 1-DEHYDRO-16ALPHA-METHYL-9ALPHA-FLUOROHYDROCORT...     13
# ESTROGEN                                               13
# 3-(2-AMINOETHYL)-1H-INDOL-5-OL                         13
# CHEBI:48432                                            12
# PGA                                                    12
# CICLOHEXIMIDE                                          12
# (S)-1-(N(2)-(1-CARBOXY-3-PHENYLPROPYL)-L-LYSYL)...     12
# CHEBI:24433                                            11
# 1-HYDROXYETHANE                                        11
# CHEBI:2720                                             11
# ANDROGENS                                              11
# (17Β)-ESTRA-1,3,5(10)-TRIENE-3,17-DIOL                 11
# (2S,3AS,7AS)-1-[(2S)-2-{[(2S)-1-ETHOXY-1-OXOPEN...     11
# (5Z,13E)-(15S)-6,9ALPHA-EPOXY-11ALPHA,15-DIHYDR...     11
# 3',5'-CYCLIC GMP                                       10

# %% [markdown]
# ## ACE Genes -> Chems <- Arterial Hypotension

# %%
art_hypotension = ht.query("Arterial Hypotension")["PhenotypicFeature"]
art_hypotension
# Out:
# [{'UMLS': 'C0020649',
#   'HP': 'HP:0002615',
#   'MESH': 'D007022',
#   'name': 'Hypotension',
#   'primary': {'identifier': 'UMLS',
#    'cls': 'PhenotypicFeature',
#    'value': 'C0020649'},
#   'display': 'UMLS(C0020649) HP(HP:0002615) MESH(D007022) name(Hypotension)',
#   'type': 'PhenotypicFeature'}]

# %%
hi = predict_many(ace_inh_gene_inputs,["PhenotypicFeature"],["ChemicalSubstance"])
# Out:
# API 1.1 semmed_chemical failed
# API 1.5 semmed_chemical failed
# API 1.9 semmed_chemical failed
# API 1.8 semmed_chemical failed
# API 1.7 semmed_chemical failed
# API 1.6 semmed_chemical failed
# API 1.4 semmed_chemical failed
# API 1.2 semmed_chemical failed
# API 1.3 semmed_chemical failed
# API 1.11 semmed_chemical failed
# API 1.10 semmed_chemical failed

# %%
list(dict.fromkeys(list(hi["output_name"])))
# Out:
# ['C0856536',
#  'C0034917',
#  'C0456984',
#  'C0019699',
#  'C0151579',
#  'C0587081',
#  'C0853878',
#  'C1619634',
#  'C0040210',
#  'C0159069',
#  'C0741132',
#  'C0279759',
#  'C0009050',
#  'C0266813',
#  'C1516006',
#  'C0427861',
#  'C0877371',
#  'C0279754',
#  'C0149709',
#  'C0457340',
#  'C0486431']

# %%
vasodilation = ht.query("Vasodilation")["BiologicalProcess"][0]
vasodilation
# Out:
# {'GO': 'GO:0042311',
#  'name': 'vasodilation',
#  'primary': {'identifier': 'GO',
#   'cls': 'BiologicalProcess',
#   'value': 'GO:0042311'},
#  'display': 'GO(GO:0042311) name(vasodilation)',
#  'type': 'BiologicalProcess'}

# %%
hi2 = predict_many(ace_inh_gene_inputs,[vasodilation],["ChemicalSubstance"])

# %%
hi3 = hi2[hi2["pred1"] != 'related_to']

# %%
hi3
# Out:
#      input input_type                      pred1 pred1_source  \
# 29    NOS3       Gene  physically_interacts_with     drugbank
# 38    NOS3       Gene       positively_regulates       SEMMED
# 0   BDKRB1       Gene  physically_interacts_with     drugbank
# 1   BDKRB1       Gene  physically_interacts_with       SEMMED
# 7    AGTR1       Gene       negatively_regulates       SEMMED
# ..     ...        ...                        ...          ...
# 26    ACE2       Gene  physically_interacts_with       SEMMED
# 27    ACE2       Gene    negatively_regulated_by       SEMMED
# 28    ACE2       Gene       positively_regulates       SEMMED
# 16   NR3C2       Gene  physically_interacts_with     drugbank
# 17   NR3C2       Gene  physically_interacts_with  drugcentral
#
#           pred1_api pred1_pubmed         node1_type  \
# 29  MyChem.info API         None  ChemicalSubstance
# 38  SEMMED Gene API     25158065  ChemicalSubstance
# 0   MyChem.info API         None  ChemicalSubstance
# 1   SEMMED Gene API     25443720  ChemicalSubstance
# 7   SEMMED Gene API     25631300  ChemicalSubstance
# ..              ...          ...                ...
# 26  SEMMED Gene API     19934006  ChemicalSubstance
# 27  SEMMED Gene API     26968558  ChemicalSubstance
# 28  SEMMED Gene API     27806985  ChemicalSubstance
# 16  MyChem.info API         None  ChemicalSubstance
# 17  MyChem.info API         None  ChemicalSubstance
#
#                                         node1_name  \
# 29  (2S)-2-AMINO-5-(CARBAMIMIDAMIDO)PENTANOIC ACID
# 38                                   PEROXYNITRITE
# 0                                    (-)-CAPTOPRIL
# 1                        1H-IMIDAZOLE-4-ETHANAMINE
# 7                                  (+)-ALDOSTERONE
# ..                                             ...
# 26                                     (+)-GLUCOSE
# 27                                     (+)-GLUCOSE
# 28                                     (+)-GLUCOSE
# 16                                 (+)-ALDOSTERONE
# 17                                 (+)-ALDOSTERONE
#
#                                              node1_id       pred2  \
# 29  name:(2S)-2-AMINO-5-(CARBAMIMIDAMIDO)PENTANOIC...  related_to
# 38                                 name:PEROXYNITRITE  related_to
# 0                                  name:(-)-CAPTOPRIL  related_to
# 1                      name:1H-IMIDAZOLE-4-ETHANAMINE  related_to
# 7                                name:(+)-ALDOSTERONE  related_to
# ..                                                ...         ...
# 26                                   name:(+)-GLUCOSE  related_to
# 27                                   name:(+)-GLUCOSE  related_to
# 28                                   name:(+)-GLUCOSE  related_to
# 16                               name:(+)-ALDOSTERONE  related_to
# 17                               name:(+)-ALDOSTERONE  related_to
#
#                        pred2_source                    pred2_api pred2_pubmed  \
# 29  Translator Text Mining Provider  CORD Biological Process API         None
# 38  Translator Text Mining Provider  CORD Biological Process API         None
# 0   Translator Text Mining Provider  CORD Biological Process API         None
# 1   Translator Text Mining Provider  CORD Biological Process API         None
# 7   Translator Text Mining Provider  CORD Biological Process API         None
# ..                              ...                          ...          ...
# 26  Translator Text Mining Provider  CORD Biological Process API         None
# 27  Translator Text Mining Provider  CORD Biological Process API         None
# 28  Translator Text Mining Provider  CORD Biological Process API         None
# 16  Translator Text Mining Provider  CORD Biological Process API         None
# 17  Translator Text Mining Provider  CORD Biological Process API         None
#
#           output_type                               output_name      output_id
# 29  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 38  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 0   ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 1   ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 7   ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# ..                ...                                       ...            ...
# 26  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 27  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 28  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 16  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 17  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
#
# [171 rows x 16 columns]

# %%
list(dict.fromkeys(list(hi2["pred1"])))
# Out:
# ['related_to',
#  'physically_interacts_with',
#  'positively_regulates',
#  'negatively_regulates',
#  'positively_regulated_by',
#  'negatively_regulated_by',
#  'metabolize']

# %%
chemical_list_2 = list(hi3["node1_name"])
d = {x:chemical_list_2.count(x) for x in chemical_list_2}
chemical_df_2 = pandas.DataFrame.from_dict({k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse = True)}, orient='index').iloc[0:50]
chemical_df_2.columns = ["count"]
chemical_df_2
# Out:
#                                                     count
# (+)-ALDOSTERONE                                        26
# (+)-GLUCOSE                                            21
# (-)-NORADRENALINE                                      12
# (15S)-PROSTAGLANDIN E2                                 12
# 2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE                      10
# 3-(2-AMINOETHYL)-1H-INDOL-5-OL                          9
# ACETYLCHOLINE                                           7
# (CIS-TRANS)-RESVERATROL                                 7
# 17BETA-HYDROXY-4-ANDROSTEN-3-ONE                        7
# A-101                                                   7
# 1H-IMIDAZOLE-4-ETHANAMINE                               6
# (-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL A...      5
# (+-)-1-(CARBAZOL-4-YLOXY)-3-((2-(O-METHOXYPHENO...      5
# 1,3,7-TRIMETHYL-2,6-DIOXOPURINE                         5
# (-)-CAPTOPRIL                                           4
# 1-((3-(4,7-DIHYDRO-1-METHYL-7-OXO-3-PROPYL-1H-P...      3
# CARBON                                                  3
# PEROXYNITRITE                                           2
# 3,4-DIHYDRO-6-(4-(1-CYCLOHEXYL-1H-TETRAZOL-5-YL...      2
# AT 877                                                  2
# 2-(DIETHYLAMINO)-2',6'-ACETOXYLIDIDE                    2
# 3-CARBOXAMIDO-4-HYDROXY-ALPHA-((1-METHYL-3-PHEN...      2
# (+/-)-NICARDIPINE                                       2
# (2S)-2-AMINO-5-(CARBAMIMIDAMIDO)PENTANOIC ACID          1
# ACARDI                                                  1
# (6R,12AR)-2,3,6,7,12,12A-HEXAHYDRO-2-METHYL-6-(...      1
# 1,1,1,3,3,3-HEXAFLUORO-2-(FLUOROMETHOXY)PROPANE         1
# 1-CHLORO-2,2,2-TRIFLUOROETHYL DIFLUOROMETHYL ETHER      1
# 4-(1,1-DIMETHYLETHYL)-N-(6-(2-HYDROXYETHOXY)-5-...      1
# BYSTOLIC                                                1
# CANDITRAL                                               1
# ALAPAV                                                  1
# (-)-OR-1259                                             1

# %%
hi3[hi3["pred1"]=="negatively_regulates"]
# Out:
#     input input_type                 pred1 pred1_source        pred1_api  \
# 7   AGTR1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 10  TGFB1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 13  TGFB1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 35  TGFB1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 38  TGFB1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 52  TGFB1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 60  TGFB1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 66  TGFB1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 77  TGFB1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 53    ACE       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 78    ACE       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 88    ACE       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 24    REN       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 29    REN       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 43    REN       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 57    REN       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 80    REN       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 83    REN       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 21   MAS1       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 21   ACE2       Gene  negatively_regulates       SEMMED  SEMMED Gene API
# 25   ACE2       Gene  negatively_regulates       SEMMED  SEMMED Gene API
#
#                                         pred1_pubmed         node1_type  \
# 7                                           25631300  ChemicalSubstance
# 10                                          19575289  ChemicalSubstance
# 13                 12525251,1322277,25587902,8440178  ChemicalSubstance
# 35                                          21521749  ChemicalSubstance
# 38                                          10202043  ChemicalSubstance
# 52                                 16360653,27830032  ChemicalSubstance
# 60                                           9526843  ChemicalSubstance
# 66                                          24659493  ChemicalSubstance
# 77                                 12765654,25140527  ChemicalSubstance
# 53                                  10937954,1521370  ChemicalSubstance
# 78                                          19559505  ChemicalSubstance
# 88                                          20051258  ChemicalSubstance
# 24  12900845,15480108,1619503,1914200,2942044,331616  ChemicalSubstance
# 29                                           1914200  ChemicalSubstance
# 43                                     865132,976208  ChemicalSubstance
# 57                                            976208  ChemicalSubstance
# 80                                          17823621  ChemicalSubstance
# 83                                 17823621,20075930  ChemicalSubstance
# 21                                          26536590  ChemicalSubstance
# 21                                          21335533  ChemicalSubstance
# 25                                          19934006  ChemicalSubstance
#
#                                            node1_name  \
# 7                                     (+)-ALDOSTERONE
# 10  (+-)-1-(CARBAZOL-4-YLOXY)-3-((2-(O-METHOXYPHEN...
# 13                                    (+)-ALDOSTERONE
# 35                  2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE
# 38                          1H-IMIDAZOLE-4-ETHANAMINE
# 52                                              A-101
# 60                             (15S)-PROSTAGLANDIN E2
# 66                                        (+)-GLUCOSE
# 77                   17BETA-HYDROXY-4-ANDROSTEN-3-ONE
# 53                                    (+)-ALDOSTERONE
# 78                  2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE
# 88                                        (+)-GLUCOSE
# 24                                    (+)-ALDOSTERONE
# 29                                    (+)-ALDOSTERONE
# 43                                  (-)-NORADRENALINE
# 57                  2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE
# 80                                        (+)-GLUCOSE
# 83                                        (+)-GLUCOSE
# 21                                  (-)-NORADRENALINE
# 21                    1,3,7-TRIMETHYL-2,6-DIOXOPURINE
# 25                                        (+)-GLUCOSE
#
#                                              node1_id       pred2  \
# 7                                name:(+)-ALDOSTERONE  related_to
# 10  name:(+-)-1-(CARBAZOL-4-YLOXY)-3-((2-(O-METHOX...  related_to
# 13                               name:(+)-ALDOSTERONE  related_to
# 35             name:2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE  related_to
# 38                     name:1H-IMIDAZOLE-4-ETHANAMINE  related_to
# 52                                         name:A-101  related_to
# 60                        name:(15S)-PROSTAGLANDIN E2  related_to
# 66                                   name:(+)-GLUCOSE  related_to
# 77              name:17BETA-HYDROXY-4-ANDROSTEN-3-ONE  related_to
# 53                               name:(+)-ALDOSTERONE  related_to
# 78             name:2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE  related_to
# 88                                   name:(+)-GLUCOSE  related_to
# 24                               name:(+)-ALDOSTERONE  related_to
# 29                               name:(+)-ALDOSTERONE  related_to
# 43                             name:(-)-NORADRENALINE  related_to
# 57             name:2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE  related_to
# 80                                   name:(+)-GLUCOSE  related_to
# 83                                   name:(+)-GLUCOSE  related_to
# 21                             name:(-)-NORADRENALINE  related_to
# 21               name:1,3,7-TRIMETHYL-2,6-DIOXOPURINE  related_to
# 25                                   name:(+)-GLUCOSE  related_to
#
#                        pred2_source                    pred2_api pred2_pubmed  \
# 7   Translator Text Mining Provider  CORD Biological Process API         None
# 10  Translator Text Mining Provider  CORD Biological Process API         None
# 13  Translator Text Mining Provider  CORD Biological Process API         None
# 35  Translator Text Mining Provider  CORD Biological Process API         None
# 38  Translator Text Mining Provider  CORD Biological Process API         None
# 52  Translator Text Mining Provider  CORD Biological Process API         None
# 60  Translator Text Mining Provider  CORD Biological Process API         None
# 66  Translator Text Mining Provider  CORD Biological Process API         None
# 77  Translator Text Mining Provider  CORD Biological Process API         None
# 53  Translator Text Mining Provider  CORD Biological Process API         None
# 78  Translator Text Mining Provider  CORD Biological Process API         None
# 88  Translator Text Mining Provider  CORD Biological Process API         None
# 24  Translator Text Mining Provider  CORD Biological Process API         None
# 29  Translator Text Mining Provider  CORD Biological Process API         None
# 43  Translator Text Mining Provider  CORD Biological Process API         None
# 57  Translator Text Mining Provider  CORD Biological Process API         None
# 80  Translator Text Mining Provider  CORD Biological Process API         None
# 83  Translator Text Mining Provider  CORD Biological Process API         None
# 21  Translator Text Mining Provider  CORD Biological Process API         None
# 21  Translator Text Mining Provider  CORD Biological Process API         None
# 25  Translator Text Mining Provider  CORD Biological Process API         None
#
#           output_type                               output_name      output_id
# 7   ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 10  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 13  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 35  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 38  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 52  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 60  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 66  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 77  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 53  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 78  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 88  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 24  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 29  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 43  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 57  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 80  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 83  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 21  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 21  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 25  ChemicalSubstance  POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311

# %%
# Out:
# {'Gene': [],
#  'SequenceVariant': [],
#  'ChemicalSubstance': [{'CHEBI': 'CHEBI:18295',
#    'INCHIKEY': 'NTYJJOPFIAHURM-UHFFFAOYSA-N',
#    'INCHI': 'InChI=1S/C5H9N3/c6-2-1-5-3-7-4-8-5/h3-4H,1-2,6H2,(H,7,8)',
#    'name': 'histamine',
#    'CAS': '51-45-6',
#    'formula': 'C5H9N3',
#    'primary': {'identifier': 'CHEBI',
#     'cls': 'ChemicalSubstance',
#     'value': 'CHEBI:18295'},
#    'display': 'CHEBI(CHEBI:18295) name(histamine) CAS(51-45-6) formula(C5H9N3)',
#    'type': 'ChemicalSubstance'},
#   {'CHEBI': 'CHEBI:29009',
#    'INCHIKEY': 'FHQDWPCFSJMNCT-UHFFFAOYSA-N',
#    'INCHI': 'InChI=1S/C6H11N3/c1-9-4-6(2-3-7)8-5-9/h4-5H,2-3,7H2,1H3',
#    'name': 'N(tele)-methylhistamine',
#    'CAS': '501-75-7',
#    'formula': 'C6H11N3',
#    'primary': {'identifier': 'CHEBI',
#     'cls': 'ChemicalSubstance',
#     'value': 'CHEBI:29009'},
#    'display': 'CHEBI(CHEBI:29009) name(N(tele)-methylhistamine) CAS(501-75-7) formula(C6H11N3)',
#    'type': 'ChemicalSubstance'},
#   {'CHEMBL.COMPOUND': 'CHEMBL90',
#    'DRUGBANK': 'DB05381',
#    'PUBCHEM': 774,
#    'CHEBI': 'CHEBI:18295',
#    'UMLS': 'C0019588',
#    'MESH': 'D006632',
#    'UNII': '3POA0Q644U',
#    'INCHIKEY': 'NTYJJOPFIAHURM-UHFFFAOYSA-N',
#    'INCHI': 'InChI=1S/C5H9N3/c6-2-1-5-3-7-4-8-5/h3-4H,1-2,6H2,(H,7,8)',
#    'KEGG': 'C00388',
#    'name': 'HISTAMINE',
#    'CAS': '51-45-6',
#    'IUPAC': '2-(1H-imidazol-5-yl)ethylamine',
#    'formula': 'C5H9N3',
#    'primary': {'identifier': 'CHEBI',
#     'cls': 'ChemicalSubstance',
#     'value': 'CHEBI:18295'},
#    'display': 'CHEBI(CHEBI:18295) CHEMBL.COMPOUND(CHEMBL90) DRUGBANK(DB05381) PUBCHEM(774) MESH(D006632) UNII(3POA0Q644U) UMLS(C0019588) name(HISTAMINE) CAS(51-45-6) IUPAC(2-(1H-imidazol-5-yl)ethylamine) formula(C5H9N3)',
#    'type': 'ChemicalSubstance'}],
#  'Disease': [],
#  'PhenotypicFeature': [],
#  'MolecularActivity': [{'GO': 'GO:0052598',
#    'MetaCyc': 'RXN-9600',
#    'RHEA': 'RHEA:25625',
#    'KEGG': 'R02150',
#    'REACT': 'R-HSA-5696131 "AOC1 deaminates Hist"',
#    'name': 'histamine oxidase activity',
#    'primary': {'identifier': 'GO',
#     'cls': 'MolecularActivity',
#     'value': 'GO:0052598'},
#    'display': 'GO(GO:0052598) MetaCyc(RXN-9600) RHEA(RHEA:25625) KEGG(R02150) REACT(R-HSA-5696131 "AOC1 deaminates Hist") name(histamine oxidase activity)',
#    'type': 'MolecularActivity'}],
#  'BiologicalProcess': [],
#  'CellularComponent': [],
#  'Pathway': [],
#  'AnatomicalEntity': [],
#  'Cell': []}

# %%
list1 = ['IL2','ADAM17','BSG','TNNI3','IL17A','DPP4','IL2RA','TMPRSS2','ACE2','TNF','IL10','TH','MET','STAT3','PHOX2B','PTEN','KRAS','SMPD1','DKC1','IGF2R','COL1A1','SCN4A','GNAS','WIPF1','NF1','SCNN1A','SCNN1B','PDGFRA','TP53','TGFB1','CFTR','CAV1','GBA','CSF2RB','HBB']

# %%
list1
# Out:
# ['IL2',
#  'ADAM17',
#  'BSG',
#  'TNNI3',
#  'IL17A',
#  'DPP4',
#  'IL2RA',
#  'TMPRSS2',
#  'ACE2',
#  'TNF',
#  'IL10',
#  'TH',
#  'MET',
#  'STAT3',
#  'PHOX2B',
#  'PTEN',
#  'KRAS',
#  'SMPD1',
#  'DKC1',
#  'IGF2R',
#  'COL1A1',
#  'SCN4A',
#  'GNAS',
#  'WIPF1',
#  'NF1',
#  'SCNN1A',
#  'SCNN1B',
#  'PDGFRA',
#  'TP53',
#  'TGFB1',
#  'CFTR',
#  'CAV1',
#  'GBA',
#  'CSF2RB',
#  'HBB']

# %%
list2 = ['ACE2','ACE', 'CRP', 'TNF', 'REN', 'TH', 'CISH', 'IL2RA', 'IL10', 'AGTR1', 'INS', 'CD4', 'POMC', 'CA2', 'CD28', 'CCL2', 'IFNA1', 'F3', 'IL6', 'PTH', 'LEP', 'ALB', 'GPT', 'CD2', 'ISG20', 'GRAP2', 'FAS', 'CCR5', 'CAT', 'EGFR', 'AKT1', 'AGTR2', 'MB', 'CCL20', 'ICAM1', 'PIK3CA', 'CXCL8', 'IL17A', 'DPP4', 'CD44', 'IL9', 'ESR1', 'EGF', 'CD80', 'TP53', 'TLR4', 'FOS', 'ANG', 'F2', 'SARS2']

# %%
list2 ## from 4 step process, no MP
# Out:
# ['ACE2',
#  'ACE',
#  'CRP',
#  'TNF',
#  'REN',
#  'TH',
#  'CISH',
#  'IL2RA',
#  'IL10',
#  'AGTR1',
#  'INS',
#  'CD4',
#  'POMC',
#  'CA2',
#  'CD28',
#  'CCL2',
#  'IFNA1',
#  'F3',
#  'IL6',
#  'PTH',
#  'LEP',
#  'ALB',
#  'GPT',
#  'CD2',
#  'ISG20',
#  'GRAP2',
#  'FAS',
#  'CCR5',
#  'CAT',
#  'EGFR',
#  'AKT1',
#  'AGTR2',
#  'MB',
#  'CCL20',
#  'ICAM1',
#  'PIK3CA',
#  'CXCL8',
#  'IL17A',
#  'DPP4',
#  'CD44',
#  'IL9',
#  'ESR1',
#  'EGF',
#  'CD80',
#  'TP53',
#  'TLR4',
#  'FOS',
#  'ANG',
#  'F2',
#  'SARS2']

# %%
for x in list1: 
    print(x in list2)
# Out:
# False
# False
# False
# False
# True
# True
# True
# False
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
