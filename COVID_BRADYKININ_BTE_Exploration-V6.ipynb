# %% [markdown]
# # Addressing COVID-19 Patient RAS-mediated Bradykinin Storm Hypothesis with  Biothings Explorer
#
# &emsp;
#
# SLIDES LINK: https://docs.google.com/presentation/d/1cL0Y-2FECPP5rWlJGI_ZWsvBysZVUGU-oDq75VexFrA/edit?usp=sharing

# %% [markdown]
# # Table of Contents
#
# ## &emsp; 0 Imports
# ## &emsp; 1 Overview of Background and BTE Approach
# ### &emsp; &emsp; 1.1 Article: Summary and Background
# ### &emsp; &emsp; 1.2 Overview of BTE Approach
# ## &emsp; 2 Determining Related Genes
# ### &emsp; &emsp; 2.1 Load COVID-19, Hypotension, and Vasodilation Nodes
# ### &emsp; &emsp; 2.2 COVID -> Genes <- Hypotension
# ### &emsp; &emsp; 2.3 COVID -> Genes <- Vasodilation
# ### &emsp; &emsp; 2.4 Create Gene Nodes
# ## &emsp; 3 Analyzing and Exploring Gene Results
# ### &emsp; &emsp; 3.1 Genes -> Pathways
# ### &emsp; &emsp; 3.2 Genes -> Biological Processes
# ### &emsp; &emsp; 3.3 Genes -> Chemical Substances
# ### &emsp; &emsp; 3.4 Genes -> Anatomical Entities
# ### &emsp; &emsp; 3.5 Genes -> Chemical Substances <- Vasodilation
# ## &emsp; 4 Exploring COVID-19 to Hyaluronic Acid Connection
# ### &emsp; &emsp; 4.1 COVID-19 -> Genes <- Hyaluronic Acid Explain Query
# ### &emsp; &emsp; 4.2 COVID/HYA Genes -> Pathways
# ## &emsp; 5 Summary
# ### &emsp; &emsp; 5.1 Summary
# ### &emsp; &emsp; 5.2 Future Directions

# %% [markdown]
# ## 0 Imports

# %%
# Import pandas and biothings explorers modules
import pandas as pandas
from biothings_explorer.query.predict import Predict
from biothings_explorer.query.visualize import display_graph
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
import nest_asyncio
nest_asyncio.apply()
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore") 
ht = Hint()
import math


## predict_many -> functionality to be fully incorporated into BTE soon, will no longer need following
def predict_many(input_object_list, output_type_list, intermediate_node_list = ''):
    df_list = []
    for input_object in input_object_list: 
        if('name' in input_object):
            for output_type in output_type_list: 
                if(len(intermediate_node_list) > 0):
                    for inter in intermediate_node_list:
                        try: 
#                             print("Running: " + input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type )
                            fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
                            fc.connect(verbose=False)
                            df = fc.display_table_view()
                            rows = df.shape[0]
                            if(rows > 0):
                                df_list.append(df)
                        except:
                            pass
#                             print(input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type + ' FAILED')
                else:
                    try:
#                         print("Running: " + input_object['name'] + ' --> output type ' + output_type )
                        fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=None)
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        rows = df.shape[0]
                        if(rows > 0):
                            df_list.append(df)
                    except:
                        pass
#                         print(input_object['name'] + ' --> output type ' + output_type + ' FAILED')

    if(len(df_list) > 0):
        return pandas.concat(df_list)
    else:
        return None
    
    

def create_gene_inputs(gene_list):
    # get gene inputs through hint module
    gene_inputs = []
    for gene in gene_list: 
        try: 
            gene_input = ht.query(gene)["Gene"][0]
            gene_inputs.append(gene_input)
        except: 
            print(gene + ' Failed')
    return(gene_inputs)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# ## 1 Overview of Background and BTE Approach
# &emsp;
# ### 1.1 Article: Summary and Background
#
# Article Reference:
#
# Garvin, Michael R., et al. "A mechanistic model and therapeutic interventions for COVID-19 involving a RAS-mediated bradykinin storm." Elife 9 (2020): e59177.
#
#
# Article Link:
#
# https://elifesciences.org/articles/59177
#
#
#
# Article Main Points:
#
# - RAS Pathway Imbalance implicated through gene expression analysis from cells in bronchoalveolar lavage fluid (BALF) from COVID-19 patients
#
# - Predicted RAS pathway imbalance to be cause of bradykinin-driven vascular dilation, vascular permeability and hypotension
#
# - Leaky membranes -> allows Hyaluronic Acid (HYA) to permeate into lungs
#
# - Analyses found that production of HYA was increased and the enzymes that could degrade it greatly decreased
#
#
# ### 1.2 Overview of BTE Approach
#
# As described in the article, vasodilation and hypotension are two distinctive signs and symptoms in severe COVID-19 cases that are predicted to lead to leaky membranes in the lung. Therefore, the following approach to determine whether or not this may be RAS-pathway linked is by looking at Genes that are both related to COVID and vasoconstriction or hypotension, and then analyzing this genes by looking at what pathways or processes they may be involved in, what chemical substances they may produce, and in what tissues or anatomical entities the genes are linked to.
#
# Also, starting in Section 4, a brief exploration of genes related to both COVID and Hyaluronic acid is done - HYA being a chemical found in the lungs of COVID patients that is hyper-absorbant and forms a gelatenous substance that blocks oxygen absorption by the lungs
#
# ## 2 Determining Related Genes
# &emsp;
# ### 2.1 Load COVID-19, Hypotension, and Vasodilation Nodes
# &emsp;

# %%
covid = ht.query('COVID-19')['Disease'][0]
covid
# Out:
# {'MONDO': 'MONDO:0100096',
#  'DOID': 'DOID:0080600',
#  'name': 'COVID-19',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0100096'},
#  'display': 'MONDO(MONDO:0100096) DOID(DOID:0080600) name(COVID-19)',
#  'type': 'Disease'}

# %%
SARS = ht.query("severe acute respiratory syndrome")["Disease"][0]
SARS
# Out:
# {'MONDO': 'MONDO:0005091',
#  'DOID': 'DOID:2945',
#  'UMLS': 'C1175175',
#  'name': 'severe acute respiratory syndrome',
#  'MESH': 'D045169',
#  'ORPHANET': '140896',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0005091'},
#  'display': 'MONDO(MONDO:0005091) DOID(DOID:2945) ORPHANET(140896) UMLS(C1175175) MESH(D045169) name(severe acute respiratory syndrome)',
#  'type': 'Disease'}

# %%
ACE2 = ht.query("ACE2")["Gene"][0]
ACE2
# Out:
# {'NCBIGene': '59272',
#  'name': 'angiotensin I converting enzyme 2',
#  'SYMBOL': 'ACE2',
#  'UMLS': 'C1422064',
#  'HGNC': '13557',
#  'UNIPROTKB': 'Q9BYF1',
#  'ENSEMBL': 'ENSG00000130234',
#  'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#  'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#  'type': 'Gene'}

# %%
fc1 = FindConnection(input_obj=covid, output_obj='Gene', intermediate_nodes=None)
fc1.connect(verbose=False)
df1 = fc1.display_table_view()

# %%
df1
# Out:
#                      input input_type       pred1 pred1_source  \
# 0   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 1   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 2   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 3   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 4   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 5   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 6   2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 7   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 8   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 9   2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 10  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 11  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 12  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 13  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 14  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 15  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 16  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 17  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 18  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 19  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 20  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 21  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 22  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 23  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 24  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 25  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 26  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 27  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 28  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 29  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 30  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 31  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 32  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 33  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 34  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 35  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 36  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 37  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 38  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 39  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 40  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 41  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 42  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 43  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 44  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 45  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 46  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 47  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 48  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 49  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 50  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 51  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 52  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 53  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 54  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 55  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 56  2019 NOVEL CORONAVIRUS    Disease  related_to         None
# 57  2019 NOVEL CORONAVIRUS    Disease  related_to         None
#
#                       pred1_api pred1_pubmed output_type output_name  \
# 0                  DISEASES API         None        Gene         CD4
# 1                  DISEASES API         None        Gene        CCL2
# 2                  DISEASES API         None        Gene         IL2
# 3                  DISEASES API         None        Gene        IFNG
# 4                  DISEASES API         None        Gene      SH2D3A
# 5                  DISEASES API         None        Gene         CRP
# 6   Automat CORD19 Scigraph API         None        Gene         CRP
# 7                  DISEASES API         None        Gene      SPECC1
# 8                  DISEASES API         None        Gene        IL1B
# 9                  DISEASES API         None        Gene         IL7
# 10                 DISEASES API         None        Gene         REN
# 11                 DISEASES API         None        Gene       IFNA1
# 12                 DISEASES API         None        Gene         ACE
# 13                 DISEASES API         None        Gene         ALB
# 14                 DISEASES API         None        Gene     SLC6A19
# 15                 DISEASES API         None        Gene      CXCL10
# 16                 DISEASES API         None        Gene       CXCL8
# 17                 DISEASES API         None        Gene          F2
# 18                 DISEASES API         None        Gene      ADAM17
# 19                 DISEASES API         None        Gene         GAK
# 20                 DISEASES API         None        Gene      CLEC4M
# 21                 DISEASES API         None        Gene      SH2D3C
# 22                 DISEASES API         None        Gene      PPP1CA
# 23                 DISEASES API         None        Gene         BSG
# 24                 DISEASES API         None        Gene          F3
# 25                 DISEASES API         None        Gene   TMPRSS11A
# 26                 DISEASES API         None        Gene       TNNI3
# 27                 DISEASES API         None        Gene       IL17A
# 28                 DISEASES API         None        Gene        CTSL
# 29                 DISEASES API         None        Gene        DPP4
# 30                 DISEASES API         None        Gene       AGTR2
# 31                 DISEASES API         None        Gene       HMGN4
# 32                 DISEASES API         None        Gene       IL2RA
# 33                 DISEASES API         None        Gene       IFNB1
# 34                 DISEASES API         None        Gene      TMEM27
# 35                 DISEASES API         None        Gene         GPT
# 36                 DISEASES API         None        Gene          MB
# 37                 DISEASES API         None        Gene     TMPRSS2
# 38  Automat CORD19 Scigraph API         None        Gene     TMPRSS2
# 39                 DISEASES API         None        Gene      IFITM3
# 40                 DISEASES API         None        Gene         IL6
# 41                 DISEASES API         None        Gene        AAK1
# 42                 DISEASES API         None        Gene        CD8A
# 43                 DISEASES API         None        Gene        ACE2
# 44  Automat CORD19 Scigraph API         None        Gene        ACE2
# 45                 DISEASES API         None        Gene         TNF
# 46                 DISEASES API         None        Gene        IL10
# 47                 DISEASES API         None        Gene       AGTR1
# 48                 DISEASES API         None        Gene        CTRL
# 49                 DISEASES API         None        Gene       SARS2
# 50                 DISEASES API         None        Gene        CCL3
# 51                 DISEASES API         None        Gene       FURIN
# 52  Automat CORD19 Scigraph API         None        Gene         SON
# 53  Automat CORD19 Scigraph API         None        Gene         POR
# 54  Automat CORD19 Scigraph API         None        Gene          TH
# 55  Automat CORD19 Scigraph API         None        Gene       MARS1
# 56                  BioLink API         None        Gene         ABO
# 57                  BioLink API         None        Gene      LZTFL1
#
#           output_id
# 0      NCBIGene:920
# 1     NCBIGene:6347
# 2     NCBIGene:3558
# 3     NCBIGene:3458
# 4    NCBIGene:10045
# 5     NCBIGene:1401
# 6     NCBIGene:1401
# 7    NCBIGene:92521
# 8     NCBIGene:3553
# 9     NCBIGene:3574
# 10    NCBIGene:5972
# 11    NCBIGene:3439
# 12    NCBIGene:1636
# 13     NCBIGene:213
# 14  NCBIGene:340024
# 15    NCBIGene:3627
# 16    NCBIGene:3576
# 17    NCBIGene:2147
# 18    NCBIGene:6868
# 19    NCBIGene:2580
# 20   NCBIGene:10332
# 21   NCBIGene:10044
# 22    NCBIGene:5499
# 23     NCBIGene:682
# 24    NCBIGene:2152
# 25  NCBIGene:339967
# 26    NCBIGene:7137
# 27    NCBIGene:3605
# 28    NCBIGene:1514
# 29    NCBIGene:1803
# 30     NCBIGene:186
# 31   NCBIGene:10473
# 32    NCBIGene:3559
# 33    NCBIGene:3456
# 34    SYMBOL:TMEM27
# 35    NCBIGene:2875
# 36    NCBIGene:4151
# 37    NCBIGene:7113
# 38    NCBIGene:7113
# 39   NCBIGene:10410
# 40    NCBIGene:3569
# 41   NCBIGene:22848
# 42     NCBIGene:925
# 43   NCBIGene:59272
# 44   NCBIGene:59272
# 45    NCBIGene:7124
# 46    NCBIGene:3586
# 47     NCBIGene:185
# 48    NCBIGene:1506
# 49   NCBIGene:54938
# 50    NCBIGene:6348
# 51    NCBIGene:5045
# 52    NCBIGene:6651
# 53    NCBIGene:5447
# 54    NCBIGene:7054
# 55    NCBIGene:4141
# 56      NCBIGene:28
# 57   NCBIGene:54585

# %%
query_config = {
    "annotate": ["nodeDegree"],
    "expand": False
}
## way to filter at the gene step for top x number of genes? 
pd2 = Predict(
    input_objs=[covid],
    intermediate_nodes =['Gene'], 
    output_types =['Gene'], 
    config= query_config 
)
pd2.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# Your query have 1 input nodes, including COVID-19 .... And BTE will find paths that connect your input nodes to your output types ['Gene']. Paths will contain 1 intermediate nodes.
#
# Intermediate node #1 will have these type constraints: Gene
#
# ========== Query # 1 ==========
#
# ==== Step #1: Query Path Planning ====
#
# Input Types: Disease
# Output Types: Gene
# Predicates: None
#
# BTE found 8 APIs based on SmartAPI Meta-KG.
#
# API 1. Automat CORD19 Scibite API (1 API calls)
# API 2. Automat CORD19 Scigraph API (1 API calls)
# API 3. MGIgene2phenotype API (1 API calls)
# API 4. Automat PHAROS API (1 API calls)
# API 5. DISEASES API (1 API calls)
# API 6. BioLink API (2 API calls)
# API 7. Molecular Data Provider API (1 API calls)
# API 8. CORD Disease API (1 API calls)
#
#
# ==== Step #2: Query path execution ====
#
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.1: https://biothings.ncats.io/mgigene2phenotype/query?fields=_id&size=300 (POST -d q=DOID:0080600&scopes=mgi.associated_with_disease.doid)
# API 3.1 MGIgene2phenotype API: 0 hits
# API 6.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0100096/genes?direct=True&rows=200&unselect_evidence=True
# API 6.1 BioLink API: 0 hits
# API 6.2: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0100096/genes?direct=True&rows=200&unselect_evidence=True
# API 6.2 BioLink API: 2 hits
# API 4.1: https://automat.renci.org/pharos/disease/gene/MONDO:0100096
# API 4.1 Automat PHAROS API: 0 hits
# API 2.1: https://automat.renci.org/cord19-scigraph/disease/gene/MONDO:0100096
# API 2.1 Automat CORD19 Scigraph API: 7 hits
# API 1.1: https://automat.renci.org/cord19-scibite/disease/gene/MONDO:0100096
# API 1.1 Automat CORD19 Scibite API: 0 hits
# API 7.1: https://translator.broadinstitute.org/molepro_reasoner/query (POST -d {'message': {'query_graph': {'edges': [{'id': 'e00', 'source_id': 'n00', 'target_id': 'n01', 'type': 'related_to'}], 'nodes': [{'curie': 'MONDO:0100096', 'id': 'n00', 'type': 'disease'}, {'id': 'n01', 'type': 'gene'}]}}})
# API 7.1 Molecular Data Provider API: 0 hits
# API 5.1: https://biothings.ncats.io/DISEASES/query?fields=DISEASES.associatedWith (POST -d q=DOID:0080600&scopes=DISEASES.doid)
# API 5.1 DISEASES API: 49 hits
# API 8.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 8.1 CORD Disease API: 0 hits
#
# BTE starts to perform id-to-object translation.
#
# After id-to-object translation, BTE retrieved 55 unique output nodes.
#
#
#
# ========== Query # 2 ==========
#
# ==== Step #1: Query Path Planning ====
#
# Input Types: Gene
# Output Types: ['Gene']
# Predicates: None
#
# BTE found 4 APIs based on SmartAPI Meta-KG.
#
# API 1. CORD Gene API (1 API calls)
# API 2. BioLink API (108 API calls)
# API 3. MyGene.info API (1 API calls)
# API 4. SEMMED Gene API (10 API calls)
#
#
# ==== Step #2: Query path execution ====
#
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.1: https://mygene.info/v3/query?fields=pantherdb.ortholog (POST -d q=5972,2152,10044,10410,186,3558,22848,5447,92521,5045,4141,3576,340024,6347,920,7113,3574,3569,1506,3439,28,10473,185,54585,3458,54938,10332,3553,6348,4151,3627,3456,682,6651,6868,2875,925,2147,1803,1401,3559,3605,7124,5499,1514,213,3586,1636,59272,7054,10045,2580,7137,339967&scopes=entrezgene)
# API 3.1 MyGene.info API: 82 hits
# API 2.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7054/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.1 BioLink API: 96 hits
# API 2.2: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6651/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.2 BioLink API: 103 hits
# API 2.3: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5447/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.3 BioLink API: 137 hits
# API 2.4: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:59272/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.4 BioLink API: 28 hits
# API 1.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=11947,17697,8568,5414,1706,9208,2367,5438,10637,399,3541,79,6008,2537,1678,16884,5417,4989,6025,6001,11183,13523,2707,27960,4113,6741,6023,2524,30615,9958,3009,5981,11782,1116,9281,5962,338,10618,11876,16885,6018,336,10627,5992,6915,11892,195,3535,27954,19679,5434,6898,13557,4552&scopes=hgnc)
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/__init__.py", line 302, in callSingleAPI
#     result = tf.transform()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/__init__.py", line 49, in transform
#     return self.tf.transform()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/transformers/base_transformer.py", line 78, in transform
#     item = self.wrap(item)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/transformers/cord_transformer.py", line 16, in wrap
#     for k in item.keys():
# RuntimeError: dictionary keys changed during iteration
# API call to CORD Gene API with input ['11947', '17697', '8568', '5414', '1706', '9208', '2367', '5438', '10637', '399', '3541', '79', '6008', '2537', '1678', '16884', '5417', '4989', '6025', '6001', '11183', '13523', '2707', '27960', '4113', '6741', '6023', '2524', '30615', '9958', '3009', '5981', '11782', '1116', '9281', '5962', '338', '10618', '11876', '16885', '6018', '336', '10627', '5992', '6915', '11892', '195', '3535', '27954', '19679', '5434', '6898', '13557', '4552'] failed with unknown response
# API 2.5: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:28/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.5 BioLink API: 13 hits
# API 4.1: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 4.1 SEMMED Gene API: 4 hits
# API 2.6: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7113/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.6 BioLink API: 71 hits
# API 4.2: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 2.7: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1401/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.7: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:4141/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.7: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:54585/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.7 BioLink API: 39 hits
# API 2.8 BioLink API: 120 hits
# API 4.2 SEMMED Gene API: 2 hits
# API 2.9 BioLink API: 195 hits
# API 4.3: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 4.3 SEMMED Gene API: 0 hits
# API 2.10: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10045/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.10 BioLink API: 14 hits
# API 4.4: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 2.11: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6347/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.11: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3458/interactions?direct=True&rows=200&unselect_evidence=True
# API 4.4 SEMMED Gene API: 1 hits
# API 2.11 BioLink API: 128 hits
# API 2.12 BioLink API: 130 hits
# API 2.13: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3558/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.13 BioLink API: 200 hits
# API 2.14: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:920/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.14 BioLink API: 198 hits
# API 4.5: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 2.15: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:92521/interactions?direct=True&rows=200&unselect_evidence=True
# API 4.5: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 2.15: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3574/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.15: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5972/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.15 BioLink API: 33 hits
# API 2.16 BioLink API: 57 hits
# API 2.17 BioLink API: 71 hits
# API 2.18: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3553/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.18: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3439/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.18 BioLink API: 35 hits
# API 2.19 BioLink API: 155 hits
# API 4.5 SEMMED Gene API: 2795 hits
# API 4.6 SEMMED Gene API: 3257 hits
# API 2.20: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:340024/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.20 BioLink API: 6 hits
# API 2.21: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1636/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.21 BioLink API: 38 hits
# API 4.7: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 2.22: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3576/interactions?direct=True&rows=200&unselect_evidence=True
# API 4.7: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 2.22 BioLink API: 199 hits
# API 2.23: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3627/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.23: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:213/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.23 BioLink API: 199 hits
# API 2.24 BioLink API: 197 hits
# API 4.7 SEMMED Gene API: 4459 hits
# API 4.8 SEMMED Gene API: 6219 hits
# API 2.25: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10332/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.25 BioLink API: 15 hits
# API 4.9: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 2.26: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6868/interactions?direct=True&rows=200&unselect_evidence=True
# API 4.9: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1540024,C1413716,C1333916,C0919550,C1335232,C1334124,C0035094,C1412186,C0879590,C1413931,C1416946,C1412332,C1426329,C1413244,C1332714,C0081714,C1332690,C0054871,C1415274,C1334122,C1336641,C1366571,C1332807,C1334085,C1334098,C1419338,C1439284,C1823096,C1539099,C1337092,C1420718,C1334112,C1332036,C1334114,C1335240,C1417035,C1414944,C1415900,C1420310,C1335817,C1417048,C1414504,C1367714,C1333522,C1412828,C1414141,C0812246,C1415898,C1420826,C1428660,C1335818,C1412099,C1413809,C1422064,C1825592,C1425041,C0021745,C1415912&scopes=umls)
# API 2.26 BioLink API: 74 hits
# API 2.27: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10044/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.27 BioLink API: 13 hits
# API 2.28: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:2147/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.28 BioLink API: 200 hits
# API 2.29: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:2580/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.29 BioLink API: 194 hits
# API 4.9 SEMMED Gene API: 4692 hits
# API 4.10 SEMMED Gene API: 0 hits
# API 2.30: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:2152/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.30 BioLink API: 41 hits
# API 2.31: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7137/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.31: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:339967/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.31 BioLink API: 9 hits
# API 2.32 BioLink API: 62 hits
# API 2.33: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5499/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.33 BioLink API: 199 hits
# API 2.34: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:682/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.34 BioLink API: 200 hits
# API 2.35: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10473/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.35 BioLink API: 12 hits
# API 2.36: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:186/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.36: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3605/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.36: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1514/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.36 BioLink API: 105 hits
# API 2.37 BioLink API: 200 hits
# API 2.38 BioLink API: 48 hits
# API 2.39: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1803/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.39 BioLink API: 35 hits
# API 2.40: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:4151/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.40 BioLink API: 19 hits
# API 2.41: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10410/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.41: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3559/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.41: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:2875/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.41 BioLink API: 106 hits
# API 2.42 BioLink API: 46 hits
# API 2.43: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3456/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.43 BioLink API: 145 hits
# API 2.44 BioLink API: 84 hits
# API 2.45: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:925/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.45 BioLink API: 52 hits
# API 2.46: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:22848/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.46: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7124/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.46 BioLink API: 150 hits
# API 2.47 BioLink API: 200 hits
# API 2.48: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3586/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.48 BioLink API: 199 hits
# API 2.49: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3569/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.49 BioLink API: 200 hits
# API 2.50: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6348/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.50 BioLink API: 60 hits
# API 2.51: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:185/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.51: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5045/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.51: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1506/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.51 BioLink API: 18 hits
# API 2.52 BioLink API: 59 hits
# API 2.53: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:54938/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.53 BioLink API: 200 hits
# API 2.54 BioLink API: 82 hits
# API 2.55: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:59272/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.55 BioLink API: 0 hits
# API 2.56: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6651/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.56 BioLink API: 0 hits
# API 2.57: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7054/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.57 BioLink API: 0 hits
# API 2.58: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5447/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.58 BioLink API: 0 hits
# API 2.59: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:4141/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.59 BioLink API: 0 hits
# API 2.60: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:28/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.60 BioLink API: 0 hits
# API 2.61: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7113/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.61 BioLink API: 0 hits
# API 2.62: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1401/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.62: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:54585/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.62 BioLink API: 0 hits
# API 2.63 BioLink API: 0 hits
# API 2.64: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:920/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.64 BioLink API: 0 hits
# API 2.65: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10045/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.65 BioLink API: 0 hits
# API 2.66: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:92521/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.66 BioLink API: 0 hits
# API 2.67: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3558/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.67: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3458/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.67 BioLink API: 0 hits
# API 2.68: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6347/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.68 BioLink API: 0 hits
# API 2.69 BioLink API: 0 hits
# API 2.70: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5972/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.70 BioLink API: 0 hits
# API 2.71: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3574/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.71 BioLink API: 0 hits
# API 2.72: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3553/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.72: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1636/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.72 BioLink API: 0 hits
# API 2.73: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3439/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.73 BioLink API: 0 hits
# API 2.74 BioLink API: 0 hits
# API 2.75: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:340024/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.75 BioLink API: 0 hits
# API 2.76: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:2147/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.76 BioLink API: 0 hits
# API 2.77: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:213/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.77: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3576/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.77 BioLink API: 0 hits
# API 2.78: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3627/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.78 BioLink API: 0 hits
# API 2.79 BioLink API: 0 hits
# API 2.80: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10332/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.80 BioLink API: 0 hits
# API 2.81: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6868/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.81: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10044/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.81 BioLink API: 0 hits
# API 2.82 BioLink API: 0 hits
# API 2.83: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:2580/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.83 BioLink API: 0 hits
# API 2.84: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5499/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.84 BioLink API: 0 hits
# API 2.85: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:339967/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.85 BioLink API: 0 hits
# API 2.86: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:2152/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.86 BioLink API: 0 hits
# API 2.87: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7137/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.87 BioLink API: 0 hits
# API 2.88: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3605/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.88 BioLink API: 0 hits
# API 2.89: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:682/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.89 BioLink API: 0 hits
# API 2.90: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10473/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.90 BioLink API: 0 hits
# API 2.91: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1803/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.91 BioLink API: 0 hits
# API 2.92: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3559/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.92 BioLink API: 0 hits
# API 2.93: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:186/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.93: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1514/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.93 BioLink API: 0 hits
# API 2.94 BioLink API: 0 hits
# API 2.95: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:4151/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.95 BioLink API: 0 hits
# API 2.96: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3456/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.96 BioLink API: 0 hits
# API 2.97: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3569/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.97: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10410/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.97: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:2875/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.97 BioLink API: 0 hits
# API 2.98 BioLink API: 0 hits
# API 2.99 BioLink API: 0 hits
# API 2.100: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:925/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.100 BioLink API: 0 hits
# API 2.101: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3586/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.101 BioLink API: 0 hits
# API 2.102: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:22848/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.102 BioLink API: 0 hits
# API 2.103: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7124/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.103: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:185/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.103 BioLink API: 0 hits
# API 2.104 BioLink API: 0 hits
# API 2.105: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1506/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.105 BioLink API: 0 hits
# API 2.106: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6348/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.106 BioLink API: 0 hits
# API 2.107: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5045/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.107 BioLink API: 0 hits
# API 2.108: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:54938/interactions?direct=True&rows=200&unselect_evidence=True
# API 2.108 BioLink API: 0 hits
#
# BTE starts to perform id-to-object translation.
#
# After id-to-object translation, BTE retrieved 7253 unique output nodes.
#
#
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
# In the #1 query, BTE found 55 unique nodes.
# In the #2 query, BTE found 7253 unique nodes.

# %%
df2 = pd2.display_table_view(extra_fields=["nodeDegree"]).sort_values(by="output_degree")
df2 = df2[df2["output_degree"] > 20]
genes_related_to_cov_w_int = list(dict.fromkeys(list(df2["output_label"])))
genes_related_to_cov_w_int = [x for x in genes_related_to_cov_w_int if not x.startswith('UMLS')]
genes_related_to_cov_w_int
# Out:
# ['TLR7',
#  'CCL20',
#  'CD79A',
#  'LBR',
#  'ITIH4',
#  'SP1',
#  'IFNB1',
#  'PTH',
#  'SGSM3',
#  'STAT6',
#  'PIK3CB',
#  'MYD88',
#  'PTPN11',
#  'CD14',
#  'MPO',
#  'CD44',
#  'SERPINE1',
#  'HSPA4',
#  'PPARA',
#  'CDKN1A',
#  'IL9',
#  'IRF3',
#  'TNFRSF10B',
#  'ERCC8',
#  'ESR1',
#  'SOCS3',
#  'TNFSF11',
#  'TRBV20OR9-2',
#  'CSH1',
#  'MAPK3',
#  'HSPA9',
#  'CD2',
#  'TLR3',
#  'ICAM1',
#  'TAT',
#  'PLAT',
#  'HLA-E',
#  'EGF',
#  'TFRC',
#  'ACE',
#  'ADA',
#  'SYK',
#  'GORASP1',
#  'AGTR1',
#  'ERVK-10',
#  'PTPRC',
#  'IL3',
#  'CD69',
#  'ISG20',
#  'CREB1',
#  'SYT1',
#  'CCL3',
#  'AHSA1',
#  'LEP',
#  'IGHE',
#  'POLDIP2',
#  'CD80',
#  'PIK3CA',
#  'ALB',
#  'CXCR4',
#  'POMC',
#  'GRAP2',
#  'ITGAM',
#  'FAS',
#  'CA2',
#  'MMP2',
#  'APP',
#  'CISH',
#  'IL2RA',
#  'MMP9',
#  'CD28',
#  'CCR5',
#  'TP53',
#  'CAT',
#  'EGFR',
#  'RELA',
#  'ATM',
#  'STAT5A',
#  'CD40',
#  'TLR4',
#  'INS',
#  'CCL5',
#  'CCL2',
#  'FOS',
#  'ANG',
#  'IL10',
#  'REN',
#  'IL6',
#  'STAT3',
#  'MAPK8',
#  'CRK',
#  'CD4',
#  'CAMP',
#  'IFNA1',
#  'IL2',
#  'TGFB1',
#  'AKT1',
#  'VEGFA',
#  'MAPK1',
#  'TNF']

# %%
len(genes_related_to_cov_w_int)
# Out:
# 100

# %%
# for x in fc1.fc.G['COVID-19'].values():
#     print(x[0]['info'])

## create Gene list
genes_related_to_covid = list(dict.fromkeys(list(df1["output_name"]) + genes_related_to_cov_w_int))
covid_gene_inputs = create_gene_inputs(genes_related_to_covid)
covid_gene_inputs
# Out:
# TMEM27 Failed
# [{'NCBIGene': '920',
#   'name': 'CD4 molecule',
#   'SYMBOL': 'CD4',
#   'UMLS': 'C1332714',
#   'HGNC': '1678',
#   'UNIPROTKB': 'P01730',
#   'ENSEMBL': 'ENSG00000010610',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '920'},
#   'display': 'NCBIGene(920) ENSEMBL(ENSG00000010610) HGNC(1678) UMLS(C1332714) UNIPROTKB(P01730) SYMBOL(CD4)',
#   'type': 'Gene'},
#  {'NCBIGene': '6347',
#   'name': 'C-C motif chemokine ligand 2',
#   'SYMBOL': 'CCL2',
#   'UMLS': 'C1337092',
#   'HGNC': '10618',
#   'UNIPROTKB': 'P13500',
#   'ENSEMBL': 'ENSG00000108691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6347'},
#   'display': 'NCBIGene(6347) ENSEMBL(ENSG00000108691) HGNC(10618) UMLS(C1337092) UNIPROTKB(P13500) SYMBOL(CCL2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3558',
#   'name': 'interleukin 2',
#   'SYMBOL': 'IL2',
#   'UMLS': 'C0879590',
#   'HGNC': '6001',
#   'UNIPROTKB': 'P60568',
#   'ENSEMBL': 'ENSG00000109471',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3558'},
#   'display': 'NCBIGene(3558) ENSEMBL(ENSG00000109471) HGNC(6001) UMLS(C0879590) UNIPROTKB(P60568) SYMBOL(IL2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3458',
#   'name': 'interferon gamma',
#   'SYMBOL': 'IFNG',
#   'UMLS': 'C1334085',
#   'HGNC': '5438',
#   'UNIPROTKB': 'P01579',
#   'ENSEMBL': 'ENSG00000111537',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3458'},
#   'display': 'NCBIGene(3458) ENSEMBL(ENSG00000111537) HGNC(5438) UMLS(C1334085) UNIPROTKB(P01579) SYMBOL(IFNG)',
#   'type': 'Gene'},
#  {'NCBIGene': '10045',
#   'name': 'SH2 domain containing 3A',
#   'SYMBOL': 'SH2D3A',
#   'UMLS': 'C1335817',
#   'HGNC': '16885',
#   'UNIPROTKB': 'Q9BRG2',
#   'ENSEMBL': 'ENSG00000125731',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10045'},
#   'display': 'NCBIGene(10045) ENSEMBL(ENSG00000125731) HGNC(16885) UMLS(C1335817) UNIPROTKB(Q9BRG2) SYMBOL(SH2D3A)',
#   'type': 'Gene'},
#  {'NCBIGene': '1401',
#   'name': 'C-reactive protein',
#   'SYMBOL': 'CRP',
#   'UMLS': 'C1413716',
#   'HGNC': '2367',
#   'UNIPROTKB': 'P02741',
#   'ENSEMBL': 'ENSG00000132693',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1401'},
#   'display': 'NCBIGene(1401) ENSEMBL(ENSG00000132693) HGNC(2367) UMLS(C1413716) UNIPROTKB(P02741) SYMBOL(CRP)',
#   'type': 'Gene'},
#  {'NCBIGene': '92521',
#   'name': 'sperm antigen with calponin homology and coiled-coil domains 1',
#   'SYMBOL': 'SPECC1',
#   'UMLS': 'C1823096',
#   'HGNC': '30615',
#   'UNIPROTKB': 'Q5M775',
#   'ENSEMBL': 'ENSG00000128487',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '92521'},
#   'display': 'NCBIGene(92521) ENSEMBL(ENSG00000128487) HGNC(30615) UMLS(C1823096) UNIPROTKB(Q5M775) SYMBOL(SPECC1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3553',
#   'name': 'interleukin 1 beta',
#   'SYMBOL': 'IL1B',
#   'UMLS': 'C1334112',
#   'HGNC': '5992',
#   'UNIPROTKB': 'P01584',
#   'ENSEMBL': 'ENSG00000125538',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3553'},
#   'display': 'NCBIGene(3553) ENSEMBL(ENSG00000125538) HGNC(5992) UMLS(C1334112) UNIPROTKB(P01584) SYMBOL(IL1B)',
#   'type': 'Gene'},
#  {'NCBIGene': '3574',
#   'name': 'interleukin 7',
#   'SYMBOL': 'IL7',
#   'UMLS': 'C1334124',
#   'HGNC': '6023',
#   'UNIPROTKB': 'P13232',
#   'ENSEMBL': 'ENSG00000104432',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3574'},
#   'display': 'NCBIGene(3574) ENSEMBL(ENSG00000104432) HGNC(6023) UMLS(C1334124) UNIPROTKB(P13232) SYMBOL(IL7)',
#   'type': 'Gene'},
#  {'NCBIGene': '5972',
#   'name': 'renin',
#   'SYMBOL': 'REN',
#   'UMLS': 'C1419338',
#   'HGNC': '9958',
#   'UNIPROTKB': 'P00797',
#   'ENSEMBL': 'ENSG00000143839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5972'},
#   'display': 'NCBIGene(5972) ENSEMBL(ENSG00000143839) HGNC(9958) UMLS(C1419338) UNIPROTKB(P00797) SYMBOL(REN)',
#   'type': 'Gene'},
#  {'NCBIGene': '3439',
#   'name': 'interferon alpha 1',
#   'SYMBOL': 'IFNA1',
#   'UMLS': 'C1415900',
#   'HGNC': '5417',
#   'UNIPROTKB': 'P01562',
#   'ENSEMBL': 'ENSG00000197919',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3439'},
#   'display': 'NCBIGene(3439) ENSEMBL(ENSG00000197919) HGNC(5417) UMLS(C1415900) UNIPROTKB(P01562) SYMBOL(IFNA1)',
#   'type': 'Gene'},
#  {'NCBIGene': '1636',
#   'name': 'angiotensin I converting enzyme',
#   'SYMBOL': 'ACE',
#   'UMLS': 'C1413931',
#   'HGNC': '2707',
#   'UNIPROTKB': 'P12821',
#   'ENSEMBL': 'ENSG00000159640',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1636'},
#   'display': 'NCBIGene(1636) ENSEMBL(ENSG00000159640) HGNC(2707) UMLS(C1413931) UNIPROTKB(P12821) SYMBOL(ACE)',
#   'type': 'Gene'},
#  {'NCBIGene': '213',
#   'name': 'albumin',
#   'SYMBOL': 'ALB',
#   'UMLS': 'C1412332',
#   'HGNC': '399',
#   'UNIPROTKB': 'P02768',
#   'ENSEMBL': 'ENSG00000163631',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '213'},
#   'display': 'NCBIGene(213) ENSEMBL(ENSG00000163631) HGNC(399) UMLS(C1412332) UNIPROTKB(P02768) SYMBOL(ALB)',
#   'type': 'Gene'},
#  {'NCBIGene': '340024',
#   'name': 'solute carrier family 6 member 19',
#   'SYMBOL': 'SLC6A19',
#   'UMLS': 'C1428660',
#   'HGNC': '27960',
#   'UNIPROTKB': 'Q695T7',
#   'ENSEMBL': 'ENSG00000174358',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '340024'},
#   'display': 'NCBIGene(340024) ENSEMBL(ENSG00000174358) HGNC(27960) UMLS(C1428660) UNIPROTKB(Q695T7) SYMBOL(SLC6A19)',
#   'type': 'Gene'},
#  {'NCBIGene': '3627',
#   'name': 'C-X-C motif chemokine ligand 10',
#   'SYMBOL': 'CXCL10',
#   'UMLS': 'C1367714',
#   'HGNC': '10637',
#   'UNIPROTKB': 'P02778',
#   'ENSEMBL': 'ENSG00000169245',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3627'},
#   'display': 'NCBIGene(3627) ENSEMBL(ENSG00000169245) HGNC(10637) UMLS(C1367714) UNIPROTKB(P02778) SYMBOL(CXCL10)',
#   'type': 'Gene'},
#  {'NCBIGene': '3576',
#   'name': 'C-X-C motif chemokine ligand 8',
#   'SYMBOL': 'CXCL8',
#   'UMLS': 'C1366571',
#   'HGNC': '6025',
#   'UNIPROTKB': 'P10145',
#   'ENSEMBL': 'ENSG00000169429',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3576'},
#   'display': 'NCBIGene(3576) ENSEMBL(ENSG00000169429) HGNC(6025) UMLS(C1366571) UNIPROTKB(P10145) SYMBOL(CXCL8)',
#   'type': 'Gene'},
#  {'NCBIGene': '2147',
#   'name': 'coagulation factor II, thrombin',
#   'SYMBOL': 'F2',
#   'UMLS': 'C1414504',
#   'HGNC': '3535',
#   'UNIPROTKB': 'P00734',
#   'ENSEMBL': 'ENSG00000180210',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2147'},
#   'display': 'NCBIGene(2147) ENSEMBL(ENSG00000180210) HGNC(3535) UMLS(C1414504) UNIPROTKB(P00734) SYMBOL(F2)',
#   'type': 'Gene'},
#  {'NCBIGene': '6868',
#   'name': 'ADAM metallopeptidase domain 17',
#   'SYMBOL': 'ADAM17',
#   'UMLS': 'C1412186',
#   'HGNC': '195',
#   'UNIPROTKB': 'P78536',
#   'ENSEMBL': 'ENSG00000151694',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6868'},
#   'display': 'NCBIGene(6868) ENSEMBL(ENSG00000151694) HGNC(195) UMLS(C1412186) UNIPROTKB(P78536) SYMBOL(ADAM17)',
#   'type': 'Gene'},
#  {'NCBIGene': '2580',
#   'name': 'cyclin G associated kinase',
#   'SYMBOL': 'GAK',
#   'UMLS': 'C1414944',
#   'HGNC': '4113',
#   'UNIPROTKB': 'O14976',
#   'ENSEMBL': 'ENSG00000178950',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2580'},
#   'display': 'NCBIGene(2580) ENSEMBL(ENSG00000178950) HGNC(4113) UMLS(C1414944) UNIPROTKB(O14976) SYMBOL(GAK)',
#   'type': 'Gene'},
#  {'NCBIGene': '10332',
#   'name': 'C-type lectin domain family 4 member M',
#   'SYMBOL': 'CLEC4M',
#   'UMLS': 'C1539099',
#   'HGNC': '13523',
#   'UNIPROTKB': 'Q9H2X3',
#   'ENSEMBL': 'ENSG00000104938',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10332'},
#   'display': 'NCBIGene(10332) ENSEMBL(ENSG00000104938) HGNC(13523) UMLS(C1539099) UNIPROTKB(Q9H2X3) SYMBOL(CLEC4M)',
#   'type': 'Gene'},
#  {'NCBIGene': '10044',
#   'name': 'SH2 domain containing 3C',
#   'SYMBOL': 'SH2D3C',
#   'UMLS': 'C1335818',
#   'HGNC': '16884',
#   'UNIPROTKB': 'Q8N5H7',
#   'ENSEMBL': 'ENSG00000095370',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10044'},
#   'display': 'NCBIGene(10044) ENSEMBL(ENSG00000095370) HGNC(16884) UMLS(C1335818) UNIPROTKB(Q8N5H7) SYMBOL(SH2D3C)',
#   'type': 'Gene'},
#  {'NCBIGene': '5499',
#   'name': 'protein phosphatase 1 catalytic subunit alpha',
#   'SYMBOL': 'PPP1CA',
#   'UMLS': 'C1335240',
#   'HGNC': '9281',
#   'UNIPROTKB': 'P62136',
#   'ENSEMBL': 'ENSG00000172531',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5499'},
#   'display': 'NCBIGene(5499) ENSEMBL(ENSG00000172531) HGNC(9281) UMLS(C1335240) UNIPROTKB(P62136) SYMBOL(PPP1CA)',
#   'type': 'Gene'},
#  {'NCBIGene': '682',
#   'name': 'basigin (Ok blood group)',
#   'SYMBOL': 'BSG',
#   'UMLS': 'C1412828',
#   'HGNC': '1116',
#   'UNIPROTKB': 'P35613',
#   'ENSEMBL': 'ENSG00000172270',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '682'},
#   'display': 'NCBIGene(682) ENSEMBL(ENSG00000172270) HGNC(1116) UMLS(C1412828) UNIPROTKB(P35613) SYMBOL(BSG)',
#   'type': 'Gene'},
#  {'NCBIGene': '2152',
#   'name': 'coagulation factor III, tissue factor',
#   'SYMBOL': 'F3',
#   'UMLS': 'C1333522',
#   'HGNC': '3541',
#   'UNIPROTKB': 'P13726',
#   'ENSEMBL': 'ENSG00000117525',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2152'},
#   'display': 'NCBIGene(2152) ENSEMBL(ENSG00000117525) HGNC(3541) UMLS(C1333522) UNIPROTKB(P13726) SYMBOL(F3)',
#   'type': 'Gene'},
#  {'NCBIGene': '339967',
#   'name': 'transmembrane serine protease 11A',
#   'SYMBOL': 'TMPRSS11A',
#   'UMLS': 'C1540024',
#   'HGNC': '27954',
#   'UNIPROTKB': 'Q6ZMR5',
#   'ENSEMBL': 'ENSG00000187054',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '339967'},
#   'display': 'NCBIGene(339967) ENSEMBL(ENSG00000187054) HGNC(27954) UMLS(C1540024) UNIPROTKB(Q6ZMR5) SYMBOL(TMPRSS11A)',
#   'type': 'Gene'},
#  {'NCBIGene': '7137',
#   'name': 'troponin I3, cardiac type',
#   'SYMBOL': 'TNNI3',
#   'UMLS': 'C1420826',
#   'HGNC': '11947',
#   'UNIPROTKB': 'P19429',
#   'ENSEMBL': 'ENSG00000129991',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7137'},
#   'display': 'NCBIGene(7137) ENSEMBL(ENSG00000129991) HGNC(11947) UMLS(C1420826) UNIPROTKB(P19429) SYMBOL(TNNI3)',
#   'type': 'Gene'},
#  {'NCBIGene': '3605',
#   'name': 'interleukin 17A',
#   'SYMBOL': 'IL17A',
#   'UMLS': 'C1825592',
#   'HGNC': '5981',
#   'UNIPROTKB': 'Q16552',
#   'ENSEMBL': 'ENSG00000112115',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3605'},
#   'display': 'NCBIGene(3605) ENSEMBL(ENSG00000112115) HGNC(5981) UMLS(C1825592) UNIPROTKB(Q16552) SYMBOL(IL17A)',
#   'type': 'Gene'},
#  {'NCBIGene': '1514',
#   'name': 'cathepsin L',
#   'SYMBOL': 'CTSL',
#   'UMLS': 'C1332807',
#   'HGNC': '2537',
#   'UNIPROTKB': 'P07711',
#   'ENSEMBL': 'ENSG00000135047',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1514'},
#   'display': 'NCBIGene(1514) ENSEMBL(ENSG00000135047) HGNC(2537) UMLS(C1332807) UNIPROTKB(P07711) SYMBOL(CTSL)',
#   'type': 'Gene'},
#  {'NCBIGene': '1803',
#   'name': 'dipeptidyl peptidase 4',
#   'SYMBOL': 'DPP4',
#   'UMLS': 'C1414141',
#   'HGNC': '3009',
#   'UNIPROTKB': 'P27487',
#   'ENSEMBL': 'ENSG00000197635',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1803'},
#   'display': 'NCBIGene(1803) ENSEMBL(ENSG00000197635) HGNC(3009) UMLS(C1414141) UNIPROTKB(P27487) SYMBOL(DPP4)',
#   'type': 'Gene'},
#  {'NCBIGene': '186',
#   'name': 'angiotensin II receptor type 2',
#   'SYMBOL': 'AGTR2',
#   'UMLS': 'C1332036',
#   'HGNC': '338',
#   'UNIPROTKB': 'P50052',
#   'ENSEMBL': 'ENSG00000180772',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '186'},
#   'display': 'NCBIGene(186) ENSEMBL(ENSG00000180772) HGNC(338) UMLS(C1332036) UNIPROTKB(P50052) SYMBOL(AGTR2)',
#   'type': 'Gene'},
#  {'NCBIGene': '10473',
#   'name': 'high mobility group nucleosomal binding domain 4',
#   'SYMBOL': 'HMGN4',
#   'UMLS': 'C1333916',
#   'HGNC': '4989',
#   'UNIPROTKB': 'O00479',
#   'ENSEMBL': 'ENSG00000182952',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10473'},
#   'display': 'NCBIGene(10473) ENSEMBL(ENSG00000182952) HGNC(4989) UMLS(C1333916) UNIPROTKB(O00479) SYMBOL(HMGN4)',
#   'type': 'Gene'},
#  {'NCBIGene': '3559',
#   'name': 'interleukin 2 receptor subunit alpha',
#   'SYMBOL': 'IL2RA',
#   'UMLS': 'C1334114',
#   'HGNC': '6008',
#   'UNIPROTKB': 'P01589',
#   'ENSEMBL': 'ENSG00000134460',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3559'},
#   'display': 'NCBIGene(3559) ENSEMBL(ENSG00000134460) HGNC(6008) UMLS(C1334114) UNIPROTKB(P01589) SYMBOL(IL2RA)',
#   'type': 'Gene'},
#  {'NCBIGene': '3456',
#   'name': 'interferon beta 1',
#   'SYMBOL': 'IFNB1',
#   'UMLS': 'C1415912',
#   'HGNC': '5434',
#   'UNIPROTKB': 'P01574',
#   'ENSEMBL': 'ENSG00000171855',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3456'},
#   'display': 'NCBIGene(3456) ENSEMBL(ENSG00000171855) HGNC(5434) UMLS(C1415912) UNIPROTKB(P01574) SYMBOL(IFNB1)',
#   'type': 'Gene'},
#  {'NCBIGene': '2875',
#   'name': 'glutamic--pyruvic transaminase',
#   'SYMBOL': 'GPT',
#   'UMLS': 'C1415274',
#   'HGNC': '4552',
#   'UNIPROTKB': 'P24298',
#   'ENSEMBL': 'ENSG00000167701',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2875'},
#   'display': 'NCBIGene(2875) ENSEMBL(ENSG00000167701) HGNC(4552) UMLS(C1415274) UNIPROTKB(P24298) SYMBOL(GPT)',
#   'type': 'Gene'},
#  {'NCBIGene': '4151',
#   'name': 'myoglobin',
#   'SYMBOL': 'MB',
#   'UMLS': 'C1417048',
#   'HGNC': '6915',
#   'UNIPROTKB': 'P02144',
#   'ENSEMBL': 'ENSG00000198125',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4151'},
#   'display': 'NCBIGene(4151) ENSEMBL(ENSG00000198125) HGNC(6915) UMLS(C1417048) UNIPROTKB(P02144) SYMBOL(MB)',
#   'type': 'Gene'},
#  {'NCBIGene': '7113',
#   'name': 'transmembrane serine protease 2',
#   'SYMBOL': 'TMPRSS2',
#   'UMLS': 'C1336641',
#   'HGNC': '11876',
#   'UNIPROTKB': 'O15393',
#   'ENSEMBL': 'ENSG00000184012',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7113'},
#   'display': 'NCBIGene(7113) ENSEMBL(ENSG00000184012) HGNC(11876) UMLS(C1336641) UNIPROTKB(O15393) SYMBOL(TMPRSS2)',
#   'type': 'Gene'},
#  {'NCBIGene': '10410',
#   'name': 'interferon induced transmembrane protein 3',
#   'SYMBOL': 'IFITM3',
#   'UMLS': 'C1415898',
#   'HGNC': '5414',
#   'UNIPROTKB': 'Q01628',
#   'ENSEMBL': 'ENSG00000142089',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10410'},
#   'display': 'NCBIGene(10410) ENSEMBL(ENSG00000142089) HGNC(5414) UMLS(C1415898) UNIPROTKB(Q01628) SYMBOL(IFITM3)',
#   'type': 'Gene'},
#  {'NCBIGene': '3569',
#   'name': 'interleukin 6',
#   'SYMBOL': 'IL6',
#   'UMLS': 'C1334122',
#   'HGNC': '6018',
#   'UNIPROTKB': 'P05231',
#   'ENSEMBL': 'ENSG00000136244',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3569'},
#   'display': 'NCBIGene(3569) ENSEMBL(ENSG00000136244) HGNC(6018) UMLS(C1334122) UNIPROTKB(P05231) SYMBOL(IL6)',
#   'type': 'Gene'},
#  {'NCBIGene': '22848',
#   'name': 'AP2 associated kinase 1',
#   'SYMBOL': 'AAK1',
#   'UMLS': 'C1426329',
#   'HGNC': '19679',
#   'UNIPROTKB': 'Q2M2I8',
#   'ENSEMBL': 'ENSG00000115977',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '22848'},
#   'display': 'NCBIGene(22848) ENSEMBL(ENSG00000115977) HGNC(19679) UMLS(C1426329) UNIPROTKB(Q2M2I8) SYMBOL(AAK1)',
#   'type': 'Gene'},
#  {'NCBIGene': '925',
#   'name': 'CD8a molecule',
#   'SYMBOL': 'CD8A',
#   'UMLS': 'C1413244',
#   'HGNC': '1706',
#   'UNIPROTKB': 'P01732',
#   'ENSEMBL': 'ENSG00000153563',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '925'},
#   'display': 'NCBIGene(925) ENSEMBL(ENSG00000153563) HGNC(1706) UMLS(C1413244) UNIPROTKB(P01732) SYMBOL(CD8A)',
#   'type': 'Gene'},
#  {'NCBIGene': '59272',
#   'name': 'angiotensin I converting enzyme 2',
#   'SYMBOL': 'ACE2',
#   'UMLS': 'C1422064',
#   'HGNC': '13557',
#   'UNIPROTKB': 'Q9BYF1',
#   'ENSEMBL': 'ENSG00000130234',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#   'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#   'type': 'Gene'},
#  {'NCBIGene': '7124',
#   'name': 'tumor necrosis factor',
#   'SYMBOL': 'TNF',
#   'UMLS': 'C0812246',
#   'HGNC': '11892',
#   'UNIPROTKB': 'P01375',
#   'ENSEMBL': 'ENSG00000204490',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7124'},
#   'display': 'NCBIGene(7124) ENSEMBL(ENSG00000204490) HGNC(11892) UMLS(C0812246) UNIPROTKB(P01375) SYMBOL(TNF)',
#   'type': 'Gene'},
#  {'NCBIGene': '3586',
#   'name': 'interleukin 10',
#   'SYMBOL': 'IL10',
#   'UMLS': 'C1334098',
#   'HGNC': '5962',
#   'UNIPROTKB': 'P22301',
#   'ENSEMBL': 'ENSG00000136634',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3586'},
#   'display': 'NCBIGene(3586) ENSEMBL(ENSG00000136634) HGNC(5962) UMLS(C1334098) UNIPROTKB(P22301) SYMBOL(IL10)',
#   'type': 'Gene'},
#  {'NCBIGene': '185',
#   'name': 'angiotensin II receptor type 1',
#   'SYMBOL': 'AGTR1',
#   'UMLS': 'C1439284',
#   'HGNC': '336',
#   'UNIPROTKB': 'P30556',
#   'ENSEMBL': 'ENSG00000144891',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '185'},
#   'display': 'NCBIGene(185) ENSEMBL(ENSG00000144891) HGNC(336) UMLS(C1439284) UNIPROTKB(P30556) SYMBOL(AGTR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '1506',
#   'name': 'chymotrypsin like',
#   'SYMBOL': 'CTRL',
#   'UMLS': 'C1413809',
#   'HGNC': '2524',
#   'UNIPROTKB': 'P40313',
#   'ENSEMBL': 'ENSG00000141086',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1506'},
#   'display': 'NCBIGene(1506) ENSEMBL(ENSG00000141086) HGNC(2524) UMLS(C1413809) UNIPROTKB(P40313) SYMBOL(CTRL)',
#   'type': 'Gene'},
#  {'NCBIGene': '54938',
#   'name': 'seryl-tRNA synthetase 2, mitochondrial',
#   'SYMBOL': 'SARS2',
#   'UMLS': 'C1425041',
#   'HGNC': '17697',
#   'UNIPROTKB': 'Q9NP81',
#   'ENSEMBL': 'ENSG00000104835',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '54938'},
#   'display': 'NCBIGene(54938) ENSEMBL(ENSG00000104835) HGNC(17697) UMLS(C1425041) UNIPROTKB(Q9NP81) SYMBOL(SARS2)',
#   'type': 'Gene'},
#  {'NCBIGene': '6348',
#   'name': 'C-C motif chemokine ligand 3',
#   'SYMBOL': 'CCL3',
#   'UMLS': 'C1332690',
#   'HGNC': '10627',
#   'UNIPROTKB': 'P10147',
#   'ENSEMBL': 'ENSG00000274221',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6348'},
#   'display': 'NCBIGene(6348) ENSEMBL(ENSG00000274221) HGNC(10627) UMLS(C1332690) UNIPROTKB(P10147) SYMBOL(CCL3)',
#   'type': 'Gene'},
#  {'NCBIGene': '5045',
#   'name': 'furin, paired basic amino acid cleaving enzyme',
#   'SYMBOL': 'FURIN',
#   'UMLS': 'C0919550',
#   'HGNC': '8568',
#   'UNIPROTKB': 'P09958',
#   'ENSEMBL': 'ENSG00000140564',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5045'},
#   'display': 'NCBIGene(5045) ENSEMBL(ENSG00000140564) HGNC(8568) UMLS(C0919550) UNIPROTKB(P09958) SYMBOL(FURIN)',
#   'type': 'Gene'},
#  {'NCBIGene': '6651',
#   'name': 'SON DNA and RNA binding protein',
#   'SYMBOL': 'SON',
#   'UMLS': 'C1420310',
#   'HGNC': '11183',
#   'UNIPROTKB': 'P18583',
#   'ENSEMBL': 'ENSG00000159140',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6651'},
#   'display': 'NCBIGene(6651) ENSEMBL(ENSG00000159140) HGNC(11183) UMLS(C1420310) UNIPROTKB(P18583) SYMBOL(SON)',
#   'type': 'Gene'},
#  {'NCBIGene': '5447',
#   'name': 'cytochrome p450 oxidoreductase',
#   'SYMBOL': 'POR',
#   'UMLS': 'C1335232',
#   'HGNC': '9208',
#   'UNIPROTKB': 'P16435',
#   'ENSEMBL': 'ENSG00000127948',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5447'},
#   'display': 'NCBIGene(5447) ENSEMBL(ENSG00000127948) HGNC(9208) UMLS(C1335232) UNIPROTKB(P16435) SYMBOL(POR)',
#   'type': 'Gene'},
#  {'NCBIGene': '7054',
#   'name': 'tyrosine hydroxylase',
#   'SYMBOL': 'TH',
#   'UMLS': 'C1420718',
#   'HGNC': '11782',
#   'UNIPROTKB': 'P07101',
#   'ENSEMBL': 'ENSG00000180176',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7054'},
#   'display': 'NCBIGene(7054) ENSEMBL(ENSG00000180176) HGNC(11782) UMLS(C1420718) UNIPROTKB(P07101) SYMBOL(TH)',
#   'type': 'Gene'},
#  {'NCBIGene': '4141',
#   'name': 'methionyl-tRNA synthetase 1',
#   'SYMBOL': 'MARS1',
#   'UMLS': 'C1417035',
#   'HGNC': '6898',
#   'UNIPROTKB': 'P56192',
#   'ENSEMBL': 'ENSG00000166986',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4141'},
#   'display': 'NCBIGene(4141) ENSEMBL(ENSG00000166986) HGNC(6898) UMLS(C1417035) UNIPROTKB(P56192) SYMBOL(MARS1)',
#   'type': 'Gene'},
#  {'NCBIGene': '28',
#   'name': 'ABO, alpha 1-3-N-acetylgalactosaminyltransferase and alpha 1-3-galactosyltransferase',
#   'SYMBOL': 'ABO',
#   'UMLS': 'C1412099',
#   'HGNC': '79',
#   'UNIPROTKB': 'P16442',
#   'ENSEMBL': 'ENSG00000175164',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '28'},
#   'display': 'NCBIGene(28) ENSEMBL(ENSG00000175164) HGNC(79) UMLS(C1412099) UNIPROTKB(P16442) SYMBOL(ABO)',
#   'type': 'Gene'},
#  {'NCBIGene': '54585',
#   'name': 'leucine zipper transcription factor like 1',
#   'SYMBOL': 'LZTFL1',
#   'UMLS': 'C1416946',
#   'HGNC': '6741',
#   'UNIPROTKB': 'Q9NQ48',
#   'ENSEMBL': 'ENSG00000163818',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '54585'},
#   'display': 'NCBIGene(54585) ENSEMBL(ENSG00000163818) HGNC(6741) UMLS(C1416946) UNIPROTKB(Q9NQ48) SYMBOL(LZTFL1)',
#   'type': 'Gene'},
#  {'NCBIGene': '51284',
#   'name': 'toll like receptor 7',
#   'SYMBOL': 'TLR7',
#   'UMLS': 'C1336639',
#   'HGNC': '15631',
#   'UNIPROTKB': 'Q9NYK1',
#   'ENSEMBL': 'ENSG00000196664',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '51284'},
#   'display': 'NCBIGene(51284) ENSEMBL(ENSG00000196664) HGNC(15631) UMLS(C1336639) UNIPROTKB(Q9NYK1) SYMBOL(TLR7)',
#   'type': 'Gene'},
#  {'NCBIGene': '6364',
#   'name': 'C-C motif chemokine ligand 20',
#   'SYMBOL': 'CCL20',
#   'UMLS': 'C1366524',
#   'HGNC': '10619',
#   'UNIPROTKB': 'P78556',
#   'ENSEMBL': 'ENSG00000115009',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6364'},
#   'display': 'NCBIGene(6364) ENSEMBL(ENSG00000115009) HGNC(10619) UMLS(C1366524) UNIPROTKB(P78556) SYMBOL(CCL20)',
#   'type': 'Gene'},
#  {'NCBIGene': '973',
#   'name': 'CD79a molecule',
#   'SYMBOL': 'CD79A',
#   'UMLS': 'C1413238',
#   'HGNC': '1698',
#   'UNIPROTKB': 'P11912',
#   'ENSEMBL': 'ENSG00000105369',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '973'},
#   'display': 'NCBIGene(973) ENSEMBL(ENSG00000105369) HGNC(1698) UMLS(C1413238) UNIPROTKB(P11912) SYMBOL(CD79A)',
#   'type': 'Gene'},
#  {'NCBIGene': '3930',
#   'name': 'lamin B receptor',
#   'SYMBOL': 'LBR',
#   'UMLS': 'C1416802',
#   'HGNC': '6518',
#   'UNIPROTKB': 'Q14739',
#   'ENSEMBL': 'ENSG00000143815',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3930'},
#   'display': 'NCBIGene(3930) ENSEMBL(ENSG00000143815) HGNC(6518) UMLS(C1416802) UNIPROTKB(Q14739) SYMBOL(LBR)',
#   'type': 'Gene'},
#  {'NCBIGene': '3700',
#   'name': 'inter-alpha-trypsin inhibitor heavy chain 4',
#   'SYMBOL': 'ITIH4',
#   'UMLS': 'C1416509',
#   'HGNC': '6169',
#   'UNIPROTKB': 'Q14624',
#   'ENSEMBL': 'ENSG00000055955',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3700'},
#   'display': 'NCBIGene(3700) ENSEMBL(ENSG00000055955) HGNC(6169) UMLS(C1416509) UNIPROTKB(Q14624) SYMBOL(ITIH4)',
#   'type': 'Gene'},
#  {'NCBIGene': '6667',
#   'name': 'Sp1 transcription factor',
#   'SYMBOL': 'SP1',
#   'UMLS': 'C1335858',
#   'HGNC': '11205',
#   'UNIPROTKB': 'P08047',
#   'ENSEMBL': 'ENSG00000185591',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6667'},
#   'display': 'NCBIGene(6667) ENSEMBL(ENSG00000185591) HGNC(11205) UMLS(C1335858) UNIPROTKB(P08047) SYMBOL(SP1)',
#   'type': 'Gene'},
#  {'NCBIGene': '5741',
#   'name': 'parathyroid hormone',
#   'SYMBOL': 'PTH',
#   'UMLS': 'C1419072',
#   'HGNC': '9606',
#   'UNIPROTKB': 'P01270',
#   'ENSEMBL': 'ENSG00000152266',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5741'},
#   'display': 'NCBIGene(5741) ENSEMBL(ENSG00000152266) HGNC(9606) UMLS(C1419072) UNIPROTKB(P01270) SYMBOL(PTH)',
#   'type': 'Gene'},
#  {'NCBIGene': '27352',
#   'name': 'small G protein signaling modulator 3',
#   'SYMBOL': 'SGSM3',
#   'UMLS': 'C1428456',
#   'HGNC': '25228',
#   'UNIPROTKB': 'Q96HU1',
#   'ENSEMBL': 'ENSG00000100359',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '27352'},
#   'display': 'NCBIGene(27352) ENSEMBL(ENSG00000100359) HGNC(25228) UMLS(C1428456) UNIPROTKB(Q96HU1) SYMBOL(SGSM3)',
#   'type': 'Gene'},
#  {'NCBIGene': '6778',
#   'name': 'signal transducer and activator of transcription 6',
#   'SYMBOL': 'STAT6',
#   'UMLS': 'C1335877',
#   'HGNC': '11368',
#   'UNIPROTKB': 'P42226',
#   'ENSEMBL': 'ENSG00000166888',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6778'},
#   'display': 'NCBIGene(6778) ENSEMBL(ENSG00000166888) HGNC(11368) UMLS(C1335877) UNIPROTKB(P42226) SYMBOL(STAT6)',
#   'type': 'Gene'},
#  {'NCBIGene': '5291',
#   'name': 'phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit beta',
#   'SYMBOL': 'PIK3CB',
#   'UMLS': 'C1335213',
#   'HGNC': '8976',
#   'UNIPROTKB': 'P42338',
#   'ENSEMBL': 'ENSG00000051382',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5291'},
#   'display': 'NCBIGene(5291) ENSEMBL(ENSG00000051382) HGNC(8976) UMLS(C1335213) UNIPROTKB(P42338) SYMBOL(PIK3CB)',
#   'type': 'Gene'},
#  {'NCBIGene': '4615',
#   'name': 'MYD88 innate immune signal transduction adaptor',
#   'SYMBOL': 'MYD88',
#   'UMLS': 'C1417530',
#   'HGNC': '7562',
#   'UNIPROTKB': 'Q99836',
#   'ENSEMBL': 'ENSG00000172936',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4615'},
#   'display': 'NCBIGene(4615) ENSEMBL(ENSG00000172936) HGNC(7562) UMLS(C1417530) UNIPROTKB(Q99836) SYMBOL(MYD88)',
#   'type': 'Gene'},
#  {'NCBIGene': '5781',
#   'name': 'protein tyrosine phosphatase non-receptor type 11',
#   'SYMBOL': 'PTPN11',
#   'UMLS': 'C1335280',
#   'HGNC': '9644',
#   'UNIPROTKB': 'Q06124',
#   'ENSEMBL': 'ENSG00000179295',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5781'},
#   'display': 'NCBIGene(5781) ENSEMBL(ENSG00000179295) HGNC(9644) UMLS(C1335280) UNIPROTKB(Q06124) SYMBOL(PTPN11)',
#   'type': 'Gene'},
#  {'NCBIGene': '929',
#   'name': 'CD14 molecule',
#   'SYMBOL': 'CD14',
#   'UMLS': 'C1367477',
#   'HGNC': '1628',
#   'UNIPROTKB': 'P08571',
#   'ENSEMBL': 'ENSG00000170458',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '929'},
#   'display': 'NCBIGene(929) ENSEMBL(ENSG00000170458) HGNC(1628) UMLS(C1367477) UNIPROTKB(P08571) SYMBOL(CD14)',
#   'type': 'Gene'},
#  {'NCBIGene': '4353',
#   'name': 'myeloperoxidase',
#   'SYMBOL': 'MPO',
#   'UMLS': 'C1417245',
#   'HGNC': '7218',
#   'UNIPROTKB': 'P05164',
#   'ENSEMBL': 'ENSG00000005381',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4353'},
#   'display': 'NCBIGene(4353) ENSEMBL(ENSG00000005381) HGNC(7218) UMLS(C1417245) UNIPROTKB(P05164) SYMBOL(MPO)',
#   'type': 'Gene'},
#  {'NCBIGene': '960',
#   'name': 'CD44 molecule (Indian blood group)',
#   'SYMBOL': 'CD44',
#   'UMLS': 'C1332712',
#   'HGNC': '1681',
#   'UNIPROTKB': 'P16070',
#   'ENSEMBL': 'ENSG00000026508',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '960'},
#   'display': 'NCBIGene(960) ENSEMBL(ENSG00000026508) HGNC(1681) UMLS(C1332712) UNIPROTKB(P16070) SYMBOL(CD44)',
#   'type': 'Gene'},
#  {'NCBIGene': '5054',
#   'name': 'serpin family E member 1',
#   'SYMBOL': 'SERPINE1',
#   'UMLS': 'C1418252',
#   'HGNC': '8583',
#   'UNIPROTKB': 'P05121',
#   'ENSEMBL': 'ENSG00000106366',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5054'},
#   'display': 'NCBIGene(5054) ENSEMBL(ENSG00000106366) HGNC(8583) UMLS(C1418252) UNIPROTKB(P05121) SYMBOL(SERPINE1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3308',
#   'name': 'heat shock protein family A (Hsp70) member 4',
#   'SYMBOL': 'HSPA4',
#   'UMLS': 'C1415760',
#   'HGNC': '5237',
#   'UNIPROTKB': 'P34932',
#   'ENSEMBL': 'ENSG00000170606',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3308'},
#   'display': 'NCBIGene(3308) ENSEMBL(ENSG00000170606) HGNC(5237) UMLS(C1415760) UNIPROTKB(P34932) SYMBOL(HSPA4)',
#   'type': 'Gene'},
#  {'NCBIGene': '5465',
#   'name': 'peroxisome proliferator activated receptor alpha',
#   'SYMBOL': 'PPARA',
#   'UMLS': 'C1418776',
#   'HGNC': '9232',
#   'UNIPROTKB': 'Q07869',
#   'ENSEMBL': 'ENSG00000186951',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5465'},
#   'display': 'NCBIGene(5465) ENSEMBL(ENSG00000186951) HGNC(9232) UMLS(C1418776) UNIPROTKB(Q07869) SYMBOL(PPARA)',
#   'type': 'Gene'},
#  {'NCBIGene': '1026',
#   'name': 'cyclin dependent kinase inhibitor 1A',
#   'SYMBOL': 'CDKN1A',
#   'UMLS': 'C0249197',
#   'HGNC': '1784',
#   'UNIPROTKB': 'P38936',
#   'ENSEMBL': 'ENSG00000124762',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1026'},
#   'display': 'NCBIGene(1026) ENSEMBL(ENSG00000124762) HGNC(1784) UMLS(C0249197) UNIPROTKB(P38936) SYMBOL(CDKN1A)',
#   'type': 'Gene'},
#  {'NCBIGene': '3578',
#   'name': 'interleukin 9',
#   'SYMBOL': 'IL9',
#   'UMLS': 'C1334127',
#   'HGNC': '6029',
#   'UNIPROTKB': 'P15248',
#   'ENSEMBL': 'ENSG00000145839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3578'},
#   'display': 'NCBIGene(3578) ENSEMBL(ENSG00000145839) HGNC(6029) UMLS(C1334127) UNIPROTKB(P15248) SYMBOL(IL9)',
#   'type': 'Gene'},
#  {'NCBIGene': '3661',
#   'name': 'interferon regulatory factor 3',
#   'SYMBOL': 'IRF3',
#   'UMLS': 'C1334139',
#   'HGNC': '6118',
#   'UNIPROTKB': 'Q14653',
#   'ENSEMBL': 'ENSG00000126456',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3661'},
#   'display': 'NCBIGene(3661) ENSEMBL(ENSG00000126456) HGNC(6118) UMLS(C1334139) UNIPROTKB(Q14653) SYMBOL(IRF3)',
#   'type': 'Gene'},
#  {'NCBIGene': '8795',
#   'name': 'TNF receptor superfamily member 10b',
#   'SYMBOL': 'TNFRSF10B',
#   'UMLS': 'C1336644',
#   'HGNC': '11905',
#   'UNIPROTKB': 'O14763',
#   'ENSEMBL': 'ENSG00000120889',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '8795'},
#   'display': 'NCBIGene(8795) ENSEMBL(ENSG00000120889) HGNC(11905) UMLS(C1336644) UNIPROTKB(O14763) SYMBOL(TNFRSF10B)',
#   'type': 'Gene'},
#  {'NCBIGene': '1161',
#   'name': 'ERCC excision repair 8, CSA ubiquitin ligase complex subunit',
#   'SYMBOL': 'ERCC8',
#   'UMLS': 'C1414440',
#   'HGNC': '3439',
#   'UNIPROTKB': 'Q13216',
#   'ENSEMBL': 'ENSG00000049167',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1161'},
#   'display': 'NCBIGene(1161) ENSEMBL(ENSG00000049167) HGNC(3439) UMLS(C1414440) UNIPROTKB(Q13216) SYMBOL(ERCC8)',
#   'type': 'Gene'},
#  {'NCBIGene': '2099',
#   'name': 'estrogen receptor 1',
#   'SYMBOL': 'ESR1',
#   'UMLS': 'C1414461',
#   'HGNC': '3467',
#   'UNIPROTKB': 'P03372',
#   'ENSEMBL': 'ENSG00000091831',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2099'},
#   'display': 'NCBIGene(2099) ENSEMBL(ENSG00000091831) HGNC(3467) UMLS(C1414461) UNIPROTKB(P03372) SYMBOL(ESR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '9021',
#   'name': 'suppressor of cytokine signaling 3',
#   'SYMBOL': 'SOCS3',
#   'UMLS': 'C1426212',
#   'HGNC': '19391',
#   'UNIPROTKB': 'O14543',
#   'ENSEMBL': 'ENSG00000184557',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9021'},
#   'display': 'NCBIGene(9021) ENSEMBL(ENSG00000184557) HGNC(19391) UMLS(C1426212) UNIPROTKB(O14543) SYMBOL(SOCS3)',
#   'type': 'Gene'},
#  {'NCBIGene': '8600',
#   'name': 'TNF superfamily member 11',
#   'SYMBOL': 'TNFSF11',
#   'UMLS': 'C1367028',
#   'HGNC': '11926',
#   'UNIPROTKB': 'O14788',
#   'ENSEMBL': 'ENSG00000120659',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '8600'},
#   'display': 'NCBIGene(8600) ENSEMBL(ENSG00000120659) HGNC(11926) UMLS(C1367028) UNIPROTKB(O14788) SYMBOL(TNFSF11)',
#   'type': 'Gene'},
#  {'name': 'T cell receptor beta variable 20/OR9-2 (non-functional)',
#   'SYMBOL': 'TRBV20OR9-2',
#   'ENSEMBL': 'ENSG00000205274',
#   'primary': {'identifier': 'ENSEMBL',
#    'cls': 'Gene',
#    'value': 'ENSG00000205274'},
#   'display': 'ENSEMBL(ENSG00000205274) SYMBOL(TRBV20OR9-2)',
#   'type': 'Gene'},
#  {'NCBIGene': '1442',
#   'name': 'chorionic somatomammotropin hormone 1',
#   'SYMBOL': 'CSH1',
#   'UMLS': 'C1413752',
#   'HGNC': '2440',
#   'UNIPROTKB': 'P0DML2',
#   'ENSEMBL': 'ENSG00000136488',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1442'},
#   'display': 'NCBIGene(1442) ENSEMBL(ENSG00000136488) HGNC(2440) UMLS(C1413752) UNIPROTKB(P0DML2) SYMBOL(CSH1)',
#   'type': 'Gene'},
#  {'NCBIGene': '5595',
#   'name': 'mitogen-activated protein kinase 3',
#   'SYMBOL': 'MAPK3',
#   'UMLS': 'C1366765',
#   'HGNC': '6877',
#   'UNIPROTKB': 'P27361',
#   'ENSEMBL': 'ENSG00000102882',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5595'},
#   'display': 'NCBIGene(5595) ENSEMBL(ENSG00000102882) HGNC(6877) UMLS(C1366765) UNIPROTKB(P27361) SYMBOL(MAPK3)',
#   'type': 'Gene'},
#  {'NCBIGene': '3313',
#   'name': 'heat shock protein family A (Hsp70) member 9',
#   'SYMBOL': 'HSPA9',
#   'UMLS': 'C1825549',
#   'HGNC': '5244',
#   'UNIPROTKB': 'P38646',
#   'ENSEMBL': 'ENSG00000113013',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3313'},
#   'display': 'NCBIGene(3313) ENSEMBL(ENSG00000113013) HGNC(5244) UMLS(C1825549) UNIPROTKB(P38646) SYMBOL(HSPA9)',
#   'type': 'Gene'},
#  {'NCBIGene': '914',
#   'name': 'CD2 molecule',
#   'SYMBOL': 'CD2',
#   'UMLS': 'C1367475',
#   'HGNC': '1639',
#   'UNIPROTKB': 'P06729',
#   'ENSEMBL': 'ENSG00000116824',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '914'},
#   'display': 'NCBIGene(914) ENSEMBL(ENSG00000116824) HGNC(1639) UMLS(C1367475) UNIPROTKB(P06729) SYMBOL(CD2)',
#   'type': 'Gene'},
#  {'NCBIGene': '7098',
#   'name': 'toll like receptor 3',
#   'SYMBOL': 'TLR3',
#   'UMLS': 'C1336635',
#   'HGNC': '11849',
#   'UNIPROTKB': 'O15455',
#   'ENSEMBL': 'ENSG00000164342',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7098'},
#   'display': 'NCBIGene(7098) ENSEMBL(ENSG00000164342) HGNC(11849) UMLS(C1336635) UNIPROTKB(O15455) SYMBOL(TLR3)',
#   'type': 'Gene'},
#  {'NCBIGene': '3383',
#   'name': 'intercellular adhesion molecule 1',
#   'SYMBOL': 'ICAM1',
#   'UMLS': 'C1334074',
#   'HGNC': '5344',
#   'UNIPROTKB': 'P05362',
#   'ENSEMBL': 'ENSG00000090339',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3383'},
#   'display': 'NCBIGene(3383) ENSEMBL(ENSG00000090339) HGNC(5344) UMLS(C1334074) UNIPROTKB(P05362) SYMBOL(ICAM1)',
#   'type': 'Gene'},
#  {'NCBIGene': '6898',
#   'name': 'tyrosine aminotransferase',
#   'SYMBOL': 'TAT',
#   'UMLS': 'C1420590',
#   'HGNC': '11573',
#   'UNIPROTKB': 'P17735',
#   'ENSEMBL': 'ENSG00000198650',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6898'},
#   'display': 'NCBIGene(6898) ENSEMBL(ENSG00000198650) HGNC(11573) UMLS(C1420590) UNIPROTKB(P17735) SYMBOL(TAT)',
#   'type': 'Gene'},
#  {'NCBIGene': '5327',
#   'name': 'plasminogen activator, tissue type',
#   'SYMBOL': 'PLAT',
#   'UMLS': 'C1367601',
#   'HGNC': '9051',
#   'UNIPROTKB': 'P00750',
#   'ENSEMBL': 'ENSG00000104368',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5327'},
#   'display': 'NCBIGene(5327) ENSEMBL(ENSG00000104368) HGNC(9051) UMLS(C1367601) UNIPROTKB(P00750) SYMBOL(PLAT)',
#   'type': 'Gene'},
#  {'NCBIGene': '3133',
#   'name': 'major histocompatibility complex, class I, E',
#   'SYMBOL': 'HLA-E',
#   'UMLS': 'C1415585',
#   'HGNC': '4962',
#   'UNIPROTKB': 'P13747',
#   'ENSEMBL': 'ENSG00000204592',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3133'},
#   'display': 'NCBIGene(3133) ENSEMBL(ENSG00000204592) HGNC(4962) UMLS(C1415585) UNIPROTKB(P13747) SYMBOL(HLA-E)',
#   'type': 'Gene'},
#  {'NCBIGene': '1950',
#   'name': 'epidermal growth factor',
#   'SYMBOL': 'EGF',
#   'UMLS': 'C1367721',
#   'HGNC': '3229',
#   'UNIPROTKB': 'P01133',
#   'ENSEMBL': 'ENSG00000138798',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1950'},
#   'display': 'NCBIGene(1950) ENSEMBL(ENSG00000138798) HGNC(3229) UMLS(C1367721) UNIPROTKB(P01133) SYMBOL(EGF)',
#   'type': 'Gene'},
#  {'NCBIGene': '7037',
#   'name': 'transferrin receptor',
#   'SYMBOL': 'TFRC',
#   'UMLS': 'C1420708',
#   'HGNC': '11763',
#   'UNIPROTKB': 'P02786',
#   'ENSEMBL': 'ENSG00000072274',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7037'},
#   'display': 'NCBIGene(7037) ENSEMBL(ENSG00000072274) HGNC(11763) UMLS(C1420708) UNIPROTKB(P02786) SYMBOL(TFRC)',
#   'type': 'Gene'},
#  {'NCBIGene': '100',
#   'name': 'adenosine deaminase',
#   'SYMBOL': 'ADA',
#   'UMLS': 'C1412179',
#   'HGNC': '186',
#   'UNIPROTKB': 'P00813',
#   'ENSEMBL': 'ENSG00000196839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '100'},
#   'display': 'NCBIGene(100) ENSEMBL(ENSG00000196839) HGNC(186) UMLS(C1412179) UNIPROTKB(P00813) SYMBOL(ADA)',
#   'type': 'Gene'},
#  {'NCBIGene': '6850',
#   'name': 'spleen associated tyrosine kinase',
#   'SYMBOL': 'SYK',
#   'UMLS': 'C1335892',
#   'HGNC': '11491',
#   'UNIPROTKB': 'P43405',
#   'ENSEMBL': 'ENSG00000165025',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6850'},
#   'display': 'NCBIGene(6850) ENSEMBL(ENSG00000165025) HGNC(11491) UMLS(C1335892) UNIPROTKB(P43405) SYMBOL(SYK)',
#   'type': 'Gene'},
#  {'NCBIGene': '64689',
#   'name': 'golgi reassembly stacking protein 1',
#   'SYMBOL': 'GORASP1',
#   'UMLS': 'C1424530',
#   'HGNC': '16769',
#   'UNIPROTKB': 'Q9BQQ3',
#   'ENSEMBL': 'ENSG00000114745',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '64689'},
#   'display': 'NCBIGene(64689) ENSEMBL(ENSG00000114745) HGNC(16769) UMLS(C1424530) UNIPROTKB(Q9BQQ3) SYMBOL(GORASP1)',
#   'type': 'Gene'},
#  {'NCBIGene': '100616101',
#   'name': 'endogenous retrovirus group K member 10',
#   'SYMBOL': 'ERVK-10',
#   'UMLS': 'C3147205',
#   'HGNC': '39004',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '100616101'},
#   'display': 'NCBIGene(100616101) HGNC(39004) UMLS(C3147205) SYMBOL(ERVK-10)',
#   'type': 'Gene'},
#  {'NCBIGene': '5788',
#   'name': 'protein tyrosine phosphatase receptor type C',
#   'SYMBOL': 'PTPRC',
#   'UMLS': 'C1335285',
#   'HGNC': '9666',
#   'UNIPROTKB': 'P08575',
#   'ENSEMBL': 'ENSG00000081237',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5788'},
#   'display': 'NCBIGene(5788) ENSEMBL(ENSG00000081237) HGNC(9666) UMLS(C1335285) UNIPROTKB(P08575) SYMBOL(PTPRC)',
#   'type': 'Gene'},
#  {'NCBIGene': '3562',
#   'name': 'interleukin 3',
#   'SYMBOL': 'IL3',
#   'UMLS': 'C1334117',
#   'HGNC': '6011',
#   'UNIPROTKB': 'P08700',
#   'ENSEMBL': 'ENSG00000164399',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3562'},
#   'display': 'NCBIGene(3562) ENSEMBL(ENSG00000164399) HGNC(6011) UMLS(C1334117) UNIPROTKB(P08700) SYMBOL(IL3)',
#   'type': 'Gene'},
#  {'NCBIGene': '969',
#   'name': 'CD69 molecule',
#   'SYMBOL': 'CD69',
#   'UMLS': 'C1413235',
#   'HGNC': '1694',
#   'UNIPROTKB': 'Q07108',
#   'ENSEMBL': 'ENSG00000110848',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '969'},
#   'display': 'NCBIGene(969) ENSEMBL(ENSG00000110848) HGNC(1694) UMLS(C1413235) UNIPROTKB(Q07108) SYMBOL(CD69)',
#   'type': 'Gene'},
#  {'NCBIGene': '3669',
#   'name': 'interferon stimulated exonuclease gene 20',
#   'SYMBOL': 'ISG20',
#   'UMLS': 'C1416478',
#   'HGNC': '6130',
#   'UNIPROTKB': 'Q96AZ6',
#   'ENSEMBL': 'ENSG00000172183',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3669'},
#   'display': 'NCBIGene(3669) ENSEMBL(ENSG00000172183) HGNC(6130) UMLS(C1416478) UNIPROTKB(Q96AZ6) SYMBOL(ISG20)',
#   'type': 'Gene'},
#  {'NCBIGene': '1385',
#   'name': 'cAMP responsive element binding protein 1',
#   'SYMBOL': 'CREB1',
#   'UMLS': 'C1413702',
#   'HGNC': '2345',
#   'UNIPROTKB': 'P16220',
#   'ENSEMBL': 'ENSG00000118260',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1385'},
#   'display': 'NCBIGene(1385) ENSEMBL(ENSG00000118260) HGNC(2345) UMLS(C1413702) UNIPROTKB(P16220) SYMBOL(CREB1)',
#   'type': 'Gene'},
#  {'NCBIGene': '6857',
#   'name': 'synaptotagmin 1',
#   'SYMBOL': 'SYT1',
#   'UMLS': 'C1420556',
#   'HGNC': '11509',
#   'UNIPROTKB': 'P21579',
#   'ENSEMBL': 'ENSG00000067715',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6857'},
#   'display': 'NCBIGene(6857) ENSEMBL(ENSG00000067715) HGNC(11509) UMLS(C1420556) UNIPROTKB(P21579) SYMBOL(SYT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '10598',
#   'name': 'activator of HSP90 ATPase activity 1',
#   'SYMBOL': 'AHSA1',
#   'UMLS': 'C1412886',
#   'HGNC': '1189',
#   'UNIPROTKB': 'O95433',
#   'ENSEMBL': 'ENSG00000100591',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '10598'},
#   'display': 'NCBIGene(10598) ENSEMBL(ENSG00000100591) HGNC(1189) UMLS(C1412886) UNIPROTKB(O95433) SYMBOL(AHSA1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3952',
#   'name': 'leptin',
#   'SYMBOL': 'LEP',
#   'UMLS': 'C1416825',
#   'HGNC': '6553',
#   'UNIPROTKB': 'P41159',
#   'ENSEMBL': 'ENSG00000174697',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3952'},
#   'display': 'NCBIGene(3952) ENSEMBL(ENSG00000174697) HGNC(6553) UMLS(C1416825) UNIPROTKB(P41159) SYMBOL(LEP)',
#   'type': 'Gene'},
#  {'NCBIGene': '3497',
#   'name': 'immunoglobulin heavy constant epsilon',
#   'SYMBOL': 'IGHE',
#   'UMLS': 'C1415975',
#   'HGNC': '5522',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3497'},
#   'display': 'NCBIGene(3497) HGNC(5522) UMLS(C1415975) SYMBOL(IGHE)',
#   'type': 'Gene'},
#  {'NCBIGene': '26073',
#   'name': 'DNA polymerase delta interacting protein 2',
#   'SYMBOL': 'POLDIP2',
#   'UMLS': 'C1428254',
#   'HGNC': '23781',
#   'UNIPROTKB': 'Q9Y2S7',
#   'ENSEMBL': 'ENSG00000004142',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '26073'},
#   'display': 'NCBIGene(26073) ENSEMBL(ENSG00000004142) HGNC(23781) UMLS(C1428254) UNIPROTKB(Q9Y2S7) SYMBOL(POLDIP2)',
#   'type': 'Gene'},
#  {'NCBIGene': '941',
#   'name': 'CD80 molecule',
#   'SYMBOL': 'CD80',
#   'UMLS': 'C1366561',
#   'HGNC': '1700',
#   'UNIPROTKB': 'P33681',
#   'ENSEMBL': 'ENSG00000121594',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '941'},
#   'display': 'NCBIGene(941) ENSEMBL(ENSG00000121594) HGNC(1700) UMLS(C1366561) UNIPROTKB(P33681) SYMBOL(CD80)',
#   'type': 'Gene'},
#  {'NCBIGene': '5290',
#   'name': 'phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha',
#   'SYMBOL': 'PIK3CA',
#   'UMLS': 'C1335212',
#   'HGNC': '8975',
#   'UNIPROTKB': 'P42336',
#   'ENSEMBL': 'ENSG00000121879',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5290'},
#   'display': 'NCBIGene(5290) ENSEMBL(ENSG00000121879) HGNC(8975) UMLS(C1335212) UNIPROTKB(P42336) SYMBOL(PIK3CA)',
#   'type': 'Gene'},
#  {'NCBIGene': '7852',
#   'name': 'C-X-C motif chemokine receptor 4',
#   'SYMBOL': 'CXCR4',
#   'UMLS': 'C1332823',
#   'HGNC': '2561',
#   'UNIPROTKB': 'P61073',
#   'ENSEMBL': 'ENSG00000121966',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7852'},
#   'display': 'NCBIGene(7852) ENSEMBL(ENSG00000121966) HGNC(2561) UMLS(C1332823) UNIPROTKB(P61073) SYMBOL(CXCR4)',
#   'type': 'Gene'},
#  {'NCBIGene': '5443',
#   'name': 'proopiomelanocortin',
#   'SYMBOL': 'POMC',
#   'UMLS': 'C1337111',
#   'HGNC': '9201',
#   'UNIPROTKB': 'P01189',
#   'ENSEMBL': 'ENSG00000115138',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5443'},
#   'display': 'NCBIGene(5443) ENSEMBL(ENSG00000115138) HGNC(9201) UMLS(C1337111) UNIPROTKB(P01189) SYMBOL(POMC)',
#   'type': 'Gene'},
#  {'NCBIGene': '9402',
#   'name': 'GRB2 related adaptor protein 2',
#   'SYMBOL': 'GRAP2',
#   'UMLS': 'C1415284',
#   'HGNC': '4563',
#   'UNIPROTKB': 'O75791',
#   'ENSEMBL': 'ENSG00000100351',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9402'},
#   'display': 'NCBIGene(9402) ENSEMBL(ENSG00000100351) HGNC(4563) UMLS(C1415284) UNIPROTKB(O75791) SYMBOL(GRAP2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3684',
#   'name': 'integrin subunit alpha M',
#   'SYMBOL': 'ITGAM',
#   'UMLS': 'C1366562',
#   'HGNC': '6149',
#   'UNIPROTKB': 'P11215',
#   'ENSEMBL': 'ENSG00000169896',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3684'},
#   'display': 'NCBIGene(3684) ENSEMBL(ENSG00000169896) HGNC(6149) UMLS(C1366562) UNIPROTKB(P11215) SYMBOL(ITGAM)',
#   'type': 'Gene'},
#  {'NCBIGene': '355',
#   'name': 'Fas cell surface death receptor',
#   'SYMBOL': 'FAS',
#   'UMLS': 'C1539477',
#   'HGNC': '11920',
#   'UNIPROTKB': 'P25445',
#   'ENSEMBL': 'ENSG00000026103',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '355'},
#   'display': 'NCBIGene(355) ENSEMBL(ENSG00000026103) HGNC(11920) UMLS(C1539477) UNIPROTKB(P25445) SYMBOL(FAS)',
#   'type': 'Gene'},
#  {'NCBIGene': '760',
#   'name': 'carbonic anhydrase 2',
#   'SYMBOL': 'CA2',
#   'UMLS': 'C1413043',
#   'HGNC': '1373',
#   'UNIPROTKB': 'P00918',
#   'ENSEMBL': 'ENSG00000104267',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '760'},
#   'display': 'NCBIGene(760) ENSEMBL(ENSG00000104267) HGNC(1373) UMLS(C1413043) UNIPROTKB(P00918) SYMBOL(CA2)',
#   'type': 'Gene'},
#  {'NCBIGene': '4313',
#   'name': 'matrix metallopeptidase 2',
#   'SYMBOL': 'MMP2',
#   'UMLS': 'C1334522',
#   'HGNC': '7166',
#   'UNIPROTKB': 'P08253',
#   'ENSEMBL': 'ENSG00000087245',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4313'},
#   'display': 'NCBIGene(4313) ENSEMBL(ENSG00000087245) HGNC(7166) UMLS(C1334522) UNIPROTKB(P08253) SYMBOL(MMP2)',
#   'type': 'Gene'},
#  {'NCBIGene': '351',
#   'name': 'amyloid beta precursor protein',
#   'SYMBOL': 'APP',
#   'UMLS': 'C1364818',
#   'HGNC': '620',
#   'UNIPROTKB': 'P05067',
#   'ENSEMBL': 'ENSG00000142192',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '351'},
#   'display': 'NCBIGene(351) ENSEMBL(ENSG00000142192) HGNC(620) UMLS(C1364818) UNIPROTKB(P05067) SYMBOL(APP)',
#   'type': 'Gene'},
#  {'NCBIGene': '1154',
#   'name': 'cytokine inducible SH2 containing protein',
#   'SYMBOL': 'CISH',
#   'UMLS': 'C1332762',
#   'HGNC': '1984',
#   'UNIPROTKB': 'Q9NSE2',
#   'ENSEMBL': 'ENSG00000114737',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1154'},
#   'display': 'NCBIGene(1154) ENSEMBL(ENSG00000114737) HGNC(1984) UMLS(C1332762) UNIPROTKB(Q9NSE2) SYMBOL(CISH)',
#   'type': 'Gene'},
#  {'NCBIGene': '4318',
#   'name': 'matrix metallopeptidase 9',
#   'SYMBOL': 'MMP9',
#   'UMLS': 'C1334523',
#   'HGNC': '7176',
#   'UNIPROTKB': 'P14780',
#   'ENSEMBL': 'ENSG00000100985',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4318'},
#   'display': 'NCBIGene(4318) ENSEMBL(ENSG00000100985) HGNC(7176) UMLS(C1334523) UNIPROTKB(P14780) SYMBOL(MMP9)',
#   'type': 'Gene'},
#  {'NCBIGene': '940',
#   'name': 'CD28 molecule',
#   'SYMBOL': 'CD28',
#   'UMLS': 'C1332709',
#   'HGNC': '1653',
#   'UNIPROTKB': 'P10747',
#   'ENSEMBL': 'ENSG00000178562',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '940'},
#   'display': 'NCBIGene(940) ENSEMBL(ENSG00000178562) HGNC(1653) UMLS(C1332709) UNIPROTKB(P10747) SYMBOL(CD28)',
#   'type': 'Gene'},
#  {'NCBIGene': '1234',
#   'name': 'C-C motif chemokine receptor 5',
#   'SYMBOL': 'CCR5',
#   'UMLS': 'C1332700',
#   'HGNC': '1606',
#   'UNIPROTKB': 'P51681',
#   'ENSEMBL': 'ENSG00000160791',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1234'},
#   'display': 'NCBIGene(1234) ENSEMBL(ENSG00000160791) HGNC(1606) UMLS(C1332700) UNIPROTKB(P51681) SYMBOL(CCR5)',
#   'type': 'Gene'},
#  {'NCBIGene': '7157',
#   'name': 'tumor protein p53',
#   'SYMBOL': 'TP53',
#   'UMLS': 'C0079419',
#   'HGNC': '11998',
#   'UNIPROTKB': 'P04637',
#   'ENSEMBL': 'ENSG00000141510',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7157'},
#   'display': 'NCBIGene(7157) ENSEMBL(ENSG00000141510) HGNC(11998) UMLS(C0079419) UNIPROTKB(P04637) SYMBOL(TP53)',
#   'type': 'Gene'},
#  {'NCBIGene': '847',
#   'name': 'catalase',
#   'SYMBOL': 'CAT',
#   'UMLS': 'C1413138',
#   'HGNC': '1516',
#   'UNIPROTKB': 'P04040',
#   'ENSEMBL': 'ENSG00000121691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '847'},
#   'display': 'NCBIGene(847) ENSEMBL(ENSG00000121691) HGNC(1516) UMLS(C1413138) UNIPROTKB(P04040) SYMBOL(CAT)',
#   'type': 'Gene'},
#  {'NCBIGene': '1956',
#   'name': 'epidermal growth factor receptor',
#   'SYMBOL': 'EGFR',
#   'UMLS': 'C1414313',
#   'HGNC': '3236',
#   'UNIPROTKB': 'P00533',
#   'ENSEMBL': 'ENSG00000146648',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1956'},
#   'display': 'NCBIGene(1956) ENSEMBL(ENSG00000146648) HGNC(3236) UMLS(C1414313) UNIPROTKB(P00533) SYMBOL(EGFR)',
#   'type': 'Gene'},
#  {'NCBIGene': '5970',
#   'name': 'RELA proto-oncogene, NF-kB subunit',
#   'SYMBOL': 'RELA',
#   'UMLS': 'C1335610',
#   'HGNC': '9955',
#   'UNIPROTKB': 'Q04206',
#   'ENSEMBL': 'ENSG00000173039',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5970'},
#   'display': 'NCBIGene(5970) ENSEMBL(ENSG00000173039) HGNC(9955) UMLS(C1335610) UNIPROTKB(Q04206) SYMBOL(RELA)',
#   'type': 'Gene'},
#  {'NCBIGene': '472',
#   'name': 'ATM serine/threonine kinase',
#   'SYMBOL': 'ATM',
#   'UMLS': 'C0919524',
#   'HGNC': '795',
#   'UNIPROTKB': 'Q13315',
#   'ENSEMBL': 'ENSG00000149311',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '472'},
#   'display': 'NCBIGene(472) ENSEMBL(ENSG00000149311) HGNC(795) UMLS(C0919524) UNIPROTKB(Q13315) SYMBOL(ATM)',
#   'type': 'Gene'},
#  {'NCBIGene': '6776',
#   'name': 'signal transducer and activator of transcription 5A',
#   'SYMBOL': 'STAT5A',
#   'UMLS': 'C1335875',
#   'HGNC': '11366',
#   'UNIPROTKB': 'P42229',
#   'ENSEMBL': 'ENSG00000126561',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6776'},
#   'display': 'NCBIGene(6776) ENSEMBL(ENSG00000126561) HGNC(11366) UMLS(C1335875) UNIPROTKB(P42229) SYMBOL(STAT5A)',
#   'type': 'Gene'},
#  {'NCBIGene': '958',
#   'name': 'CD40 molecule',
#   'SYMBOL': 'CD40',
#   'UMLS': 'C1539081',
#   'HGNC': '11919',
#   'UNIPROTKB': 'P25942',
#   'ENSEMBL': 'ENSG00000101017',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '958'},
#   'display': 'NCBIGene(958) ENSEMBL(ENSG00000101017) HGNC(11919) UMLS(C1539081) UNIPROTKB(P25942) SYMBOL(CD40)',
#   'type': 'Gene'},
#  {'NCBIGene': '7099',
#   'name': 'toll like receptor 4',
#   'SYMBOL': 'TLR4',
#   'UMLS': 'C1336636',
#   'HGNC': '11850',
#   'UNIPROTKB': 'O00206',
#   'ENSEMBL': 'ENSG00000136869',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7099'},
#   'display': 'NCBIGene(7099) ENSEMBL(ENSG00000136869) HGNC(11850) UMLS(C1336636) UNIPROTKB(O00206) SYMBOL(TLR4)',
#   'type': 'Gene'},
#  {'NCBIGene': '3630',
#   'name': 'insulin',
#   'SYMBOL': 'INS',
#   'UMLS': 'C1337112',
#   'HGNC': '6081',
#   'UNIPROTKB': 'P01308',
#   'ENSEMBL': 'ENSG00000254647',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3630'},
#   'display': 'NCBIGene(3630) ENSEMBL(ENSG00000254647) HGNC(6081) UMLS(C1337112) UNIPROTKB(P01308) SYMBOL(INS)',
#   'type': 'Gene'},
#  {'NCBIGene': '6352',
#   'name': 'C-C motif chemokine ligand 5',
#   'SYMBOL': 'CCL5',
#   'UMLS': 'C1332691',
#   'HGNC': '10632',
#   'UNIPROTKB': 'P13501',
#   'ENSEMBL': 'ENSG00000271503',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6352'},
#   'display': 'NCBIGene(6352) ENSEMBL(ENSG00000271503) HGNC(10632) UMLS(C1332691) UNIPROTKB(P13501) SYMBOL(CCL5)',
#   'type': 'Gene'},
#  {'NCBIGene': '2353',
#   'name': 'Fos proto-oncogene, AP-1 transcription factor subunit',
#   'SYMBOL': 'FOS',
#   'UMLS': 'C0087140',
#   'HGNC': '3796',
#   'UNIPROTKB': 'P01100',
#   'ENSEMBL': 'ENSG00000170345',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2353'},
#   'display': 'NCBIGene(2353) ENSEMBL(ENSG00000170345) HGNC(3796) UMLS(C0087140) UNIPROTKB(P01100) SYMBOL(FOS)',
#   'type': 'Gene'},
#  {'NCBIGene': '283',
#   'name': 'angiogenin',
#   'SYMBOL': 'ANG',
#   'UMLS': 'C1367482',
#   'HGNC': '483',
#   'UNIPROTKB': 'P03950',
#   'ENSEMBL': 'ENSG00000214274',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '283'},
#   'display': 'NCBIGene(283) ENSEMBL(ENSG00000214274) HGNC(483) UMLS(C1367482) UNIPROTKB(P03950) SYMBOL(ANG)',
#   'type': 'Gene'},
#  {'NCBIGene': '6774',
#   'name': 'signal transducer and activator of transcription 3',
#   'SYMBOL': 'STAT3',
#   'UMLS': 'C1367307',
#   'HGNC': '11364',
#   'UNIPROTKB': 'P40763',
#   'ENSEMBL': 'ENSG00000168610',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6774'},
#   'display': 'NCBIGene(6774) ENSEMBL(ENSG00000168610) HGNC(11364) UMLS(C1367307) UNIPROTKB(P40763) SYMBOL(STAT3)',
#   'type': 'Gene'},
#  {'NCBIGene': '5599',
#   'name': 'mitogen-activated protein kinase 8',
#   'SYMBOL': 'MAPK8',
#   'UMLS': 'C1367731',
#   'HGNC': '6881',
#   'UNIPROTKB': 'P45983',
#   'ENSEMBL': 'ENSG00000107643',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5599'},
#   'display': 'NCBIGene(5599) ENSEMBL(ENSG00000107643) HGNC(6881) UMLS(C1367731) UNIPROTKB(P45983) SYMBOL(MAPK8)',
#   'type': 'Gene'},
#  {'NCBIGene': '1398',
#   'name': 'CRK proto-oncogene, adaptor protein',
#   'SYMBOL': 'CRK',
#   'UMLS': 'C0812252',
#   'HGNC': '2362',
#   'UNIPROTKB': 'P46108',
#   'ENSEMBL': 'ENSG00000167193',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1398'},
#   'display': 'NCBIGene(1398) ENSEMBL(ENSG00000167193) HGNC(2362) UMLS(C0812252) UNIPROTKB(P46108) SYMBOL(CRK)',
#   'type': 'Gene'},
#  {'NCBIGene': '820',
#   'name': 'cathelicidin antimicrobial peptide',
#   'SYMBOL': 'CAMP',
#   'UMLS': 'C1413106',
#   'HGNC': '1472',
#   'UNIPROTKB': 'P49913',
#   'ENSEMBL': 'ENSG00000164047',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '820'},
#   'display': 'NCBIGene(820) ENSEMBL(ENSG00000164047) HGNC(1472) UMLS(C1413106) UNIPROTKB(P49913) SYMBOL(CAMP)',
#   'type': 'Gene'},
#  {'NCBIGene': '7040',
#   'name': 'transforming growth factor beta 1',
#   'SYMBOL': 'TGFB1',
#   'UMLS': 'C1366557',
#   'HGNC': '11766',
#   'UNIPROTKB': 'P01137',
#   'ENSEMBL': 'ENSG00000105329',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7040'},
#   'display': 'NCBIGene(7040) ENSEMBL(ENSG00000105329) HGNC(11766) UMLS(C1366557) UNIPROTKB(P01137) SYMBOL(TGFB1)',
#   'type': 'Gene'},
#  {'NCBIGene': '207',
#   'name': 'AKT serine/threonine kinase 1',
#   'SYMBOL': 'AKT1',
#   'UMLS': 'C0812228',
#   'HGNC': '391',
#   'UNIPROTKB': 'P31749',
#   'ENSEMBL': 'ENSG00000142208',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '207'},
#   'display': 'NCBIGene(207) ENSEMBL(ENSG00000142208) HGNC(391) UMLS(C0812228) UNIPROTKB(P31749) SYMBOL(AKT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '7422',
#   'name': 'vascular endothelial growth factor A',
#   'SYMBOL': 'VEGFA',
#   'UMLS': 'C1823619',
#   'HGNC': '12680',
#   'UNIPROTKB': 'P15692',
#   'ENSEMBL': 'ENSG00000112715',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7422'},
#   'display': 'NCBIGene(7422) ENSEMBL(ENSG00000112715) HGNC(12680) UMLS(C1823619) UNIPROTKB(P15692) SYMBOL(VEGFA)',
#   'type': 'Gene'},
#  {'NCBIGene': '5594',
#   'name': 'mitogen-activated protein kinase 1',
#   'SYMBOL': 'MAPK1',
#   'UMLS': 'C1366882',
#   'HGNC': '6871',
#   'UNIPROTKB': 'P28482',
#   'ENSEMBL': 'ENSG00000100030',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5594'},
#   'display': 'NCBIGene(5594) ENSEMBL(ENSG00000100030) HGNC(6871) UMLS(C1366882) UNIPROTKB(P28482) SYMBOL(MAPK1)',
#   'type': 'Gene'}]

# %%
genes_related_to_AE = predict_many(covid_gene_inputs,[ACE2],['AnatomicalEntity'])
# Out:
# The first query doesn't return any result. So BTE does not find any connection between your input and output

# %%
genes_related_to_AE
# Out:
#     input input_type       pred1                     pred1_source  \
# 0     CD4       Gene  related_to                             None
# 1     CD4       Gene  related_to  Translator Text Mining Provider
# 2     CD4       Gene  related_to  Translator Text Mining Provider
# 3     CD4       Gene  related_to  Translator Text Mining Provider
# 4     CD4       Gene  related_to                             None
# ..    ...        ...         ...                              ...
# 1   MAPK1       Gene  related_to  Translator Text Mining Provider
# 2   MAPK1       Gene  related_to  Translator Text Mining Provider
# 3   MAPK1       Gene  related_to  Translator Text Mining Provider
# 4   MAPK1       Gene  related_to  Translator Text Mining Provider
# 5   MAPK1       Gene  related_to  Translator Text Mining Provider
#
#         pred1_api pred1_pubmed        node1_type  \
# 0     BioLink API         None  AnatomicalEntity
# 1   CORD Gene API         None  AnatomicalEntity
# 2   CORD Gene API         None  AnatomicalEntity
# 3   CORD Gene API         None  AnatomicalEntity
# 4     BioLink API         None  AnatomicalEntity
# ..            ...          ...               ...
# 1   CORD Gene API         None  AnatomicalEntity
# 2   CORD Gene API         None  AnatomicalEntity
# 3   CORD Gene API         None  AnatomicalEntity
# 4   CORD Gene API         None  AnatomicalEntity
# 5   CORD Gene API         None  AnatomicalEntity
#
#                                    node1_name               node1_id  \
# 0             EPITHELIUM OF LACTIFEROUS GLAND  UBERON:UBERON:0003244
# 1                                 ENDOMETRIUM  UBERON:UBERON:0001295
# 2                                        LIEN  UBERON:UBERON:0002106
# 3                                       BRAIN  UBERON:UBERON:0000955
# 4   COLUMNAR EPITHELIUM OF THE FALLOPIAN TUBE  UBERON:UBERON:0004804
# ..                                        ...                    ...
# 1                             ANATOMICAL UNIT  UBERON:UBERON:0000062
# 2                           PORTION OF TISSUE  UBERON:UBERON:0000479
# 3                                     CARDIUM  UBERON:UBERON:0000948
# 4                                 BLOOD SERUM  UBERON:UBERON:0001977
# 5                                      KIDNEY  UBERON:UBERON:0002113
#
#          pred2                     pred2_source      pred2_api pred2_pubmed  \
# 0   related_to                             None    BioLink API         None
# 1   related_to                             None    BioLink API         None
# 2   related_to                             None    BioLink API         None
# 3   related_to                             None    BioLink API         None
# 4   related_to                             None    BioLink API         None
# ..         ...                              ...            ...          ...
# 1   related_to  Translator Text Mining Provider  CORD Gene API         None
# 2   related_to  Translator Text Mining Provider  CORD Gene API         None
# 3   related_to  Translator Text Mining Provider  CORD Gene API         None
# 4   related_to  Translator Text Mining Provider  CORD Gene API         None
# 5   related_to  Translator Text Mining Provider  CORD Gene API         None
#
#          output_type output_name       output_id
# 0   AnatomicalEntity        ACE2  NCBIGene:59272
# 1   AnatomicalEntity        ACE2  NCBIGene:59272
# 2   AnatomicalEntity        ACE2  NCBIGene:59272
# 3   AnatomicalEntity        ACE2  NCBIGene:59272
# 4   AnatomicalEntity        ACE2  NCBIGene:59272
# ..               ...         ...             ...
# 1   AnatomicalEntity        ACE2  NCBIGene:59272
# 2   AnatomicalEntity        ACE2  NCBIGene:59272
# 3   AnatomicalEntity        ACE2  NCBIGene:59272
# 4   AnatomicalEntity        ACE2  NCBIGene:59272
# 5   AnatomicalEntity        ACE2  NCBIGene:59272
#
# [876 rows x 16 columns]

# %%
gene_list_2 = list(genes_related_to_AE["input"])
d = {x:gene_list_2.count(x) for x in gene_list_2}
d2_gene_df = pandas.DataFrame.from_dict({k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse = True)}, orient='index').iloc[0:50]
d2_gene_df.columns = ["count"]
d2_gene_df
# Out:
#         count
# ACE2       31
# ACE        17
# CRP        16
# TNF        16
# REN        15
# TH         15
# CISH       15
# IL2RA      13
# IL10       13
# AGTR1      13
# INS        13
# CD4        12
# POMC       12
# CA2        12
# CD28       12
# CCL2       11
# IFNA1      11
# F3         11
# IL6        11
# PTH        11
# LEP        11
# ALB        10
# GPT        10
# CD2        10
# ISG20      10
# GRAP2      10
# FAS        10
# CCR5       10
# CAT        10
# EGFR       10
# AKT1       10
# AGTR2       9
# MB          9
# CCL20       9
# ICAM1       9
# PIK3CA      9
# CXCL8       8
# IL17A       8
# DPP4        8
# CD44        8
# IL9         8
# ESR1        8
# EGF         8
# CD80        8
# TP53        8
# TLR4        8
# FOS         8
# ANG         8
# F2          7
# SARS2       7

# %%
d2_genes = list(d2_gene_df[d2_gene_df["count"] >= 5].index)
d2_genes
# Out:
# ['ACE2',
#  'ACE',
#  'CRP',
#  'TNF',
#  'REN',
#  'TH',
#  'CISH',
#  'IL2RA',
#  'IL10',
#  'AGTR1',
#  'INS',
#  'CD4',
#  'POMC',
#  'CA2',
#  'CD28',
#  'CCL2',
#  'IFNA1',
#  'F3',
#  'IL6',
#  'PTH',
#  'LEP',
#  'ALB',
#  'GPT',
#  'CD2',
#  'ISG20',
#  'GRAP2',
#  'FAS',
#  'CCR5',
#  'CAT',
#  'EGFR',
#  'AKT1',
#  'AGTR2',
#  'MB',
#  'CCL20',
#  'ICAM1',
#  'PIK3CA',
#  'CXCL8',
#  'IL17A',
#  'DPP4',
#  'CD44',
#  'IL9',
#  'ESR1',
#  'EGF',
#  'CD80',
#  'TP53',
#  'TLR4',
#  'FOS',
#  'ANG',
#  'F2',
#  'SARS2']

# %%
v2_gene_inputs = create_gene_inputs(d2_genes)
v2_gene_inputs
# Out:
# [{'NCBIGene': '59272',
#   'name': 'angiotensin I converting enzyme 2',
#   'SYMBOL': 'ACE2',
#   'UMLS': 'C1422064',
#   'HGNC': '13557',
#   'UNIPROTKB': 'Q9BYF1',
#   'ENSEMBL': 'ENSG00000130234',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#   'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#   'type': 'Gene'},
#  {'NCBIGene': '1636',
#   'name': 'angiotensin I converting enzyme',
#   'SYMBOL': 'ACE',
#   'UMLS': 'C1413931',
#   'HGNC': '2707',
#   'UNIPROTKB': 'P12821',
#   'ENSEMBL': 'ENSG00000159640',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1636'},
#   'display': 'NCBIGene(1636) ENSEMBL(ENSG00000159640) HGNC(2707) UMLS(C1413931) UNIPROTKB(P12821) SYMBOL(ACE)',
#   'type': 'Gene'},
#  {'NCBIGene': '1401',
#   'name': 'C-reactive protein',
#   'SYMBOL': 'CRP',
#   'UMLS': 'C1413716',
#   'HGNC': '2367',
#   'UNIPROTKB': 'P02741',
#   'ENSEMBL': 'ENSG00000132693',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1401'},
#   'display': 'NCBIGene(1401) ENSEMBL(ENSG00000132693) HGNC(2367) UMLS(C1413716) UNIPROTKB(P02741) SYMBOL(CRP)',
#   'type': 'Gene'},
#  {'NCBIGene': '7124',
#   'name': 'tumor necrosis factor',
#   'SYMBOL': 'TNF',
#   'UMLS': 'C0812246',
#   'HGNC': '11892',
#   'UNIPROTKB': 'P01375',
#   'ENSEMBL': 'ENSG00000204490',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7124'},
#   'display': 'NCBIGene(7124) ENSEMBL(ENSG00000204490) HGNC(11892) UMLS(C0812246) UNIPROTKB(P01375) SYMBOL(TNF)',
#   'type': 'Gene'},
#  {'NCBIGene': '5972',
#   'name': 'renin',
#   'SYMBOL': 'REN',
#   'UMLS': 'C1419338',
#   'HGNC': '9958',
#   'UNIPROTKB': 'P00797',
#   'ENSEMBL': 'ENSG00000143839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5972'},
#   'display': 'NCBIGene(5972) ENSEMBL(ENSG00000143839) HGNC(9958) UMLS(C1419338) UNIPROTKB(P00797) SYMBOL(REN)',
#   'type': 'Gene'},
#  {'NCBIGene': '7054',
#   'name': 'tyrosine hydroxylase',
#   'SYMBOL': 'TH',
#   'UMLS': 'C1420718',
#   'HGNC': '11782',
#   'UNIPROTKB': 'P07101',
#   'ENSEMBL': 'ENSG00000180176',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7054'},
#   'display': 'NCBIGene(7054) ENSEMBL(ENSG00000180176) HGNC(11782) UMLS(C1420718) UNIPROTKB(P07101) SYMBOL(TH)',
#   'type': 'Gene'},
#  {'NCBIGene': '1154',
#   'name': 'cytokine inducible SH2 containing protein',
#   'SYMBOL': 'CISH',
#   'UMLS': 'C1332762',
#   'HGNC': '1984',
#   'UNIPROTKB': 'Q9NSE2',
#   'ENSEMBL': 'ENSG00000114737',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1154'},
#   'display': 'NCBIGene(1154) ENSEMBL(ENSG00000114737) HGNC(1984) UMLS(C1332762) UNIPROTKB(Q9NSE2) SYMBOL(CISH)',
#   'type': 'Gene'},
#  {'NCBIGene': '3559',
#   'name': 'interleukin 2 receptor subunit alpha',
#   'SYMBOL': 'IL2RA',
#   'UMLS': 'C1334114',
#   'HGNC': '6008',
#   'UNIPROTKB': 'P01589',
#   'ENSEMBL': 'ENSG00000134460',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3559'},
#   'display': 'NCBIGene(3559) ENSEMBL(ENSG00000134460) HGNC(6008) UMLS(C1334114) UNIPROTKB(P01589) SYMBOL(IL2RA)',
#   'type': 'Gene'},
#  {'NCBIGene': '3586',
#   'name': 'interleukin 10',
#   'SYMBOL': 'IL10',
#   'UMLS': 'C1334098',
#   'HGNC': '5962',
#   'UNIPROTKB': 'P22301',
#   'ENSEMBL': 'ENSG00000136634',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3586'},
#   'display': 'NCBIGene(3586) ENSEMBL(ENSG00000136634) HGNC(5962) UMLS(C1334098) UNIPROTKB(P22301) SYMBOL(IL10)',
#   'type': 'Gene'},
#  {'NCBIGene': '185',
#   'name': 'angiotensin II receptor type 1',
#   'SYMBOL': 'AGTR1',
#   'UMLS': 'C1439284',
#   'HGNC': '336',
#   'UNIPROTKB': 'P30556',
#   'ENSEMBL': 'ENSG00000144891',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '185'},
#   'display': 'NCBIGene(185) ENSEMBL(ENSG00000144891) HGNC(336) UMLS(C1439284) UNIPROTKB(P30556) SYMBOL(AGTR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3630',
#   'name': 'insulin',
#   'SYMBOL': 'INS',
#   'UMLS': 'C1337112',
#   'HGNC': '6081',
#   'UNIPROTKB': 'P01308',
#   'ENSEMBL': 'ENSG00000254647',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3630'},
#   'display': 'NCBIGene(3630) ENSEMBL(ENSG00000254647) HGNC(6081) UMLS(C1337112) UNIPROTKB(P01308) SYMBOL(INS)',
#   'type': 'Gene'},
#  {'NCBIGene': '920',
#   'name': 'CD4 molecule',
#   'SYMBOL': 'CD4',
#   'UMLS': 'C1332714',
#   'HGNC': '1678',
#   'UNIPROTKB': 'P01730',
#   'ENSEMBL': 'ENSG00000010610',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '920'},
#   'display': 'NCBIGene(920) ENSEMBL(ENSG00000010610) HGNC(1678) UMLS(C1332714) UNIPROTKB(P01730) SYMBOL(CD4)',
#   'type': 'Gene'},
#  {'NCBIGene': '5443',
#   'name': 'proopiomelanocortin',
#   'SYMBOL': 'POMC',
#   'UMLS': 'C1337111',
#   'HGNC': '9201',
#   'UNIPROTKB': 'P01189',
#   'ENSEMBL': 'ENSG00000115138',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5443'},
#   'display': 'NCBIGene(5443) ENSEMBL(ENSG00000115138) HGNC(9201) UMLS(C1337111) UNIPROTKB(P01189) SYMBOL(POMC)',
#   'type': 'Gene'},
#  {'NCBIGene': '760',
#   'name': 'carbonic anhydrase 2',
#   'SYMBOL': 'CA2',
#   'UMLS': 'C1413043',
#   'HGNC': '1373',
#   'UNIPROTKB': 'P00918',
#   'ENSEMBL': 'ENSG00000104267',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '760'},
#   'display': 'NCBIGene(760) ENSEMBL(ENSG00000104267) HGNC(1373) UMLS(C1413043) UNIPROTKB(P00918) SYMBOL(CA2)',
#   'type': 'Gene'},
#  {'NCBIGene': '940',
#   'name': 'CD28 molecule',
#   'SYMBOL': 'CD28',
#   'UMLS': 'C1332709',
#   'HGNC': '1653',
#   'UNIPROTKB': 'P10747',
#   'ENSEMBL': 'ENSG00000178562',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '940'},
#   'display': 'NCBIGene(940) ENSEMBL(ENSG00000178562) HGNC(1653) UMLS(C1332709) UNIPROTKB(P10747) SYMBOL(CD28)',
#   'type': 'Gene'},
#  {'NCBIGene': '6347',
#   'name': 'C-C motif chemokine ligand 2',
#   'SYMBOL': 'CCL2',
#   'UMLS': 'C1337092',
#   'HGNC': '10618',
#   'UNIPROTKB': 'P13500',
#   'ENSEMBL': 'ENSG00000108691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6347'},
#   'display': 'NCBIGene(6347) ENSEMBL(ENSG00000108691) HGNC(10618) UMLS(C1337092) UNIPROTKB(P13500) SYMBOL(CCL2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3439',
#   'name': 'interferon alpha 1',
#   'SYMBOL': 'IFNA1',
#   'UMLS': 'C1415900',
#   'HGNC': '5417',
#   'UNIPROTKB': 'P01562',
#   'ENSEMBL': 'ENSG00000197919',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3439'},
#   'display': 'NCBIGene(3439) ENSEMBL(ENSG00000197919) HGNC(5417) UMLS(C1415900) UNIPROTKB(P01562) SYMBOL(IFNA1)',
#   'type': 'Gene'},
#  {'NCBIGene': '2152',
#   'name': 'coagulation factor III, tissue factor',
#   'SYMBOL': 'F3',
#   'UMLS': 'C1333522',
#   'HGNC': '3541',
#   'UNIPROTKB': 'P13726',
#   'ENSEMBL': 'ENSG00000117525',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2152'},
#   'display': 'NCBIGene(2152) ENSEMBL(ENSG00000117525) HGNC(3541) UMLS(C1333522) UNIPROTKB(P13726) SYMBOL(F3)',
#   'type': 'Gene'},
#  {'NCBIGene': '3569',
#   'name': 'interleukin 6',
#   'SYMBOL': 'IL6',
#   'UMLS': 'C1334122',
#   'HGNC': '6018',
#   'UNIPROTKB': 'P05231',
#   'ENSEMBL': 'ENSG00000136244',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3569'},
#   'display': 'NCBIGene(3569) ENSEMBL(ENSG00000136244) HGNC(6018) UMLS(C1334122) UNIPROTKB(P05231) SYMBOL(IL6)',
#   'type': 'Gene'},
#  {'NCBIGene': '5741',
#   'name': 'parathyroid hormone',
#   'SYMBOL': 'PTH',
#   'UMLS': 'C1419072',
#   'HGNC': '9606',
#   'UNIPROTKB': 'P01270',
#   'ENSEMBL': 'ENSG00000152266',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5741'},
#   'display': 'NCBIGene(5741) ENSEMBL(ENSG00000152266) HGNC(9606) UMLS(C1419072) UNIPROTKB(P01270) SYMBOL(PTH)',
#   'type': 'Gene'},
#  {'NCBIGene': '3952',
#   'name': 'leptin',
#   'SYMBOL': 'LEP',
#   'UMLS': 'C1416825',
#   'HGNC': '6553',
#   'UNIPROTKB': 'P41159',
#   'ENSEMBL': 'ENSG00000174697',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3952'},
#   'display': 'NCBIGene(3952) ENSEMBL(ENSG00000174697) HGNC(6553) UMLS(C1416825) UNIPROTKB(P41159) SYMBOL(LEP)',
#   'type': 'Gene'},
#  {'NCBIGene': '213',
#   'name': 'albumin',
#   'SYMBOL': 'ALB',
#   'UMLS': 'C1412332',
#   'HGNC': '399',
#   'UNIPROTKB': 'P02768',
#   'ENSEMBL': 'ENSG00000163631',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '213'},
#   'display': 'NCBIGene(213) ENSEMBL(ENSG00000163631) HGNC(399) UMLS(C1412332) UNIPROTKB(P02768) SYMBOL(ALB)',
#   'type': 'Gene'},
#  {'NCBIGene': '2875',
#   'name': 'glutamic--pyruvic transaminase',
#   'SYMBOL': 'GPT',
#   'UMLS': 'C1415274',
#   'HGNC': '4552',
#   'UNIPROTKB': 'P24298',
#   'ENSEMBL': 'ENSG00000167701',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2875'},
#   'display': 'NCBIGene(2875) ENSEMBL(ENSG00000167701) HGNC(4552) UMLS(C1415274) UNIPROTKB(P24298) SYMBOL(GPT)',
#   'type': 'Gene'},
#  {'NCBIGene': '914',
#   'name': 'CD2 molecule',
#   'SYMBOL': 'CD2',
#   'UMLS': 'C1367475',
#   'HGNC': '1639',
#   'UNIPROTKB': 'P06729',
#   'ENSEMBL': 'ENSG00000116824',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '914'},
#   'display': 'NCBIGene(914) ENSEMBL(ENSG00000116824) HGNC(1639) UMLS(C1367475) UNIPROTKB(P06729) SYMBOL(CD2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3669',
#   'name': 'interferon stimulated exonuclease gene 20',
#   'SYMBOL': 'ISG20',
#   'UMLS': 'C1416478',
#   'HGNC': '6130',
#   'UNIPROTKB': 'Q96AZ6',
#   'ENSEMBL': 'ENSG00000172183',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3669'},
#   'display': 'NCBIGene(3669) ENSEMBL(ENSG00000172183) HGNC(6130) UMLS(C1416478) UNIPROTKB(Q96AZ6) SYMBOL(ISG20)',
#   'type': 'Gene'},
#  {'NCBIGene': '9402',
#   'name': 'GRB2 related adaptor protein 2',
#   'SYMBOL': 'GRAP2',
#   'UMLS': 'C1415284',
#   'HGNC': '4563',
#   'UNIPROTKB': 'O75791',
#   'ENSEMBL': 'ENSG00000100351',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9402'},
#   'display': 'NCBIGene(9402) ENSEMBL(ENSG00000100351) HGNC(4563) UMLS(C1415284) UNIPROTKB(O75791) SYMBOL(GRAP2)',
#   'type': 'Gene'},
#  {'NCBIGene': '355',
#   'name': 'Fas cell surface death receptor',
#   'SYMBOL': 'FAS',
#   'UMLS': 'C1539477',
#   'HGNC': '11920',
#   'UNIPROTKB': 'P25445',
#   'ENSEMBL': 'ENSG00000026103',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '355'},
#   'display': 'NCBIGene(355) ENSEMBL(ENSG00000026103) HGNC(11920) UMLS(C1539477) UNIPROTKB(P25445) SYMBOL(FAS)',
#   'type': 'Gene'},
#  {'NCBIGene': '1234',
#   'name': 'C-C motif chemokine receptor 5',
#   'SYMBOL': 'CCR5',
#   'UMLS': 'C1332700',
#   'HGNC': '1606',
#   'UNIPROTKB': 'P51681',
#   'ENSEMBL': 'ENSG00000160791',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1234'},
#   'display': 'NCBIGene(1234) ENSEMBL(ENSG00000160791) HGNC(1606) UMLS(C1332700) UNIPROTKB(P51681) SYMBOL(CCR5)',
#   'type': 'Gene'},
#  {'NCBIGene': '847',
#   'name': 'catalase',
#   'SYMBOL': 'CAT',
#   'UMLS': 'C1413138',
#   'HGNC': '1516',
#   'UNIPROTKB': 'P04040',
#   'ENSEMBL': 'ENSG00000121691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '847'},
#   'display': 'NCBIGene(847) ENSEMBL(ENSG00000121691) HGNC(1516) UMLS(C1413138) UNIPROTKB(P04040) SYMBOL(CAT)',
#   'type': 'Gene'},
#  {'NCBIGene': '1956',
#   'name': 'epidermal growth factor receptor',
#   'SYMBOL': 'EGFR',
#   'UMLS': 'C1414313',
#   'HGNC': '3236',
#   'UNIPROTKB': 'P00533',
#   'ENSEMBL': 'ENSG00000146648',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1956'},
#   'display': 'NCBIGene(1956) ENSEMBL(ENSG00000146648) HGNC(3236) UMLS(C1414313) UNIPROTKB(P00533) SYMBOL(EGFR)',
#   'type': 'Gene'},
#  {'NCBIGene': '207',
#   'name': 'AKT serine/threonine kinase 1',
#   'SYMBOL': 'AKT1',
#   'UMLS': 'C0812228',
#   'HGNC': '391',
#   'UNIPROTKB': 'P31749',
#   'ENSEMBL': 'ENSG00000142208',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '207'},
#   'display': 'NCBIGene(207) ENSEMBL(ENSG00000142208) HGNC(391) UMLS(C0812228) UNIPROTKB(P31749) SYMBOL(AKT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '186',
#   'name': 'angiotensin II receptor type 2',
#   'SYMBOL': 'AGTR2',
#   'UMLS': 'C1332036',
#   'HGNC': '338',
#   'UNIPROTKB': 'P50052',
#   'ENSEMBL': 'ENSG00000180772',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '186'},
#   'display': 'NCBIGene(186) ENSEMBL(ENSG00000180772) HGNC(338) UMLS(C1332036) UNIPROTKB(P50052) SYMBOL(AGTR2)',
#   'type': 'Gene'},
#  {'NCBIGene': '4151',
#   'name': 'myoglobin',
#   'SYMBOL': 'MB',
#   'UMLS': 'C1417048',
#   'HGNC': '6915',
#   'UNIPROTKB': 'P02144',
#   'ENSEMBL': 'ENSG00000198125',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4151'},
#   'display': 'NCBIGene(4151) ENSEMBL(ENSG00000198125) HGNC(6915) UMLS(C1417048) UNIPROTKB(P02144) SYMBOL(MB)',
#   'type': 'Gene'},
#  {'NCBIGene': '6364',
#   'name': 'C-C motif chemokine ligand 20',
#   'SYMBOL': 'CCL20',
#   'UMLS': 'C1366524',
#   'HGNC': '10619',
#   'UNIPROTKB': 'P78556',
#   'ENSEMBL': 'ENSG00000115009',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6364'},
#   'display': 'NCBIGene(6364) ENSEMBL(ENSG00000115009) HGNC(10619) UMLS(C1366524) UNIPROTKB(P78556) SYMBOL(CCL20)',
#   'type': 'Gene'},
#  {'NCBIGene': '3383',
#   'name': 'intercellular adhesion molecule 1',
#   'SYMBOL': 'ICAM1',
#   'UMLS': 'C1334074',
#   'HGNC': '5344',
#   'UNIPROTKB': 'P05362',
#   'ENSEMBL': 'ENSG00000090339',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3383'},
#   'display': 'NCBIGene(3383) ENSEMBL(ENSG00000090339) HGNC(5344) UMLS(C1334074) UNIPROTKB(P05362) SYMBOL(ICAM1)',
#   'type': 'Gene'},
#  {'NCBIGene': '5290',
#   'name': 'phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha',
#   'SYMBOL': 'PIK3CA',
#   'UMLS': 'C1335212',
#   'HGNC': '8975',
#   'UNIPROTKB': 'P42336',
#   'ENSEMBL': 'ENSG00000121879',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5290'},
#   'display': 'NCBIGene(5290) ENSEMBL(ENSG00000121879) HGNC(8975) UMLS(C1335212) UNIPROTKB(P42336) SYMBOL(PIK3CA)',
#   'type': 'Gene'},
#  {'NCBIGene': '3576',
#   'name': 'C-X-C motif chemokine ligand 8',
#   'SYMBOL': 'CXCL8',
#   'UMLS': 'C1366571',
#   'HGNC': '6025',
#   'UNIPROTKB': 'P10145',
#   'ENSEMBL': 'ENSG00000169429',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3576'},
#   'display': 'NCBIGene(3576) ENSEMBL(ENSG00000169429) HGNC(6025) UMLS(C1366571) UNIPROTKB(P10145) SYMBOL(CXCL8)',
#   'type': 'Gene'},
#  {'NCBIGene': '3605',
#   'name': 'interleukin 17A',
#   'SYMBOL': 'IL17A',
#   'UMLS': 'C1825592',
#   'HGNC': '5981',
#   'UNIPROTKB': 'Q16552',
#   'ENSEMBL': 'ENSG00000112115',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3605'},
#   'display': 'NCBIGene(3605) ENSEMBL(ENSG00000112115) HGNC(5981) UMLS(C1825592) UNIPROTKB(Q16552) SYMBOL(IL17A)',
#   'type': 'Gene'},
#  {'NCBIGene': '1803',
#   'name': 'dipeptidyl peptidase 4',
#   'SYMBOL': 'DPP4',
#   'UMLS': 'C1414141',
#   'HGNC': '3009',
#   'UNIPROTKB': 'P27487',
#   'ENSEMBL': 'ENSG00000197635',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1803'},
#   'display': 'NCBIGene(1803) ENSEMBL(ENSG00000197635) HGNC(3009) UMLS(C1414141) UNIPROTKB(P27487) SYMBOL(DPP4)',
#   'type': 'Gene'},
#  {'NCBIGene': '960',
#   'name': 'CD44 molecule (Indian blood group)',
#   'SYMBOL': 'CD44',
#   'UMLS': 'C1332712',
#   'HGNC': '1681',
#   'UNIPROTKB': 'P16070',
#   'ENSEMBL': 'ENSG00000026508',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '960'},
#   'display': 'NCBIGene(960) ENSEMBL(ENSG00000026508) HGNC(1681) UMLS(C1332712) UNIPROTKB(P16070) SYMBOL(CD44)',
#   'type': 'Gene'},
#  {'NCBIGene': '3578',
#   'name': 'interleukin 9',
#   'SYMBOL': 'IL9',
#   'UMLS': 'C1334127',
#   'HGNC': '6029',
#   'UNIPROTKB': 'P15248',
#   'ENSEMBL': 'ENSG00000145839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3578'},
#   'display': 'NCBIGene(3578) ENSEMBL(ENSG00000145839) HGNC(6029) UMLS(C1334127) UNIPROTKB(P15248) SYMBOL(IL9)',
#   'type': 'Gene'},
#  {'NCBIGene': '2099',
#   'name': 'estrogen receptor 1',
#   'SYMBOL': 'ESR1',
#   'UMLS': 'C1414461',
#   'HGNC': '3467',
#   'UNIPROTKB': 'P03372',
#   'ENSEMBL': 'ENSG00000091831',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2099'},
#   'display': 'NCBIGene(2099) ENSEMBL(ENSG00000091831) HGNC(3467) UMLS(C1414461) UNIPROTKB(P03372) SYMBOL(ESR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '1950',
#   'name': 'epidermal growth factor',
#   'SYMBOL': 'EGF',
#   'UMLS': 'C1367721',
#   'HGNC': '3229',
#   'UNIPROTKB': 'P01133',
#   'ENSEMBL': 'ENSG00000138798',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1950'},
#   'display': 'NCBIGene(1950) ENSEMBL(ENSG00000138798) HGNC(3229) UMLS(C1367721) UNIPROTKB(P01133) SYMBOL(EGF)',
#   'type': 'Gene'},
#  {'NCBIGene': '941',
#   'name': 'CD80 molecule',
#   'SYMBOL': 'CD80',
#   'UMLS': 'C1366561',
#   'HGNC': '1700',
#   'UNIPROTKB': 'P33681',
#   'ENSEMBL': 'ENSG00000121594',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '941'},
#   'display': 'NCBIGene(941) ENSEMBL(ENSG00000121594) HGNC(1700) UMLS(C1366561) UNIPROTKB(P33681) SYMBOL(CD80)',
#   'type': 'Gene'},
#  {'NCBIGene': '7157',
#   'name': 'tumor protein p53',
#   'SYMBOL': 'TP53',
#   'UMLS': 'C0079419',
#   'HGNC': '11998',
#   'UNIPROTKB': 'P04637',
#   'ENSEMBL': 'ENSG00000141510',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7157'},
#   'display': 'NCBIGene(7157) ENSEMBL(ENSG00000141510) HGNC(11998) UMLS(C0079419) UNIPROTKB(P04637) SYMBOL(TP53)',
#   'type': 'Gene'},
#  {'NCBIGene': '7099',
#   'name': 'toll like receptor 4',
#   'SYMBOL': 'TLR4',
#   'UMLS': 'C1336636',
#   'HGNC': '11850',
#   'UNIPROTKB': 'O00206',
#   'ENSEMBL': 'ENSG00000136869',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7099'},
#   'display': 'NCBIGene(7099) ENSEMBL(ENSG00000136869) HGNC(11850) UMLS(C1336636) UNIPROTKB(O00206) SYMBOL(TLR4)',
#   'type': 'Gene'},
#  {'NCBIGene': '2353',
#   'name': 'Fos proto-oncogene, AP-1 transcription factor subunit',
#   'SYMBOL': 'FOS',
#   'UMLS': 'C0087140',
#   'HGNC': '3796',
#   'UNIPROTKB': 'P01100',
#   'ENSEMBL': 'ENSG00000170345',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2353'},
#   'display': 'NCBIGene(2353) ENSEMBL(ENSG00000170345) HGNC(3796) UMLS(C0087140) UNIPROTKB(P01100) SYMBOL(FOS)',
#   'type': 'Gene'},
#  {'NCBIGene': '283',
#   'name': 'angiogenin',
#   'SYMBOL': 'ANG',
#   'UMLS': 'C1367482',
#   'HGNC': '483',
#   'UNIPROTKB': 'P03950',
#   'ENSEMBL': 'ENSG00000214274',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '283'},
#   'display': 'NCBIGene(283) ENSEMBL(ENSG00000214274) HGNC(483) UMLS(C1367482) UNIPROTKB(P03950) SYMBOL(ANG)',
#   'type': 'Gene'},
#  {'NCBIGene': '2147',
#   'name': 'coagulation factor II, thrombin',
#   'SYMBOL': 'F2',
#   'UMLS': 'C1414504',
#   'HGNC': '3535',
#   'UNIPROTKB': 'P00734',
#   'ENSEMBL': 'ENSG00000180210',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2147'},
#   'display': 'NCBIGene(2147) ENSEMBL(ENSG00000180210) HGNC(3535) UMLS(C1414504) UNIPROTKB(P00734) SYMBOL(F2)',
#   'type': 'Gene'},
#  {'NCBIGene': '54938',
#   'name': 'seryl-tRNA synthetase 2, mitochondrial',
#   'SYMBOL': 'SARS2',
#   'UMLS': 'C1425041',
#   'HGNC': '17697',
#   'UNIPROTKB': 'Q9NP81',
#   'ENSEMBL': 'ENSG00000104835',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '54938'},
#   'display': 'NCBIGene(54938) ENSEMBL(ENSG00000104835) HGNC(17697) UMLS(C1425041) UNIPROTKB(Q9NP81) SYMBOL(SARS2)',
#   'type': 'Gene'}]

# %%
genes_related_to_phens = predict_many(v2_gene_inputs,[SARS,covid],['BiologicalProcess','PhenotypicFeature'])
genes_related_to_phens
# Out:
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
#     input input_type       pred1                     pred1_source  \
# 0    ACE2       Gene     affects                           SEMMED
# 1    ACE2       Gene    disrupts                           SEMMED
# 2    ACE2       Gene     affects                           SEMMED
# 3    ACE2       Gene     affects                           SEMMED
# 4    ACE2       Gene     affects                           SEMMED
# ..    ...        ...         ...                              ...
# 10  SARS2       Gene  related_to  Translator Text Mining Provider
# 11  SARS2       Gene  related_to  Translator Text Mining Provider
# 12  SARS2       Gene  related_to  Translator Text Mining Provider
# 0   SARS2       Gene  related_to                             None
# 1   SARS2       Gene  related_to                             None
#
#           pred1_api pred1_pubmed         node1_type            node1_name  \
# 0   SEMMED Gene API     15825152  BiologicalProcess              C0007613
# 1   SEMMED Gene API     27806985  BiologicalProcess              C0007613
# 2   SEMMED Gene API     23013041  BiologicalProcess              C0017262
# 3   SEMMED Gene API     23013041  BiologicalProcess              C0017262
# 4   SEMMED Gene API     23013041  BiologicalProcess              C0017262
# ..              ...          ...                ...                   ...
# 10    CORD Gene API         None  BiologicalProcess  MEMBRANE EVAGINATION
# 11    CORD Gene API         None  BiologicalProcess      HYPERSENSITIVITY
# 12    CORD Gene API         None  BiologicalProcess             LACTATION
# 0       BioLink API         None  PhenotypicFeature     DIABETES MELLITUS
# 1       BioLink API         None  PhenotypicFeature     DIABETES MELLITUS
#
#          node1_id        pred2                     pred2_source  \
# 0   UMLS:C0007613      affects                           SEMMED
# 1   UMLS:C0007613      affects                           SEMMED
# 2   UMLS:C0017262      affects                           SEMMED
# 3   UMLS:C0017262   related_to                           SEMMED
# 4   UMLS:C0017262  affected_by                           SEMMED
# ..            ...          ...                              ...
# 10  GO:GO:0006900   related_to  Translator Text Mining Provider
# 11  GO:GO:0002524   related_to  Translator Text Mining Provider
# 12  GO:GO:0007595   related_to  Translator Text Mining Provider
# 0   UMLS:C0011849   related_to                             None
# 1   UMLS:C0011849   related_to                              hpo
#
#              pred2_api                        pred2_pubmed        output_type  \
# 0   SEMMED Disease API                            19364769  BiologicalProcess
# 1   SEMMED Disease API                            19364769  BiologicalProcess
# 2   SEMMED Disease API  12565954,12650527,12749904,3208739  BiologicalProcess
# 3   SEMMED Disease API                             8049444  BiologicalProcess
# 4   SEMMED Disease API                            16174304  BiologicalProcess
# ..                 ...                                 ...                ...
# 10    CORD Disease API                                None  BiologicalProcess
# 11    CORD Disease API                                None  BiologicalProcess
# 12    CORD Disease API                                None  BiologicalProcess
# 0          BioLink API                                None  PhenotypicFeature
# 1   mydisease.info API                                None  PhenotypicFeature
#
#                                 output_name            output_id
# 0   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 1   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 2   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 3   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 4   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# ..                                      ...                  ...
# 10  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 11  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 12  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 0   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 1   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
#
# [2086 rows x 16 columns]

# %%
genes_related_to_phens[genes_related_to_phens["input"] == "ACE"]
# Out:
#    input input_type        pred1                     pred1_source  \
# 0    ACE       Gene      affects                           SEMMED
# 1    ACE       Gene       causes                           SEMMED
# 2    ACE       Gene      affects                           SEMMED
# 3    ACE       Gene      affects                           SEMMED
# 4    ACE       Gene     disrupts                           SEMMED
# 5    ACE       Gene      affects                           SEMMED
# 6    ACE       Gene     disrupts                           SEMMED
# 7    ACE       Gene      affects                           SEMMED
# 8    ACE       Gene     disrupts                           SEMMED
# 9    ACE       Gene      affects                           SEMMED
# 10   ACE       Gene      affects                           SEMMED
# 11   ACE       Gene      affects                           SEMMED
# 12   ACE       Gene      affects                           SEMMED
# 13   ACE       Gene       causes                           SEMMED
# 14   ACE       Gene     disrupts                           SEMMED
# 15   ACE       Gene       causes                           SEMMED
# 16   ACE       Gene     disrupts                           SEMMED
# 17   ACE       Gene       causes                           SEMMED
# 18   ACE       Gene      affects                           SEMMED
# 19   ACE       Gene      affects                           SEMMED
# 20   ACE       Gene      affects                           SEMMED
# 21   ACE       Gene     disrupts                           SEMMED
# 22   ACE       Gene      affects                           SEMMED
# 23   ACE       Gene  affected_by                           SEMMED
# 24   ACE       Gene      affects                           SEMMED
# 25   ACE       Gene  affected_by                           SEMMED
# 26   ACE       Gene      affects                           SEMMED
# 27   ACE       Gene  affected_by                           SEMMED
# 28   ACE       Gene       causes                           SEMMED
# 29   ACE       Gene  affected_by                           SEMMED
# 30   ACE       Gene     disrupts                           SEMMED
# 31   ACE       Gene      affects                           SEMMED
# 32   ACE       Gene      affects                           SEMMED
# 33   ACE       Gene     disrupts                           SEMMED
# 34   ACE       Gene       causes                           SEMMED
# 35   ACE       Gene   related_to  Translator Text Mining Provider
# 36   ACE       Gene   related_to  Translator Text Mining Provider
#
#           pred1_api                                       pred1_pubmed  \
# 0   SEMMED Gene API                                           12570788
# 1   SEMMED Gene API                                           27310436
# 2   SEMMED Gene API                                           21349701
# 3   SEMMED Gene API                                   17921161,9389791
# 4   SEMMED Gene API                                            9482924
# 5   SEMMED Gene API                                   17921161,9389791
# 6   SEMMED Gene API                                            9482924
# 7   SEMMED Gene API                                   17921161,9389791
# 8   SEMMED Gene API                                            9482924
# 9   SEMMED Gene API                                           26724739
# 10  SEMMED Gene API                                           26724739
# 11  SEMMED Gene API                                           26724739
# 12  SEMMED Gene API                                            8389141
# 13  SEMMED Gene API                                    1335236,2983326
# 14  SEMMED Gene API                                   26421871,8087842
# 15  SEMMED Gene API                                           27402326
# 16  SEMMED Gene API                                   26421871,8087842
# 17  SEMMED Gene API                                           27402326
# 18  SEMMED Gene API                                           28533364
# 19  SEMMED Gene API                                           28318412
# 20  SEMMED Gene API                                           28318412
# 21  SEMMED Gene API                                           18709157
# 22  SEMMED Gene API                                            7925000
# 23  SEMMED Gene API                                           10207138
# 24  SEMMED Gene API                                            7925000
# 25  SEMMED Gene API                                           10207138
# 26  SEMMED Gene API         12515125,18657531,24156506,8839808,9830503
# 27  SEMMED Gene API  11217909,15498266,16981144,17768594,19636212,2...
# 28  SEMMED Gene API                                           10402431
# 29  SEMMED Gene API                                           19275271
# 30  SEMMED Gene API                                   23740817,7523412
# 31  SEMMED Gene API                                           14730327
# 32  SEMMED Gene API                                           24707974
# 33  SEMMED Gene API                                           25894556
# 34  SEMMED Gene API                 23774520,25591763,27167344,9689050
# 35    CORD Gene API                                               None
# 36    CORD Gene API                                               None
#
#            node1_type       node1_name       node1_id        pred2  \
# 0   BiologicalProcess         C0007587  UMLS:C0007587      affects
# 1   BiologicalProcess         C0007587  UMLS:C0007587      affects
# 2   BiologicalProcess         C0007595  UMLS:C0007595      affects
# 3   BiologicalProcess         C0015895  UMLS:C0015895      affects
# 4   BiologicalProcess         C0015895  UMLS:C0015895      affects
# 5   BiologicalProcess         C0015895  UMLS:C0015895   related_to
# 6   BiologicalProcess         C0015895  UMLS:C0015895   related_to
# 7   BiologicalProcess         C0015895  UMLS:C0015895  affected_by
# 8   BiologicalProcess         C0015895  UMLS:C0015895  affected_by
# 9   BiologicalProcess         C0017262  UMLS:C0017262      affects
# 10  BiologicalProcess         C0017262  UMLS:C0017262   related_to
# 11  BiologicalProcess         C0017262  UMLS:C0017262  affected_by
# 12  BiologicalProcess         C1330957  UMLS:C1330957      affects
# 13  BiologicalProcess         C1330957  UMLS:C1330957      affects
# 14  BiologicalProcess         C0011065  UMLS:C0011065       causes
# 15  BiologicalProcess         C0011065  UMLS:C0011065       causes
# 16  BiologicalProcess         C0011065  UMLS:C0011065   related_to
# 17  BiologicalProcess         C0011065  UMLS:C0011065   related_to
# 18  BiologicalProcess         C0014653  UMLS:C0014653       causes
# 19  BiologicalProcess         C0301872  UMLS:C0301872       causes
# 20  BiologicalProcess         C0301872  UMLS:C0301872   related_to
# 21  BiologicalProcess         C0005615  UMLS:C0005615   related_to
# 22  BiologicalProcess         C0026882  UMLS:C0026882   related_to
# 23  BiologicalProcess         C0026882  UMLS:C0026882   related_to
# 24  BiologicalProcess         C0026882  UMLS:C0026882    caused_by
# 25  BiologicalProcess         C0026882  UMLS:C0026882    caused_by
# 26  BiologicalProcess         C0032529  UMLS:C0032529   related_to
# 27  BiologicalProcess         C0032529  UMLS:C0032529   related_to
# 28  BiologicalProcess         C0041904  UMLS:C0041904   related_to
# 29  BiologicalProcess         C0041904  UMLS:C0041904   related_to
# 30  BiologicalProcess         C0243102  UMLS:C0243102   related_to
# 31  BiologicalProcess         C1150171  UMLS:C1150171   related_to
# 32  BiologicalProcess         C0162638  UMLS:C0162638  affected_by
# 33  BiologicalProcess         C0162638  UMLS:C0162638  affected_by
# 34  BiologicalProcess         C0162638  UMLS:C0162638  affected_by
# 35  BiologicalProcess  GENE EXPRESSION  GO:GO:0010467   related_to
# 36  BiologicalProcess        BREAKDOWN  GO:GO:0009056   related_to
#
#                        pred2_source           pred2_api  \
# 0                            SEMMED  SEMMED Disease API
# 1                            SEMMED  SEMMED Disease API
# 2                            SEMMED  SEMMED Disease API
# 3                            SEMMED  SEMMED Disease API
# 4                            SEMMED  SEMMED Disease API
# 5                            SEMMED  SEMMED Disease API
# 6                            SEMMED  SEMMED Disease API
# 7                            SEMMED  SEMMED Disease API
# 8                            SEMMED  SEMMED Disease API
# 9                            SEMMED  SEMMED Disease API
# 10                           SEMMED  SEMMED Disease API
# 11                           SEMMED  SEMMED Disease API
# 12                           SEMMED  SEMMED Disease API
# 13                           SEMMED  SEMMED Disease API
# 14                           SEMMED  SEMMED Disease API
# 15                           SEMMED  SEMMED Disease API
# 16                           SEMMED  SEMMED Disease API
# 17                           SEMMED  SEMMED Disease API
# 18                           SEMMED  SEMMED Disease API
# 19                           SEMMED  SEMMED Disease API
# 20                           SEMMED  SEMMED Disease API
# 21                           SEMMED  SEMMED Disease API
# 22                           SEMMED  SEMMED Disease API
# 23                           SEMMED  SEMMED Disease API
# 24                           SEMMED  SEMMED Disease API
# 25                           SEMMED  SEMMED Disease API
# 26                           SEMMED  SEMMED Disease API
# 27                           SEMMED  SEMMED Disease API
# 28                           SEMMED  SEMMED Disease API
# 29                           SEMMED  SEMMED Disease API
# 30                           SEMMED  SEMMED Disease API
# 31                           SEMMED  SEMMED Disease API
# 32                           SEMMED  SEMMED Disease API
# 33                           SEMMED  SEMMED Disease API
# 34                           SEMMED  SEMMED Disease API
# 35  Translator Text Mining Provider    CORD Disease API
# 36  Translator Text Mining Provider    CORD Disease API
#
#                                          pred2_pubmed        output_type  \
# 0                                            17714515  BiologicalProcess
# 1                                            17714515  BiologicalProcess
# 2                                            16615058  BiologicalProcess
# 3                                            12409129  BiologicalProcess
# 4                                            12409129  BiologicalProcess
# 5                          11556770,12126208,12383464  BiologicalProcess
# 6                          11556770,12126208,12383464  BiologicalProcess
# 7                                            12409129  BiologicalProcess
# 8                                            12409129  BiologicalProcess
# 9                  12565954,12650527,12749904,3208739  BiologicalProcess
# 10                                            8049444  BiologicalProcess
# 11                                           16174304  BiologicalProcess
# 12                                           19101154  BiologicalProcess
# 13                                           19101154  BiologicalProcess
# 14  12881621,12882681,12890365,15490031,17194199,1...  BiologicalProcess
# 15  12881621,12882681,12890365,15490031,17194199,1...  BiologicalProcess
# 16                         14720422,15385183,19508437  BiologicalProcess
# 17                         14720422,15385183,19508437  BiologicalProcess
# 18                                            7181968  BiologicalProcess
# 19                                           20622733  BiologicalProcess
# 20  14504188,15851378,16095648,16689659,17532082,2...  BiologicalProcess
# 21                         12383464,23790003,23961955  BiologicalProcess
# 22                                  15350733,22100303  BiologicalProcess
# 23                                  15350733,22100303  BiologicalProcess
# 24                                           17012389  BiologicalProcess
# 25                                           17012389  BiologicalProcess
# 26                                           16652313  BiologicalProcess
# 27                                           16652313  BiologicalProcess
# 28                                           11004191  BiologicalProcess
# 29                                           11004191  BiologicalProcess
# 30                                           12968926  BiologicalProcess
# 31                                           15214807  BiologicalProcess
# 32                                           12919893  BiologicalProcess
# 33                                           12919893  BiologicalProcess
# 34                                           12919893  BiologicalProcess
# 35                                               None  BiologicalProcess
# 36                                               None  BiologicalProcess
#
#                                 output_name            output_id
# 0   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 1   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 2   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 3   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 4   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 5   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 6   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 7   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 8   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 9   ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 10  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 11  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 12  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 13  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 14  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 15  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 16  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 17  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 18  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 19  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 20  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 21  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 22  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 23  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 24  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 25  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 26  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 27  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 28  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 29  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 30  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 31  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 32  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 33  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 34  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 35  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091
# 36  ACUTE RESPIRATORY CORONAVIRUS INFECTION  MONDO:MONDO:0005091

# %%
v3_genes = list(dict.fromkeys(list(genes_related_to_phens["input"])))
v3_gene_inputs = create_gene_inputs(v3_genes)
v3_gene_inputs
# Out:
# [{'NCBIGene': '59272',
#   'name': 'angiotensin I converting enzyme 2',
#   'SYMBOL': 'ACE2',
#   'UMLS': 'C1422064',
#   'HGNC': '13557',
#   'UNIPROTKB': 'Q9BYF1',
#   'ENSEMBL': 'ENSG00000130234',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#   'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#   'type': 'Gene'},
#  {'NCBIGene': '1636',
#   'name': 'angiotensin I converting enzyme',
#   'SYMBOL': 'ACE',
#   'UMLS': 'C1413931',
#   'HGNC': '2707',
#   'UNIPROTKB': 'P12821',
#   'ENSEMBL': 'ENSG00000159640',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1636'},
#   'display': 'NCBIGene(1636) ENSEMBL(ENSG00000159640) HGNC(2707) UMLS(C1413931) UNIPROTKB(P12821) SYMBOL(ACE)',
#   'type': 'Gene'},
#  {'NCBIGene': '1401',
#   'name': 'C-reactive protein',
#   'SYMBOL': 'CRP',
#   'UMLS': 'C1413716',
#   'HGNC': '2367',
#   'UNIPROTKB': 'P02741',
#   'ENSEMBL': 'ENSG00000132693',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1401'},
#   'display': 'NCBIGene(1401) ENSEMBL(ENSG00000132693) HGNC(2367) UMLS(C1413716) UNIPROTKB(P02741) SYMBOL(CRP)',
#   'type': 'Gene'},
#  {'NCBIGene': '7124',
#   'name': 'tumor necrosis factor',
#   'SYMBOL': 'TNF',
#   'UMLS': 'C0812246',
#   'HGNC': '11892',
#   'UNIPROTKB': 'P01375',
#   'ENSEMBL': 'ENSG00000204490',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7124'},
#   'display': 'NCBIGene(7124) ENSEMBL(ENSG00000204490) HGNC(11892) UMLS(C0812246) UNIPROTKB(P01375) SYMBOL(TNF)',
#   'type': 'Gene'},
#  {'NCBIGene': '5972',
#   'name': 'renin',
#   'SYMBOL': 'REN',
#   'UMLS': 'C1419338',
#   'HGNC': '9958',
#   'UNIPROTKB': 'P00797',
#   'ENSEMBL': 'ENSG00000143839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5972'},
#   'display': 'NCBIGene(5972) ENSEMBL(ENSG00000143839) HGNC(9958) UMLS(C1419338) UNIPROTKB(P00797) SYMBOL(REN)',
#   'type': 'Gene'},
#  {'NCBIGene': '7054',
#   'name': 'tyrosine hydroxylase',
#   'SYMBOL': 'TH',
#   'UMLS': 'C1420718',
#   'HGNC': '11782',
#   'UNIPROTKB': 'P07101',
#   'ENSEMBL': 'ENSG00000180176',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7054'},
#   'display': 'NCBIGene(7054) ENSEMBL(ENSG00000180176) HGNC(11782) UMLS(C1420718) UNIPROTKB(P07101) SYMBOL(TH)',
#   'type': 'Gene'},
#  {'NCBIGene': '1154',
#   'name': 'cytokine inducible SH2 containing protein',
#   'SYMBOL': 'CISH',
#   'UMLS': 'C1332762',
#   'HGNC': '1984',
#   'UNIPROTKB': 'Q9NSE2',
#   'ENSEMBL': 'ENSG00000114737',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1154'},
#   'display': 'NCBIGene(1154) ENSEMBL(ENSG00000114737) HGNC(1984) UMLS(C1332762) UNIPROTKB(Q9NSE2) SYMBOL(CISH)',
#   'type': 'Gene'},
#  {'NCBIGene': '3559',
#   'name': 'interleukin 2 receptor subunit alpha',
#   'SYMBOL': 'IL2RA',
#   'UMLS': 'C1334114',
#   'HGNC': '6008',
#   'UNIPROTKB': 'P01589',
#   'ENSEMBL': 'ENSG00000134460',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3559'},
#   'display': 'NCBIGene(3559) ENSEMBL(ENSG00000134460) HGNC(6008) UMLS(C1334114) UNIPROTKB(P01589) SYMBOL(IL2RA)',
#   'type': 'Gene'},
#  {'NCBIGene': '3586',
#   'name': 'interleukin 10',
#   'SYMBOL': 'IL10',
#   'UMLS': 'C1334098',
#   'HGNC': '5962',
#   'UNIPROTKB': 'P22301',
#   'ENSEMBL': 'ENSG00000136634',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3586'},
#   'display': 'NCBIGene(3586) ENSEMBL(ENSG00000136634) HGNC(5962) UMLS(C1334098) UNIPROTKB(P22301) SYMBOL(IL10)',
#   'type': 'Gene'},
#  {'NCBIGene': '185',
#   'name': 'angiotensin II receptor type 1',
#   'SYMBOL': 'AGTR1',
#   'UMLS': 'C1439284',
#   'HGNC': '336',
#   'UNIPROTKB': 'P30556',
#   'ENSEMBL': 'ENSG00000144891',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '185'},
#   'display': 'NCBIGene(185) ENSEMBL(ENSG00000144891) HGNC(336) UMLS(C1439284) UNIPROTKB(P30556) SYMBOL(AGTR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '3630',
#   'name': 'insulin',
#   'SYMBOL': 'INS',
#   'UMLS': 'C1337112',
#   'HGNC': '6081',
#   'UNIPROTKB': 'P01308',
#   'ENSEMBL': 'ENSG00000254647',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3630'},
#   'display': 'NCBIGene(3630) ENSEMBL(ENSG00000254647) HGNC(6081) UMLS(C1337112) UNIPROTKB(P01308) SYMBOL(INS)',
#   'type': 'Gene'},
#  {'NCBIGene': '920',
#   'name': 'CD4 molecule',
#   'SYMBOL': 'CD4',
#   'UMLS': 'C1332714',
#   'HGNC': '1678',
#   'UNIPROTKB': 'P01730',
#   'ENSEMBL': 'ENSG00000010610',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '920'},
#   'display': 'NCBIGene(920) ENSEMBL(ENSG00000010610) HGNC(1678) UMLS(C1332714) UNIPROTKB(P01730) SYMBOL(CD4)',
#   'type': 'Gene'},
#  {'NCBIGene': '5443',
#   'name': 'proopiomelanocortin',
#   'SYMBOL': 'POMC',
#   'UMLS': 'C1337111',
#   'HGNC': '9201',
#   'UNIPROTKB': 'P01189',
#   'ENSEMBL': 'ENSG00000115138',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5443'},
#   'display': 'NCBIGene(5443) ENSEMBL(ENSG00000115138) HGNC(9201) UMLS(C1337111) UNIPROTKB(P01189) SYMBOL(POMC)',
#   'type': 'Gene'},
#  {'NCBIGene': '760',
#   'name': 'carbonic anhydrase 2',
#   'SYMBOL': 'CA2',
#   'UMLS': 'C1413043',
#   'HGNC': '1373',
#   'UNIPROTKB': 'P00918',
#   'ENSEMBL': 'ENSG00000104267',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '760'},
#   'display': 'NCBIGene(760) ENSEMBL(ENSG00000104267) HGNC(1373) UMLS(C1413043) UNIPROTKB(P00918) SYMBOL(CA2)',
#   'type': 'Gene'},
#  {'NCBIGene': '940',
#   'name': 'CD28 molecule',
#   'SYMBOL': 'CD28',
#   'UMLS': 'C1332709',
#   'HGNC': '1653',
#   'UNIPROTKB': 'P10747',
#   'ENSEMBL': 'ENSG00000178562',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '940'},
#   'display': 'NCBIGene(940) ENSEMBL(ENSG00000178562) HGNC(1653) UMLS(C1332709) UNIPROTKB(P10747) SYMBOL(CD28)',
#   'type': 'Gene'},
#  {'NCBIGene': '6347',
#   'name': 'C-C motif chemokine ligand 2',
#   'SYMBOL': 'CCL2',
#   'UMLS': 'C1337092',
#   'HGNC': '10618',
#   'UNIPROTKB': 'P13500',
#   'ENSEMBL': 'ENSG00000108691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6347'},
#   'display': 'NCBIGene(6347) ENSEMBL(ENSG00000108691) HGNC(10618) UMLS(C1337092) UNIPROTKB(P13500) SYMBOL(CCL2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3439',
#   'name': 'interferon alpha 1',
#   'SYMBOL': 'IFNA1',
#   'UMLS': 'C1415900',
#   'HGNC': '5417',
#   'UNIPROTKB': 'P01562',
#   'ENSEMBL': 'ENSG00000197919',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3439'},
#   'display': 'NCBIGene(3439) ENSEMBL(ENSG00000197919) HGNC(5417) UMLS(C1415900) UNIPROTKB(P01562) SYMBOL(IFNA1)',
#   'type': 'Gene'},
#  {'NCBIGene': '2152',
#   'name': 'coagulation factor III, tissue factor',
#   'SYMBOL': 'F3',
#   'UMLS': 'C1333522',
#   'HGNC': '3541',
#   'UNIPROTKB': 'P13726',
#   'ENSEMBL': 'ENSG00000117525',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2152'},
#   'display': 'NCBIGene(2152) ENSEMBL(ENSG00000117525) HGNC(3541) UMLS(C1333522) UNIPROTKB(P13726) SYMBOL(F3)',
#   'type': 'Gene'},
#  {'NCBIGene': '3569',
#   'name': 'interleukin 6',
#   'SYMBOL': 'IL6',
#   'UMLS': 'C1334122',
#   'HGNC': '6018',
#   'UNIPROTKB': 'P05231',
#   'ENSEMBL': 'ENSG00000136244',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3569'},
#   'display': 'NCBIGene(3569) ENSEMBL(ENSG00000136244) HGNC(6018) UMLS(C1334122) UNIPROTKB(P05231) SYMBOL(IL6)',
#   'type': 'Gene'},
#  {'NCBIGene': '5741',
#   'name': 'parathyroid hormone',
#   'SYMBOL': 'PTH',
#   'UMLS': 'C1419072',
#   'HGNC': '9606',
#   'UNIPROTKB': 'P01270',
#   'ENSEMBL': 'ENSG00000152266',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5741'},
#   'display': 'NCBIGene(5741) ENSEMBL(ENSG00000152266) HGNC(9606) UMLS(C1419072) UNIPROTKB(P01270) SYMBOL(PTH)',
#   'type': 'Gene'},
#  {'NCBIGene': '3952',
#   'name': 'leptin',
#   'SYMBOL': 'LEP',
#   'UMLS': 'C1416825',
#   'HGNC': '6553',
#   'UNIPROTKB': 'P41159',
#   'ENSEMBL': 'ENSG00000174697',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3952'},
#   'display': 'NCBIGene(3952) ENSEMBL(ENSG00000174697) HGNC(6553) UMLS(C1416825) UNIPROTKB(P41159) SYMBOL(LEP)',
#   'type': 'Gene'},
#  {'NCBIGene': '213',
#   'name': 'albumin',
#   'SYMBOL': 'ALB',
#   'UMLS': 'C1412332',
#   'HGNC': '399',
#   'UNIPROTKB': 'P02768',
#   'ENSEMBL': 'ENSG00000163631',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '213'},
#   'display': 'NCBIGene(213) ENSEMBL(ENSG00000163631) HGNC(399) UMLS(C1412332) UNIPROTKB(P02768) SYMBOL(ALB)',
#   'type': 'Gene'},
#  {'NCBIGene': '2875',
#   'name': 'glutamic--pyruvic transaminase',
#   'SYMBOL': 'GPT',
#   'UMLS': 'C1415274',
#   'HGNC': '4552',
#   'UNIPROTKB': 'P24298',
#   'ENSEMBL': 'ENSG00000167701',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2875'},
#   'display': 'NCBIGene(2875) ENSEMBL(ENSG00000167701) HGNC(4552) UMLS(C1415274) UNIPROTKB(P24298) SYMBOL(GPT)',
#   'type': 'Gene'},
#  {'NCBIGene': '914',
#   'name': 'CD2 molecule',
#   'SYMBOL': 'CD2',
#   'UMLS': 'C1367475',
#   'HGNC': '1639',
#   'UNIPROTKB': 'P06729',
#   'ENSEMBL': 'ENSG00000116824',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '914'},
#   'display': 'NCBIGene(914) ENSEMBL(ENSG00000116824) HGNC(1639) UMLS(C1367475) UNIPROTKB(P06729) SYMBOL(CD2)',
#   'type': 'Gene'},
#  {'NCBIGene': '3669',
#   'name': 'interferon stimulated exonuclease gene 20',
#   'SYMBOL': 'ISG20',
#   'UMLS': 'C1416478',
#   'HGNC': '6130',
#   'UNIPROTKB': 'Q96AZ6',
#   'ENSEMBL': 'ENSG00000172183',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3669'},
#   'display': 'NCBIGene(3669) ENSEMBL(ENSG00000172183) HGNC(6130) UMLS(C1416478) UNIPROTKB(Q96AZ6) SYMBOL(ISG20)',
#   'type': 'Gene'},
#  {'NCBIGene': '9402',
#   'name': 'GRB2 related adaptor protein 2',
#   'SYMBOL': 'GRAP2',
#   'UMLS': 'C1415284',
#   'HGNC': '4563',
#   'UNIPROTKB': 'O75791',
#   'ENSEMBL': 'ENSG00000100351',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '9402'},
#   'display': 'NCBIGene(9402) ENSEMBL(ENSG00000100351) HGNC(4563) UMLS(C1415284) UNIPROTKB(O75791) SYMBOL(GRAP2)',
#   'type': 'Gene'},
#  {'NCBIGene': '355',
#   'name': 'Fas cell surface death receptor',
#   'SYMBOL': 'FAS',
#   'UMLS': 'C1539477',
#   'HGNC': '11920',
#   'UNIPROTKB': 'P25445',
#   'ENSEMBL': 'ENSG00000026103',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '355'},
#   'display': 'NCBIGene(355) ENSEMBL(ENSG00000026103) HGNC(11920) UMLS(C1539477) UNIPROTKB(P25445) SYMBOL(FAS)',
#   'type': 'Gene'},
#  {'NCBIGene': '1234',
#   'name': 'C-C motif chemokine receptor 5',
#   'SYMBOL': 'CCR5',
#   'UMLS': 'C1332700',
#   'HGNC': '1606',
#   'UNIPROTKB': 'P51681',
#   'ENSEMBL': 'ENSG00000160791',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1234'},
#   'display': 'NCBIGene(1234) ENSEMBL(ENSG00000160791) HGNC(1606) UMLS(C1332700) UNIPROTKB(P51681) SYMBOL(CCR5)',
#   'type': 'Gene'},
#  {'NCBIGene': '847',
#   'name': 'catalase',
#   'SYMBOL': 'CAT',
#   'UMLS': 'C1413138',
#   'HGNC': '1516',
#   'UNIPROTKB': 'P04040',
#   'ENSEMBL': 'ENSG00000121691',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '847'},
#   'display': 'NCBIGene(847) ENSEMBL(ENSG00000121691) HGNC(1516) UMLS(C1413138) UNIPROTKB(P04040) SYMBOL(CAT)',
#   'type': 'Gene'},
#  {'NCBIGene': '1956',
#   'name': 'epidermal growth factor receptor',
#   'SYMBOL': 'EGFR',
#   'UMLS': 'C1414313',
#   'HGNC': '3236',
#   'UNIPROTKB': 'P00533',
#   'ENSEMBL': 'ENSG00000146648',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1956'},
#   'display': 'NCBIGene(1956) ENSEMBL(ENSG00000146648) HGNC(3236) UMLS(C1414313) UNIPROTKB(P00533) SYMBOL(EGFR)',
#   'type': 'Gene'},
#  {'NCBIGene': '207',
#   'name': 'AKT serine/threonine kinase 1',
#   'SYMBOL': 'AKT1',
#   'UMLS': 'C0812228',
#   'HGNC': '391',
#   'UNIPROTKB': 'P31749',
#   'ENSEMBL': 'ENSG00000142208',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '207'},
#   'display': 'NCBIGene(207) ENSEMBL(ENSG00000142208) HGNC(391) UMLS(C0812228) UNIPROTKB(P31749) SYMBOL(AKT1)',
#   'type': 'Gene'},
#  {'NCBIGene': '186',
#   'name': 'angiotensin II receptor type 2',
#   'SYMBOL': 'AGTR2',
#   'UMLS': 'C1332036',
#   'HGNC': '338',
#   'UNIPROTKB': 'P50052',
#   'ENSEMBL': 'ENSG00000180772',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '186'},
#   'display': 'NCBIGene(186) ENSEMBL(ENSG00000180772) HGNC(338) UMLS(C1332036) UNIPROTKB(P50052) SYMBOL(AGTR2)',
#   'type': 'Gene'},
#  {'NCBIGene': '4151',
#   'name': 'myoglobin',
#   'SYMBOL': 'MB',
#   'UMLS': 'C1417048',
#   'HGNC': '6915',
#   'UNIPROTKB': 'P02144',
#   'ENSEMBL': 'ENSG00000198125',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4151'},
#   'display': 'NCBIGene(4151) ENSEMBL(ENSG00000198125) HGNC(6915) UMLS(C1417048) UNIPROTKB(P02144) SYMBOL(MB)',
#   'type': 'Gene'},
#  {'NCBIGene': '6364',
#   'name': 'C-C motif chemokine ligand 20',
#   'SYMBOL': 'CCL20',
#   'UMLS': 'C1366524',
#   'HGNC': '10619',
#   'UNIPROTKB': 'P78556',
#   'ENSEMBL': 'ENSG00000115009',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6364'},
#   'display': 'NCBIGene(6364) ENSEMBL(ENSG00000115009) HGNC(10619) UMLS(C1366524) UNIPROTKB(P78556) SYMBOL(CCL20)',
#   'type': 'Gene'},
#  {'NCBIGene': '3383',
#   'name': 'intercellular adhesion molecule 1',
#   'SYMBOL': 'ICAM1',
#   'UMLS': 'C1334074',
#   'HGNC': '5344',
#   'UNIPROTKB': 'P05362',
#   'ENSEMBL': 'ENSG00000090339',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3383'},
#   'display': 'NCBIGene(3383) ENSEMBL(ENSG00000090339) HGNC(5344) UMLS(C1334074) UNIPROTKB(P05362) SYMBOL(ICAM1)',
#   'type': 'Gene'},
#  {'NCBIGene': '5290',
#   'name': 'phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha',
#   'SYMBOL': 'PIK3CA',
#   'UMLS': 'C1335212',
#   'HGNC': '8975',
#   'UNIPROTKB': 'P42336',
#   'ENSEMBL': 'ENSG00000121879',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5290'},
#   'display': 'NCBIGene(5290) ENSEMBL(ENSG00000121879) HGNC(8975) UMLS(C1335212) UNIPROTKB(P42336) SYMBOL(PIK3CA)',
#   'type': 'Gene'},
#  {'NCBIGene': '3576',
#   'name': 'C-X-C motif chemokine ligand 8',
#   'SYMBOL': 'CXCL8',
#   'UMLS': 'C1366571',
#   'HGNC': '6025',
#   'UNIPROTKB': 'P10145',
#   'ENSEMBL': 'ENSG00000169429',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3576'},
#   'display': 'NCBIGene(3576) ENSEMBL(ENSG00000169429) HGNC(6025) UMLS(C1366571) UNIPROTKB(P10145) SYMBOL(CXCL8)',
#   'type': 'Gene'},
#  {'NCBIGene': '3605',
#   'name': 'interleukin 17A',
#   'SYMBOL': 'IL17A',
#   'UMLS': 'C1825592',
#   'HGNC': '5981',
#   'UNIPROTKB': 'Q16552',
#   'ENSEMBL': 'ENSG00000112115',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3605'},
#   'display': 'NCBIGene(3605) ENSEMBL(ENSG00000112115) HGNC(5981) UMLS(C1825592) UNIPROTKB(Q16552) SYMBOL(IL17A)',
#   'type': 'Gene'},
#  {'NCBIGene': '1803',
#   'name': 'dipeptidyl peptidase 4',
#   'SYMBOL': 'DPP4',
#   'UMLS': 'C1414141',
#   'HGNC': '3009',
#   'UNIPROTKB': 'P27487',
#   'ENSEMBL': 'ENSG00000197635',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1803'},
#   'display': 'NCBIGene(1803) ENSEMBL(ENSG00000197635) HGNC(3009) UMLS(C1414141) UNIPROTKB(P27487) SYMBOL(DPP4)',
#   'type': 'Gene'},
#  {'NCBIGene': '960',
#   'name': 'CD44 molecule (Indian blood group)',
#   'SYMBOL': 'CD44',
#   'UMLS': 'C1332712',
#   'HGNC': '1681',
#   'UNIPROTKB': 'P16070',
#   'ENSEMBL': 'ENSG00000026508',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '960'},
#   'display': 'NCBIGene(960) ENSEMBL(ENSG00000026508) HGNC(1681) UMLS(C1332712) UNIPROTKB(P16070) SYMBOL(CD44)',
#   'type': 'Gene'},
#  {'NCBIGene': '3578',
#   'name': 'interleukin 9',
#   'SYMBOL': 'IL9',
#   'UMLS': 'C1334127',
#   'HGNC': '6029',
#   'UNIPROTKB': 'P15248',
#   'ENSEMBL': 'ENSG00000145839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3578'},
#   'display': 'NCBIGene(3578) ENSEMBL(ENSG00000145839) HGNC(6029) UMLS(C1334127) UNIPROTKB(P15248) SYMBOL(IL9)',
#   'type': 'Gene'},
#  {'NCBIGene': '2099',
#   'name': 'estrogen receptor 1',
#   'SYMBOL': 'ESR1',
#   'UMLS': 'C1414461',
#   'HGNC': '3467',
#   'UNIPROTKB': 'P03372',
#   'ENSEMBL': 'ENSG00000091831',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2099'},
#   'display': 'NCBIGene(2099) ENSEMBL(ENSG00000091831) HGNC(3467) UMLS(C1414461) UNIPROTKB(P03372) SYMBOL(ESR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '1950',
#   'name': 'epidermal growth factor',
#   'SYMBOL': 'EGF',
#   'UMLS': 'C1367721',
#   'HGNC': '3229',
#   'UNIPROTKB': 'P01133',
#   'ENSEMBL': 'ENSG00000138798',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1950'},
#   'display': 'NCBIGene(1950) ENSEMBL(ENSG00000138798) HGNC(3229) UMLS(C1367721) UNIPROTKB(P01133) SYMBOL(EGF)',
#   'type': 'Gene'},
#  {'NCBIGene': '941',
#   'name': 'CD80 molecule',
#   'SYMBOL': 'CD80',
#   'UMLS': 'C1366561',
#   'HGNC': '1700',
#   'UNIPROTKB': 'P33681',
#   'ENSEMBL': 'ENSG00000121594',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '941'},
#   'display': 'NCBIGene(941) ENSEMBL(ENSG00000121594) HGNC(1700) UMLS(C1366561) UNIPROTKB(P33681) SYMBOL(CD80)',
#   'type': 'Gene'},
#  {'NCBIGene': '7157',
#   'name': 'tumor protein p53',
#   'SYMBOL': 'TP53',
#   'UMLS': 'C0079419',
#   'HGNC': '11998',
#   'UNIPROTKB': 'P04637',
#   'ENSEMBL': 'ENSG00000141510',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7157'},
#   'display': 'NCBIGene(7157) ENSEMBL(ENSG00000141510) HGNC(11998) UMLS(C0079419) UNIPROTKB(P04637) SYMBOL(TP53)',
#   'type': 'Gene'},
#  {'NCBIGene': '7099',
#   'name': 'toll like receptor 4',
#   'SYMBOL': 'TLR4',
#   'UMLS': 'C1336636',
#   'HGNC': '11850',
#   'UNIPROTKB': 'O00206',
#   'ENSEMBL': 'ENSG00000136869',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7099'},
#   'display': 'NCBIGene(7099) ENSEMBL(ENSG00000136869) HGNC(11850) UMLS(C1336636) UNIPROTKB(O00206) SYMBOL(TLR4)',
#   'type': 'Gene'},
#  {'NCBIGene': '2353',
#   'name': 'Fos proto-oncogene, AP-1 transcription factor subunit',
#   'SYMBOL': 'FOS',
#   'UMLS': 'C0087140',
#   'HGNC': '3796',
#   'UNIPROTKB': 'P01100',
#   'ENSEMBL': 'ENSG00000170345',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2353'},
#   'display': 'NCBIGene(2353) ENSEMBL(ENSG00000170345) HGNC(3796) UMLS(C0087140) UNIPROTKB(P01100) SYMBOL(FOS)',
#   'type': 'Gene'},
#  {'NCBIGene': '283',
#   'name': 'angiogenin',
#   'SYMBOL': 'ANG',
#   'UMLS': 'C1367482',
#   'HGNC': '483',
#   'UNIPROTKB': 'P03950',
#   'ENSEMBL': 'ENSG00000214274',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '283'},
#   'display': 'NCBIGene(283) ENSEMBL(ENSG00000214274) HGNC(483) UMLS(C1367482) UNIPROTKB(P03950) SYMBOL(ANG)',
#   'type': 'Gene'},
#  {'NCBIGene': '2147',
#   'name': 'coagulation factor II, thrombin',
#   'SYMBOL': 'F2',
#   'UMLS': 'C1414504',
#   'HGNC': '3535',
#   'UNIPROTKB': 'P00734',
#   'ENSEMBL': 'ENSG00000180210',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2147'},
#   'display': 'NCBIGene(2147) ENSEMBL(ENSG00000180210) HGNC(3535) UMLS(C1414504) UNIPROTKB(P00734) SYMBOL(F2)',
#   'type': 'Gene'},
#  {'NCBIGene': '54938',
#   'name': 'seryl-tRNA synthetase 2, mitochondrial',
#   'SYMBOL': 'SARS2',
#   'UMLS': 'C1425041',
#   'HGNC': '17697',
#   'UNIPROTKB': 'Q9NP81',
#   'ENSEMBL': 'ENSG00000104835',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '54938'},
#   'display': 'NCBIGene(54938) ENSEMBL(ENSG00000104835) HGNC(17697) UMLS(C1425041) UNIPROTKB(Q9NP81) SYMBOL(SARS2)',
#   'type': 'Gene'}]

# %%
len(v3_genes)
v3_genes
# Out:
# ['ACE2',
#  'ACE',
#  'CRP',
#  'TNF',
#  'REN',
#  'TH',
#  'CISH',
#  'IL2RA',
#  'IL10',
#  'AGTR1',
#  'INS',
#  'CD4',
#  'POMC',
#  'CA2',
#  'CD28',
#  'CCL2',
#  'IFNA1',
#  'F3',
#  'IL6',
#  'PTH',
#  'LEP',
#  'ALB',
#  'GPT',
#  'CD2',
#  'ISG20',
#  'GRAP2',
#  'FAS',
#  'CCR5',
#  'CAT',
#  'EGFR',
#  'AKT1',
#  'AGTR2',
#  'MB',
#  'CCL20',
#  'ICAM1',
#  'PIK3CA',
#  'CXCL8',
#  'IL17A',
#  'DPP4',
#  'CD44',
#  'IL9',
#  'ESR1',
#  'EGF',
#  'CD80',
#  'TP53',
#  'TLR4',
#  'FOS',
#  'ANG',
#  'F2',
#  'SARS2']

# %%
genes_to_pathways = predict_many(v3_gene_inputs,['Pathway'])
genes_to_pathways
# Out:
#     input input_type                   pred1 pred1_source        pred1_api  \
# 0    ACE2       Gene  functional_association         CPDB  MyGene.info API
# 1    ACE2       Gene  functional_association         CPDB  MyGene.info API
# 2    ACE2       Gene  functional_association         CPDB  MyGene.info API
# 3    ACE2       Gene  functional_association         CPDB  MyGene.info API
# 5    ACE2       Gene  functional_association         CPDB  MyGene.info API
# ..    ...        ...                     ...          ...              ...
# 0   SARS2       Gene  functional_association         CPDB  MyGene.info API
# 1   SARS2       Gene  functional_association         CPDB  MyGene.info API
# 2   SARS2       Gene  functional_association         CPDB  MyGene.info API
# 3   SARS2       Gene  functional_association         CPDB  MyGene.info API
# 4   SARS2       Gene  functional_association         CPDB  MyGene.info API
#
#    pred1_pubmed output_type                             output_name  \
# 0          None     Pathway                           R-HSA-9678108
# 1          None     Pathway                           R-HSA-9678110
# 2          None     Pathway                           R-HSA-9679191
# 3          None     Pathway                           R-HSA-9679506
# 5          None     Pathway                           R-HSA-9694516
# ..          ...         ...                                     ...
# 0          None     Pathway                     TRNA AMINOACYLATION
# 1          None     Pathway       MITOCHONDRIAL TRNA AMINOACYLATION
# 2          None     Pathway                  METABOLISM OF PROTEINS
# 3          None     Pathway                             TRANSLATION
# 4          None     Pathway  SELENIUM METABOLISM AND SELENOPROTEINS
#
#               output_id
# 0   REACT:R-HSA-9678108
# 1   REACT:R-HSA-9678110
# 2   REACT:R-HSA-9679191
# 3   REACT:R-HSA-9679506
# 5   REACT:R-HSA-9694516
# ..                  ...
# 0    REACT:R-HSA-379724
# 1    REACT:R-HSA-379726
# 2    REACT:R-HSA-392499
# 3     REACT:R-HSA-72766
# 4     WIKIPATHWAYS:WP28
#
# [1757 rows x 9 columns]

# %%
# list(dict.fromkeys(list(genes_to_pathways["output_id"])))
genes_to_pathways = genes_to_pathways[genes_to_pathways["output_id"].str.contains('WIKIPATHWAYS')]

# %%
gene_list_3 = list(genes_to_pathways["input"])
gene_to_path_count_dict = {x:gene_list_3.count(x) for x in gene_list_3}
gene_to_path_count_dict
# Out:
# {'ACE2': 1,
#  'ACE': 1,
#  'CRP': 6,
#  'TNF': 53,
#  'REN': 1,
#  'TH': 8,
#  'CISH': 9,
#  'IL2RA': 8,
#  'IL10': 10,
#  'AGTR1': 5,
#  'INS': 16,
#  'CD4': 5,
#  'POMC': 3,
#  'CD28': 6,
#  'CCL2': 22,
#  'IFNA1': 5,
#  'F3': 5,
#  'IL6': 42,
#  'PTH': 4,
#  'LEP': 10,
#  'ALB': 4,
#  'GPT': 2,
#  'ISG20': 1,
#  'GRAP2': 2,
#  'FAS': 18,
#  'CCR5': 6,
#  'CAT': 6,
#  'EGFR': 40,
#  'AKT1': 102,
#  'AGTR2': 3,
#  'MB': 1,
#  'CCL20': 5,
#  'ICAM1': 15,
#  'PIK3CA': 51,
#  'CXCL8': 26,
#  'IL17A': 5,
#  'CD44': 3,
#  'IL9': 3,
#  'ESR1': 14,
#  'EGF': 24,
#  'CD80': 9,
#  'TP53': 52,
#  'TLR4': 19,
#  'FOS': 45,
#  'F2': 9,
#  'SARS2': 1}

# %%
# pathways
gene_to_pathway_results = {}
gene_to_pathway_genes = list(genes_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'genes_related_count' : 0,
        "genes_related" : [],
        "weighted_score" : []
    }

    
for index, row in genes_to_pathways.iterrows():
    gene_to_pathway_results[row['output_name']]['genes_related_count'] = gene_to_pathway_results[row['output_name']]['genes_related_count'] + 1
    gene_to_pathway_results[row['output_name']]['genes_related'].append(row['input'])

for index, row in genes_to_pathways.iterrows():
    score = 0 
    gene_to_pathway_results[row['output_name']]['genes_related_count'] = len(list(dict.fromkeys(list( gene_to_pathway_results[row['output_name']]['genes_related']))))
    for x in  gene_to_pathway_results[row['output_name']]['genes_related']:
        score = score + (1/math.sqrt(gene_to_path_count_dict[x]))
#         score = score + (1/gene_to_path_count_dict[x])
    gene_to_pathway_results[row['output_name']]['weighted_score'] = score
#     gene_to_pathway_results[row['output_name']]['genes_related_count'] =( 
#         gene_to_pathway_results[row['output_name']]['genes_related_count'] 
# #         + len(list(set(gene_to_pathway_results[row['output_name']]['genes_related']) & set(more_than_one)))
#     )
gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['weighted_score'], reverse = True))

# gene_to_pathway_results
pandas.DataFrame.from_dict(gene_to_pathway_results, orient='index').iloc[0:50]
# Out:
#                                                     genes_related_count  \
# ACE INHIBITOR PATHWAY                                                 5
# T-CELL ANTIGEN RECEPTOR (TCR) SIGNALING PATHWAY                      10
# ALLOGRAFT REJECTION                                                   9
# FOLATE METABOLISM                                                    10
# INTERLEUKIN-4 AND INTERLEUKIN-13 SIGNALING                           11
# SELENIUM MICRONUTRIENT NETWORK                                        9
# T-CELL ANTIGEN RECEPTOR (TCR) PATHWAY DURING ST...                    8
# VITAMIN B12 METABOLISM                                                8
# REGULATION OF TOLL-LIKE RECEPTOR SIGNALING PATHWAY                   10
# PI3K-AKT SIGNALING PATHWAY                                           10
# INTERLEUKIN-10 SIGNALING                                              8
# VIRAL ACUTE MYOCARDITIS                                               8
# SPINAL CORD INJURY                                                   10
# TOLL-LIKE RECEPTOR SIGNALING PATHWAY                                  9
# NONALCOHOLIC FATTY LIVER DISEASE                                      9
# VEGFA-VEGFR2 SIGNALING PATHWAY                                        7
# PEPTIDE GPCRS                                                         3
# GPCRS, CLASS A RHODOPSIN-LIKE                                         3
# JAK-STAT                                                              7
# SENESCENCE AND AUTOPHAGY IN CANCER                                    5
# DEVELOPMENT AND HETEROGENEITY OF THE ILC FAMILY                       4
# CONTROL OF IMMUNE TOLERANCE BY VASOACTIVE INTES...                    4
# MIRNAS INVOLVEMENT IN THE IMMUNE RESPONSE IN SE...                    6
# THYMIC STROMAL LYMPHOPOIETIN (TSLP) SIGNALING P...                    6
# CORTICOTROPIN-RELEASING HORMONE SIGNALING PATHWAY                     5
# NUCLEAR RECEPTORS META-PATHWAY                                        5
# FOCAL ADHESION-PI3K-AKT-MTOR-SIGNALING PATHWAY                        6
# HUMAN COMPLEMENT SYSTEM                                               3
# HEPATITIS C AND HEPATOCELLULAR CARCINOMA                              5
# LTF DANGER SIGNAL RESPONSE PATHWAY                                    5
# SUDDEN INFANT DEATH SYNDROME (SIDS) SUSCEPTIBIL...                    5
# BREAST CANCER PATHWAY                                                 7
# SELENIUM METABOLISM AND SELENOPROTEINS                                2
# MAPK SIGNALING PATHWAY                                                7
# INFLAMMATORY RESPONSE PATHWAY                                         3
# ADIPOGENESIS                                                          5
# CYTOKINES AND INFLAMMATORY RESPONSE                                   4
# LEPTIN SIGNALING PATHWAY                                              4
# INTERFERON ALPHA-BETA SIGNALING                                       1
# EFFECTS OF NITRIC OXIDE                                               1
# PHOTODYNAMIC THERAPY-INDUCED AP-1 SURVIVAL SIGN...                    6
# CORI CYCLE                                                            2
# IL1 AND MEGAKARYOCYTES IN OBESITY                                     4
# IL-2 SIGNALING PATHWAY                                                4
# NON-GENOMIC ACTIONS OF 1,25 DIHYDROXYVITAMIN D3                       5
# MICRORNAS IN CARDIOMYOCYTE HYPERTROPHY                                5
# LUNG FIBROSIS                                                         5
# OVERVIEW OF NANOPARTICLE EFFECTS                                      4
# ENDOMETRIAL CANCER                                                    6
# PI3K-AKT-MTOR - VITD3 SIGNALLING                                      4
#
#                                                                                         genes_related  \
# ACE INHIBITOR PATHWAY                                                  [ACE2, ACE, REN, AGTR1, AGTR2]
# T-CELL ANTIGEN RECEPTOR (TCR) SIGNALING PATHWAY     [CD4, CD28, IL6, GRAP2, FAS, CCR5, AKT1, IL17A...
# ALLOGRAFT REJECTION                                 [TNF, IL2RA, IL10, AGTR1, CD28, FAS, CXCL8, IL...
# FOLATE METABOLISM                                   [CRP, TNF, INS, CCL2, IL6, ALB, CAT, ICAM1, TP...
# INTERLEUKIN-4 AND INTERLEUKIN-13 SIGNALING          [TNF, IL10, POMC, CCL2, IL6, AKT1, ICAM1, CXCL...
# SELENIUM MICRONUTRIENT NETWORK                        [CRP, TNF, INS, CCL2, IL6, ALB, CAT, ICAM1, F2]
# T-CELL ANTIGEN RECEPTOR (TCR) PATHWAY DURING ST...   [TNF, IL10, CD4, CD28, GRAP2, AKT1, PIK3CA, FOS]
# VITAMIN B12 METABOLISM                                     [CRP, TNF, INS, CCL2, IL6, ALB, ICAM1, F2]
# REGULATION OF TOLL-LIKE RECEPTOR SIGNALING PATHWAY  [TNF, CISH, IFNA1, IL6, AKT1, PIK3CA, CXCL8, C...
# PI3K-AKT SIGNALING PATHWAY                          [IL2RA, INS, IFNA1, IL6, EGFR, AKT1, PIK3CA, E...
# INTERLEUKIN-10 SIGNALING                            [TNF, CCL2, IL6, CCR5, CCL20, ICAM1, CXCL8, CD80]
# VIRAL ACUTE MYOCARDITIS                                 [TNF, IL10, CD4, IL6, CCR5, AKT1, CD80, TLR4]
# SPINAL CORD INJURY                                  [TNF, CCL2, IL6, LEP, EGFR, ICAM1, CXCL8, TP53...
# TOLL-LIKE RECEPTOR SIGNALING PATHWAY                [TNF, IFNA1, IL6, AKT1, PIK3CA, CXCL8, CD80, T...
# NONALCOHOLIC FATTY LIVER DISEASE                    [TNF, INS, CCL2, IL6, LEP, FAS, AKT1, PIK3CA, ...
# VEGFA-VEGFR2 SIGNALING PATHWAY                            [CCL2, F3, FAS, AKT1, ICAM1, PIK3CA, CXCL8]
# PEPTIDE GPCRS                                                                    [AGTR1, CCR5, AGTR2]
# GPCRS, CLASS A RHODOPSIN-LIKE                                                    [AGTR1, CCR5, AGTR2]
# JAK-STAT                                                   [CISH, EGFR, AKT1, PIK3CA, ESR1, EGF, FOS]
# SENESCENCE AND AUTOPHAGY IN CANCER                                      [INS, IL6, CXCL8, CD44, TP53]
# DEVELOPMENT AND HETEROGENEITY OF THE ILC FAMILY                                [TNF, IL6, IL17A, IL9]
# CONTROL OF IMMUNE TOLERANCE BY VASOACTIVE INTES...                            [IL10, CD28, FAS, CD80]
# MIRNAS INVOLVEMENT IN THE IMMUNE RESPONSE IN SE...               [TNF, IL10, IL6, ICAM1, CXCL8, TLR4]
# THYMIC STROMAL LYMPHOPOIETIN (TSLP) SIGNALING P...            [CISH, IL2RA, IL6, AKT1, PIK3CA, CXCL8]
# CORTICOTROPIN-RELEASING HORMONE SIGNALING PATHWAY                      [POMC, AKT1, CXCL8, TLR4, FOS]
# NUCLEAR RECEPTORS META-PATHWAY                                         [TNF, CCL2, EGFR, CCL20, ESR1]
# FOCAL ADHESION-PI3K-AKT-MTOR-SIGNALING PATHWAY                  [IL2RA, INS, EGFR, AKT1, PIK3CA, EGF]
# HUMAN COMPLEMENT SYSTEM                                                             [CRP, ALB, ICAM1]
# HEPATITIS C AND HEPATOCELLULAR CARCINOMA                               [IL6, AKT1, CXCL8, CD44, TP53]
# LTF DANGER SIGNAL RESPONSE PATHWAY                                     [TNF, IFNA1, IL6, CXCL8, TLR4]
# SUDDEN INFANT DEATH SYNDROME (SIDS) SUSCEPTIBIL...                        [TNF, TH, IL10, IL6, CXCL8]
# BREAST CANCER PATHWAY                                      [EGFR, AKT1, PIK3CA, ESR1, EGF, TP53, FOS]
# SELENIUM METABOLISM AND SELENOPROTEINS                                                   [FOS, SARS2]
# MAPK SIGNALING PATHWAY                                         [TNF, FAS, EGFR, AKT1, EGF, TP53, FOS]
# INFLAMMATORY RESPONSE PATHWAY                                                     [IL2RA, CD28, CD80]
# ADIPOGENESIS                                                                [TNF, INS, IL6, LEP, FAS]
# CYTOKINES AND INFLAMMATORY RESPONSE                                             [TNF, IL10, CD4, IL6]
# LEPTIN SIGNALING PATHWAY                                                      [CISH, LEP, AKT1, ESR1]
# INTERFERON ALPHA-BETA SIGNALING                                                               [ISG20]
# EFFECTS OF NITRIC OXIDE                                                                          [MB]
# PHOTODYNAMIC THERAPY-INDUCED AP-1 SURVIVAL SIGN...                   [TNF, IL6, FAS, EGFR, TP53, FOS]
# CORI CYCLE                                                                                 [INS, GPT]
# IL1 AND MEGAKARYOCYTES IN OBESITY                                           [CCL2, ICAM1, PIK3CA, F2]
# IL-2 SIGNALING PATHWAY                                                       [CISH, IL2RA, AKT1, FOS]
# NON-GENOMIC ACTIONS OF 1,25 DIHYDROXYVITAMIN D3                         [TNF, CCL2, IL6, CXCL8, TLR4]
# MICRORNAS IN CARDIOMYOCYTE HYPERTROPHY                                 [TNF, CISH, AKT1, PIK3CA, EGF]
# LUNG FIBROSIS                                                            [TNF, CCL2, IL6, CXCL8, EGF]
# OVERVIEW OF NANOPARTICLE EFFECTS                                               [CRP, TNF, IL6, CXCL8]
# ENDOMETRIAL CANCER                                               [EGFR, AKT1, PIK3CA, EGF, TP53, FOS]
# PI3K-AKT-MTOR - VITD3 SIGNALLING                                           [IL10, AKT1, PIK3CA, CD80]
#
#                                                     weighted_score
# ACE INHIBITOR PATHWAY                                     4.024564
# T-CELL ANTIGEN RECEPTOR (TCR) SIGNALING PATHWAY           3.633472
# ALLOGRAFT REJECTION                                       2.874969
# FOLATE METABOLISM                                         2.801568
# INTERLEUKIN-4 AND INTERLEUKIN-13 SIGNALING                2.686732
# SELENIUM MICRONUTRIENT NETWORK                            2.662893
# T-CELL ANTIGEN RECEPTOR (TCR) PATHWAY DURING ST...        2.404271
# VITAMIN B12 METABOLISM                                    2.254645
# REGULATION OF TOLL-LIKE RECEPTOR SIGNALING PATHWAY        2.219190
# PI3K-AKT SIGNALING PATHWAY                                2.174442
# INTERLEUKIN-10 SIGNALING                                  2.147975
# VIRAL ACUTE MYOCARDITIS                                   2.125117
# SPINAL CORD INJURY                                        1.950683
# TOLL-LIKE RECEPTOR SIGNALING PATHWAY                      1.885857
# NONALCOHOLIC FATTY LIVER DISEASE                          1.741954
# VEGFA-VEGFR2 SIGNALING PATHWAY                            1.589474
# PEPTIDE GPCRS                                             1.432812
# GPCRS, CLASS A RHODOPSIN-LIKE                             1.432812
# JAK-STAT                                                  1.350947
# SENESCENCE AND AUTOPHAGY IN CANCER                        1.316445
# DEVELOPMENT AND HETEROGENEITY OF THE ILC FAMILY           1.316228
# CONTROL OF IMMUNE TOLERANCE BY VASOACTIVE INTES...        1.293512
# MIRNAS INVOLVEMENT IN THE IMMUNE RESPONSE IN SE...        1.291622
# THYMIC STROMAL LYMPHOPOIETIN (TSLP) SIGNALING P...        1.276349
# CORTICOTROPIN-RELEASING HORMONE SIGNALING PATHWAY         1.250968
# NUCLEAR RECEPTORS META-PATHWAY                            1.223150
# FOCAL ADHESION-PI3K-AKT-MTOR-SIGNALING PATHWAY            1.204834
# HUMAN COMPLEMENT SYSTEM                                   1.166447
# HEPATITIS C AND HEPATOCELLULAR CARCINOMA                  1.165460
# LTF DANGER SIGNAL RESPONSE PATHWAY                        1.164409
# SUDDEN INFANT DEATH SYNDROME (SIDS) SUSCEPTIBIL...        1.157561
# BREAST CANCER PATHWAY                                     1.156288
# SELENIUM METABOLISM AND SELENOPROTEINS                    1.149071
# MAPK SIGNALING PATHWAY                                    1.122062
# INFLAMMATORY RESPONSE PATHWAY                             1.095135
# ADIPOGENESIS                                              1.093594
# CYTOKINES AND INFLAMMATORY RESPONSE                       1.055105
# LEPTIN SIGNALING PATHWAY                                  1.015837
# INTERFERON ALPHA-BETA SIGNALING                           1.000000
# EFFECTS OF NITRIC OXIDE                                   1.000000
# PHOTODYNAMIC THERAPY-INDUCED AP-1 SURVIVAL SIGN...        0.973226
# CORI CYCLE                                                0.957107
# IL1 AND MEGAKARYOCYTES IN OBESITY                         0.944761
# IL-2 SIGNALING PATHWAY                                    0.934973
# NON-GENOMIC ACTIONS OF 1,25 DIHYDROXYVITAMIN D3           0.930396
# MICRORNAS IN CARDIOMYOCYTE HYPERTROPHY                    0.913861
# LUNG FIBROSIS                                             0.905105
# OVERVIEW OF NANOPARTICLE EFFECTS                          0.896028
# ENDOMETRIAL CANCER                                        0.889027
# PI3K-AKT-MTOR - VITD3 SIGNALLING                          0.888604

# %% [markdown]
# Result table interpretation: In agreement with argument made in article, top ranking results of "ACE Inhibitor Pathway" and "Metabolism of Angiotensinogen to Angiotensins" are both components of the RAS pathway.

# %% [markdown]
# ### 3.2 Genes -> Biological Processes
#
# Look at bbiological processes related to the genes, and then display top biological process occurrences in results (and which genes related to each biological processes).

# %%
gene_to_bioprocesses = predict_many(v3_gene_inputs, ['BiologicalProcess'])

# %%
gene_to_bioprocesses = gene_to_bioprocesses[gene_to_bioprocesses["pred1_api"] == "MyGene.info API"]
gene_to_bioprocesses
# Out:
#     input input_type                   pred1 pred1_source        pred1_api  \
# 37   ACE2       Gene  functional_association       entrez  MyGene.info API
# 38   ACE2       Gene  functional_association       entrez  MyGene.info API
# 39   ACE2       Gene  functional_association       entrez  MyGene.info API
# 40   ACE2       Gene  functional_association       entrez  MyGene.info API
# 41   ACE2       Gene  functional_association       entrez  MyGene.info API
# ..    ...        ...                     ...          ...              ...
# 70  SARS2       Gene  functional_association       entrez  MyGene.info API
# 71  SARS2       Gene  functional_association       entrez  MyGene.info API
# 72  SARS2       Gene  functional_association       entrez  MyGene.info API
# 73  SARS2       Gene  functional_association       entrez  MyGene.info API
# 74  SARS2       Gene  functional_association       entrez  MyGene.info API
#
#    pred1_pubmed        output_type  \
# 37     15380922  BiologicalProcess
# 38     10924499  BiologicalProcess
# 39         None  BiologicalProcess
# 40     18258853  BiologicalProcess
# 41     10924499  BiologicalProcess
# ..          ...                ...
# 70         None  BiologicalProcess
# 71     21873635  BiologicalProcess
# 72     10764807  BiologicalProcess
# 73     21873635  BiologicalProcess
# 74         None  BiologicalProcess
#
#                                        output_name      output_id
# 37               REGULATION OF CYTOKINE PRODUCTION  GO:GO:0001817
# 38                          ANGIOTENSIN MATURATION  GO:GO:0002003
# 39                          ANGIOTENSIN MATURATION  GO:GO:0002003
# 40          ANGIOTENSIN MEDIATED DRINKING BEHAVIOR  GO:GO:0003051
# 41  BLOOD PRESSURE REGULATION BY RENIN-ANGIOTENSIN  GO:GO:0003081
# ..                                             ...            ...
# 70     TRNA AMINOACYLATION FOR PROTEIN TRANSLATION  GO:GO:0006418
# 71                       SERYL-TRNA AMINOACYLATION  GO:GO:0006434
# 72                       SERYL-TRNA AMINOACYLATION  GO:GO:0006434
# 73         MITOCHONDRIAL SERYL-TRNA AMINOACYLATION  GO:GO:0070158
# 74             SELENOCYSTEINYL-TRNA(SEC) ANABOLISM  GO:GO:0097056
#
# [2153 rows x 9 columns]

# %%
gene_list_4 = list(gene_to_bioprocesses["input"])
gene_to_bp_count_dict = {x:gene_list_4.count(x) for x in gene_list_4}
gene_to_bp_count_dict
# Out:
# {'ACE2': 22,
#  'ACE': 38,
#  'CRP': 14,
#  'TNF': 177,
#  'REN': 19,
#  'TH': 65,
#  'CISH': 9,
#  'IL2RA': 19,
#  'IL10': 78,
#  'AGTR1': 34,
#  'INS': 68,
#  'CD4': 43,
#  'POMC': 14,
#  'CA2': 22,
#  'CD28': 32,
#  'CCL2': 60,
#  'IFNA1': 12,
#  'F3': 15,
#  'IL6': 105,
#  'PTH': 36,
#  'LEP': 105,
#  'ALB': 12,
#  'GPT': 5,
#  'CD2': 13,
#  'ISG20': 12,
#  'GRAP2': 5,
#  'FAS': 30,
#  'CCR5': 23,
#  'CAT': 39,
#  'EGFR': 109,
#  'AKT1': 153,
#  'AGTR2': 46,
#  'MB': 9,
#  'CCL20': 23,
#  'ICAM1': 59,
#  'PIK3CA': 48,
#  'CXCL8': 41,
#  'IL17A': 22,
#  'DPP4': 16,
#  'CD44': 29,
#  'IL9': 6,
#  'ESR1': 49,
#  'EGF': 45,
#  'CD80': 18,
#  'TP53': 143,
#  'TLR4': 95,
#  'FOS': 40,
#  'ANG': 31,
#  'F2': 40,
#  'SARS2': 5}

# %%
# bioprocesses

gene_to_bioprocess_results = {}
gene_to_bioprocess_genes = list(gene_to_bioprocesses["output_name"]) # create list of genes
gene_to_bioprocess_genes = list(dict.fromkeys(gene_to_bioprocess_genes))  # remove duplicates


for gene in gene_to_bioprocess_genes: 
    gene_to_bioprocess_results[gene] = {
        'bioprocess_count' : 0,
        "genes_related" : [],
        "weighted_score" : []
    }

for index, row in gene_to_bioprocesses.iterrows():
    gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] = gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] + 1
    gene_to_bioprocess_results[row['output_name']]['genes_related'].append(row['input'])

for index, row in gene_to_bioprocesses.iterrows():
    score = 0 
    gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] = len(list(dict.fromkeys(list(gene_to_bioprocess_results[row['output_name']]['genes_related']))))
    for x in  gene_to_bioprocess_results[row['output_name']]['genes_related']:
        score = score + (1/math.sqrt(gene_to_bp_count_dict[x]))
    gene_to_bioprocess_results[row['output_name']]['weighted_score'] = score
    
    
for index, row in gene_to_bioprocesses.iterrows():
    gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] = gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] + 1
    gene_to_bioprocess_results[row['output_name']]['genes_related'].append(row['input'])

# %%
## extra step needed to analyze biological processes because many are returned as UMLS id instead of name

gene_to_bioprocess_results = dict(sorted(gene_to_bioprocess_results.items(), key = lambda x: x[1]['weighted_score'], reverse = True))
counter = 0 
gene_to_bioprocess_results_copy = gene_to_bioprocess_results
for key in gene_to_bioprocess_results_copy.keys(): 
    if counter < 300: 
        if(('C0' in key) or ('C1' in key)): 
            try: 
                name = ht.query(key)['BiologicalProcess'][0]['name']
                gene_to_bioprocess_results[name] = gene_to_bioprocess_results[key]
                del gene_to_bioprocess_results[key]
            except: 
                pass
    counter = counter + 1

# %%
# gene_to_bioprocess_results
pandas.DataFrame.from_dict(gene_to_bioprocess_results, orient='index').iloc[0:50]
# Out:
#                                                     bioprocess_count  \
# CYTOKINE AND CHEMOKINE MEDIATED SIGNALING PATHWAY                 40
# INFLAMMATION                                                      34
# G PROTEIN COUPLED RECEPTOR PROTEIN SIGNALING PA...                30
# ACTIVATION OF GLOBAL TRANSCRIPTION FROM RNA POL...                32
# POSITIVE REGULATION OF GENE EXPRESSION                            31
# IMMUNE RESPONSE                                                   20
# ACTIVATION OF GENE-SPECIFIC TRANSCRIPTION                         28
# SIGNAL TRANSDUCTION                                               23
# POSITIVE REGULATION OF CELL POPULATION PROLIFER...                22
# CELL SURFACE RECEPTOR LINKED SIGNAL TRANSDUCTION                  20
# T CELL CO-STIMULATION                                             14
# ANTI-APOPTOSIS                                                    24
# CELL-CELL SIGNALING                                               14
# POSITIVE REGULATION OF AKT SIGNALING CASCADE                      21
# CELLULAR RESPONSE TO ENDOTOXIN                                    19
# POSITIVE REGULATION OF ERK CASCADE                                19
# RESPONSE TO HYPOXIA                                               14
# ANGIOTENSIN MATURATION                                            10
# ANGIOGENESIS                                                      15
# T CELL ACTIVATION                                                 11
# CELL ADHESION                                                     12
# ENTRY OF VIRUS INTO HOST CELL                                     11
# INTRACELLULAR SIGNAL TRANSDUCTION                                 13
# POSITIVE REGULATION OF PHOSPHATIDYLINOSITOL 3-K...                16
# POSITIVE REGULATION OF T CELL PROLIFERATION                       12
# CELLULAR RESPONSE TO IL-1                                         12
# BLOOD PRESSURE REGULATION BY RENIN-ANGIOTENSIN                     9
# NEGATIVE REGULATION OF GENE EXPRESSION                            15
# ACTIVATION OF NF-KAPPAB                                           16
# ANTIVIRAL RESPONSE                                                 7
# CELLULAR RESPONSE TO TNF                                          12
# POSITIVE REGULATION OF IL-8 PRODUCTION                            12
# T CELL RECEPTOR SIGNALING PATHWAY                                  8
# BLOOD PRESSURE HOMEOSTASIS                                        10
# APOPTOSIS ACTIVATOR ACTIVITY                                       8
# IMMUNE CELL MIGRATION                                             10
# SERYL-TRNA AMINOACYLATION                                          3
# REGULATION OF VASOCONSTRICTION                                     8
# MAP KINASE CASCADE                                                12
# POSITIVE REGULATION OF PEPTIDYL-TYROSINE PHOSPH...                12
# POSITIVE REGULATION OF CELL GROWTH                                10
# POSITIVE REGULATION OF PROTEIN AMINO ACID PHOSP...                14
# EGF RECEPTOR SIGNALING PATHWAY                                    11
# NEUTROPHIL CHEMOTAXIS                                              8
# RESPONSE TO ETHANOL                                               11
# PEPTIDOLYSIS                                                       8
# POSITIVE REGULATION OF APOPTOTIC PROCESS                          12
# KIDNEY DEVELOPMENT                                                 8
# HUMORAL IMMUNE RESPONSE                                           10
# APOPTOSIS REGULATOR ACTIVITY                                      10
#
#                                                                                         genes_related  \
# CYTOKINE AND CHEMOKINE MEDIATED SIGNALING PATHWAY   [TNF, IL2RA, IL10, CD4, POMC, CCL2, CCL2, IFNA...
# INFLAMMATION                                        [CRP, TNF, IL2RA, AGTR1, CCL2, CCL2, IL6, CCR5...
# G PROTEIN COUPLED RECEPTOR PROTEIN SIGNALING PA...  [AGTR1, AGTR1, AGTR1, INS, POMC, CCL2, PTH, CC...
# ACTIVATION OF GLOBAL TRANSCRIPTION FROM RNA POL...  [TNF, TNF, TNF, TNF, POMC, CD28, IL6, IL6, PTH...
# POSITIVE REGULATION OF GENE EXPRESSION              [CRP, TNF, TNF, TNF, TNF, INS, CD28, F3, IL6, ...
# IMMUNE RESPONSE                                     [IL2RA, CD4, FAS, CCR5, CCL20, CXCL8, IL17A, I...
# ACTIVATION OF GENE-SPECIFIC TRANSCRIPTION           [TNF, IL10, IL10, CD4, IL6, IL6, EGFR, AKT1, A...
# SIGNAL TRANSDUCTION                                 [CD4, POMC, CCL2, FAS, EGFR, EGFR, AKT1, CCL20...
# POSITIVE REGULATION OF CELL POPULATION PROLIFER...  [INS, IL6, IL6, IL6, EGFR, EGFR, EGFR, AKT1, A...
# CELL SURFACE RECEPTOR LINKED SIGNAL TRANSDUCTION    [IL2RA, CD4, CD28, CCL2, CD2, CCR5, EGFR, AGTR...
# T CELL CO-STIMULATION                               [CD28, CD28, GRAP2, AKT1, PIK3CA, DPP4, CD80, ...
# ANTI-APOPTOSIS                                      [IL10, CD28, IL6, LEP, ALB, FAS, CAT, EGFR, EG...
# CELL-CELL SIGNALING                                 [INS, POMC, PTH, GRAP2, CCR5, CCL20, IL17A, IN...
# POSITIVE REGULATION OF AKT SIGNALING CASCADE        [TNF, INS, CD28, F3, LEP, EGFR, EGFR, PIK3CA, ...
# CELLULAR RESPONSE TO ENDOTOXIN                      [IL10, CCL2, IL6, CCR5, ICAM1, CXCL8, CXCL8, C...
# POSITIVE REGULATION OF ERK CASCADE                  [TNF, CD4, CD4, CCL2, EGFR, EGFR, CCL20, ICAM1...
# RESPONSE TO HYPOXIA                                 [TH, TH, LEP, CAT, MB, DPP4, ANG, ANG, TH, TH,...
# ANGIOTENSIN MATURATION                              [ACE2, ACE2, ACE, ACE, REN, REN, REN, ACE2, AC...
# ANGIOGENESIS                                        [CCL2, LEP, PIK3CA, CXCL8, EGF, ANG, ANG, ANG,...
# T CELL ACTIVATION                                   [CD4, CD28, CD28, CD2, DPP4, CD44, CD4, CD28, ...
# CELL ADHESION                                       [CD4, CCL2, ICAM1, ICAM1, DPP4, CD44, CD44, CD...
# ENTRY OF VIRUS INTO HOST CELL                       [ACE2, ACE2, EGFR, ICAM1, DPP4, CD80, ACE2, AC...
# INTRACELLULAR SIGNAL TRANSDUCTION                   [CISH, LEP, AKT1, AKT1, AGTR2, CXCL8, CD80, CI...
# POSITIVE REGULATION OF PHOSPHATIDYLINOSITOL 3-K...  [TNF, INS, CD28, LEP, LEP, LEP, CAT, PIK3CA, F...
# POSITIVE REGULATION OF T CELL PROLIFERATION         [CD4, CD28, CD28, CD28, IL6, LEP, CD80, CD4, C...
# CELLULAR RESPONSE TO IL-1                           [CCL2, CCL2, CCL2, CCL20, ICAM1, CXCL8, IL17A,...
# BLOOD PRESSURE REGULATION BY RENIN-ANGIOTENSIN      [ACE2, ACE2, ACE, ACE, ACE, AGTR1, ACE2, ACE2,...
# NEGATIVE REGULATION OF GENE EXPRESSION              [ACE, TNF, TNF, CD28, PTH, AKT1, CXCL8, ESR1, ...
# ACTIVATION OF NF-KAPPAB                             [TNF, TNF, TNF, TNF, INS, IL6, CAT, ICAM1, TLR...
# ANTIVIRAL RESPONSE                                  [IFNA1, IL6, ISG20, ISG20, IFNA1, IL6, ISG20, ...
# CELLULAR RESPONSE TO TNF                            [CCL2, CCL2, CCL2, AKT1, CCL20, ICAM1, CXCL8, ...
# POSITIVE REGULATION OF IL-8 PRODUCTION              [TNF, TNF, TNF, F3, IL6, CD2, TLR4, TNF, TNF, ...
# T CELL RECEPTOR SIGNALING PATHWAY                   [CD4, CD28, GRAP2, PIK3CA, CD4, CD28, GRAP2, P...
# BLOOD PRESSURE HOMEOSTASIS                          [ACE, REN, POMC, LEP, AGTR2, ACE, REN, POMC, L...
# APOPTOSIS ACTIVATOR ACTIVITY                         [IL2RA, CD2, FAS, IL17A, IL2RA, CD2, FAS, IL17A]
# IMMUNE CELL MIGRATION                               [CD2, ICAM1, PIK3CA, CD44, F2, CD2, ICAM1, PIK...
# SERYL-TRNA AMINOACYLATION                                                [SARS2, SARS2, SARS2, SARS2]
# REGULATION OF VASOCONSTRICTION                      [ACE2, ACE, AGTR1, AGTR1, AGTR1, ACE2, ACE, AG...
# MAP KINASE CASCADE                                  [TNF, IL2RA, CCL2, CCR5, EGFR, EGF, TNF, IL2RA...
# POSITIVE REGULATION OF PEPTIDYL-TYROSINE PHOSPH...  [CD4, IL6, ICAM1, CD44, CD80, TP53, CD4, IL6, ...
# POSITIVE REGULATION OF CELL GROWTH                  [INS, EGFR, AKT1, IL9, F2, INS, EGFR, AKT1, IL...
# POSITIVE REGULATION OF PROTEIN AMINO ACID PHOSP...  [TNF, CD4, LEP, FAS, EGFR, AKT1, F2, TNF, CD4,...
# EGF RECEPTOR SIGNALING PATHWAY                      [EGFR, EGFR, EGFR, AKT1, PIK3CA, EGF, EGF, EGF...
# NEUTROPHIL CHEMOTAXIS                               [CCL2, CCL20, CXCL8, CXCL8, CXCL8, CCL2, CCL20...
# RESPONSE TO ETHANOL                                 [TH, TH, PTH, LEP, CAT, ICAM1, TH, TH, PTH, LE...
# PEPTIDOLYSIS                                                 [ACE, REN, DPP4, F2, ACE, REN, DPP4, F2]
# POSITIVE REGULATION OF APOPTOTIC PROCESS            [TNF, TNF, IL6, FAS, FAS, AKT1, TP53, TNF, TNF...
# KIDNEY DEVELOPMENT                                       [ACE, REN, AGTR1, CA2, ACE, REN, AGTR1, CA2]
# HUMORAL IMMUNE RESPONSE                             [TNF, CD28, CCL2, IFNA1, IL6, TNF, CD28, CCL2,...
# APOPTOSIS REGULATOR ACTIVITY                        [FAS, FAS, AKT1, ESR1, TP53, TP53, FAS, FAS, A...
#
#                                                     weighted_score
# CYTOKINE AND CHEMOKINE MEDIATED SIGNALING PATHWAY         3.457036
# INFLAMMATION                                              3.124649
# G PROTEIN COUPLED RECEPTOR PROTEIN SIGNALING PA...        3.014645
# ACTIVATION OF GLOBAL TRANSCRIPTION FROM RNA POL...        2.467041
# POSITIVE REGULATION OF GENE EXPRESSION                    2.339937
# IMMUNE RESPONSE                                           2.097440
# ACTIVATION OF GENE-SPECIFIC TRANSCRIPTION                 1.984475
# SIGNAL TRANSDUCTION                                       1.896163
# POSITIVE REGULATION OF CELL POPULATION PROLIFER...        1.895106
# CELL SURFACE RECEPTOR LINKED SIGNAL TRANSDUCTION          1.810696
# T CELL CO-STIMULATION                                     1.747354
# ANTI-APOPTOSIS                                            1.739137
# CELL-CELL SIGNALING                                       1.632639
# POSITIVE REGULATION OF AKT SIGNALING CASCADE              1.592531
# CELLULAR RESPONSE TO ENDOTOXIN                            1.534464
# POSITIVE REGULATION OF ERK CASCADE                        1.513518
# RESPONSE TO HYPOXIA                                       1.448332
# ANGIOTENSIN MATURATION                                    1.439091
# ANGIOGENESIS                                              1.394693
# T CELL ACTIVATION                                         1.219097
# CELL ADHESION                                             1.163367
# ENTRY OF VIRUS INTO HOST CELL                             1.138075
# INTRACELLULAR SIGNAL TRANSDUCTION                         1.131932
# POSITIVE REGULATION OF PHOSPHATIDYLINOSITOL 3-K...        1.128559
# POSITIVE REGULATION OF T CELL PROLIFERATION               1.113711
# CELLULAR RESPONSE TO IL-1                                 1.095376
# BLOOD PRESSURE REGULATION BY RENIN-ANGIOTENSIN            1.084564
# NEGATIVE REGULATION OF GENE EXPRESSION                    1.035870
# ACTIVATION OF NF-KAPPAB                                   1.015029
# ANTIVIRAL RESPONSE                                        0.963615
# CELLULAR RESPONSE TO TNF                                  0.963021
# POSITIVE REGULATION OF IL-8 PRODUCTION                    0.961231
# T CELL RECEPTOR SIGNALING PATHWAY                         0.920826
# BLOOD PRESSURE HOMEOSTASIS                                0.903930
# APOPTOSIS ACTIVATOR ACTIVITY                              0.902541
# IMMUNE CELL MIGRATION                                     0.895686
# SERYL-TRNA AMINOACYLATION                                 0.894427
# REGULATION OF VASOCONSTRICTION                            0.889918
# MAP KINASE CASCADE                                        0.887048
# POSITIVE REGULATION OF PEPTIDYL-TYROSINE PHOSPH...        0.885299
# POSITIVE REGULATION OF CELL GROWTH                        0.864258
# POSITIVE REGULATION OF PROTEIN AMINO ACID PHOSP...        0.842569
# EGF RECEPTOR SIGNALING PATHWAY                            0.810673
# NEUTROPHIL CHEMOTAXIS                                     0.806135
# RESPONSE TO ETHANOL                                       0.802643
# PEPTIDOLYSIS                                              0.799751
# POSITIVE REGULATION OF APOPTOTIC PROCESS                  0.777537
# KIDNEY DEVELOPMENT                                        0.776336
# HUMORAL IMMUNE RESPONSE                                   0.767306
# APOPTOSIS REGULATOR ACTIVITY                              0.756099

# %% [markdown]
# Result table interpretation: In agreement with argument made in article, top ranking results of "renin activity," "Angiogenic Process," and "ANGIOTENSIN MATURATIONs" are components of the RAS pathway / bioprocesses.

# %% [markdown]
# ### 3.3 Genes -> PhenotypicFeatures
#
# Look at chemical substances related to the genes, and then display top chemical substance occurrences in results (and which genes related to each chemical substances).

# %%
gene_to_phenotypic_features = predict_many(v3_gene_inputs, ['PhenotypicFeature'])
# Out:
# {'ACE': 10,
#  'TNF': 7,
#  'REN': 18,
#  'TH': 54,
#  'IL2RA': 19,
#  'IL10': 2,
#  'AGTR1': 10,
#  'INS': 79,
#  'CD4': 4,
#  'POMC': 22,
#  'CA2': 52,
#  'CD28': 1,
#  'IFNA1': 3,
#  'PTH': 16,
#  'LEP': 28,
#  'ALB': 22,
#  'GPT': 1,
#  'FAS': 76,
#  'CCR5': 1,
#  'CAT': 25,
#  'EGFR': 4,
#  'AKT1': 209,
#  'AGTR2': 37,
#  'PIK3CA': 243,
#  'DPP4': 1,
#  'CD44': 3,
#  'ESR1': 26,
#  'EGF': 16,
#  'TP53': 109,
#  'FOS': 77,
#  'ANG': 25,
#  'F2': 71,
#  'SARS2': 21}

# %%
gene_list_5 = list(gene_to_phenotypic_features["input"])
gene_to_phenotypic_feature_count_dict = {x:gene_list_5.count(x) for x in gene_list_5}
gene_to_phenotypic_feature_count_dict

gene_to_phenotypic_feature_results = {}
gene_to_phenotypic_feature_genes = list(gene_to_phenotypic_features["output_name"]) # create list of genes
gene_to_phenotypic_feature_genes = list(dict.fromkeys(gene_to_phenotypic_feature_genes))  # remove duplicates


for gene in gene_to_phenotypic_feature_genes: 
    gene_to_phenotypic_feature_results[gene] = {
        'phenotypic_feature_count' : 0,
        "genes_related" : [],
        "weighted_score" : []
    }

for index, row in gene_to_phenotypic_features.iterrows():
    gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] = gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] + 1
    gene_to_phenotypic_feature_results[row['output_name']]['genes_related'].append(row['input'])

for index, row in gene_to_phenotypic_features.iterrows():
    score = 0 
    gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] = len(list(dict.fromkeys(list(gene_to_phenotypic_feature_results[row['output_name']]['genes_related']))))
    for x in  gene_to_phenotypic_feature_results[row['output_name']]['genes_related']:
        score = score + (1/math.sqrt(gene_to_phenotypic_feature_count_dict[x]))
    gene_to_phenotypic_feature_results[row['output_name']]['weighted_score'] = score
    
    
for index, row in gene_to_phenotypic_features.iterrows():
    gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] = gene_to_phenotypic_feature_results[row['output_name']]['phenotypic_feature_count'] + 1
    gene_to_phenotypic_feature_results[row['output_name']]['genes_related'].append(row['input'])

# %%
gene_to_phenotypic_feature_results = dict(sorted(gene_to_phenotypic_feature_results.items(), key = lambda x: x[1]['weighted_score'], reverse = True))
pandas.DataFrame.from_dict(gene_to_phenotypic_feature_results, orient='index').iloc[0:20]
# Out:
#                                        phenotypic_feature_count  \
# C0034917                                                     31
# C0019699                                                     18
# EPILEPSY                                                     18
# PROGRESSIVE RESPIRATORY FAILURE                              10
# ARTERIAL HYPOTENSION                                         12
# C0456984                                                      6
# ECZEMA                                                        4
# ABNORMALLY SMALL CRANIUM                                     10
# HAVING TOO MUCH BODY FAT                                     12
# LOW LEVELS OF AMNIOTIC FLUID                                  8
# ANAEMIA                                                      13
# COGNITIVE DELAY                                              15
# FAILURE TO THRIVE                                            14
# INCREASED SPLEEN SIZE                                        15
# MOUTH SORE                                                    4
# WIDELY PATENT FONTANELLES AND SUTURES                         6
# HYPOPLASTIC LUNG                                              6
# POTTER FACIES                                                 6
# ABNORMALITY OF THE URINARY SYSTEM                             6
# ABSENT URINE OUTPUT                                           6
#
#                                                                            genes_related  \
# C0034917                               [TNF, TNF, TNF, TNF, TNF, INS, CD4, CA2, ALB, ...
# C0019699                               [TNF, TNF, IL10, CD4, IFNA1, IFNA1, LEP, FAS, ...
# EPILEPSY                               [INS, PTH, PTH, FAS, AKT1, AGTR2, PIK3CA, PIK3...
# PROGRESSIVE RESPIRATORY FAILURE        [ACE, REN, AGTR1, ANG, SARS2, ACE, REN, AGTR1,...
# ARTERIAL HYPOTENSION                   [ACE, REN, AGTR1, ALB, PIK3CA, TP53, ACE, REN,...
# C0456984                                              [CA2, DPP4, TP53, CA2, DPP4, TP53]
# ECZEMA                                                        [IL2RA, CD28, IL2RA, CD28]
# ABNORMALLY SMALL CRANIUM               [ACE, REN, AGTR1, EGF, TP53, ACE, REN, AGTR1, ...
# HAVING TOO MUCH BODY FAT               [INS, POMC, LEP, ALB, AGTR2, EGF, INS, POMC, L...
# LOW LEVELS OF AMNIOTIC FLUID                [ACE, REN, AGTR1, ALB, ACE, REN, AGTR1, ALB]
# ANAEMIA                                [REN, CA2, CA2, PIK3CA, TP53, F2, SARS2, REN, ...
# COGNITIVE DELAY                        [INS, CA2, AKT1, AGTR2, PIK3CA, PIK3CA, EGF, T...
# FAILURE TO THRIVE                      [INS, POMC, CA2, AKT1, PIK3CA, FOS, SARS2, INS...
# INCREASED SPLEEN SIZE                  [IL2RA, CA2, FAS, AKT1, PIK3CA, PIK3CA, FOS, F...
# MOUTH SORE                                                        [IL10, CAT, IL10, CAT]
# WIDELY PATENT FONTANELLES AND SUTURES                 [ACE, REN, AGTR1, ACE, REN, AGTR1]
# HYPOPLASTIC LUNG                                      [ACE, REN, AGTR1, ACE, REN, AGTR1]
# POTTER FACIES                                         [ACE, REN, AGTR1, ACE, REN, AGTR1]
# ABNORMALITY OF THE URINARY SYSTEM                     [ACE, REN, AGTR1, ACE, REN, AGTR1]
# ABSENT URINE OUTPUT                                   [ACE, REN, AGTR1, ACE, REN, AGTR1]
#
#                                        weighted_score
# C0034917                                     7.282040
# C0019699                                     4.485576
# EPILEPSY                                     1.434870
# PROGRESSIVE RESPIRATORY FAILURE              1.286376
# ARTERIAL HYPOTENSION                         1.241291
# C0456984                                     1.234458
# ECZEMA                                       1.229416
# ABNORMALLY SMALL CRANIUM                     1.213940
# HAVING TOO MUCH BODY FAT                     1.142291
# LOW LEVELS OF AMNIOTIC FLUID                 1.081359
# ANAEMIA                                      1.009881
# COGNITIVE DELAY                              0.958837
# FAILURE TO THRIVE                            0.929884
# INCREASED SPLEEN SIZE                        0.912909
# MOUTH SORE                                   0.907107
# WIDELY PATENT FONTANELLES AND SUTURES        0.868158
# HYPOPLASTIC LUNG                             0.868158
# POTTER FACIES                                0.868158
# ABNORMALITY OF THE URINARY SYSTEM            0.868158
# ABSENT URINE OUTPUT                          0.868158

# %% [markdown]
# Concept: [C0034917]  Reduced Glutathione
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7263077/
#
# Polonikov, Alexey. "Endogenous Deficiency of Glutathione as the Most Likely Cause of Serious Manifestations and Death in COVID-19 Patients." ACS Infectious Diseases (2020).
#
#
# C0019699
# Concept: [C0019699]  HIV Seropositivity

# %% [markdown]
# ### 4.1 COVID-19 -> Genes <- Hyaluronic Acid Explain Query

# %%
## Get Hayluronic Acid node
HYA = ht.query('hyaluronic acid')['ChemicalSubstance'][0]
HYA

# %%
fc3 = FindConnection(input_obj=covid, output_obj=HYA, intermediate_nodes=['Gene'])
fc3.connect(verbose=False)
df3 = fc3.display_table_view()
df3

# %% [markdown]
# ### 4.2 COVID/HYA Genes -> Pathways

# %%
## get related genes and turn them into nodes
genes_related_to_HYA = list(df3["node1_name"])
# get gene inputs through hint module
gene_inputs_2 = []
for gene in genes_related_to_HYA: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        gene_inputs_2.append(gene_input)
    except: 
        print(gene + ' Failed')

# %%
## Query Genes -> Pathways
HYA_gene_to_pathways = predict_many(gene_inputs_2, ['Pathway'])

# %%
# Display Pathway Counts and Genes related to each pathway 
gene_to_pathway_results = {}
gene_to_pathway_genes = list(HYA_gene_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'pathway_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_pathways_2.iterrows():
    gene_to_pathway_results[row['output_name']]['pathway_count'] = gene_to_pathway_results[row['output_name']]['pathway_count'] + 1
    gene_to_pathway_results[row['output_name']]['genes_related'].append(row['input'])
    

gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['pathway_count'], reverse = True))

# gene_to_pathway_results
pandas.DataFrame.from_dict(gene_to_pathway_results, orient='index').iloc[0:50]

# %% [markdown]
# Interestingly, cytokine signaling is the pathway most indicated as being related to genes that are related to both COVID and HYA. This may be in agreement with a large amount of research indicating cytokine concentration elevation to be correlated with severe COVID cases:
#
#
# - Cao, Xuetao. "COVID-19: immunopathology and its implications for therapy." Nature reviews immunology 20.5 (2020): 269-270.
#
# - Mangalmurti, Nilam, and Christopher A. Hunter. "Cytokine storms: understanding COVID-19." Immunity (2020).
#
# - Wu, Dandan, and Xuexian O. Yang. "TH17 responses in cytokine storm of COVID-19: An emerging target of JAK2 inhibitor Fedratinib." Journal of Microbiology, Immunology and Infection (2020).
#
#
#
# Additionally, and interestingly, past research has indicated a role of cytokines in hyaluronic acid production / degredation:
#
# - Sampson, Phyllis M., et al. "Cytokine regulation of human lung fibroblast hyaluronan (hyaluronic acid) production. Evidence for cytokine-regulated hyaluronan (hyaluronic acid) degradation and human lung fibroblast-derived hyaluronidase." The Journal of clinical investigation 90.4 (1992): 1492-1503.

# %% [markdown]
# ## 5 Summary
# ### 5.1 Summary
#
#
# - RAS Pathway and corresponding proteins, pathways, and processes, and chemicals were highly implicated through genes derived from COVID -> Genes <- Vasodilation / Hypotension query
#
# - Anatomical Entities related to genes were very representative of areas where symptoms in COVID patients often occur
#
# - Cytokine pathways may be relevant to different COVID symptoms (Hyaluronic Acid Production) than initially proposed
#
#
# ### 5.2 Future Directions
#
# - Investigate COVID & Hyaluronic Acid connection further
