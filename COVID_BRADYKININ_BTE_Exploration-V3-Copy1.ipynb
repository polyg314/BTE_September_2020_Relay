# %% [markdown]
# # Addressing COVID-19 Patient RAS-mediated Bradykinin Storm Hypothesis with  Biothings Explorer
#
# &emsp;
#
# SLIDES LINK: https://docs.google.com/presentation/d/1cL0Y-2FECPP5rWlJGI_ZWsvBysZVUGU-oDq75VexFrA/edit?usp=sharing

# %% [markdown]
# # Table of Contents
#
# ## &emsp; 0 Imports
# ## &emsp; 1 Overview of Background and BTE Approach
# ### &emsp; &emsp; 1.1 Article: Summary and Background
# ### &emsp; &emsp; 1.2 Overview of BTE Approach
# ## &emsp; 2 Determining Related Genes
# ### &emsp; &emsp; 2.1 Load COVID-19, Hypotension, and Vasodilation Nodes
# ### &emsp; &emsp; 2.2 COVID -> Genes <- Hypotension
# ### &emsp; &emsp; 2.3 COVID -> Genes <- Vasodilation
# ### &emsp; &emsp; 2.4 Create Gene Nodes
# ## &emsp; 3 Analyzing and Exploring Gene Results
# ### &emsp; &emsp; 3.1 Genes -> Pathways
# ### &emsp; &emsp; 3.2 Genes -> Biological Processes
# ### &emsp; &emsp; 3.3 Genes -> Chemical Substances
# ### &emsp; &emsp; 3.4 Genes -> Anatomical Entities
# ### &emsp; &emsp; 3.5 Genes -> Chemical Substances <- Vasodilation
# ## &emsp; 4 Exploring COVID-19 to Hyaluronic Acid Connection
# ### &emsp; &emsp; 4.1 COVID-19 -> Genes <- Hyaluronic Acid Explain Query
# ### &emsp; &emsp; 4.2 COVID/HYA Genes -> Pathways
# ## &emsp; 5 Summary
# ### &emsp; &emsp; 5.1 Summary
# ### &emsp; &emsp; 5.2 Future Directions

# %% [markdown]
# ## 0 Imports

# %%
# Import pandas and biothings explorers modules
import pandas as pandas
from biothings_explorer.query.predict import Predict
from biothings_explorer.query.visualize import display_graph
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
import nest_asyncio
nest_asyncio.apply()
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore") 
ht = Hint()


## predict_many -> functionality to be fully incorporated into BTE soon, will no longer need following
def predict_many(input_object_list, output_type_list, intermediate_node_list = ''):
    df_list = []
    for input_object in input_object_list: 
        if('name' in input_object):
            for output_type in output_type_list: 
                if(len(intermediate_node_list) > 0):
                    for inter in intermediate_node_list:
                        try: 
#                             print("Running: " + input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type )
                            fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
                            fc.connect(verbose=False)
                            df = fc.display_table_view()
                            rows = df.shape[0]
                            if(rows > 0):
                                df_list.append(df)
                        except:
                            pass
#                             print(input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type + ' FAILED')
                else:
                    try:
#                         print("Running: " + input_object['name'] + ' --> output type ' + output_type )
                        fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=None)
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        rows = df.shape[0]
                        if(rows > 0):
                            df_list.append(df)
                    except:
                        pass
#                         print(input_object['name'] + ' --> output type ' + output_type + ' FAILED')

    if(len(df_list) > 0):
        return pandas.concat(df_list)
    else:
        return None

# %% [markdown]
# ## 1 Overview of Background and BTE Approach
# &emsp;
# ### 1.1 Article: Summary and Background
#
# Article Reference:
#
# Garvin, Michael R., et al. "A mechanistic model and therapeutic interventions for COVID-19 involving a RAS-mediated bradykinin storm." Elife 9 (2020): e59177.
#
#
# Article Link:
#
# https://elifesciences.org/articles/59177
#
#
#
# Article Main Points:
#
# - RAS Pathway Imbalance implicated through gene expression analysis from cells in bronchoalveolar lavage fluid (BALF) from COVID-19 patients
#
# - Predicted RAS pathway imbalance to be cause of bradykinin-driven vascular dilation, vascular permeability and hypotension
#
# - Leaky membranes -> allows Hyaluronic Acid (HYA) to permeate into lungs
#
# - Analyses found that production of HYA was increased and the enzymes that could degrade it greatly decreased
#
#
# ### 1.2 Overview of BTE Approach
#
# As described in the article, vasodilation and hypotension are two distinctive signs and symptoms in severe COVID-19 cases that are predicted to lead to leaky membranes in the lung. Therefore, the following approach to determine whether or not this may be RAS-pathway linked is by looking at Genes that are both related to COVID and vasoconstriction or hypotension, and then analyzing this genes by looking at what pathways or processes they may be involved in, what chemical substances they may produce, and in what tissues or anatomical entities the genes are linked to.
#
# Also, starting in Section 4, a brief exploration of genes related to both COVID and Hyaluronic acid is done - HYA being a chemical found in the lungs of COVID patients that is hyper-absorbant and forms a gelatenous substance that blocks oxygen absorption by the lungs
#
# ## 2 Determining Related Genes
# &emsp;
# ### 2.1 Load COVID-19, Hypotension, and Vasodilation Nodes
# &emsp;

# %%
covid = ht.query('COVID-19')['Disease'][0]
covid
# Out:
# {'MONDO': 'MONDO:0100096',
#  'DOID': 'DOID:0080600',
#  'name': 'COVID-19',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0100096'},
#  'display': 'MONDO(MONDO:0100096) DOID(DOID:0080600) name(COVID-19)',
#  'type': 'Disease'}

# %%
hypotension = ht.query('hypotension')['PhenotypicFeature'][0]
hypotension
# Out:
# {'UMLS': 'C0003126',
#  'HP': 'HP:0000458',
#  'MESH': 'D000857',
#  'name': 'Anosmia',
#  'primary': {'identifier': 'UMLS',
#   'cls': 'PhenotypicFeature',
#   'value': 'C0003126'},
#  'display': 'UMLS(C0003126) HP(HP:0000458) MESH(D000857) name(Anosmia)',
#  'type': 'PhenotypicFeature'}

# %%
vasodilation = ht.query('vasodilation')['BiologicalProcess'][0]
vasodilation
# Out:
# {'UMLS': 'C0003126',
#  'HP': 'HP:0000458',
#  'MESH': 'D000857',
#  'name': 'Anosmia',
#  'primary': {'identifier': 'UMLS',
#   'cls': 'PhenotypicFeature',
#   'value': 'C0003126'},
#  'display': 'UMLS(C0003126) HP(HP:0000458) MESH(D000857) name(Anosmia)',
#  'type': 'PhenotypicFeature'}

# %%
vasc_perm = ht.query("positive regulation of vascular permeability")['BiologicalProcess'][0]
vasc_perm
# Out:
# {'GO': 'GO:0043117',
#  'name': 'positive regulation of vascular permeability',
#  'primary': {'identifier': 'GO',
#   'cls': 'BiologicalProcess',
#   'value': 'GO:0043117'},
#  'display': 'GO(GO:0043117) name(positive regulation of vascular permeability)',
#  'type': 'BiologicalProcess'}

# %%
SARS = ht.query("severe acute respiratory syndrome")["Disease"][0]

dfs = predict_many([SARS],["PhenotypicFeature"])
dfs = dfs[dfs["pred1_source"] =="hpo"]
dfs

sars_symptoms = list(dict.fromkeys(list(dfs["output_name"])))
sars_symptoms
# Out:
# ['DECREASED IMMUNE FUNCTION',
#  'ABNORMAL TISSUE MASS',
#  'COUGH',
#  'HYPOXEMIA',
#  'BREATHING DIFFICULTIES',
#  'ABNORMAL BREATHING',
#  'DIABETES MELLITUS',
#  'ABNORMALITY OF THE CARDIOVASCULAR SYSTEM',
#  'FEVER',
#  'RESPIRATORY DISTRESS NECESSITATING MECHANICAL VENTILATION',
#  'PHARYNGITIS',
#  'MUSCLE ACHE',
#  'ACUTE KIDNEY FAILURE',
#  'ACUTE INFECTIOUS PNEUMONIA',
#  'CHRONIC LUNG DISEASE',
#  'HEADACHE']

# %%
influenza = ht.query("flu")["Disease"][0]
influenza
# Out:
# {'MONDO': 'MONDO:0018695',
#  'DOID': 'DOID:4492',
#  'UMLS': 'C0016627',
#  'name': 'avian influenza',
#  'MESH': 'D005585',
#  'ORPHANET': '454836',
#  'OMOP': '314979',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0018695'},
#  'display': 'MONDO(MONDO:0018695) DOID(DOID:4492) ORPHANET(454836) UMLS(C0016627) MESH(D005585) name(avian influenza) OMOP(314979)',
#  'type': 'Disease'}

# %%
dfi = predict_many([influenza],["PhenotypicFeature"])
dfi 

inf_symptoms = list(dfi["output_name"])
print(len(inf_symptoms))
print(inf_symptoms)
# Out:
# 41
# ['FEVER', 'MUSCLE ACHE', 'FATIGUE', 'COUGH', 'PHARYNGITIS', 'LOW PLATELET COUNT', 'DECREASED BLOOD LEUKOCYTE NUMBER', 'ABSOLUTE LYMPHOCYTE COUNT DECREASE', 'LUNG INFILTRATES', 'HEADACHE', 'ELEVATED C-REACTIVE PROTEIN LEVEL', 'HYPOXEMIA', 'GROUND-GLASS OPACIFICATION ON PULMONARY HRCT', 'DRY COUGH', 'CONJUNCTIVITIS', 'EMESIS', 'DIARRHEA', 'ABDOMINAL DISCOMFORT', 'PNEUMONIA', 'ABNORMAL BREATHING', 'FLUID AROUND LUNGS', 'RESPIRATORY FAILURE', 'MISCARRIAGE', 'INCREASED LACTATE DEHYDROGENASE LEVEL', 'PRODUCTIVE COUGH', 'CHEST PAIN', 'MENINGITIS', 'CARDIAC FAILURE', 'ACUTE KIDNEY FAILURE', 'BREATHING DIFFICULTIES', 'COLLAPSED LUNG', 'BRAIN INFLAMMATION', 'INCREASED RESPIRATORY RATE OR DEPTH OF BREATHING', 'ABNORMAL LIVER ENZYMES', 'HYPOALBUMINAEMIA', 'BREAKDOWN OF SKELETAL MUSCLE', 'ELEVATED BLOOD CREATINE PHOSPHOKINASE', 'DISSEMINATED INTRAVASCULAR COAGULATION', 'HEPATITIS', 'INFLAMMATION OF SPINAL CORD', 'INFECTION IN BLOOD STREAM']

# %%
list(set(sars_symptoms) & set(inf_symptoms))

print(len(sars_symptoms))
print(len(list(set(sars_symptoms) & set(inf_symptoms))))
# Out:
# 16
# 9

# %%
ACE = ht.query("ACE")["Gene"][0]
ACE
# Out:
# {'NCBIGene': '1636',
#  'name': 'angiotensin I converting enzyme',
#  'SYMBOL': 'ACE',
#  'UMLS': 'C1413931',
#  'HGNC': '2707',
#  'UNIPROTKB': 'P12821',
#  'ENSEMBL': 'ENSG00000159640',
#  'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1636'},
#  'display': 'NCBIGene(1636) ENSEMBL(ENSG00000159640) HGNC(2707) UMLS(C1413931) UNIPROTKB(P12821) SYMBOL(ACE)',
#  'type': 'Gene'}

# %%
df12 = predict_many([ACE2], ["BiologicalProcess","PhenotypicFeature"])
df12
# Out:
#    input input_type                   pred1                     pred1_source  \
# 0   ACE2       Gene                 affects                           SEMMED
# 1   ACE2       Gene                 affects                           SEMMED
# 2   ACE2       Gene                 affects                           SEMMED
# 3   ACE2       Gene                disrupts                           SEMMED
# 4   ACE2       Gene                 affects                           SEMMED
# 5   ACE2       Gene                 affects                           SEMMED
# 6   ACE2       Gene                 affects                           SEMMED
# 7   ACE2       Gene                 affects                           SEMMED
# 8   ACE2       Gene                 affects                           SEMMED
# 9   ACE2       Gene                 affects                           SEMMED
# 10  ACE2       Gene                 affects                           SEMMED
# 11  ACE2       Gene                 affects                           SEMMED
# 12  ACE2       Gene                 affects                           SEMMED
# 13  ACE2       Gene                 affects                           SEMMED
# 14  ACE2       Gene                 affects                           SEMMED
# 15  ACE2       Gene                 affects                           SEMMED
# 16  ACE2       Gene                 affects                           SEMMED
# 17  ACE2       Gene                 affects                           SEMMED
# 18  ACE2       Gene                 affects                           SEMMED
# 19  ACE2       Gene                 affects                           SEMMED
# 20  ACE2       Gene                 affects                           SEMMED
# 21  ACE2       Gene                 affects                           SEMMED
# 22  ACE2       Gene                 affects                           SEMMED
# 23  ACE2       Gene                disrupts                           SEMMED
# 24  ACE2       Gene                disrupts                           SEMMED
# 25  ACE2       Gene                disrupts                           SEMMED
# 26  ACE2       Gene                disrupts                           SEMMED
# 27  ACE2       Gene                disrupts                           SEMMED
# 28  ACE2       Gene                  causes                           SEMMED
# 29  ACE2       Gene                  causes                           SEMMED
# 30  ACE2       Gene                  causes                           SEMMED
# 31  ACE2       Gene                  causes                           SEMMED
# 32  ACE2       Gene             affected_by                           SEMMED
# 33  ACE2       Gene             affected_by                           SEMMED
# 34  ACE2       Gene              related_to  Translator Text Mining Provider
# 35  ACE2       Gene              related_to  Translator Text Mining Provider
# 36  ACE2       Gene              related_to  Translator Text Mining Provider
# 37  ACE2       Gene  functional_association                           entrez
# 38  ACE2       Gene  functional_association                           entrez
# 39  ACE2       Gene  functional_association                           entrez
# 40  ACE2       Gene  functional_association                           entrez
# 41  ACE2       Gene  functional_association                           entrez
# 42  ACE2       Gene  functional_association                           entrez
# 43  ACE2       Gene  functional_association                           entrez
# 44  ACE2       Gene  functional_association                           entrez
# 45  ACE2       Gene  functional_association                           entrez
# 46  ACE2       Gene  functional_association                           entrez
# 47  ACE2       Gene  functional_association                           entrez
# 48  ACE2       Gene  functional_association                           entrez
# 49  ACE2       Gene  functional_association                           entrez
# 50  ACE2       Gene  functional_association                           entrez
# 51  ACE2       Gene  functional_association                           entrez
# 52  ACE2       Gene  functional_association                           entrez
# 53  ACE2       Gene  functional_association                           entrez
# 54  ACE2       Gene  functional_association                           entrez
# 55  ACE2       Gene  functional_association                           entrez
# 56  ACE2       Gene  functional_association                           entrez
# 57  ACE2       Gene  functional_association                           entrez
# 58  ACE2       Gene  functional_association                           entrez
#
#           pred1_api                        pred1_pubmed        output_type  \
# 0   SEMMED Gene API          12691672,18258853,20392165  BiologicalProcess
# 1   SEMMED Gene API                            21656919  BiologicalProcess
# 2   SEMMED Gene API                            15825152  BiologicalProcess
# 3   SEMMED Gene API                            27806985  BiologicalProcess
# 4   SEMMED Gene API                            24846945  BiologicalProcess
# 5   SEMMED Gene API                   18310259,20692300  BiologicalProcess
# 6   SEMMED Gene API                            23013041  BiologicalProcess
# 7   SEMMED Gene API                            22837003  BiologicalProcess
# 8   SEMMED Gene API                            15255906  BiologicalProcess
# 9   SEMMED Gene API  1730413,18076379,23013041,27589033  BiologicalProcess
# 10  SEMMED Gene API          15075283,15825152,19220748  BiologicalProcess
# 11  SEMMED Gene API                            29108260  BiologicalProcess
# 12  SEMMED Gene API                            21695173  BiologicalProcess
# 13  SEMMED Gene API                    10409653,8668141  BiologicalProcess
# 14  SEMMED Gene API                   14754895,15151696  BiologicalProcess
# 15  SEMMED Gene API                   20844835,21418997  BiologicalProcess
# 16  SEMMED Gene API                            22340266  BiologicalProcess
# 17  SEMMED Gene API                            18258853  BiologicalProcess
# 18  SEMMED Gene API                            18715118  BiologicalProcess
# 19  SEMMED Gene API                            24219285  BiologicalProcess
# 20  SEMMED Gene API                            18310102  BiologicalProcess
# 21  SEMMED Gene API                            17254576  BiologicalProcess
# 22  SEMMED Gene API                            27629265  BiologicalProcess
# 23  SEMMED Gene API                            22750422  BiologicalProcess
# 24  SEMMED Gene API                            25405471  BiologicalProcess
# 25  SEMMED Gene API                   22155301,25644821  BiologicalProcess
# 26  SEMMED Gene API                            18258853  BiologicalProcess
# 27  SEMMED Gene API                            23823602  BiologicalProcess
# 28  SEMMED Gene API                            27633839  BiologicalProcess
# 29  SEMMED Gene API                            22750422  BiologicalProcess
# 30  SEMMED Gene API                            27302421  BiologicalProcess
# 31  SEMMED Gene API                            19841732  BiologicalProcess
# 32  SEMMED Gene API                   20671240,22330342  BiologicalProcess
# 33  SEMMED Gene API                            24564768  BiologicalProcess
# 34    CORD Gene API                                None  BiologicalProcess
# 35    CORD Gene API                                None  BiologicalProcess
# 36    CORD Gene API                                None  BiologicalProcess
# 37  MyGene.info API                            15380922  BiologicalProcess
# 38  MyGene.info API                            10924499  BiologicalProcess
# 39  MyGene.info API                                None  BiologicalProcess
# 40  MyGene.info API                            18258853  BiologicalProcess
# 41  MyGene.info API                            10924499  BiologicalProcess
# 42  MyGene.info API                            18258853  BiologicalProcess
# 43  MyGene.info API                                None  BiologicalProcess
# 44  MyGene.info API                            15380922  BiologicalProcess
# 45  MyGene.info API                            25534429  BiologicalProcess
# 46  MyGene.info API                            18258853  BiologicalProcess
# 47  MyGene.info API                            17703127  BiologicalProcess
# 48  MyGene.info API                            32221306  BiologicalProcess
# 49  MyGene.info API                            15165741  BiologicalProcess
# 50  MyGene.info API                   18343844,32221306  BiologicalProcess
# 51  MyGene.info API                            15380922  BiologicalProcess
# 52  MyGene.info API                            19185582  BiologicalProcess
# 53  MyGene.info API                                None  BiologicalProcess
# 54  MyGene.info API                            15380922  BiologicalProcess
# 55  MyGene.info API                            12967627  BiologicalProcess
# 56  MyGene.info API                            12967627  BiologicalProcess
# 57  MyGene.info API                            25534429  BiologicalProcess
# 58  MyGene.info API                            15380922  BiologicalProcess
#
#                                           output_name      output_id
# 0                                            C0007227  UMLS:C0007227
# 1                                            C0007586  UMLS:C0007586
# 2                                            C0007613  UMLS:C0007613
# 3                                            C0007613  UMLS:C0007613
# 4                                            C0010813  UMLS:C0010813
# 5                                            C0013081  UMLS:C0013081
# 6                                            C0017262  UMLS:C0017262
# 7                                            C0019868  UMLS:C0019868
# 8                                            C0026559  UMLS:C0026559
# 9                                            C0040649  UMLS:C0040649
# 10                                           C0042765  UMLS:C0042765
# 11                                           C0078994  UMLS:C0078994
# 12                                           C0080311  UMLS:C0080311
# 13                                           C0162493  UMLS:C0162493
# 14                                           C0232164  UMLS:C0232164
# 15                                           C0596290  UMLS:C0596290
# 16                                           C0600520  UMLS:C0600520
# 17                                           C0678863  UMLS:C0678863
# 18                                           C1148759  UMLS:C1148759
# 19                                           C1150182  UMLS:C1150182
# 20                                           C1156247  UMLS:C1156247
# 21                                           C1510890  UMLS:C1510890
# 22                                           C1150120  UMLS:C1150120
# 23                                           C0031715  UMLS:C0031715
# 24                                           C0037313  UMLS:C0037313
# 25                                           C0162638  UMLS:C0162638
# 26                                           C0870868  UMLS:C0870868
# 27                                           C0920644  UMLS:C0920644
# 28                                           C0004391  UMLS:C0004391
# 29                                           C0037083  UMLS:C0037083
# 30                                           C0086982  UMLS:C0086982
# 31                                           C1155692  UMLS:C1155692
# 32                                           C0041904  UMLS:C0041904
# 33                                           C1514248  UMLS:C1514248
# 34                                       PATHOGENESIS  GO:GO:0009405
# 35                                  METABOLIC PROCESS  GO:GO:0008152
# 36                                    GENE EXPRESSION  GO:GO:0010467
# 37                  REGULATION OF CYTOKINE PRODUCTION  GO:GO:0001817
# 38                             ANGIOTENSIN MATURATION  GO:GO:0002003
# 39                             ANGIOTENSIN MATURATION  GO:GO:0002003
# 40             ANGIOTENSIN MEDIATED DRINKING BEHAVIOR  GO:GO:0003051
# 41     BLOOD PRESSURE REGULATION BY RENIN-ANGIOTENSIN  GO:GO:0003081
# 42     BLOOD PRESSURE REGULATION BY RENIN-ANGIOTENSIN  GO:GO:0003081
# 43                               TRYPTOPHAN TRANSPORT  GO:GO:0015827
# 44                     REGULATION OF VASOCONSTRICTION  GO:GO:0019229
# 45   REGULATION OF TRANSMEMBRANE TRANSPORTER ACTIVITY  GO:GO:0022898
# 46                                 RECEPTOR ANABOLISM  GO:GO:0032800
# 47        REGULATION OF CELL POPULATION PROLIFERATION  GO:GO:0042127
# 48                      ENTRY OF VIRUS INTO HOST CELL  GO:GO:0046718
# 49                      ENTRY OF VIRUS INTO HOST CELL  GO:GO:0046718
# 50   RECEPTOR-MEDIATED VIRION ATTACHMENT TO HOST CELL  GO:GO:0046813
# 51                REGULATION OF INFLAMMATORY RESPONSE  GO:GO:0050727
# 52  POSITIVE REGULATION OF AMINO ACID TRANSMEMBRAN...  GO:GO:0051957
# 53  POSITIVE REGULATION OF CARDIAC MUSCLE CONTRACTION  GO:GO:0060452
# 54                REGULATION OF BLOOD VESSEL DIAMETER  GO:GO:0097746
# 55       POSITIVE REGULATION OF GAP JUNCTION ASSEMBLY  GO:GO:1903598
# 56                   REGULATION OF CARDIAC CONDUCTION  GO:GO:1903779
# 57  POSITIVE REGULATION OF L-PROLINE IMPORT ACROSS...  GO:GO:1905737
# 58  POSITIVE REGULATION OF REACTIVE OXYGEN SPECIES...  GO:GO:2000379

# %% [markdown]
# ### 2.2 COVID -> Genes <- Hypotension
# Use explain query to determine genes related to both COVID and Hypotension

# %%
# Out:
# {'Gene': [],
#  'SequenceVariant': [],
#  'ChemicalSubstance': [],
#  'Disease': [{'MONDO': 'MONDO:0010034',
#    'name': 'anosmia for butyl mercaptan',
#    'OMIM': '270350',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0010034'},
#    'display': 'MONDO(MONDO:0010034) OMIM(270350) name(anosmia for butyl mercaptan)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0009686',
#    'UMLS': 'C1850807',
#    'name': 'musk, inability to smell',
#    'MESH': 'C564980',
#    'OMIM': '254150',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0009686'},
#    'display': 'MONDO(MONDO:0009686) OMIM(254150) UMLS(C1850807) MESH(C564980) name(musk, inability to smell)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0008432',
#    'name': 'ketone compounds, ability to smell',
#    'OMIM': '182270',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0008432'},
#    'display': 'MONDO(MONDO:0008432) OMIM(182270) name(ketone compounds, ability to smell)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0009244',
#    'name': 'Freesia Flowers, inability to smell',
#    'OMIM': '229250',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0009244'},
#    'display': 'MONDO(MONDO:0009244) OMIM(229250) name(Freesia Flowers, inability to smell)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0009474',
#    'name': 'isovaleric acid, inability to smell',
#    'OMIM': '243450',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0009474'},
#    'display': 'MONDO(MONDO:0009474) OMIM(243450) name(isovaleric acid, inability to smell)',
#    'type': 'Disease'}],
#  'PhenotypicFeature': [{'UMLS': 'C0003126',
#    'HP': 'HP:0000458',
#    'MESH': 'D000857',
#    'name': 'Anosmia',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0003126'},
#    'display': 'UMLS(C0003126) HP(HP:0000458) MESH(D000857) name(Anosmia)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C4021655',
#    'HP': 'HP:0004408',
#    'name': 'Abnormality of the sense of smell',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C4021655'},
#    'display': 'UMLS(C4021655) HP(HP:0004408) name(Abnormality of the sense of smell)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C2364082',
#    'HP': 'HP:0004409',
#    'name': 'Hyposmia',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C2364082'},
#    'display': 'UMLS(C2364082) HP(HP:0004409) name(Hyposmia)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C0278045',
#    'HP': 'HP:0012088',
#    'name': 'Abnormal urinary odor',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0278045'},
#    'display': 'UMLS(C0278045) HP(HP:0012088) name(Abnormal urinary odor)',
#    'type': 'PhenotypicFeature'}],
#  'MolecularActivity': [],
#  'BiologicalProcess': [{'GO': 'GO:0007608',
#    'name': 'sensory perception of smell',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0007608'},
#    'display': 'GO(GO:0007608) name(sensory perception of smell)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0050911',
#    'name': 'detection of chemical stimulus involved in sensory perception of smell',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0050911'},
#    'display': 'GO(GO:0050911) name(detection of chemical stimulus involved in sensory perception of smell)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0042048',
#    'name': 'olfactory behavior',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0042048'},
#    'display': 'GO(GO:0042048) name(olfactory behavior)',
#    'type': 'BiologicalProcess'},
#   {'name': 'Smell Perception',
#    'primary': {'identifier': 'name',
#     'cls': 'BiologicalProcess',
#     'value': 'Smell Perception'},
#    'display': 'name(Smell Perception)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0007608',
#    'name': 'sensory perception of smell',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0007608'},
#    'display': 'GO(GO:0007608) name(sensory perception of smell)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0050911',
#    'name': 'detection of chemical stimulus involved in sensory perception of smell',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0050911'},
#    'display': 'GO(GO:0050911) name(detection of chemical stimulus involved in sensory perception of smell)',
#    'type': 'BiologicalProcess'}],
#  'CellularComponent': [],
#  'Pathway': [],
#  'AnatomicalEntity': [{'UBERON': 'UBERON:0001579',
#    'UMLS': 'C0028938',
#    'MESH': 'D009832',
#    'name': 'olfactory nerve',
#    'primary': {'identifier': 'UBERON',
#     'cls': 'AnatomicalEntity',
#     'value': 'UBERON:0001579'},
#    'display': 'UBERON(UBERON:0001579) UMLS(C0028938) MESH(D009832) name(olfactory nerve)',
#    'type': 'AnatomicalEntity'}],
#  'Cell': []}

# %%
df = predict_many([covid], [vasodilation, hypotension, vasc_perm], intermediate_node_list = ['Gene'])
df
# Out:
# The second query doesn't return any result. So BTE does not find any connection between your input and output

# %% [markdown]
# ### 2.3.1 COVID -> Genes -> Genes <- Hypotension/Vasodilation

# %%
degree_2_genes = list(dict.fromkeys(list(df["node1_name"])))
# len(degree_2_genes)
# degree_2_genes_whole = list(df0["output_name"])

# remove_i = []
# for i in range(0,len(degree_2_genes)):
#     if(degree_2_genes_whole.count(degree_2_genes[i]) < 2):
#         remove_i.append(i)
#         print(degree_2_genes_whole.count(degree_2_genes[i]))

# print(len(remove_i))
# print(degree_2_genes_whole)

# %%
degree_2_inputs = []
for gene in degree_2_genes: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        degree_2_inputs.append(gene_input)
    except: 
        print(gene + ' Failed')

# %%
degree_2_inputs
# Out:
# [{'NCBIGene': '4151',
#   'name': 'myoglobin',
#   'SYMBOL': 'MB',
#   'UMLS': 'C1417048',
#   'HGNC': '6915',
#   'UNIPROTKB': 'P02144',
#   'ENSEMBL': 'ENSG00000198125',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4151'},
#   'display': 'NCBIGene(4151) ENSEMBL(ENSG00000198125) HGNC(6915) UMLS(C1417048) UNIPROTKB(P02144) SYMBOL(MB)',
#   'type': 'Gene'},
#  {'NCBIGene': '1401',
#   'name': 'C-reactive protein',
#   'SYMBOL': 'CRP',
#   'UMLS': 'C1413716',
#   'HGNC': '2367',
#   'UNIPROTKB': 'P02741',
#   'ENSEMBL': 'ENSG00000132693',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1401'},
#   'display': 'NCBIGene(1401) ENSEMBL(ENSG00000132693) HGNC(2367) UMLS(C1413716) UNIPROTKB(P02741) SYMBOL(CRP)',
#   'type': 'Gene'},
#  {'NCBIGene': '1636',
#   'name': 'angiotensin I converting enzyme',
#   'SYMBOL': 'ACE',
#   'UMLS': 'C1413931',
#   'HGNC': '2707',
#   'UNIPROTKB': 'P12821',
#   'ENSEMBL': 'ENSG00000159640',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1636'},
#   'display': 'NCBIGene(1636) ENSEMBL(ENSG00000159640) HGNC(2707) UMLS(C1413931) UNIPROTKB(P12821) SYMBOL(ACE)',
#   'type': 'Gene'},
#  {'NCBIGene': '1803',
#   'name': 'dipeptidyl peptidase 4',
#   'SYMBOL': 'DPP4',
#   'UMLS': 'C1414141',
#   'HGNC': '3009',
#   'UNIPROTKB': 'P27487',
#   'ENSEMBL': 'ENSG00000197635',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1803'},
#   'display': 'NCBIGene(1803) ENSEMBL(ENSG00000197635) HGNC(3009) UMLS(C1414141) UNIPROTKB(P27487) SYMBOL(DPP4)',
#   'type': 'Gene'},
#  {'NCBIGene': '7054',
#   'name': 'tyrosine hydroxylase',
#   'SYMBOL': 'TH',
#   'UMLS': 'C1420718',
#   'HGNC': '11782',
#   'UNIPROTKB': 'P07101',
#   'ENSEMBL': 'ENSG00000180176',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7054'},
#   'display': 'NCBIGene(7054) ENSEMBL(ENSG00000180176) HGNC(11782) UMLS(C1420718) UNIPROTKB(P07101) SYMBOL(TH)',
#   'type': 'Gene'},
#  {'NCBIGene': '5972',
#   'name': 'renin',
#   'SYMBOL': 'REN',
#   'UMLS': 'C1419338',
#   'HGNC': '9958',
#   'UNIPROTKB': 'P00797',
#   'ENSEMBL': 'ENSG00000143839',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5972'},
#   'display': 'NCBIGene(5972) ENSEMBL(ENSG00000143839) HGNC(9958) UMLS(C1419338) UNIPROTKB(P00797) SYMBOL(REN)',
#   'type': 'Gene'},
#  {'NCBIGene': '185',
#   'name': 'angiotensin II receptor type 1',
#   'SYMBOL': 'AGTR1',
#   'UMLS': 'C1439284',
#   'HGNC': '336',
#   'UNIPROTKB': 'P30556',
#   'ENSEMBL': 'ENSG00000144891',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '185'},
#   'display': 'NCBIGene(185) ENSEMBL(ENSG00000144891) HGNC(336) UMLS(C1439284) UNIPROTKB(P30556) SYMBOL(AGTR1)',
#   'type': 'Gene'},
#  {'NCBIGene': '213',
#   'name': 'albumin',
#   'SYMBOL': 'ALB',
#   'UMLS': 'C1412332',
#   'HGNC': '399',
#   'UNIPROTKB': 'P02768',
#   'ENSEMBL': 'ENSG00000163631',
#   'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '213'},
#   'display': 'NCBIGene(213) ENSEMBL(ENSG00000163631) HGNC(399) UMLS(C1412332) UNIPROTKB(P02768) SYMBOL(ALB)',
#   'type': 'Gene'}]

# %%
degree_2_symptoms_to_genes = predict_many(degree_2_inputs, [vasodilation, hypotension], ['Gene'])
degree_2_symptoms_to_genes
# Out:
#    input input_type                      pred1  \
# 0     MB       Gene                 related_to
# 1     MB       Gene                 related_to
# 2     MB       Gene                 related_to
# 3     MB       Gene                 related_to
# 4     MB       Gene                 related_to
# ..   ...        ...                        ...
# 11   ALB       Gene  physically_interacts_with
# 12   ALB       Gene    negatively_regulated_by
# 13   ALB       Gene       positively_regulates
# 14   ALB       Gene  physically_interacts_with
# 16   ALB       Gene       negatively_regulates
#
#                        pred1_source        pred1_api pred1_pubmed node1_type  \
# 0   Translator Text Mining Provider    CORD Gene API         None       Gene
# 1   Translator Text Mining Provider    CORD Gene API         None       Gene
# 2   Translator Text Mining Provider    CORD Gene API         None       Gene
# 3   Translator Text Mining Provider    CORD Gene API         None       Gene
# 4   Translator Text Mining Provider    CORD Gene API         None       Gene
# ..                              ...              ...          ...        ...
# 11                           SEMMED  SEMMED Gene API      9537435       Gene
# 12                           SEMMED  SEMMED Gene API     10542249       Gene
# 13                           SEMMED  SEMMED Gene API     10542249       Gene
# 14                           SEMMED  SEMMED Gene API     28903918       Gene
# 16                           SEMMED  SEMMED Gene API      2181637       Gene
#
#    node1_name        node1_id       pred2                     pred2_source  \
# 0        7841       HGNC:7841  related_to  Translator Text Mining Provider
# 1     CFAP410    NCBIGene:755  related_to  Translator Text Mining Provider
# 2         CA2    NCBIGene:760  related_to  Translator Text Mining Provider
# 3      CASP14  NCBIGene:23581  related_to  Translator Text Mining Provider
# 4      ISYNA1  NCBIGene:51477  related_to  Translator Text Mining Provider
# ..        ...             ...         ...                              ...
# 11       TP53   NCBIGene:7157  related_to                             None
# 12       TP53   NCBIGene:7157  related_to                             None
# 13       TP53   NCBIGene:7157  related_to                             None
# 14        REN   NCBIGene:5972  related_to                             None
# 16        ACE   NCBIGene:1636  related_to                             None
#
#                       pred2_api pred2_pubmed output_type  \
# 0   CORD Biological Process API         None        Gene
# 1   CORD Biological Process API         None        Gene
# 2   CORD Biological Process API         None        Gene
# 3   CORD Biological Process API         None        Gene
# 4   CORD Biological Process API         None        Gene
# ..                          ...          ...         ...
# 11                  BioLink API         None        Gene
# 12                  BioLink API         None        Gene
# 13                  BioLink API         None        Gene
# 14                  BioLink API         None        Gene
# 16                  BioLink API         None        Gene
#
#                                  output_name      output_id
# 0   POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 1   POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 2   POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 3   POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# 4   POSITIVE REGULATION OF BLOOD VESSEL SIZE  GO:GO:0042311
# ..                                       ...            ...
# 11                      ARTERIAL HYPOTENSION  UMLS:C0020649
# 12                      ARTERIAL HYPOTENSION  UMLS:C0020649
# 13                      ARTERIAL HYPOTENSION  UMLS:C0020649
# 14                      ARTERIAL HYPOTENSION  UMLS:C0020649
# 16                      ARTERIAL HYPOTENSION  UMLS:C0020649
#
# [734 rows x 16 columns]

# %%
d2_gene_list = list(degree_2_symptoms_to_genes["node1_name"])

# %%
d = {x:d2_gene_list.count(x) for x in d2_gene_list}
d2_gene_df = pandas.DataFrame.from_dict({k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse = True)}, orient='index').iloc[0:50]
d2_gene_df.columns = ["count"]
d2_gene_df
# Out:
#          count
# REN         64
# ACE         46
# ANG         23
# INS         22
# AGTR1       22
# ALB         16
# TH          15
# AKT1        13
# CA2         11
# NOS3        10
# DPP4        10
# MICE         9
# TP53         9
# AGT          9
# CASP14       8
# FGFR1        8
# PPIB         8
# MB           7
# RLN2         7
# SLC25A5      7
# TG           7
# 7841         6
# NMS          6
# PAH          6
# ALDH7A1      6
# GC           6
# LAT2         6
# NR3C2        6
# PIK3CA       6
# CSH1         6
# EDN1         6
# CRP          6
# GCG          6
# CST12P       5
# LMOD1        5
# ROS1         5
# NOS2         5
# MTOR         5
# OLFM1        5
# DHX40        5
# PADI4        5
# SCN10A       4
# SCG2         4
# CS           4
# MITF         4
# MSC          4
# NPY          4
# EPB42        4
# AMH          4
# PLG          4

# %%
d2_genes = list(d2_gene_df[d2_gene_df["count"] >= 5].index)
d2_genes
# Out:
# ['REN',
#  'ACE',
#  'ANG',
#  'INS',
#  'AGTR1',
#  'ALB',
#  'TH',
#  'AKT1',
#  'CA2',
#  'NOS3',
#  'DPP4',
#  'MICE',
#  'TP53',
#  'AGT',
#  'CASP14',
#  'FGFR1',
#  'PPIB',
#  'MB',
#  'RLN2',
#  'SLC25A5',
#  'TG',
#  '7841',
#  'NMS',
#  'PAH',
#  'ALDH7A1',
#  'GC',
#  'LAT2',
#  'NR3C2',
#  'PIK3CA',
#  'CSH1',
#  'EDN1',
#  'CRP',
#  'GCG',
#  'CST12P',
#  'LMOD1',
#  'ROS1',
#  'NOS2',
#  'MTOR',
#  'OLFM1',
#  'DHX40',
#  'PADI4']

# %% [markdown]
# ### 2.4 Create Gene Nodes

# %%
## create Gene list
genes_related_to_syptoms = list(df["node1_name"]) + d2_genes
genes_related_to_syptoms
# Out:
# ['MB',
#  'CRP',
#  'CRP',
#  'ACE',
#  'DPP4',
#  'TH',
#  'REN',
#  'AGTR1',
#  'ALB',
#  'REN',
#  'ACE',
#  'REN',
#  'ACE',
#  'ANG',
#  'INS',
#  'AGTR1',
#  'ALB',
#  'TH',
#  'AKT1',
#  'CA2',
#  'NOS3',
#  'DPP4',
#  'MICE',
#  'TP53',
#  'AGT',
#  'CASP14',
#  'FGFR1',
#  'PPIB',
#  'MB',
#  'RLN2',
#  'SLC25A5',
#  'TG',
#  '7841',
#  'NMS',
#  'PAH',
#  'ALDH7A1',
#  'GC',
#  'LAT2',
#  'NR3C2',
#  'PIK3CA',
#  'CSH1',
#  'EDN1',
#  'CRP',
#  'GCG',
#  'CST12P',
#  'LMOD1',
#  'ROS1',
#  'NOS2',
#  'MTOR',
#  'OLFM1',
#  'DHX40',
#  'PADI4']

# %%
# get gene inputs through hint module
gene_inputs = []
for gene in genes_related_to_syptoms: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        gene_inputs.append(gene_input)
    except: 
        print(gene + ' Failed')

# %% [markdown]
# ## 3 Analyzing and Exploring Gene Results
#
# Look at the determined genes (from explain queries above) to analyze what pathways, biological processes, chemical substances, and anatomical entities the genes are related to.

# %% [markdown]
# ### 3.1 Genes -> Pathways
#
# Look at pathways related to the genes, and then display top pathway occurrences in results (and which genes related to each pathway).

# %%
gene_to_pathways = predict_many(gene_inputs, ['Pathway'])

# %%
# pathways
gene_to_pathway_results = {}
gene_to_pathway_genes = list(gene_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'pathway_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_pathways.iterrows():
    gene_to_pathway_results[row['output_name']]['pathway_count'] = gene_to_pathway_results[row['output_name']]['pathway_count'] + 1
    gene_to_pathway_results[row['output_name']]['genes_related'].append(row['input'])
    

gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['pathway_count'], reverse = True))

# gene_to_pathway_results
pandas.DataFrame.from_dict(gene_to_pathway_results, orient='index').iloc[0:50]
# Out:
#                                                  pathway_count  \
# METABOLISM OF PROTEINS                                      16
# METABOLISM                                                  14
# SIGNAL TRANSDUCTION                                         14
# IMMUNE SYSTEM                                               12
# PEPTIDE HORMONE METABOLISM                                  11
# ACE INHIBITOR PATHWAY                                       11
# DISEASE                                                     10
# SIGNALING BY GPCR                                            9
# GPCR DOWNSTREAM SIGNALLING                                   9
# FOCAL ADHESION-PI3K-AKT-MTOR-SIGNALING PATHWAY               8
# PI3K-AKT SIGNALING PATHWAY                                   8
# INNATE IMMUNE SYSTEM                                         7
# FOLATE METABOLISM                                            7
# METABOLISM OF ANGIOTENSINOGEN TO ANGIOTENSINS                7
# G ALPHA (Q) SIGNALLING EVENTS                                7
# GPCR LIGAND BINDING                                          7
# HEMOSTASIS                                                   7
# TRANSPORT OF SMALL MOLECULES                                 6
# SELENIUM MICRONUTRIENT NETWORK                               6
# VITAMIN B12 METABOLISM                                       6
# CLASS A/1 (RHODOPSIN-LIKE RECEPTORS)                         6
# PEPTIDE LIGAND-BINDING RECEPTORS                             6
# VESICLE-MEDIATED TRANSPORT                                   6
# POST-TRANSLATIONAL PROTEIN MODIFICATION                      6
# PIP3 ACTIVATES AKT SIGNALING                                 6
# INTRACELLULAR SIGNALING BY SECOND MESSENGERS                 6
# SIGNALING BY RECEPTOR TYROSINE KINASES                       6
# CYTOKINE SIGNALING IN IMMUNE SYSTEM                          6
# HUMAN COMPLEMENT SYSTEM                                      5
# IL-6 SIGNALING PATHWAY                                       5
# METABOLISM OF LIPIDS                                         5
# DEVELOPMENTAL BIOLOGY                                        5
# GENERIC TRANSCRIPTION PATHWAY                                5
# RNA POLYMERASE II TRANSCRIPTION                              5
# GENE EXPRESSION (TRANSCRIPTION)                              5
# MICRORNAS IN CARDIOMYOCYTE HYPERTROPHY                       5
# PROLACTIN SIGNALING PATHWAY                                  5
# BREAST CANCER PATHWAY                                        5
# INFECTIOUS DISEASE                                           5
# EFFECTS OF NITRIC OXIDE                                      4
# METABOLISM OF AMINO ACIDS AND DERIVATIVES                    4
# MEMBRANE TRAFFICKING                                         4
# PLATELET ACTIVATION, SIGNALING AND AGGREGATION               4
# NEGATIVE REGULATION OF THE PI3K/AKT NETWORK                  4
# PI5P, PP2A AND IER3 REGULATE PI3K/AKT SIGNALING              4
# AGE-RAGE PATHWAY                                             4
# SIGNALING BY VEGF                                            4
# PI3K/AKT SIGNALING IN CANCER                                 4
# VEGFA-VEGFR2 PATHWAY                                         4
# SIGNALING BY INTERLEUKINS                                    4
#
#                                                                                      genes_related
# METABOLISM OF PROTEINS                           [ACE, DPP4, REN, ALB, REN, ACE, REN, ACE, INS,...
# METABOLISM                                       [TH, ALB, INS, ALB, TH, AKT1, CA2, NOS3, AGT, ...
# SIGNAL TRANSDUCTION                              [AGTR1, INS, AGTR1, AKT1, NOS3, TP53, AGT, FGF...
# IMMUNE SYSTEM                                    [CRP, CRP, AKT1, NOS3, TP53, FGFR1, LAT2, PIK3...
# PEPTIDE HORMONE METABOLISM                       [ACE, DPP4, REN, REN, ACE, REN, ACE, INS, DPP4...
# ACE INHIBITOR PATHWAY                            [ACE, REN, AGTR1, REN, ACE, REN, ACE, AGTR1, N...
# DISEASE                                          [AKT1, FGFR1, RLN2, SLC25A5, MOGS, PAH, PIK3CA...
# SIGNALING BY GPCR                                [AGTR1, AGTR1, AKT1, AGT, RLN2, NMS, PIK3CA, E...
# GPCR DOWNSTREAM SIGNALLING                       [AGTR1, AGTR1, AKT1, AGT, RLN2, NMS, PIK3CA, E...
# FOCAL ADHESION-PI3K-AKT-MTOR-SIGNALING PATHWAY   [INS, AKT1, NOS3, FGFR1, PIK3CA, CSH1, NOS2, M...
# PI3K-AKT SIGNALING PATHWAY                       [INS, AKT1, NOS3, TP53, FGFR1, PIK3CA, CSH1, M...
# INNATE IMMUNE SYSTEM                                     [CRP, CRP, NOS3, LAT2, PIK3CA, CRP, NOS2]
# FOLATE METABOLISM                                             [CRP, CRP, ALB, INS, ALB, TP53, CRP]
# METABOLISM OF ANGIOTENSINOGEN TO ANGIOTENSINS                  [ACE, REN, REN, ACE, REN, ACE, AGT]
# G ALPHA (Q) SIGNALLING EVENTS                          [AGTR1, AGTR1, AGT, NMS, PIK3CA, EDN1, GCG]
# GPCR LIGAND BINDING                                      [AGTR1, AGTR1, AGT, RLN2, NMS, EDN1, GCG]
# HEMOSTASIS                                              [ALB, ALB, AKT1, NOS3, TP53, PIK3CA, NOS2]
# TRANSPORT OF SMALL MOLECULES                                      [MB, ALB, ALB, CA2, MB, SLC25A5]
# SELENIUM MICRONUTRIENT NETWORK                                      [CRP, CRP, ALB, INS, ALB, CRP]
# VITAMIN B12 METABOLISM                                              [CRP, CRP, ALB, INS, ALB, CRP]
# CLASS A/1 (RHODOPSIN-LIKE RECEPTORS)                          [AGTR1, AGTR1, AGT, RLN2, NMS, EDN1]
# PEPTIDE LIGAND-BINDING RECEPTORS                              [AGTR1, AGTR1, AGT, RLN2, NMS, EDN1]
# VESICLE-MEDIATED TRANSPORT                                     [AGTR1, ALB, INS, AGTR1, ALB, AKT1]
# POST-TRANSLATIONAL PROTEIN MODIFICATION                         [ALB, INS, ALB, TP53, MOGS, NR3C2]
# PIP3 ACTIVATES AKT SIGNALING                                [INS, AKT1, TP53, FGFR1, PIK3CA, MTOR]
# INTRACELLULAR SIGNALING BY SECOND MESSENGERS                [INS, AKT1, TP53, FGFR1, PIK3CA, MTOR]
# SIGNALING BY RECEPTOR TYROSINE KINASES                      [INS, AKT1, NOS3, FGFR1, PIK3CA, MTOR]
# CYTOKINE SIGNALING IN IMMUNE SYSTEM                        [AKT1, TP53, FGFR1, PIK3CA, CSH1, NOS2]
# HUMAN COMPLEMENT SYSTEM                                                  [CRP, CRP, ALB, ALB, CRP]
# IL-6 SIGNALING PATHWAY                                                  [CRP, CRP, AKT1, AGT, CRP]
# METABOLISM OF LIPIDS                                                   [ALB, ALB, AGT, GC, PIK3CA]
# DEVELOPMENTAL BIOLOGY                                           [INS, AKT1, CASP14, FGFR1, PIK3CA]
# GENERIC TRANSCRIPTION PATHWAY                                       [INS, AKT1, TP53, NR3C2, MTOR]
# RNA POLYMERASE II TRANSCRIPTION                                     [INS, AKT1, TP53, NR3C2, MTOR]
# GENE EXPRESSION (TRANSCRIPTION)                                     [INS, AKT1, TP53, NR3C2, MTOR]
# MICRORNAS IN CARDIOMYOCYTE HYPERTROPHY                             [AKT1, AGT, PIK3CA, EDN1, MTOR]
# PROLACTIN SIGNALING PATHWAY                                       [AKT1, PPIB, PIK3CA, NOS2, MTOR]
# BREAST CANCER PATHWAY                                            [AKT1, TP53, FGFR1, PIK3CA, MTOR]
# INFECTIOUS DISEASE                                                [RLN2, SLC25A5, MOGS, GCG, NOS2]
# EFFECTS OF NITRIC OXIDE                                                       [MB, NOS3, MB, NOS2]
# METABOLISM OF AMINO ACIDS AND DERIVATIVES                                   [TH, TH, PAH, ALDH7A1]
# MEMBRANE TRAFFICKING                                                     [AGTR1, INS, AGTR1, AKT1]
# PLATELET ACTIVATION, SIGNALING AND AGGREGATION                            [ALB, ALB, AKT1, PIK3CA]
# NEGATIVE REGULATION OF THE PI3K/AKT NETWORK                             [INS, AKT1, FGFR1, PIK3CA]
# PI5P, PP2A AND IER3 REGULATE PI3K/AKT SIGNALING                         [INS, AKT1, FGFR1, PIK3CA]
# AGE-RAGE PATHWAY                                                           [INS, AKT1, NOS3, NOS2]
# SIGNALING BY VEGF                                                       [AKT1, NOS3, PIK3CA, MTOR]
# PI3K/AKT SIGNALING IN CANCER                                           [AKT1, FGFR1, PIK3CA, MTOR]
# VEGFA-VEGFR2 PATHWAY                                                    [AKT1, NOS3, PIK3CA, MTOR]
# SIGNALING BY INTERLEUKINS                                               [AKT1, TP53, PIK3CA, NOS2]

# %% [markdown]
# Result table interpretation: In agreement with argument made in article, top ranking results of "ACE Inhibitor Pathway" and "Metabolism of Angiotensinogen to Angiotensins" are both components of the RAS pathway.

# %% [markdown]
# ### 3.2 Genes -> Biological Processes
#
# Look at bbiological processes related to the genes, and then display top biological process occurrences in results (and which genes related to each biological processes).

# %%
# bioprocesss
gene_to_bioprocesses = predict_many(gene_inputs, ['BiologicalProcess'])
gene_to_bioprocess_results = {}
gene_to_bioprocess_genes = list(gene_to_bioprocesses["output_name"]) # create list of genes
gene_to_bioprocess_genes = list(dict.fromkeys(gene_to_bioprocess_genes))  # remove duplicates

for gene in gene_to_bioprocess_genes: 
    gene_to_bioprocess_results[gene] = {
        'bioprocess_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_bioprocesses.iterrows():
    gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] = gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] + 1
    gene_to_bioprocess_results[row['output_name']]['genes_related'].append(row['input'])

# %%
## extra step needed to analyze biological processes because many are returned as UMLS id instead of name

gene_to_bioprocess_results = dict(sorted(gene_to_bioprocess_results.items(), key = lambda x: x[1]['bioprocess_count'], reverse = True))
counter = 0 
gene_to_bioprocess_results_copy = gene_to_bioprocess_results
for key in gene_to_bioprocess_results_copy.keys(): 
    if counter < 100: 
        if(('C0' in key) or ('C1' in key)): 
            try: 
                name = ht.query(key)['BiologicalProcess'][0]['name']
                gene_to_bioprocess_results[name] = gene_to_bioprocess_results[key]
                del gene_to_bioprocess_results[key]
            except: 
                pass
    counter = counter + 1
# Out:
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-27b68a67aec1> in <module>
#       4 counter = 0
#       5 gene_to_bioprocess_results_copy = gene_to_bioprocess_results
# ----> 6 for key in gene_to_bioprocess_results_copy.keys():
#       7     if counter < 100:
#       8         if(('C0' in key) or ('C1' in key)):
#
# RuntimeError: dictionary keys changed during iteration

# %%
# gene_to_bioprocess_results
pandas.DataFrame.from_dict(gene_to_bioprocess_results, orient='index').iloc[0:50]
# Out:
#                                           bioprocess_count  \
# GENE EXPRESSION                                         46
# GROWTH                                                  45
# POSITIVE REGULATION OF BLOOD VESSEL SIZE                44
# METABOLIC PROCESS                                       42
# BREAKDOWN                                               37
# SECRETION                                               36
# ANGIOGENESIS                                            36
# PATHOGENESIS                                            34
# INFLAMMATION                                            33
# GO:0016265                                              32
# CATAGEN                                                 32
# LACTATION                                               32
# CELL ADHESION                                           31
# CONJUGATION                                             31
# PIGMENTATION                                            31
# NEGATIVE REGULATION OF BLOOD VESSEL SIZE                30
# PROTEIN ANABOLISM                                       29
# DIGESTION                                               29
# CELL POPULATION PROLIFERATION                           28
# INNATE IMMUNE RESPONSE                                  28
# IMMUNE RESPONSE                                         27
# EXCRETION                                               26
# LIPID METABOLIC PROCESS                                 26
# IMPORT INTO CELL                                        26
# EXOGEN                                                  25
# CELL ACTIVATION                                         25
# MEMORY                                                  24
# ALVEOLARIZATION                                         24
# NEURAL TUBE FORMATION                                   24
# TRANSDUCTION                                            24
# AGEING                                                  24
# ACCIDENTAL CELL DEATH                                   23
# PEPTIDOLYSIS                                            23
# LEARNING                                                23
# AUTOPHAGY                                               22
# PHASE II METABOLISM                                     22
# CELL MIGRATION                                          22
# CHEMOATTRACTION                                         21
# WOUND HEALING                                           20
# GLOMERULAR FILTRATION                                   20
# CELL DIFFERENTIATION                                    20
# C0597297                                                20
# C0232164                                                19
# ARREST OF CELL CYCLE PROGRESSION                        19
# CELL EXPANSION                                          19
# C0220781                                                19
# C0008018                                                19
# C1515670                                                19
# C1155873                                                19
# CELLULAR GLUCOSE METABOLIC PROCESS                      19
#
#                                                                               genes_related
# GENE EXPRESSION                           [MB, CRP, CRP, ACE, DPP4, TH, REN, AGTR1, REN,...
# GROWTH                                    [MB, CRP, CRP, DPP4, TH, REN, AGTR1, ALB, REN,...
# POSITIVE REGULATION OF BLOOD VESSEL SIZE  [MB, CRP, CRP, ACE, DPP4, TH, REN, REN, ACE, R...
# METABOLIC PROCESS                         [CRP, CRP, DPP4, TH, REN, AGTR1, ALB, REN, REN...
# BREAKDOWN                                 [MB, ACE, DPP4, TH, ALB, ACE, ACE, ANG, INS, A...
# SECRETION                                 [MB, DPP4, TH, REN, ALB, REN, REN, ANG, INS, A...
# ANGIOGENESIS                              [MB, DPP4, TH, REN, REN, REN, ANG, ANG, ANG, A...
# PATHOGENESIS                              [CRP, CRP, ACE, TH, REN, ALB, REN, ACE, REN, A...
# INFLAMMATION                              [CRP, CRP, CRP, CRP, DPP4, TH, REN, AGTR1, REN...
# GO:0016265                                [MB, CRP, CRP, TH, ALB, INS, ALB, TH, AKT1, CA...
# CATAGEN                                   [MB, TH, ALB, INS, ALB, TH, AKT1, CA2, NOS3, T...
# LACTATION                                 [MB, CRP, CRP, TH, ALB, INS, ALB, TH, AKT1, CA...
# CELL ADHESION                             [MB, CRP, CRP, DPP4, DPP4, TH, REN, ALB, REN, ...
# CONJUGATION                               [MB, CRP, CRP, TH, ALB, ALB, TH, AKT1, TP53, C...
# PIGMENTATION                              [MB, TH, TH, REN, ALB, REN, REN, INS, ALB, TH,...
# NEGATIVE REGULATION OF BLOOD VESSEL SIZE  [CRP, CRP, ACE, DPP4, REN, REN, ACE, REN, ACE,...
# PROTEIN ANABOLISM                         [MB, CRP, CRP, TH, REN, ALB, REN, REN, INS, AL...
# DIGESTION                                 [MB, ACE, TH, REN, ALB, REN, ACE, REN, ACE, IN...
# CELL POPULATION PROLIFERATION             [MB, DPP4, TH, ANG, INS, TH, AKT1, AKT1, CA2, ...
# INNATE IMMUNE RESPONSE                    [CRP, CRP, CRP, CRP, DPP4, TH, ANG, INS, TH, A...
# IMMUNE RESPONSE                           [CRP, CRP, DPP4, TH, ALB, ANG, INS, ALB, TH, A...
# EXCRETION                                 [CRP, CRP, DPP4, TH, REN, ALB, REN, REN, INS, ...
# LIPID METABOLIC PROCESS                   [CRP, CRP, TH, REN, ALB, REN, REN, INS, ALB, T...
# IMPORT INTO CELL                          [TH, REN, ALB, REN, REN, INS, ALB, TH, AKT1, C...
# EXOGEN                                    [MB, TH, ALB, ANG, INS, ALB, TH, AKT1, CA2, TP...
# CELL ACTIVATION                           [MB, CRP, CRP, DPP4, TH, INS, TH, CA2, DPP4, T...
# MEMORY                                    [MB, ACE, TH, TH, REN, REN, ACE, REN, ACE, INS...
# ALVEOLARIZATION                           [CRP, CRP, ACE, TH, AGTR1, ALB, ACE, ACE, AGTR...
# NEURAL TUBE FORMATION                     [DPP4, TH, INS, TH, AKT1, CA2, DPP4, TP53, CAS...
# TRANSDUCTION                              [TH, ALB, INS, ALB, TH, AKT1, CA2, NOS3, TP53,...
# AGEING                                    [TH, ANG, INS, TH, AKT1, CA2, NOS3, TP53, AGT,...
# ACCIDENTAL CELL DEATH                     [MB, DPP4, TH, AGTR1, INS, AGTR1, TH, AKT1, CA...
# PEPTIDOLYSIS                              [ACE, ACE, DPP4, TH, REN, REN, REN, REN, ACE, ...
# LEARNING                                  [TH, TH, REN, REN, REN, INS, TH, TH, CASP14, F...
# AUTOPHAGY                                 [MB, TH, AGTR1, INS, AGTR1, TH, AKT1, CA2, TP5...
# PHASE II METABOLISM                       [MB, TH, ALB, INS, ALB, TH, AKT1, NOS3, AGT, C...
# CELL MIGRATION                            [MB, TH, ANG, ANG, TH, AKT1, CA2, TP53, CASP14...
# CHEMOATTRACTION                           [CRP, CRP, TH, ALB, INS, ALB, TH, CA2, CASP14,...
# WOUND HEALING                             [MB, TH, REN, REN, REN, INS, INS, TH, CASP14, ...
# GLOMERULAR FILTRATION                     [CRP, CRP, ACE, REN, ALB, REN, ACE, REN, ACE, ...
# CELL DIFFERENTIATION                      [TH, AGTR1, INS, AGTR1, TH, AKT1, AKT1, TP53, ...
# C0597297                                  [ALB, ALB, INS, INS, INS, ALB, ALB, AKT1, AKT1...
# C0232164                                  [MB, ACE, TH, AGTR1, ACE, ACE, ANG, ANG, INS, ...
# ARREST OF CELL CYCLE PROGRESSION          [MB, INS, AKT1, TP53, TP53, TP53, CASP14, FGFR...
# CELL EXPANSION                            [MB, TH, INS, TH, AKT1, TP53, CASP14, FGFR1, P...
# C0220781                                  [ACE, TH, REN, REN, REN, REN, ACE, REN, REN, A...
# C0008018                                  [DPP4, ALB, ANG, INS, INS, ALB, AKT1, AKT1, AK...
# C1515670                                  [TH, TH, REN, AGTR1, REN, REN, INS, INS, INS, ...
# C1155873                                  [TH, INS, TH, AKT1, AKT1, AKT1, CA2, TP53, TP5...
# CELLULAR GLUCOSE METABOLIC PROCESS        [TH, INS, INS, TH, AKT1, AKT1, CA2, TP53, CASP...

# %% [markdown]
# Result table interpretation: In agreement with argument made in article, top ranking results of "renin activity," "Angiogenic Process," and "ANGIOTENSIN MATURATIONs" are components of the RAS pathway / bioprocesses.

# %% [markdown]
# ### 3.3 Genes -> Chemical Substances
#
# Look at chemical substances related to the genes, and then display top chemical substance occurrences in results (and which genes related to each chemical substances).

# %%
# chemical_substances
gene_to_chemical_substance = predict_many(gene_inputs, ['ChemicalSubstance'])
gene_to_chemical_substance_results = {}
gene_to_chemical_substance_genes = list(gene_to_chemical_substance["output_name"]) # create list of genes
gene_to_chemical_substance_genes = list(dict.fromkeys(gene_to_chemical_substance_genes))  # remove duplicates

for gene in gene_to_chemical_substance_genes: 
    gene_to_chemical_substance_results[gene] = {
        'chemical_substance_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_chemical_substance.iterrows():
    gene_to_chemical_substance_results[row['output_name']]['chemical_substance_count'] = gene_to_chemical_substance_results[row['output_name']]['chemical_substance_count'] + 1
    gene_to_chemical_substance_results[row['output_name']]['genes_related'].append(row['input'])

# %%
gene_to_chemical_substance_results = dict(sorted(gene_to_chemical_substance_results.items(), key = lambda x: x[1]['chemical_substance_count'], reverse = True))
pandas.DataFrame.from_dict(gene_to_chemical_substance_results, orient='index').iloc[0:20]
# Out:
#                                                     chemical_substance_count  \
# (+)-GLUCOSE                                                              152
# PHARMACEUTICAL PREPARATIONS                                              112
# (+)-ALDOSTERONE                                                          111
# EDRF                                                                     107
# MESSENGER RNA                                                             94
# (2-BUTYL-4-CHLORO-1-{[2'-(1H-TETRAZOL-5-YL)BIPH...                        88
# OXYGEN SPECIES, REACTIVE                                                  85
# (15S)-PROSTAGLANDIN E2                                                    84
# CALCIO                                                                    81
# 10% SODIUM CHLORIDE INJECTION                                             79
# 2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE                                         77
# (S)-4-PREGNENE-3,20-DIONE                                                 77
# LIPOPOLYSACCHARIDES                                                       76
# 1-HYDROXYETHANE                                                           76
# 17BETA-HYDROXY-4-ANDROSTEN-3-ONE                                          74
# AGONISTS                                                                  71
# A-101                                                                     68
# 3-(2-AMINOETHYL)-1H-INDOL-5-OL                                            68
# (-)-NORADRENALINE                                                         68
# 3',5'-CYCLIC AMP                                                          65
#
#                                                                                         genes_related
# (+)-GLUCOSE                                         [MB, MB, MB, MB, CRP, CRP, CRP, CRP, ACE, ACE,...
# PHARMACEUTICAL PREPARATIONS                         [ACE, ACE, ACE, DPP4, DPP4, DPP4, TH, TH, TH, ...
# (+)-ALDOSTERONE                                     [CRP, CRP, ACE, ACE, ACE, ACE, ACE, ACE, ACE, ...
# EDRF                                                [MB, MB, MB, ACE, ACE, ACE, TH, TH, TH, TH, TH...
# MESSENGER RNA                                       [CRP, CRP, ACE, ACE, TH, TH, TH, TH, TH, REN, ...
# (2-BUTYL-4-CHLORO-1-{[2'-(1H-TETRAZOL-5-YL)BIPH...  [ACE, ACE, ACE, ACE, ACE, TH, REN, REN, REN, R...
# OXYGEN SPECIES, REACTIVE                            [MB, MB, ACE, ACE, TH, TH, TH, REN, REN, REN, ...
# (15S)-PROSTAGLANDIN E2                              [CRP, CRP, ACE, DPP4, TH, TH, TH, REN, REN, RE...
# CALCIO                                              [TH, TH, TH, TH, REN, REN, REN, REN, REN, REN,...
# 10% SODIUM CHLORIDE INJECTION                       [ACE, ACE, TH, TH, TH, REN, REN, REN, REN, REN...
# 2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE                   [MB, CRP, CRP, ACE, TH, TH, TH, TH, TH, TH, TH...
# (S)-4-PREGNENE-3,20-DIONE                           [CRP, CRP, TH, TH, TH, TH, REN, REN, REN, REN,...
# LIPOPOLYSACCHARIDES                                 [CRP, CRP, ACE, ACE, ACE, DPP4, DPP4, TH, TH, ...
# 1-HYDROXYETHANE                                     [ACE, ACE, ACE, TH, TH, TH, TH, REN, REN, ALB,...
# 17BETA-HYDROXY-4-ANDROSTEN-3-ONE                    [MB, CRP, CRP, CRP, CRP, TH, TH, TH, TH, TH, R...
# AGONISTS                                            [ACE, ACE, DPP4, TH, TH, TH, TH, REN, REN, REN...
# A-101                                               [MB, MB, MB, MB, TH, TH, TH, ALB, ALB, ALB, AL...
# 3-(2-AMINOETHYL)-1H-INDOL-5-OL                      [MB, CRP, CRP, ACE, ACE, TH, TH, TH, TH, TH, R...
# (-)-NORADRENALINE                                   [CRP, CRP, ACE, ACE, TH, TH, TH, TH, TH, TH, T...
# 3',5'-CYCLIC AMP                                    [CRP, CRP, CRP, CRP, TH, TH, TH, TH, TH, REN, ...

# %% [markdown]
# (15S)-PROSTAGLANDIN E2	 - prostacyclin
#
#
# In agreement with article, (+)-ALDOSTERONE (top occurring result) is a critical component in the RAS pathway, as well as ANGIOTENSIN CONVERTING ENZYME INHIBITORS.
#
# (2-BUTYL-4-CHLORO-1-{[2'-(1H-TETRAZOL-5-YL)BIPHENYL-4-YL]METHYL}-1H-IMIDAZOL-5-YL)METHANOL:
# Losartan (Cozaar) belongs to a group of drugs called angiotensin II receptor antagonists. It keeps blood vessels from narrowing, which lowers blood pressure and improves blood flow. Losartan is used to treat high blood pressure (hypertension).
#
# "EDRF interacts with the renin-angiotensin system to control juxtamedullary afferent and efferent arteriolar resistance"

# %% [markdown]
# ### 3.4 Genes -> Anatomical Entities
#
# Look at anatomical entities related to the genes, and then display top anatomical entity occurrences in results (and which genes related to each anatomical entities).

# %%
ints_to_anatomical_entity = predict_many(gene_inputs, ['AnatomicalEntity'])
list(dict.fromkeys(list(ints_to_anatomical_entity["output_name"])))
# anatomical_entity
int_to_anatomical_entity_results = {}
int_to_anatomical_entity_ints = list(ints_to_anatomical_entity["output_name"]) # create list of ints
int_to_anatomical_entity_ints = list(dict.fromkeys(int_to_anatomical_entity_ints))  # remove duplicates

for int in int_to_anatomical_entity_ints: 
    int_to_anatomical_entity_results[int] = {
        'anatomical_entity_count' : 0,
        "ints_related" : []
    }

for index, row in ints_to_anatomical_entity.iterrows():
    int_to_anatomical_entity_results[row['output_name']]['anatomical_entity_count'] = int_to_anatomical_entity_results[row['output_name']]['anatomical_entity_count'] + 1
    int_to_anatomical_entity_results[row['output_name']]['ints_related'].append(row['input'])
    

int_to_anatomical_entity_results = dict(sorted(int_to_anatomical_entity_results.items(), key = lambda x: x[1]['anatomical_entity_count'], reverse = True))

    
# int_to_anatomical_entity_results
pandas.DataFrame.from_dict(int_to_anatomical_entity_results, orient='index').iloc[0:50]
# Out:
#                                  anatomical_entity_count  \
# BLOOD                                                 73
# LUNG                                                  59
# ADIPOSE                                               56
# BRAIN                                                 56
# KIDNEY                                                55
# PORTION OF SKIN                                       54
# CARDIUM                                               49
# PORTION OF TISSUE                                     48
# FORELIMB AUTOPOD                                      46
# BLOOD SERUM                                           45
# IECUR                                                 43
# ENTIRE LIFE CYCLE                                     41
# BONE MARROW                                           39
# GLANDULA THYROIDEA                                    36
# BREAST                                                35
# SCALE                                                 33
# CEREBRAL SPINAL FLUID                                 31
# ANATOMICAL UNIT                                       31
# ARTERIAL SUBTREE                                      31
# MESENCHYMA                                            30
# ADULT ORGANISM                                        30
# CORONARY ARTERIAL TREE                                30
# CENTRAL NERVOUS SYSTEM                                29
# CEPHALIC AREA                                         29
# INVOLUNTARY MUSCLE                                    29
# ARM                                                   28
# ANTERIOR INTESTINE                                    27
# CARDIAC LEFT VENTRICLE                                27
# FOOT                                                  27
# MATERIAL ANATOMICAL ENTITY                            26
# VESSEL                                                26
# LUNGS                                                 26
# BOWEL                                                 25
# CA2                                                   25
# ANIMAL OVARY                                          25
# COLON                                                 25
# BRAIN CORTEX                                          25
# ENDOTHELIUM                                           25
# LIEN                                                  25
# MALE PROSTATE                                         24
# BLOOD VESSEL INVOLUNTARY MUSCLE                       24
# COLLUM                                                23
# URINE                                                 23
# BACK                                                  23
# EYE                                                   23
# DEVELOPING ORGANISM                                   23
# ORGANISMAL SEGMENT                                    22
# IMMUNE SYSTEM                                         22
# MELANOPHORE SPOT                                      22
# NERVE                                                 22
#
#                                                                       ints_related
# BLOOD                            [MB, CRP, CRP, ACE, DPP4, TH, TH, TH, REN, REN...
# LUNG                             [MB, MB, CRP, CRP, CRP, CRP, ACE, DPP4, TH, TH...
# ADIPOSE                          [MB, MB, CRP, CRP, CRP, CRP, DPP4, TH, REN, RE...
# BRAIN                            [MB, MB, CRP, CRP, CRP, CRP, ACE, DPP4, TH, RE...
# KIDNEY                           [MB, MB, CRP, CRP, ACE, DPP4, TH, TH, REN, AGT...
# PORTION OF SKIN                  [CRP, CRP, CRP, CRP, ACE, ACE, TH, TH, REN, AG...
# CARDIUM                          [MB, CRP, CRP, ACE, DPP4, TH, REN, AGTR1, ALB,...
# PORTION OF TISSUE                [MB, CRP, CRP, ACE, DPP4, TH, REN, AGTR1, ALB,...
# FORELIMB AUTOPOD                 [MB, CRP, CRP, DPP4, TH, REN, AGTR1, ALB, REN,...
# BLOOD SERUM                      [MB, CRP, CRP, ACE, TH, REN, ALB, REN, ACE, RE...
# IECUR                            [MB, CRP, CRP, ACE, DPP4, TH, REN, ALB, REN, A...
# ENTIRE LIFE CYCLE                [MB, CRP, CRP, DPP4, TH, REN, ALB, REN, REN, I...
# BONE MARROW                      [CRP, CRP, DPP4, TH, AGTR1, ALB, INS, AGTR1, A...
# GLANDULA THYROIDEA               [MB, CRP, CRP, ACE, TH, TH, ALB, ACE, ACE, INS...
# BREAST                           [MB, CRP, CRP, TH, REN, ALB, REN, REN, ANG, IN...
# SCALE                            [MB, CRP, CRP, TH, REN, ALB, REN, REN, INS, AL...
# CEREBRAL SPINAL FLUID            [MB, CRP, CRP, DPP4, TH, ALB, ANG, ALB, TH, AK...
# ANATOMICAL UNIT                  [CRP, CRP, ACE, TH, REN, ALB, REN, ACE, REN, A...
# ARTERIAL SUBTREE                 [CRP, CRP, ACE, DPP4, TH, REN, REN, ACE, REN, ...
# MESENCHYMA                       [MB, TH, AGTR1, ALB, INS, AGTR1, ALB, TH, AKT1...
# ADULT ORGANISM                   [CRP, CRP, TH, ALB, INS, ALB, TH, TP53, CASP14...
# CORONARY ARTERIAL TREE           [CRP, CRP, ACE, ACE, DPP4, AGTR1, ALB, ACE, AC...
# CENTRAL NERVOUS SYSTEM           [MB, CRP, CRP, TH, INS, TH, AKT1, CA2, TP53, C...
# CEPHALIC AREA                    [CRP, CRP, TH, ALB, INS, ALB, TH, AKT1, CA2, T...
# INVOLUNTARY MUSCLE               [DPP4, TH, REN, AGTR1, REN, REN, ANG, INS, AGT...
# ARM                              [CRP, CRP, ACE, TH, REN, REN, ACE, REN, ACE, A...
# ANTERIOR INTESTINE               [MB, MB, TH, ALB, ALB, INS, ALB, ALB, TH, NOS3...
# CARDIAC LEFT VENTRICLE           [CRP, CRP, ACE, DPP4, REN, REN, REN, REN, ACE,...
# FOOT                             [CRP, CRP, DPP4, TH, ALB, INS, ALB, TH, NOS3, ...
# MATERIAL ANATOMICAL ENTITY       [MB, CRP, CRP, ACE, DPP4, TH, REN, AGTR1, REN,...
# VESSEL                           [CRP, CRP, ACE, DPP4, ALB, ACE, ACE, INS, ALB,...
# LUNGS                            [ACE, TH, AGTR1, ALB, ACE, ACE, ANG, AGTR1, AL...
# BOWEL                            [MB, CRP, CRP, ACE, TH, REN, REN, ACE, REN, AC...
# CA2                              [MB, DPP4, TH, ANG, INS, TH, AKT1, CA2, NOS3, ...
# ANIMAL OVARY                     [MB, CRP, CRP, TH, ALB, INS, INS, ALB, TH, AKT...
# COLON                            [MB, TH, ALB, INS, ALB, TH, AKT1, CA2, TP53, C...
# BRAIN CORTEX                     [CRP, CRP, ACE, TH, AGTR1, ALB, ACE, ACE, ANG,...
# ENDOTHELIUM                      [ACE, DPP4, TH, REN, ALB, REN, ACE, REN, ACE, ...
# LIEN                             [TH, REN, REN, REN, REN, REN, REN, TH, AKT1, C...
# MALE PROSTATE                    [MB, TH, INS, TH, AKT1, CA2, NOS3, TP53, CASP1...
# BLOOD VESSEL INVOLUNTARY MUSCLE  [CRP, CRP, DPP4, REN, REN, REN, ANG, INS, CA2,...
# COLLUM                           [CRP, CRP, TH, ALB, ALB, TH, AKT1, NOS3, TP53,...
# URINE                            [CRP, CRP, TH, ALB, INS, ALB, TH, CA2, NOS3, C...
# BACK                             [CRP, CRP, TH, AGTR1, INS, AGTR1, TH, AKT1, CA...
# EYE                              [ACE, TH, ALB, ACE, ACE, ALB, TH, AKT1, CA2, N...
# DEVELOPING ORGANISM              [TH, ALB, INS, ALB, TH, AKT1, CA2, NOS3, NOS3,...
# ORGANISMAL SEGMENT               [MB, CRP, CRP, ACE, ALB, ACE, ACE, INS, ALB, C...
# IMMUNE SYSTEM                    [MB, CRP, CRP, DPP4, TH, INS, TH, AKT1, CA2, D...
# MELANOPHORE SPOT                 [MB, TH, ALB, INS, ALB, TH, AKT1, CASP14, FGFR...
# NERVE                            [DPP4, DPP4, TH, ALB, INS, ALB, TH, AKT1, AKT1...

# %% [markdown]
# In agreement with article, which states “...the Bradykinin-Storm is likely to affect major organs that are regulated by angiotensin derivatives. These include altered electrolyte balance from affected kidney and heart tissue, arrhythmia in dysregulated cardiac tissue, neurological disruptions in the brain, myalgia in muscles and severe alterations in oxygen uptake in the lung itself.” as well as “Finally, COVID-19 patients also frequently display skin rashes including ‘covid-toe’ that appear to be related to dysfunction of the underlying vasculature,” Lung, blood, portion of skin, brain, kidney, and cardium (heart) are all top ranking results related to genes.
#
# Of note: adipose tissue is an iteresting top ranking result, and the connection between obesity being a risk-factor for severe COVID illness and symptom related genes being prevalent in adipose tissue may want to be investigated.

# %% [markdown]
# ### 3.5 Genes -> Chemical Substances <- Vasodilation
#
# Look at determined Gene inputs (related to both COVID and vasodilation/hypotension) and determine chemical substances related to these genes that are also related to vasodilation symptom

# %%
genes_to_chem_to_vasodilation = predict_many(gene_inputs, [vasodilation,vasc_perm], ['ChemicalSubstance'])
# Out:
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The first query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output
# The second query doesn't return any result. So BTE does not find any connection between your input and output

# %%
genes_to_chem_to_vasodilation_list = list(genes_to_chem_to_vasodilation["node1_name"])

# %%
genes_to_chem_to_vasodilation_list
# Out:
# ['CHEBI:18059',
#  'CHEBI:50249',
#  'CHEBI:23888',
#  'CHEBI:37527',
#  'CHEBI:26195',
#  'CHEBI:50114',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:36357',
#  'CHEBI:35224',
#  'CHEBI:24870',
#  'CHEBI:35222',
#  'CHEBI:22315',
#  'CHEBI:26519',
#  '(.)NO',
#  '(5Z,8Z,11Z,14Z)-N-(2-HYDROXYETHYL)-5,8,11,14-EICOSATETRAENAMIDE',
#  '(N-METHYLCARBAMIMIDAMIDO)ACETATE',
#  '(5Z,8Z,11Z,14Z)-5,8,11,14-ICOSATETRAENOIC ACID',
#  '(O2)(.-)',
#  'LEAD',
#  'PHOSPHORUS MONOXIDE',
#  'CA(0)',
#  'CA(0)',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CARBON',
#  'CARBON',
#  '((AMINO(IMINO)METHYL)(METHYL)AMINO)ACETIC ACID',
#  'A-101',
#  'A-101',
#  'A-101',
#  'A-101',
#  'PEROXYNITRITE',
#  'ALAPAV',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '1-((5-(P-NITROPHENYL)FURFURYLIDENE)AMINO)HYDANTOIN',
#  'ACQUA',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  'CHEBI:32952',
#  'CHEBI:25212',
#  'CHEBI:47867',
#  'CHEBI:47867',
#  'CHEBI:24261',
#  'CHEBI:24261',
#  'CHEBI:50904',
#  'CHEBI:50904',
#  'CHEBI:27026',
#  'CHEBI:27026',
#  'CHEBI:35498',
#  'CHEBI:18059',
#  'CHEBI:50249',
#  'CHEBI:50249',
#  'CHEBI:25029',
#  'CHEBI:24505',
#  'CHEBI:24505',
#  'CHEBI:23888',
#  'CHEBI:37527',
#  'CHEBI:80234',
#  'CHEBI:80234',
#  'CHEBI:26195',
#  'CHEBI:50114',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:47775',
#  'CHEBI:47775',
#  'CHEBI:26333',
#  'CHEBI:36357',
#  'CHEBI:26523',
#  'CHEBI:33290',
#  'CHEBI:27226',
#  'CHEBI:16646',
#  'CHEBI:35222',
#  'CHEBI:47774',
#  'CHEBI:48432',
#  '(.)NO',
#  '(.)NO',
#  '(+-)-4-(2-((3-(P-HYDROXYPHENYL)-1-METHYLPROPYL)AMINO)ETHYL)PYROCATECHOL',
#  '(N-METHYLCARBAMIMIDAMIDO)ACETATE',
#  '(+)-ALDOSTERONE',
#  'ESTRADIOL',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  'LEAD',
#  'A STEROID',
#  'CA(0)',
#  'CA(0)',
#  '(1S,2S,3R,5S)-3-(7-((1R,2S)-2-(3,4-DIFLUOROPHENYL)CYCLOPROPYLAMINO)-5-(PROPYLTHIO)-3H-(1,2,3)TRIAZOLO(4,5-D)PYRIMIDIN-3-YL)-5-(2-HYDROXYETHOXY)CYCLOPENTANE-1,2-DIOL',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CANDITRAL',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  'CARBON',
#  '(CIS-TRANS)-RESVERATROL',
#  "5'-ADENOSINE MONOPHOSPHATE",
#  '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#  '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#  '((AMINO(IMINO)METHYL)(METHYL)AMINO)ACETIC ACID',
#  '((AMINO(IMINO)METHYL)(METHYL)AMINO)ACETIC ACID',
#  '(+-)-ADRENALINE',
#  'ARDEPARIN SODIUM',
#  'ARDEPARIN SODIUM',
#  'BRL 14151K',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  'A TRIACYLGLYCEROL',
#  'A TRIACYLGLYCEROL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '6-O-METHYL ERYTHROMYCIN',
#  '(-)-OR-1259',
#  '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#  '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  'CHEBI:32952',
#  'CHEBI:25212',
#  'CHEBI:47867',
#  'CHEBI:47867',
#  'CHEBI:24261',
#  'CHEBI:24261',
#  'CHEBI:50904',
#  'CHEBI:50904',
#  'CHEBI:27026',
#  'CHEBI:27026',
#  'CHEBI:35498',
#  'CHEBI:18059',
#  'CHEBI:50249',
#  'CHEBI:50249',
#  'CHEBI:25029',
#  'CHEBI:24505',
#  'CHEBI:24505',
#  'CHEBI:23888',
#  'CHEBI:37527',
#  'CHEBI:80234',
#  'CHEBI:80234',
#  'CHEBI:26195',
#  'CHEBI:50114',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:47775',
#  'CHEBI:47775',
#  'CHEBI:26333',
#  'CHEBI:36357',
#  'CHEBI:26523',
#  'CHEBI:33290',
#  'CHEBI:27226',
#  'CHEBI:16646',
#  'CHEBI:35222',
#  'CHEBI:47774',
#  'CHEBI:48432',
#  '(.)NO',
#  '(.)NO',
#  '(+-)-4-(2-((3-(P-HYDROXYPHENYL)-1-METHYLPROPYL)AMINO)ETHYL)PYROCATECHOL',
#  '(N-METHYLCARBAMIMIDAMIDO)ACETATE',
#  '(+)-ALDOSTERONE',
#  'ESTRADIOL',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  'LEAD',
#  'A STEROID',
#  'CA(0)',
#  'CA(0)',
#  '(1S,2S,3R,5S)-3-(7-((1R,2S)-2-(3,4-DIFLUOROPHENYL)CYCLOPROPYLAMINO)-5-(PROPYLTHIO)-3H-(1,2,3)TRIAZOLO(4,5-D)PYRIMIDIN-3-YL)-5-(2-HYDROXYETHOXY)CYCLOPENTANE-1,2-DIOL',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CANDITRAL',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  'CARBON',
#  '(CIS-TRANS)-RESVERATROL',
#  "5'-ADENOSINE MONOPHOSPHATE",
#  '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#  '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#  '((AMINO(IMINO)METHYL)(METHYL)AMINO)ACETIC ACID',
#  '((AMINO(IMINO)METHYL)(METHYL)AMINO)ACETIC ACID',
#  '(+-)-ADRENALINE',
#  'ARDEPARIN SODIUM',
#  'ARDEPARIN SODIUM',
#  'BRL 14151K',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  'A TRIACYLGLYCEROL',
#  'A TRIACYLGLYCEROL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '6-O-METHYL ERYTHROMYCIN',
#  '(-)-OR-1259',
#  '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#  '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  'CHEBI:25212',
#  'CHEBI:25212',
#  'CHEBI:18154',
#  'CHEBI:80308',
#  'CHEBI:80308',
#  'CHEBI:38559',
#  'CHEBI:53188',
#  'CHEBI:35498',
#  'CHEBI:22910',
#  'CHEBI:24505',
#  'CHEBI:23888',
#  'CHEBI:37527',
#  'CHEBI:37527',
#  'CHEBI:77608',
#  'CHEBI:80234',
#  'CHEBI:51081',
#  'CHEBI:50114',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:26333',
#  'CHEBI:36357',
#  'CHEBI:26523',
#  'CHEBI:33290',
#  'CHEBI:22563',
#  'CHEBI:38215',
#  'CHEBI:50264',
#  'CHEBI:24870',
#  'CHEBI:35222',
#  'CHEBI:35222',
#  'CHEBI:35620',
#  'CHEBI:48432',
#  'CHEBI:48432',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(.)NO',
#  'NITRATE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  'AG 1343',
#  'ACETYLCHOLINE',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ESTRADIOL',
#  '(O2)(.-)',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  'LEAD',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '(BO3)3-',
#  '1-((3-(4,7-DIHYDRO-1-METHYL-7-OXO-3-PROPYL-1H-PYRAZOLO(4,3-D)PYRIMIDIN-5-YL)-4-ETHOXYPHENYL)SULFONYL)-4-METHYLPIPERAZINE',
#  'CA(0)',
#  'DYNORPHIN A',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CANDITRAL',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  'CARBON',
#  '(CIS-TRANS)-RESVERATROL',
#  '(13-ALPHA,14-ALPHA)-14,19-DIHYDRO-12,13-DIHYDROXY-20-NORCROTALANAN-11,15-DIONE',
#  '(13-ALPHA,14-ALPHA)-14,19-DIHYDRO-12,13-DIHYDROXY-20-NORCROTALANAN-11,15-DIONE',
#  'ARDEPARIN SODIUM',
#  'BRL 14151K',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  'A TRIACYLGLYCEROL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '6-O-METHYL ERYTHROMYCIN',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'A-84538',
#  'CHEBI:80270',
#  'CHEBI:80308',
#  'CHEBI:35498',
#  'CHEBI:18059',
#  'CHEBI:23888',
#  'CHEBI:80234',
#  'CHEBI:50114',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:22260',
#  'CHEBI:22260',
#  'CHEBI:35222',
#  'CHEBI:35222',
#  'CHEBI:48432',
#  '(.)NO',
#  '(+-)-4-(2-((3-(P-HYDROXYPHENYL)-1-METHYLPROPYL)AMINO)ETHYL)PYROCATECHOL',
#  '(+)-ALDOSTERONE',
#  'ACETYLCHOLINE',
#  'ACETYLCHOLINE',
#  'LEAD',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  'CA(0)',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'A-84538',
#  'CHEBI:32952',
#  'CHEBI:25212',
#  'CHEBI:25212',
#  'CHEBI:47867',
#  'CHEBI:47867',
#  'CHEBI:24261',
#  'CHEBI:24261',
#  'CHEBI:50904',
#  'CHEBI:27026',
#  'CHEBI:18059',
#  'CHEBI:50249',
#  'CHEBI:25029',
#  'CHEBI:24505',
#  'CHEBI:23888',
#  'CHEBI:37527',
#  'CHEBI:37527',
#  'CHEBI:51081',
#  'CHEBI:50114',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:22260',
#  'CHEBI:26333',
#  'CHEBI:36357',
#  'CHEBI:26523',
#  'CHEBI:33290',
#  'CHEBI:67194',
#  'CHEBI:62488',
#  'CHEBI:26347',
#  'CHEBI:38637',
#  'CHEBI:27226',
#  'CHEBI:35224',
#  'CHEBI:35224',
#  'CHEBI:24870',
#  'CHEBI:35222',
#  'CHEBI:26519',
#  '(2S)-2-AMINO-5-(CARBAMIMIDAMIDO)PENTANOATE',
#  '(.)NO',
#  'NITRATE',
#  '(+-)-4-(2-((3-(P-HYDROXYPHENYL)-1-METHYLPROPYL)AMINO)ETHYL)PYROCATECHOL',
#  '(+)-ALDOSTERONE',
#  'ACETYLCHOLINE',
#  'ACETYLCHOLINE',
#  'ACETYLCHOLINE',
#  'ACETYLCHOLINE',
#  '(5Z,8Z,11Z,14Z)-5,8,11,14-ICOSATETRAENOIC ACID',
#  '(O2)(.-)',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  'LEAD',
#  'PHOSPHORUS MONOXIDE',
#  '3,4-DIHYDRO-6-(4-(1-CYCLOHEXYL-1H-TETRAZOL-5-YL)BUTOXY)-2(1H)-QUINOLINONE',
#  'A STEROID',
#  'A STEROID',
#  'CA(0)',
#  'CA(0)',
#  '(2S)-2-AMINO-5-(CARBAMIMIDAMIDO)PENTANOIC ACID',
#  '4-(4-METHYL-PIPERAZIN-1-YLMETHYL)-N-[4-METHYL-3-(4-PYRIDIN-3-YL-PYRIMIDIN-2-YLAMINO)-PHENYL]-BENZAMIDE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  'CARBON',
#  '(CIS-TRANS)-RESVERATROL',
#  "5'-ADENOSINE MONOPHOSPHATE",
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#  "1,6-DIHYDRO-2-METHYL-6-OXO(3,4'-BIPYRIDINE)-5-CARBONITRILE",
#  'A-101',
#  'A-101',
#  'A-101',
#  '(+-)-ADRENALINE',
#  'ARDEPARIN SODIUM',
#  'PEROXYNITRITE',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  'AMINAL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '(+/-)-NICARDIPINE',
#  '1-((5-(P-NITROPHENYL)FURFURYLIDENE)AMINO)HYDANTOIN',
#  'ACQUA',
#  'ACQUA',
#  'ACQUA',
#  '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  'CHEBI:25212',
#  'CHEBI:24261',
#  'CHEBI:38559',
#  'CHEBI:53188',
#  'CHEBI:35498',
#  'CHEBI:18059',
#  'CHEBI:23888',
#  'CHEBI:77608',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:26333',
#  'CHEBI:36357',
#  'CHEBI:33290',
#  'CHEBI:38215',
#  'CHEBI:50264',
#  'CHEBI:24870',
#  'CHEBI:35222',
#  'CHEBI:48432',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(.)NO',
#  '(+-)-1-(CARBAZOL-4-YLOXY)-3-((2-(O-METHOXYPHENOXY)ETHYL)AMINO)-2-PROPANOL',
#  '(+-)-1-(CARBAZOL-4-YLOXY)-3-((2-(O-METHOXYPHENOXY)ETHYL)AMINO)-2-PROPANOL',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  'AG 1343',
#  'ACETYLCHOLINE',
#  'PIG SECRETIN',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ESTRADIOL',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '3,4-DIHYDRO-6-(4-(1-CYCLOHEXYL-1H-TETRAZOL-5-YL)BUTOXY)-2(1H)-QUINOLINONE',
#  'BYSTOLIC',
#  'A STEROID',
#  'CA(0)',
#  '1-CHLORO-2,2,2-TRIFLUOROETHYL DIFLUOROMETHYL ETHER',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CANDITRAL',
#  'CANDITRAL',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  '(CIS-TRANS)-RESVERATROL',
#  "5'-ADENOSINE MONOPHOSPHATE",
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '3-CARBOXAMIDO-4-HYDROXY-ALPHA-((1-METHYL-3-PHENYLPROPYLAMINO)METHYL)BENZYL ALCOHOL',
#  '3-CARBOXAMIDO-4-HYDROXY-ALPHA-((1-METHYL-3-PHENYLPROPYLAMINO)METHYL)BENZYL ALCOHOL',
#  'BRL 14151K',
#  'ALAPAV',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '(+/-)-NICARDIPINE',
#  '(+/-)-NICARDIPINE',
#  '6-O-METHYL ERYTHROMYCIN',
#  '(-)-OR-1259',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ACQUA',
#  '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  'A-84538',
#  'CHEBI:25212',
#  'CHEBI:80270',
#  'CHEBI:24433',
#  'CHEBI:36357',
#  'CHEBI:35224',
#  'CHEBI:35222',
#  'CHEBI:48432',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  'ACETYLCHOLINE',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  '(-)-NORADRENALINE',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '(CIS-TRANS)-RESVERATROL',
#  '(CIS-TRANS)-RESVERATROL',
#  'ACARDI',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  'CHEBI:22198',
#  'CHEBI:16247',
#  'CHEBI:25212',
#  'CHEBI:47867',
#  'CHEBI:50904',
#  'CHEBI:27026',
#  'CHEBI:18059',
#  'CHEBI:24505',
#  'CHEBI:23888',
#  'CHEBI:37527',
#  'CHEBI:80234',
#  'CHEBI:51081',
#  'CHEBI:33942',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:47775',
#  'CHEBI:22260',
#  'CHEBI:36357',
#  'CHEBI:26523',
#  'CHEBI:33290',
#  'CHEBI:22563',
#  'CHEBI:27226',
#  'CHEBI:35224',
#  'CHEBI:16646',
#  'CHEBI:24870',
#  'CHEBI:35222',
#  'CHEBI:26519',
#  'CHEBI:47774',
#  '(.)NO',
#  'NITRATE',
#  '(N-METHYLCARBAMIMIDAMIDO)ACETATE',
#  'AG 1343',
#  'ACETYLCHOLINE',
#  '(O2)(.-)',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  'PHOSPHORUS MONOXIDE',
#  'CA(0)',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CANDITRAL',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  '(CIS-TRANS)-RESVERATROL',
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '(3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL',
#  '((AMINO(IMINO)METHYL)(METHYL)AMINO)ACETIC ACID',
#  "2-(DIETHYLAMINO)-2',6'-ACETOXYLIDIDE",
#  'A-101',
#  'A-101',
#  'A-101',
#  'A-101',
#  'A-101',
#  'A-101',
#  'ARDEPARIN SODIUM',
#  'BRL 14151K',
#  'PEROXYNITRITE',
#  'ACETYL-BETA-METHYLCHOLINE',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  'A TRIACYLGLYCEROL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '(+/-)-NICARDIPINE',
#  '1-((5-(P-NITROPHENYL)FURFURYLIDENE)AMINO)HYDANTOIN',
#  'ACQUA',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  'CHEBI:25212',
#  'CHEBI:24261',
#  'CHEBI:38559',
#  'CHEBI:53188',
#  'CHEBI:35498',
#  'CHEBI:18059',
#  'CHEBI:23888',
#  'CHEBI:77608',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:26333',
#  'CHEBI:36357',
#  'CHEBI:33290',
#  'CHEBI:38215',
#  'CHEBI:50264',
#  'CHEBI:24870',
#  'CHEBI:35222',
#  'CHEBI:48432',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(.)NO',
#  '(+-)-1-(CARBAZOL-4-YLOXY)-3-((2-(O-METHOXYPHENOXY)ETHYL)AMINO)-2-PROPANOL',
#  '(+-)-1-(CARBAZOL-4-YLOXY)-3-((2-(O-METHOXYPHENOXY)ETHYL)AMINO)-2-PROPANOL',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  'AG 1343',
#  'ACETYLCHOLINE',
#  'PIG SECRETIN',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ESTRADIOL',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '3,4-DIHYDRO-6-(4-(1-CYCLOHEXYL-1H-TETRAZOL-5-YL)BUTOXY)-2(1H)-QUINOLINONE',
#  'BYSTOLIC',
#  'A STEROID',
#  'CA(0)',
#  '1-CHLORO-2,2,2-TRIFLUOROETHYL DIFLUOROMETHYL ETHER',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CANDITRAL',
#  'CANDITRAL',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  '(CIS-TRANS)-RESVERATROL',
#  "5'-ADENOSINE MONOPHOSPHATE",
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '3-CARBOXAMIDO-4-HYDROXY-ALPHA-((1-METHYL-3-PHENYLPROPYLAMINO)METHYL)BENZYL ALCOHOL',
#  '3-CARBOXAMIDO-4-HYDROXY-ALPHA-((1-METHYL-3-PHENYLPROPYLAMINO)METHYL)BENZYL ALCOHOL',
#  'BRL 14151K',
#  'ALAPAV',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '(+/-)-NICARDIPINE',
#  '(+/-)-NICARDIPINE',
#  '6-O-METHYL ERYTHROMYCIN',
#  '(-)-OR-1259',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ACQUA',
#  '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  'A-84538',
#  'CHEBI:25212',
#  'CHEBI:25212',
#  'CHEBI:18154',
#  'CHEBI:80308',
#  'CHEBI:80308',
#  'CHEBI:38559',
#  'CHEBI:53188',
#  'CHEBI:35498',
#  'CHEBI:22910',
#  'CHEBI:24505',
#  'CHEBI:23888',
#  'CHEBI:37527',
#  'CHEBI:37527',
#  'CHEBI:77608',
#  'CHEBI:80234',
#  'CHEBI:51081',
#  'CHEBI:50114',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:26333',
#  'CHEBI:36357',
#  'CHEBI:26523',
#  'CHEBI:33290',
#  'CHEBI:22563',
#  'CHEBI:38215',
#  'CHEBI:50264',
#  'CHEBI:24870',
#  'CHEBI:35222',
#  'CHEBI:35222',
#  'CHEBI:35620',
#  'CHEBI:48432',
#  'CHEBI:48432',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(.)NO',
#  'NITRATE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  'AG 1343',
#  'ACETYLCHOLINE',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ESTRADIOL',
#  '(O2)(.-)',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  'LEAD',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '(BO3)3-',
#  '1-((3-(4,7-DIHYDRO-1-METHYL-7-OXO-3-PROPYL-1H-PYRAZOLO(4,3-D)PYRIMIDIN-5-YL)-4-ETHOXYPHENYL)SULFONYL)-4-METHYLPIPERAZINE',
#  'CA(0)',
#  'DYNORPHIN A',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CANDITRAL',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  'CARBON',
#  '(CIS-TRANS)-RESVERATROL',
#  '(13-ALPHA,14-ALPHA)-14,19-DIHYDRO-12,13-DIHYDROXY-20-NORCROTALANAN-11,15-DIONE',
#  '(13-ALPHA,14-ALPHA)-14,19-DIHYDRO-12,13-DIHYDROXY-20-NORCROTALANAN-11,15-DIONE',
#  'ARDEPARIN SODIUM',
#  'BRL 14151K',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  'A TRIACYLGLYCEROL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '6-O-METHYL ERYTHROMYCIN',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'A-84538',
#  'CHEBI:25212',
#  'CHEBI:24261',
#  'CHEBI:38559',
#  'CHEBI:53188',
#  'CHEBI:35498',
#  'CHEBI:18059',
#  'CHEBI:23888',
#  'CHEBI:77608',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:26333',
#  'CHEBI:36357',
#  'CHEBI:33290',
#  'CHEBI:38215',
#  'CHEBI:50264',
#  'CHEBI:24870',
#  'CHEBI:35222',
#  'CHEBI:48432',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(.)NO',
#  '(+-)-1-(CARBAZOL-4-YLOXY)-3-((2-(O-METHOXYPHENOXY)ETHYL)AMINO)-2-PROPANOL',
#  '(+-)-1-(CARBAZOL-4-YLOXY)-3-((2-(O-METHOXYPHENOXY)ETHYL)AMINO)-2-PROPANOL',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  'AG 1343',
#  'ACETYLCHOLINE',
#  'PIG SECRETIN',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ESTRADIOL',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '(-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL ALCOHOL',
#  '3,4-DIHYDRO-6-(4-(1-CYCLOHEXYL-1H-TETRAZOL-5-YL)BUTOXY)-2(1H)-QUINOLINONE',
#  'BYSTOLIC',
#  'A STEROID',
#  'CA(0)',
#  '1-CHLORO-2,2,2-TRIFLUOROETHYL DIFLUOROMETHYL ETHER',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CANDITRAL',
#  'CANDITRAL',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  '(CIS-TRANS)-RESVERATROL',
#  "5'-ADENOSINE MONOPHOSPHATE",
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '1,3,7-TRIMETHYL-2,6-DIOXOPURINE',
#  '3-CARBOXAMIDO-4-HYDROXY-ALPHA-((1-METHYL-3-PHENYLPROPYLAMINO)METHYL)BENZYL ALCOHOL',
#  '3-CARBOXAMIDO-4-HYDROXY-ALPHA-((1-METHYL-3-PHENYLPROPYLAMINO)METHYL)BENZYL ALCOHOL',
#  'BRL 14151K',
#  'ALAPAV',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '3-(2-AMINOETHYL)-1H-INDOL-5-OL',
#  '(+/-)-NICARDIPINE',
#  '(+/-)-NICARDIPINE',
#  '6-O-METHYL ERYTHROMYCIN',
#  '(-)-OR-1259',
#  'ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG',
#  'ACQUA',
#  '(11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  '17BETA-HYDROXY-4-ANDROSTEN-3-ONE',
#  'A-84538',
#  'CHEBI:25212',
#  'CHEBI:25212',
#  'CHEBI:18154',
#  'CHEBI:80308',
#  'CHEBI:80308',
#  'CHEBI:38559',
#  'CHEBI:53188',
#  'CHEBI:35498',
#  'CHEBI:22910',
#  'CHEBI:24505',
#  'CHEBI:23888',
#  'CHEBI:37527',
#  'CHEBI:37527',
#  'CHEBI:77608',
#  'CHEBI:80234',
#  'CHEBI:51081',
#  'CHEBI:50114',
#  'CHEBI:24433',
#  'CHEBI:25741',
#  'CHEBI:26333',
#  'CHEBI:36357',
#  'CHEBI:26523',
#  'CHEBI:33290',
#  'CHEBI:22563',
#  'CHEBI:38215',
#  'CHEBI:50264',
#  'CHEBI:24870',
#  'CHEBI:35222',
#  'CHEBI:35222',
#  'CHEBI:35620',
#  'CHEBI:48432',
#  'CHEBI:48432',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(-)-CAPTOPRIL',
#  '(.)NO',
#  'NITRATE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  '(+)-ALDOSTERONE',
#  'AG 1343',
#  'ACETYLCHOLINE',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ANGIOTENSIN',
#  'ESTRADIOL',
#  '(O2)(.-)',
#  '(-)-NORADRENALINE',
#  '(-)-NORADRENALINE',
#  'LEAD',
#  'LEAD',
#  '(R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-METHYL-1-(4-METHYLQUINAZOLIN-2-YLMETHYL)-3,7-DIHYDRO-PURINE-2,6-DIONE',
#  '(BO3)3-',
#  '1-((3-(4,7-DIHYDRO-1-METHYL-7-OXO-3-PROPYL-1H-PYRAZOLO(4,3-D)PYRIMIDIN-5-YL)-4-ETHOXYPHENYL)SULFONYL)-4-METHYLPIPERAZINE',
#  'CA(0)',
#  'DYNORPHIN A',
#  '2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE',
#  'CANDITRAL',
#  '1H-IMIDAZOLE-4-ETHANAMINE',
#  'CARBON',
#  '(CIS-TRANS)-RESVERATROL',
#  '(13-ALPHA,14-ALPHA)-14,19-DIHYDRO-12,13-DIHYDROXY-20-NORCROTALANAN-11,15-DIONE',
#  '(13-ALPHA,14-ALPHA)-14,19-DIHYDRO-12,13-DIHYDROXY-20-NORCROTALANAN-11,15-DIONE',
#  'ARDEPARIN SODIUM',
#  'BRL 14151K',
#  '(15S)-PROSTAGLANDIN E2',
#  '(+)-GLUCOSE',
#  '(+)-GLUCOSE',
#  ...]

# %%
d = {x:genes_to_chem_to_vasodilation_list.count(x) for x in genes_to_chem_to_vasodilation_list}

# %%
## display counts for occurrence of each chemical in results
genes_to_chem_to_vasodilation_df = pandas.DataFrame.from_dict({k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse = True)}, orient='index').iloc[0:50]
genes_to_chem_to_vasodilation_df.columns = ["count"]
genes_to_chem_to_vasodilation_df
# Out:
#                                                     count
# (+)-GLUCOSE                                           152
# (+)-ALDOSTERONE                                       111
# (15S)-PROSTAGLANDIN E2                                 84
# 2-(3,4-DIHYDROXYPHENYL)ETHYLAMINE                      77
# 17BETA-HYDROXY-4-ANDROSTEN-3-ONE                       74
# A-101                                                  68
# 3-(2-AMINOETHYL)-1H-INDOL-5-OL                         68
# (-)-NORADRENALINE                                      68
# (CIS-TRANS)-RESVERATROL                                59
# CHEBI:35222                                            58
# LEAD                                                   57
# CA(0)                                                  51
# CHEBI:24433                                            50
# (.)NO                                                  48
# ACETYLCHOLINE                                          48
# 1H-IMIDAZOLE-4-ETHANAMINE                              47
# CHEBI:25741                                            45
# CHEBI:25212                                            45
# 1,3,7-TRIMETHYL-2,6-DIOXOPURINE                        45
# ACQUA                                                  44
# CHEBI:18059                                            43
# CHEBI:23888                                            43
# CHEBI:36357                                            43
# CHEBI:37527                                            40
# CHEBI:35224                                            34
# CHEBI:33290                                            34
# CHEBI:48432                                            34
# (-)-CAPTOPRIL                                          34
# (-)-M-HYDROXY-ALPHA-(METHYLAMINOMETHYL)BENZYL A...     34
# PHOSPHORUS MONOXIDE                                    33
# CARBON                                                 33
# (3BETA,14BETA,17ALPHA)-CHOLEST-5-EN-3-OL               33
# CHEBI:24870                                            32
# CHEBI:26523                                            31
# ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG                    31
# CHEBI:50114                                            30
# CHEBI:24261                                            30
# 5'-ADENOSINE MONOPHOSPHATE                             30
# ANGIOTENSIN                                            29
# (R)-8-(3-AMINOPIPERIDIN-1-YL)-7-BUT-2-YNYL-3-ME...     28
# CHEBI:22260                                            27
# (O2)(.-)                                               25
# PEROXYNITRITE                                          25
# CHEBI:47867                                            25
# A TRIACYLGLYCEROL                                      25
# (11BETA)-11,17,21-TRIHYDROXYPREGN-4-ENE-3,20-DIONE     25
# 1-CHLORO-2,2,2-TRIFLUOROETHYL DIFLUOROMETHYL ETHER     25
# A STEROID                                              24
# CHEBI:50904                                            23
# CHEBI:27026                                            23

# %% [markdown]
# In agreement with article, (+)-ALDOSTERONE ranks most highly, and other top results include ANGIOTENSIN and Bradykinin (ARG-PRO-PRO-GLY-PHE-SER-PRO-PHE-ARG).

# %% [markdown]
# ## 4 Exploring COVID-19 to Hyaluronic Acid Connection
#
# Look at genes connected to both COVID and HYA, and hypotehsize what pathways may be involved in the HYA production

# %% [markdown]
# ### 4.1 COVID-19 -> Genes <- Hyaluronic Acid Explain Query

# %%
## Get Hayluronic Acid node
HYA = ht.query('hyaluronic acid')['ChemicalSubstance'][0]
HYA

# %%
fc3 = FindConnection(input_obj=covid, output_obj=HYA, intermediate_nodes=['Gene'])
fc3.connect(verbose=False)
df3 = fc3.display_table_view()
df3

# %% [markdown]
# ### 4.2 COVID/HYA Genes -> Pathways

# %%
## get related genes and turn them into nodes
genes_related_to_HYA = list(df3["node1_name"])
# get gene inputs through hint module
gene_inputs_2 = []
for gene in genes_related_to_HYA: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        gene_inputs_2.append(gene_input)
    except: 
        print(gene + ' Failed')

# %%
## Query Genes -> Pathways
HYA_gene_to_pathways = predict_many(gene_inputs_2, ['Pathway'])

# %%
# Display Pathway Counts and Genes related to each pathway 
gene_to_pathway_results = {}
gene_to_pathway_genes = list(HYA_gene_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'pathway_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_pathways_2.iterrows():
    gene_to_pathway_results[row['output_name']]['pathway_count'] = gene_to_pathway_results[row['output_name']]['pathway_count'] + 1
    gene_to_pathway_results[row['output_name']]['genes_related'].append(row['input'])
    

gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['pathway_count'], reverse = True))

# gene_to_pathway_results
pandas.DataFrame.from_dict(gene_to_pathway_results, orient='index').iloc[0:50]

# %% [markdown]
# Interestingly, cytokine signaling is the pathway most indicated as being related to genes that are related to both COVID and HYA. This may be in agreement with a large amount of research indicating cytokine concentration elevation to be correlated with severe COVID cases:
#
#
# - Cao, Xuetao. "COVID-19: immunopathology and its implications for therapy." Nature reviews immunology 20.5 (2020): 269-270.
#
# - Mangalmurti, Nilam, and Christopher A. Hunter. "Cytokine storms: understanding COVID-19." Immunity (2020).
#
# - Wu, Dandan, and Xuexian O. Yang. "TH17 responses in cytokine storm of COVID-19: An emerging target of JAK2 inhibitor Fedratinib." Journal of Microbiology, Immunology and Infection (2020).
#
#
#
# Additionally, and interestingly, past research has indicated a role of cytokines in hyaluronic acid production / degredation:
#
# - Sampson, Phyllis M., et al. "Cytokine regulation of human lung fibroblast hyaluronan (hyaluronic acid) production. Evidence for cytokine-regulated hyaluronan (hyaluronic acid) degradation and human lung fibroblast-derived hyaluronidase." The Journal of clinical investigation 90.4 (1992): 1492-1503.

# %% [markdown]
# ## 5 Summary
# ### 5.1 Summary
#
#
# - RAS Pathway and corresponding proteins, pathways, and processes, and chemicals were highly implicated through genes derived from COVID -> Genes <- Vasodilation / Hypotension query
#
# - Anatomical Entities related to genes were very representative of areas where symptoms in COVID patients often occur
#
# - Cytokine pathways may be relevant to different COVID symptoms (Hyaluronic Acid Production) than initially proposed
#
#
# ### 5.2 Future Directions
#
# - Investigate COVID & Hyaluronic Acid connection further
