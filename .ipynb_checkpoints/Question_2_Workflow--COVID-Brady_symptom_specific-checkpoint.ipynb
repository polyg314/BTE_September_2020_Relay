# %% [markdown]
# # Question 2 Workflow

# %% [markdown]
# ## Workfolow Summary

# %% [markdown]
# ## Imports

# %%
# Import pandas and biothings explorers modules
import pandas as pandas
from biothings_explorer.query.predict import Predict
from biothings_explorer.query.visualize import display_graph
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
import nest_asyncio
nest_asyncio.apply()
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# ## Set Parameters

# %%
max_direct = 20
max_indirect = 50

# %%
disease_name = 'COVID-19'
ht = Hint()
disease = ht.query(disease_name)['Disease'][0]
disease
# Out:
# {'MONDO': 'MONDO:0100096',
#  'DOID': 'DOID:0080600',
#  'name': 'COVID-19',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0100096'},
#  'display': 'MONDO(MONDO:0100096) DOID(DOID:0080600) name(COVID-19)',
#  'type': 'Disease'}

# %% [markdown]
# ## Get Symptoms

# %%
import requests 

symptoms = ([ 'fever','cough', 'hemoptysis', 
'shortness of breath', 'myalgia', 'fatigue', 'sore throat', 
'nausea', 'vomiting', 'diarrhea', 'conjunctivitis', 'anorexia',
'headache', 'leukopenia', 'eosinopenia', 'neutrophilia', 'elevated liver enzymes', 'C-reactive protein', 'ferritin',
'hyaline membrane', 'alveolar lesions', 'prominent hyaline membranes', 'alveolar damage',
 'acute myocardial injury', ' myocarditis', 'arrhythmias','cardiac dysfunction', 'encephalopathy'])


symptom_dict = {}

for symptom_name in symptoms: 
    try: 
        symptom = ht.query(symptom_name)['PhenotypicFeature'][0]
#         print(symptom['name'])
#         pd = Predict(
#             input_objs=[symptom],
#             intermediate_nodes =[None], 
#             output_types = ['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
#                 'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
#                 'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'], 
#             config={"expand": False}
#         )
#         pd.connect(verbose=False)
#         df = pd.display_table_view()
#         edges_out = df.shape[0]
        edges_out = 10
        symptom_dict[symptom['HP']] = {
            'names': [symptom['name'].upper()],
            'frequency': 'Unknown', 
            'edges_out' : edges_out
        }
        r = requests.get('https://biothings.ncats.io/hpo/phenotype/' + str(symptom['HP']))
        res = r.json()
#         print(res)
        if('synonym' in res):
            if('exact' in res['synonym']):
                for name in res['synonym']['exact']:
                    if name.upper() not in symptom_dict[res['_id']]['names']: 
#                         print(name.upper())
                        symptom_dict[res['_id']]['names'].append(name.upper())
    except:
        print(symptom_name + " failed")
# Out:
# eosinopenia failed
# hyaline membrane failed
# alveolar lesions failed
# prominent hyaline membranes failed
# acute myocardial injury failed
# cardiac dysfunction failed

# %%
# symptom_dict
disease_symptom_df = pandas.DataFrame.from_dict(symptom_dict, orient='index')
disease_symptom_df
# Out:
#                                                         names frequency  \
# HP:0011134                      [LOW-GRADE FEVER, MILD FEVER]   Unknown
# HP:0012735                                  [COUGH, COUGHING]   Unknown
# HP:0002105       [HEMOPTYSIS, COUGHING UP BLOOD, HAEMOPTYSIS]   Unknown
# HP:0002098  [RESPIRATORY DISTRESS, BREATHING DIFFICULTIES,...   Unknown
# HP:0003326                [MYALGIA, MUSCLE ACHE, MUSCLE PAIN]   Unknown
# HP:0012378                        [FATIGUE, TIRED, TIREDNESS]   Unknown
# HP:0033050                         [THROAT PAIN, SORE THROAT]   Unknown
# HP:0002018                                           [NAUSEA]   Unknown
# HP:0025089  [FECULENT VOMITING, FECAL VOMITING, STERCORACE...   Unknown
# HP:0002014                [DIARRHEA, DIARRHOEA, WATERY STOOL]   Unknown
# HP:0500039  [CONJUNCTIVAL CICATRIZATION, CICATRICIAL CONJU...   Unknown
# HP:0002039                                         [ANOREXIA]   Unknown
# HP:0002315                              [HEADACHE, HEADACHES]   Unknown
# HP:0001882  [LEUKOPENIA, DECREASED BLOOD LEUKOCYTE NUMBER,...   Unknown
# HP:0011897  [NEUTROPHILIA, INCREASED BLOOD NEUTROPHIL COUNTS]   Unknown
# HP:0002910  [ELEVATED HEPATIC TRANSAMINASE, ABNORMAL LIVER...   Unknown
# HP:0032436                [ABNORMAL C-REACTIVE PROTEIN LEVEL]   Unknown
# HP:0040133  [ABNORMAL SERUM FERRITIN, ABNORMAL PLASMA FERR...   Unknown
# HP:0033006                          [DIFFUSE ALVEOLAR DAMAGE]   Unknown
# HP:0012819        [MYOCARDITIS, INFLAMMATION OF HEART MUSCLE]   Unknown
# HP:0005115  [SUPRAVENTRICULAR ARRHYTHMIA, ARRHYTHMIAS, SUP...   Unknown
# HP:0001298                                   [ENCEPHALOPATHY]   Unknown
#
#             edges_out
# HP:0011134         10
# HP:0012735         10
# HP:0002105         10
# HP:0002098         10
# HP:0003326         10
# HP:0012378         10
# HP:0033050         10
# HP:0002018         10
# HP:0025089         10
# HP:0002014         10
# HP:0500039         10
# HP:0002039         10
# HP:0002315         10
# HP:0001882         10
# HP:0011897         10
# HP:0002910         10
# HP:0032436         10
# HP:0040133         10
# HP:0033006         10
# HP:0012819         10
# HP:0005115         10
# HP:0001298         10

# %%
## also save disease symptoms as a list
disease_symptoms = []
for x in disease_symptom_df['names']: 
    disease_symptoms = disease_symptoms + x
# disease_symptoms

# %% [markdown]
# ## Disease -> Gene -> [Phenotypic Feature, Disease, Biological Process]

# %%
pd = Predict(
    input_objs=[disease],
    intermediate_nodes =['Gene'], 
    output_types =['PhenotypicFeature', 'Disease', 'BiologicalProcess'], 
    config={"expand": False}
)
pd.connect(verbose=False)
# Out:
# API call to Automat CORD19 Scibite API with input 7054 failed with timeout error. Current timeout limit is 5 seconds
# API call to CORD Gene API with input ['399', '6018', '5962', '3009', '5414', '6023', '11782', '11876', '11892', '4113', '9281', '5438', '1706', '5417', '16884', '5992', '11183', '6741', '19679', '1116', '10627', '79', '6001', '2367', '338', '13523', '27960', '6025', '2524', '195', '10618', '6915', '30615', '27954', '4552', '11947', '9208', '17697', '6898', '5434', '4989', '10637', '336', '1678', '6008', '8568', '2707', '3535', '5981', '2537', '9958', '13557', '16885', '3541'] failed with timeout error. Current timeout limit is 20 seconds
# API call to CORD Gene API with input ['399', '6018', '5962', '3009', '5414', '6023', '11782', '11876', '11892', '4113', '9281', '5438', '1706', '5417', '16884', '5992', '11183', '6741', '19679', '1116', '10627', '79', '6001', '2367', '338', '13523', '27960', '6025', '2524', '195', '10618', '6915', '30615', '27954', '4552', '11947', '9208', '17697', '6898', '5434', '4989', '10637', '336', '1678', '6008', '8568', '2707', '3535', '5981', '2537', '9958', '13557', '16885', '3541'] failed with timeout error. Current timeout limit is 20 seconds
# API call to SEMMED Gene API with input ['C1332807', 'C0054871', 'C1414504', 'C1417035', 'C1420310', 'C1420826', 'C0021745', 'C1415900', 'C1422064', 'C1335817', 'C1335818', 'C0035094', 'C1333916', 'C1415912', 'C1415274', 'C1413809', 'C1335232', 'C0879590', 'C1334098', 'C1414944', 'C1823096', 'C1332036', 'C1334114', 'C1413716', 'C1334085', 'C1334124', 'C1415898', 'C1426329', 'C1419338', 'C0919550', 'C1413244', 'C1412099', 'C1412186', 'C1412828', 'C1335240', 'C1367714', 'C1412332', 'C1539099', 'C0812246', 'C1417048', 'C1332714', 'C1439284', 'C1336641', 'C1420718', 'C1825592', 'C1337092', 'C1334112', 'C0081714', 'C1540024', 'C1425041', 'C1366571', 'C1416946', 'C1414141', 'C1333522', 'C1334122', 'C1332690', 'C1428660', 'C1413931'] failed with timeout error. Current timeout limit is 20 seconds

# %%
df = pd.display_table_view()
df.shape
# Out:
# (32428, 19)

# %%
# filter gene -> symptoms table to only include rows where symptoms match disease symptoms
indices_with_symptom_outputs = [i for i, val in enumerate([x.upper() for x in list(df['output_label'])]) if val in disease_symptoms]
direct_relevant_genes_to_symptoms_df = df.iloc[indices_with_symptom_outputs]
direct_relevant_genes_to_symptoms_df.shape
# Out:
# (102, 19)

# %%
direct_genes = 	list(direct_relevant_genes_to_symptoms_df["node1_label"])
direct_gene_dict = {x:direct_genes.count(x) for x in direct_genes}
direct_gene_dict = dict(sorted(direct_gene_dict.items(), key=lambda x: x[1], reverse=True)[:max_direct])
direct_gene_dict
# Out:
# {'TNF': 21,
#  'CRP': 12,
#  'IFNA1': 12,
#  'CD4': 7,
#  'IL6': 7,
#  'IL2': 6,
#  'ACE': 4,
#  'MARS1': 3,
#  'CCL2': 3,
#  'F2': 3,
#  'IFNG': 2,
#  'IL1B': 2,
#  'F3': 2,
#  'TNNI3': 2,
#  'GPT': 2,
#  'MB': 2,
#  'CD8A': 2,
#  'POR': 1,
#  'SON': 1,
#  'ALB': 1}

# %% [markdown]
# ## Disease X -> Intermediate Node -> Gene ->  [Phenotypic Feature, Disease, Biological Process]

# %%
query_config = {
    "filters": [
        {
        },
        {
            "nodeDegree": {
                ">" : 20
            }
        }
    ],
    "annotate": ["ngd","nodeDegree"],
    "expand": False
}

# %%
## way to filter at the gene step for top x number of genes? 
pd2 = Predict(
    input_objs=[disease],
    intermediate_nodes =[['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'],'Gene'], 
    output_types =['PhenotypicFeature', 'Disease', 'BiologicalProcess'], 
    config= query_config 
)
pd2.connect(verbose=True)
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# Your query have 1 input nodes, including COVID-19 .... And BTE will find paths that connect your input nodes to your output types ['PhenotypicFeature', 'Disease', 'BiologicalProcess']. Paths will contain 2 intermediate nodes.
#
# Intermediate node #1 will have these type constraints: ['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 'Pathway', 'AnatomicalEntity', 'PhenotypicFeature']
# Intermediate node #2 will have these type constraints: Gene
#
# ========== Query # 1 ==========
#
# ==== Step #1: Query Path Planning ====
#
# Input Types: Disease
# Output Types: ['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 'Pathway', 'AnatomicalEntity', 'PhenotypicFeature']
# Predicates: None
#
# BTE found 12 APIs based on SmartAPI Meta-KG.
#
# API 1. Ontology Lookup Service API (1 API calls)
# API 2. Automat CORD19 Scibite API (3 API calls)
# API 3. mydisease.info API (2 API calls)
# API 4. Automat CORD19 Scigraph API (3 API calls)
# API 5. MGIgene2phenotype API (1 API calls)
# API 6. TCGA Mutation Frequency KP API (1 API calls)
# API 7. Automat PHAROS API (3 API calls)
# API 8. DISEASES API (1 API calls)
# API 9. BioLink API (4 API calls)
# API 10. Molecular Data Provider API (1 API calls)
# API 11. Automat HMDB API (2 API calls)
# API 12. CORD Disease API (8 API calls)
#
#
# ==== Step #2: Query path execution ====
#
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.1: http://mydisease.info/v1/query?fields=mondo.descendants (POST -d q=MONDO:0100096&scopes=mondo.mondo)
# API 3.1 mydisease.info API: 0 hits
# API 6.1: https://biothings.ncats.io/tcga_mut_freq_kp/query?fields=association.freq_by_sample,subject.SYMBOL&q=object.id:"MONDO:0100096"%20AND%20association.freq_by_sample:>0.1&size=1000&sort=-association.freq_by_sample
# API 6.1 TCGA Mutation Frequency KP API: 0 hits
# API 8.1: https://pending.biothings.io/DISEASES/query?fields=DISEASES.associatedWith (POST -d q=DOID:0080600&scopes=DISEASES.doid)
# API 8.1 DISEASES API: 49 hits
# API 12.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 12.1 CORD Disease API: 0 hits
# API 12.2: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 12.2 CORD Disease API: 0 hits
# API 12.3: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 12.3 CORD Disease API: 0 hits
# API 12.4: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 12.4 CORD Disease API: 0 hits
# API 9.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0100096/genes?direct=True&rows=200&unselect_evidence=True
# API 9.1 BioLink API: 0 hits
# API 9.2: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0100096/genes?direct=True&rows=200&unselect_evidence=True
# API 9.2 BioLink API: 2 hits
# API 9.3: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0100096/pathways?direct=True&rows=200&unselect_evidence=True
# API 9.3 BioLink API: 0 hits
# API 9.4: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0100096/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 9.4 BioLink API: 0 hits
# API 5.1: https://pending.biothings.io/mgigene2phenotype/query?fields=_id&size=300 (POST -d q=DOID:0080600&scopes=mgi.associated_with_disease.doid)
# API 5.1 MGIgene2phenotype API: 0 hits
# API 3.2: http://mydisease.info/v1/query?fields=mondo.parents (POST -d q=MONDO:0100096&scopes=mondo.mondo)
# API 3.2 mydisease.info API: 1 hits
# API 10.1: https://translator.broadinstitute.org/molepro_reasoner/query (POST -d {'message': {'query_graph': {'edges': [{'id': 'e00', 'source_id': 'n00', 'target_id': 'n01', 'type': 'related_to'}], 'nodes': [{'curie': 'MONDO:0100096', 'id': 'n00', 'type': 'disease'}, {'id': 'n01', 'type': 'gene'}]}}})
# API 10.1 Molecular Data Provider API: 0 hits
# API 7.1: https://automat.renci.org/pharos/disease/gene/MONDO:0100096
# API 7.1 Automat PHAROS API: 0 hits
# API 7.2: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0100096
# API call to Automat PHAROS API with input MONDO:0100096 failed with status code 404
# {'error': 'Failed to get response from http://pharos-plater-plater-service:8080/disease/chemical_substance/MONDO:0100096?. Status code 404'}
# API 7.2: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0100096
# API call to Automat PHAROS API with input MONDO:0100096 failed with status code 404
# {'error': 'Failed to get response from http://pharos-plater-plater-service:8080/disease/chemical_substance/MONDO:0100096?. Status code 404'}
# API 11.1: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0100096
# API 11.1 Automat HMDB API: 0 hits
# API 11.2: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0100096
# API 11.2 Automat HMDB API: 0 hits
# API 2.1: https://automat.renci.org/cord19-scibite/disease/chemical_substance/MONDO:0100096
# API 2.1 Automat CORD19 Scibite API: 0 hits
# API 2.2: https://automat.renci.org/cord19-scibite/disease/chemical_substance/MONDO:0100096
# API 2.2 Automat CORD19 Scibite API: 0 hits
# API 2.3: https://automat.renci.org/cord19-scibite/disease/gene/MONDO:0100096
# API 2.3 Automat CORD19 Scibite API: 0 hits
# API 4.1: https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0100096
# API 4.1 Automat CORD19 Scigraph API: 0 hits
# API 4.2: https://automat.renci.org/cord19-scigraph/disease/gene/MONDO:0100096
# API 4.2 Automat CORD19 Scigraph API: 7 hits
# API 4.3: https://automat.renci.org/cord19-scigraph/disease/chemical_substance/MONDO:0100096
# API 4.3 Automat CORD19 Scigraph API: 13 hits
# API 1.1: https://www.ebi.ac.uk/ols/api/ontologies/doid/children?id=DOID:0080600
# API 1.1 Ontology Lookup Service API: 0 hits
# API 12.5: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 12.5 CORD Disease API: 0 hits
# API 12.6: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 12.6 CORD Disease API: 0 hits
# API 12.7: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 12.7 CORD Disease API: 0 hits
# API 12.8: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 12.8 CORD Disease API: 0 hits
#
# BTE starts to perform id-to-object translation.
#
# After id-to-object translation, BTE retrieved 69 unique output nodes.
#
#
#
# After applying post-query filter, BTE retrieved 69 unique output nodes.
#
# ========== Query # 2 ==========
#
# ==== Step #1: Query Path Planning ====
#
# Input Types: Disease,Gene,ChemicalSubstance
# Output Types: Gene
# Predicates: None
#
# BTE found 21 APIs based on SmartAPI Meta-KG.
#
# API 1. Automat CORD19 Scibite API (17 API calls)
# API 2. Automat CORD19 Scigraph API (17 API calls)
# API 3. MGIgene2phenotype API (1 API calls)
# API 4. TCGA Mutation Frequency KP API (1 API calls)
# API 5. Automat PHAROS API (17 API calls)
# API 6. DISEASES API (1 API calls)
# API 7. BioLink API (110 API calls)
# API 8. Molecular Data Provider API (1 API calls)
# API 9. CORD Disease API (1 API calls)
# API 10. CORD Gene API (1 API calls)
# API 11. MyGene.info API (1 API calls)
# API 12. SEMMED Gene API (10 API calls)
# API 13. Text Mining Targeted Association API (32 API calls)
# API 14. SEMMED Chemical API (13 API calls)
# API 15. MyChem.info API (3 API calls)
# API 16. CTD API (10 API calls)
# API 17. CORD Chemical API (1 API calls)
# API 18. Automat CHEMBIO API (16 API calls)
# API 19. Automat HMDB API (16 API calls)
# API 20. Drug Response KP API (9 API calls)
# API 21. BioThings DGIdb API (1 API calls)
#
#
# ==== Step #2: Query path execution ====
#
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 16.1: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=D003401&inputType=chem&report=genes_curated
# API 16.1 CTD API: 14 hits
# API 16.2: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=D061466&inputType=chem&report=genes_curated
# API 16.2 CTD API: 16 hits
# API 16.3: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=C112035&inputType=chem&report=genes_curated
# API 16.3 CTD API: 0 hits
# API 15.1: https://mychem.info/v1/query?fields=drugbank.targets (POST -d q=DB00148,DB00503,DB09140,DB00608,DB13609,DB01601,DB01611&scopes=drugbank.id)
# API 15.1 MyChem.info API: 21 hits
# API 15.2: https://mychem.info/v1/query?fields=drugcentral.bioactivity (POST -d q=CHEMBL729,CHEMBL1690,CHEMBL76,CHEMBL1234886,CHEMBL58510,CHEMBL1669,CHEMBL283800,CHEMBL163,CHEMBL1214598,CHEMBL2095223,CHEMBL1326,CHEMBL47047,CHEMBL1535&scopes=chembl.molecule_chembl_id)
# API 15.2 MyChem.info API: 31 hits
# API 4.1: https://biothings.ncats.io/tcga_mut_freq_kp/query?fields=association.freq_by_sample,subject.SYMBOL&q=object.id:"MONDO:0020753"%20AND%20association.freq_by_sample:>0.1&size=1000&sort=-association.freq_by_sample
# API 4.1 TCGA Mutation Frequency KP API: 0 hits
# API 6.1: https://pending.biothings.io/DISEASES/query?fields=DISEASES.associatedWith (POST -d q=DOID:0080599&scopes=DISEASES.doid)
# API 6.1 DISEASES API: 0 hits
# API 3.1: https://pending.biothings.io/mgigene2phenotype/query?fields=_id&size=300 (POST -d q=DOID:0080599&scopes=mgi.associated_with_disease.doid)
# API 3.1 MGIgene2phenotype API: 0 hits
# API 11.1: https://mygene.info/v3/query?fields=pantherdb.ortholog (POST -d q=925,6347,7124,5447,2580,3586,6348,1506,7137,92521,3574,185,682,3439,2152,10332,10044,10473,3627,54585,920,5045,5499,3456,3553,5972,1514,186,59272,7113,10045,1803,22848,3569,3558,6868,339967,54938,1401,6651,213,28,2875,3605,2147,7054,3559,3576,1636,10410,4151,3458,4141,340024&scopes=entrezgene)
# API 11.1 MyGene.info API: 82 hits
# API 16.4: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=D010100&inputType=chem&report=genes_curated
# API 13.1: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:27140" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.1 Text Mining Targeted Association API: 0 hits
# API 20.1: https://biothings.ncats.io/drug_response_kp/query?fields=association.context.disease.mondo,subject.NCBIGene,association.effect_size,association.pvalue&q=object.PUBCHEM:392622%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05&size=1000&sort=association.pvalue
# API 20.1 Drug Response KP API: 0 hits
# API 20.2: https://biothings.ncats.io/drug_response_kp/query?fields=association.context.disease.mondo,subject.NCBIGene,association.effect_size,association.pvalue&q=object.PUBCHEM:586%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05&size=1000&sort=association.pvalue
# API 20.2 Drug Response KP API: 0 hits
# API 13.2: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:15379" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.2 Text Mining Targeted Association API: 0 hits
# API 20.3: https://biothings.ncats.io/drug_response_kp/query?fields=association.context.disease.mondo,subject.NCBIGene,association.effect_size,association.pvalue&q=object.PUBCHEM:977%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05&size=1000&sort=association.pvalue
# API 20.3 Drug Response KP API: 0 hits
# API 13.3: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:31781" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.3 Text Mining Targeted Association API: 0 hits
# API 20.4: https://biothings.ncats.io/drug_response_kp/query?fields=association.context.disease.mondo,subject.NCBIGene,association.effect_size,association.pvalue&q=object.PUBCHEM:92727%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05&size=1000&sort=association.pvalue
# API 20.4 Drug Response KP API: 0 hits
# API 13.4: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:25805" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.4 Text Mining Targeted Association API: 199 hits
# API 14.1: https://biothings.ncats.io/semmedchemical/query?fields=disrupted_by (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 14.1 SEMMED Chemical API: 0 hits
# API 14.2: https://biothings.ncats.io/semmedchemical/query?fields=affected_by (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 14.2 SEMMED Chemical API: 0 hits
# API 14.3: https://biothings.ncats.io/semmedchemical/query?fields=coexists_with (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 21.1: https://biothings.ncats.io/dgidb/query?fields=subject.NCBIGene,association.provided_by,association.pubmed&size=1000 (POST -d q=CHEMBL729,CHEMBL1690,CHEMBL76,CHEMBL1234886,CHEMBL58510,CHEMBL1669,CHEMBL283800,CHEMBL163,CHEMBL1214598,CHEMBL2095223,CHEMBL1326,CHEMBL47047,CHEMBL1535&scopes=object.CHEMBL_COMPOUND)
# API 21.1 BioThings DGIdb API: 25 hits
# API 9.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080599&scopes=doid)
# API call to CORD Disease API with input ['DOID:0080599'] failed with unknown response
# API 1.1: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:15379
# API 1.1 Automat CORD19 Scibite API: 0 hits
# API 1.2: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:25805
# API 1.2 Automat CORD19 Scibite API: 0 hits
# API 5.1: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:15379
# API 5.1 Automat PHAROS API: 0 hits
# API 2.1: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:15379
# API 2.1 Automat CORD19 Scigraph API: 27 hits
# API 19.1: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:31781
# API 19.1 Automat HMDB API: 7 hits
# API 5.2: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:25805
# API 5.2 Automat PHAROS API: 0 hits
# API 18.1: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:25805
# API 18.1 Automat CHEMBIO API: 0 hits
# API 1.3: https://automat.renci.org/cord19-scibite/disease/gene/MONDO:0020753
# API 1.3 Automat CORD19 Scibite API: 0 hits
# API 19.2: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:15379
# API 19.2 Automat HMDB API: 197 hits
# API 18.2: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:31781
# API 18.2 Automat CHEMBIO API: 0 hits
# API 2.2: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:27140
# API 2.2 Automat CORD19 Scigraph API: 0 hits
# API 5.3: https://automat.renci.org/pharos/disease/gene/MONDO:0020753
# API 5.3 Automat PHAROS API: 0 hits
# API 2.3: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:25805
# API 2.3 Automat CORD19 Scigraph API: 0 hits
# API 5.4: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:27140
# API 5.4 Automat PHAROS API: 0 hits
# API 18.3: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:15379
# API 18.3 Automat CHEMBIO API: 0 hits
# API 1.4: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:27140
# API 1.4 Automat CORD19 Scibite API: 0 hits
# API 2.4: https://automat.renci.org/cord19-scigraph/disease/gene/MONDO:0020753
# API 2.4 Automat CORD19 Scigraph API: 0 hits
# API 18.4: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:27140
# API 18.4 Automat CHEMBIO API: 0 hits
# API 19.3: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:27140
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/__init__.py", line 297, in callSingleAPI
#     result = tf.transform()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/__init__.py", line 49, in transform
#     return self.tf.transform()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/transformers/base_transformer.py", line 78, in transform
#     item = self.wrap(item)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/transformers/cord_transformer.py", line 16, in wrap
#     for k in item.keys():
# RuntimeError: dictionary keys changed during iteration
# API 19.3 Automat HMDB API: 0 hits
# API 19.4: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:25805
# API 19.4 Automat HMDB API: 0 hits
# API 17.1: https://biothings.ncats.io/cord_chemical/query?fields=associated_with (POST -d q=CHEBI:15379,CHEBI:31781,CHEBI:134730,CHEBI:24261,CHEBI:29194,CHEBI:57947,CHEBI:45409,CHEBI:5801,CHEBI:33098,CHEBI:48433,CHEBI:29995,CHEBI:132943,CHEBI:25805,CHEBI:27140,CHEBI:3638,CHEBI:16919&scopes=chebi)
# API 14.3: https://biothings.ncats.io/semmedchemical/query?fields=affects (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 14.3 SEMMED Chemical API: 0 hits
# API 8.1: https://translator.broadinstitute.org/molepro_reasoner/query (POST -d {'message': {'query_graph': {'edges': [{'id': 'e00', 'source_id': 'n00', 'target_id': 'n01', 'type': 'related_to'}], 'nodes': [{'curie': 'MONDO:0020753', 'id': 'n00', 'type': 'disease'}, {'id': 'n01', 'type': 'gene'}]}}})
# API 8.1 Molecular Data Provider API: 0 hits
# API 12.1: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 12.1 SEMMED Gene API: 4 hits
# API 12.2: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 12.2 SEMMED Gene API: 0 hits
# API 12.3: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 12.3: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 10.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=399,6018,5962,3009,5414,6023,11782,11876,11892,4113,9281,5438,1706,5417,16884,5992,11183,6741,19679,1116,10627,79,6001,2367,338,13523,27960,6025,2524,195,10618,6915,30615,27954,4552,11947,9208,17697,6898,5434,4989,10637,336,1678,6008,8568,2707,3535,5981,2537,9958,13557,16885,3541&scopes=hgnc)
# API 7.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0020753/genes?direct=True&rows=200&unselect_evidence=True
# API 7.1 BioLink API: 0 hits
# API 7.2: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0020753/genes?direct=True&rows=200&unselect_evidence=True
# API 7.2 BioLink API: 0 hits
# API 7.3: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:59272/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.3 BioLink API: 28 hits
# API 7.4: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:4141/interactions?direct=True&rows=200&unselect_evidence=True
# API 16.4 CTD API: 4588 hits
# API 14.4 SEMMED Chemical API: 710 hits
# API call to CORD Chemical API with input ['CHEBI:15379', 'CHEBI:31781', 'CHEBI:134730', 'CHEBI:24261', 'CHEBI:29194', 'CHEBI:57947', 'CHEBI:45409', 'CHEBI:5801', 'CHEBI:33098', 'CHEBI:48433', 'CHEBI:29995', 'CHEBI:132943', 'CHEBI:25805', 'CHEBI:27140', 'CHEBI:3638', 'CHEBI:16919'] failed with unknown response
# API 12.3 SEMMED Gene API: 1 hits
# API 7.4 BioLink API: 195 hits
# API 15.3: https://mychem.info/v1/query?fields=drugbank.enzymes (POST -d q=DB00148,DB00503,DB09140,DB00608,DB13609,DB01601,DB01611&scopes=drugbank.id)
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/__init__.py", line 297, in callSingleAPI
#     result = tf.transform()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/__init__.py", line 49, in transform
#     return self.tf.transform()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/transformers/base_transformer.py", line 78, in transform
#     item = self.wrap(item)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/transformers/cord_transformer.py", line 16, in wrap
#     for k in item.keys():
# RuntimeError: dictionary keys changed during iteration
# API 15.3 MyChem.info API: 33 hits
# API 12.4 SEMMED Gene API: 2 hits
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/__init__.py", line 297, in callSingleAPI
#     result = tf.transform()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/__init__.py", line 49, in transform
#     return self.tf.transform()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/transformers/base_transformer.py", line 78, in transform
#     item = self.wrap(item)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/call_apis/api_response_transform/transformers/cord_transformer.py", line 16, in wrap
#     for k in item.keys():
# RuntimeError: dictionary keys changed during iteration
# API call to CORD Gene API with input ['399', '6018', '5962', '3009', '5414', '6023', '11782', '11876', '11892', '4113', '9281', '5438', '1706', '5417', '16884', '5992', '11183', '6741', '19679', '1116', '10627', '79', '6001', '2367', '338', '13523', '27960', '6025', '2524', '195', '10618', '6915', '30615', '27954', '4552', '11947', '9208', '17697', '6898', '5434', '4989', '10637', '336', '1678', '6008', '8568', '2707', '3535', '5981', '2537', '9958', '13557', '16885', '3541'] failed with unknown response
# API 13.5: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:57947" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.5 Text Mining Targeted Association API: 0 hits
# API 13.6: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:24261" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.6: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:29194" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.6 Text Mining Targeted Association API: 0 hits
# API 13.7: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:16919" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.7 Text Mining Targeted Association API: 8 hits
# API 13.8 Text Mining Targeted Association API: 136 hits
# API 20.5: https://biothings.ncats.io/drug_response_kp/query?fields=association.context.disease.mondo,subject.NCBIGene,association.effect_size,association.pvalue&q=object.PUBCHEM:28446253%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05&size=1000&sort=association.pvalue
# API 20.5 Drug Response KP API: 0 hits
# API 20.6: https://biothings.ncats.io/drug_response_kp/query?fields=association.context.disease.mondo,subject.NCBIGene,association.effect_size,association.pvalue&q=object.PUBCHEM:131411%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05&size=1000&sort=association.pvalue
# API 20.6 Drug Response KP API: 0 hits
# API 20.7: https://biothings.ncats.io/drug_response_kp/query?fields=association.context.disease.mondo,subject.NCBIGene,association.effect_size,association.pvalue&q=object.PUBCHEM:6944%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05&size=1000&sort=association.pvalue
# API 20.7 Drug Response KP API: 0 hits
# API 20.8: https://biothings.ncats.io/drug_response_kp/query?fields=association.context.disease.mondo,subject.NCBIGene,association.effect_size,association.pvalue&q=object.PUBCHEM:3652%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05&size=1000&sort=association.pvalue
# API 20.8 Drug Response KP API: 0 hits
# API 2.5: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:57947
# API 2.5 Automat CORD19 Scigraph API: 0 hits
# API 1.5: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:24261
# API 1.5 Automat CORD19 Scibite API: 0 hits
# API 5.5: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:16919
# API 5.5 Automat PHAROS API: 0 hits
# API 18.5: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:24261
# API 18.5 Automat CHEMBIO API: 0 hits
# API 1.6: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:57947
# API 1.6 Automat CORD19 Scibite API: 0 hits
# API 1.7: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:16919
# API 1.7 Automat CORD19 Scibite API: 0 hits
# API 2.6: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:31781
# API 2.6 Automat CORD19 Scigraph API: 2 hits
# API 18.6: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:29194
# API 18.6 Automat CHEMBIO API: 0 hits
# API 5.6: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:29194
# API 5.6 Automat PHAROS API: 0 hits
# API 18.7: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:45409
# API 18.7 Automat CHEMBIO API: 0 hits
# API 5.7: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:57947
# API 5.7 Automat PHAROS API: 0 hits
# API 18.8: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:16919
# API 18.8 Automat CHEMBIO API: 0 hits
# API 1.8: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:31781
# API 1.8 Automat CORD19 Scibite API: 5 hits
# API 5.8: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:24261
# API 5.8 Automat PHAROS API: 0 hits
# API 5.9: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:31781
# API 5.9 Automat PHAROS API: 1 hits
# API 13.9: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:45409" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.9 Text Mining Targeted Association API: 0 hits
# API 18.9: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:57947
# API 18.9 Automat CHEMBIO API: 0 hits
# API 1.9: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:29194
# API 1.9 Automat CORD19 Scibite API: 0 hits
# API 20.9: https://biothings.ncats.io/drug_response_kp/query?fields=association.context.disease.mondo,subject.NCBIGene,association.effect_size,association.pvalue&q=object.PUBCHEM:2719%20AND%20association.effect_size:<0%20AND%20association.pvalue:<0.05&size=1000&sort=association.pvalue
# API 20.9 Drug Response KP API: 0 hits
# API 2.7: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:16919
# API 2.7 Automat CORD19 Scigraph API: 12 hits
# API 2.8: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:29194
# API 2.8 Automat CORD19 Scigraph API: 25 hits
# API 2.9: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:24261
# API 2.9 Automat CORD19 Scigraph API: 42 hits
# API 16.5: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=C029955&inputType=chem&report=genes_curated
# API 16.5 CTD API: 67 hits
# API 16.6: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=D019438&inputType=chem&report=genes_curated
# API 16.6 CTD API: 127 hits
# API 14.5: https://biothings.ncats.io/semmedchemical/query?fields=positively_regulated_by (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 14.5 SEMMED Chemical API: 299 hits
# API 16.7: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=C086979&inputType=chem&report=genes_curated
# API 16.7 CTD API: 0 hits
# API 16.8: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=D002738&inputType=chem&report=genes_curated
# API 7.5: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7113/interactions?direct=True&rows=200&unselect_evidence=True
# API 14.6: https://biothings.ncats.io/semmedchemical/query?fields=physically_interacts_with (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 16.8: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=D006886&inputType=chem&report=genes_curated
# API 16.8 CTD API: 81 hits
# API 14.6: https://biothings.ncats.io/semmedchemical/query?fields=negatively_regulated_by (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 14.6: https://biothings.ncats.io/semmedchemical/query?fields=disrupts (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 16.9 CTD API: 324 hits
# API 7.5 BioLink API: 71 hits
# API 14.6 SEMMED Chemical API: 212 hits
# API 14.7 SEMMED Chemical API: 0 hits
# API 14.8: https://biothings.ncats.io/semmedchemical/query?fields=negatively_regulates (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 14.8 SEMMED Chemical API: 564 hits
# API 7.6: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1401/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.6: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7054/interactions?direct=True&rows=200&unselect_evidence=True
# API 12.5: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 12.5: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 19.5: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:57947
# API 19.5 Automat HMDB API: 10 hits
# API 19.6: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:29194
# API 19.6 Automat HMDB API: 0 hits
# API 19.7: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:24261
# API 19.7 Automat HMDB API: 0 hits
# API 7.6 BioLink API: 120 hits
# API 7.7 BioLink API: 96 hits
# API 7.8: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5447/interactions?direct=True&rows=200&unselect_evidence=True
# API 12.5: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 14.9 SEMMED Chemical API: 971 hits
# API 12.5: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 7.8: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6651/interactions?direct=True&rows=200&unselect_evidence=True
# API 12.5: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 19.8: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:16919
# API 19.8 Automat HMDB API: 0 hits
# API 19.9: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:45409
# API 19.9 Automat HMDB API: 16 hits
# API 7.8 BioLink API: 137 hits
# API 12.5 SEMMED Gene API: 2795 hits
# API 7.9 BioLink API: 103 hits
# API 12.6 SEMMED Gene API: 4459 hits
# API 12.7 SEMMED Gene API: 4692 hits
# API 12.8 SEMMED Gene API: 3257 hits
# API 12.9 SEMMED Gene API: 6219 hits
# API 13.10: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:134730" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.10 Text Mining Targeted Association API: 0 hits
# API 13.11: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:33098" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.11 Text Mining Targeted Association API: 0 hits
# API 13.12: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:29995" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.12 Text Mining Targeted Association API: 13 hits
# API 13.13: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:5801" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.13 Text Mining Targeted Association API: 11 hits
# API 13.14: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:48433" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.14 Text Mining Targeted Association API: 39 hits
# API 18.10: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:48433
# API 18.10 Automat CHEMBIO API: 0 hits
# API 14.10: https://biothings.ncats.io/semmedchemical/query?fields=positively_regulates (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 1.10: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:33098
# API 1.10 Automat CORD19 Scibite API: 0 hits
# API 1.11: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:5801
# API 1.11 Automat CORD19 Scibite API: 0 hits
# API 18.11: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:29995
# API 18.11 Automat CHEMBIO API: 0 hits
# API 18.12: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:134730
# API 18.12 Automat CHEMBIO API: 0 hits
# API 5.10: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:48433
# API 5.10 Automat PHAROS API: 0 hits
# API 18.13: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:33098
# API 18.13 Automat CHEMBIO API: 0 hits
# API 7.10: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10045/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.10 BioLink API: 14 hits
# API 1.12: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:48433
# API 1.12 Automat CORD19 Scibite API: 0 hits
# API 1.13: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:29995
# API 1.13 Automat CORD19 Scibite API: 0 hits
# API 1.14: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:45409
# API 1.14 Automat CORD19 Scibite API: 7 hits
# API 5.11: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:33098
# API 5.11 Automat PHAROS API: 0 hits
# API 5.12: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:29995
# API 5.12 Automat PHAROS API: 0 hits
# API 5.13: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:45409
# API 5.13 Automat PHAROS API: 4 hits
# API 2.10: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:5801
# API 2.10 Automat CORD19 Scigraph API: 2 hits
# API 18.14: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:5801
# API 18.14 Automat CHEMBIO API: 2 hits
# API 5.14: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:5801
# API 5.14 Automat PHAROS API: 2 hits
# API 19.10: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:134730
# API 19.10 Automat HMDB API: 0 hits
# API 19.11: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:29995
# API 19.11 Automat HMDB API: 0 hits
# API 19.12: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:33098
# API 19.12 Automat HMDB API: 0 hits
# API 19.13: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:48433
# API 19.13 Automat HMDB API: 0 hits
# API 2.11: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:33098
# API 2.11 Automat CORD19 Scigraph API: 16 hits
# API 2.12: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:48433
# API 2.12 Automat CORD19 Scigraph API: 10 hits
# API 19.14: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:5801
# API 19.14 Automat HMDB API: 2 hits
# API 2.13: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:45409
# API 2.13 Automat CORD19 Scigraph API: 5 hits
# API 2.14: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:29995
# API 2.14 Automat CORD19 Scigraph API: 11 hits
# API 14.10: https://biothings.ncats.io/semmedchemical/query?fields=related_to (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 16.10: http://ctdbase.org/tools/batchQuery.go?format=json&inputTerms=C023676&inputType=chem&report=genes_curated
# API 14.10: https://biothings.ncats.io/semmedchemical/query?fields=produces (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 14.10 SEMMED Chemical API: 0 hits
# API 14.11: https://biothings.ncats.io/semmedchemical/query?fields=produced_by (POST -d q=C0008269,C0292818,C0674432,C0010286,C0020336,C0254211,C0700447,C0046462,C0030054,C0003751&scopes=umls)
# API 14.11 SEMMED Chemical API: 5 hits
# API 14.12 SEMMED Chemical API: 512 hits
# API 14.13 SEMMED Chemical API: 0 hits
# API 16.10 CTD API: 65 hits
# API 7.11: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6347/interactions?direct=True&rows=200&unselect_evidence=True
# API 12.10: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1332807,C0054871,C1414504,C1417035,C1420310,C1420826,C0021745,C1415900,C1422064,C1335817,C1335818,C0035094,C1333916,C1415912,C1415274,C1413809,C1335232,C0879590,C1334098,C1414944,C1823096,C1332036,C1334114,C1413716,C1334085,C1334124,C1415898,C1426329,C1419338,C0919550,C1413244,C1412099,C1412186,C1412828,C1335240,C1367714,C1412332,C1539099,C0812246,C1417048,C1332714,C1439284,C1336641,C1420718,C1825592,C1337092,C1334112,C0081714,C1540024,C1425041,C1366571,C1416946,C1414141,C1333522,C1334122,C1332690,C1428660,C1413931&scopes=umls)
# API 7.11 BioLink API: 130 hits
# API 7.12: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3558/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.12: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:920/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.12 BioLink API: 200 hits
# API 7.13: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3458/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.13 BioLink API: 198 hits
# API 12.10 SEMMED Gene API: 0 hits
# API 7.14 BioLink API: 128 hits
# API 13.15: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:132943" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.15 Text Mining Targeted Association API: 0 hits
# API 13.16: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:27140" AND association.edge_label:negatively_regulates_entity_to_entity&size=1000
# API 13.16 Text Mining Targeted Association API: 0 hits
# API 13.17: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:15379" AND association.edge_label:negatively_regulates_entity_to_entity&size=1000
# API 13.17 Text Mining Targeted Association API: 0 hits
# API 13.18: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:3638" AND association.edge_label:positively_regulates_entity_to_entity&size=1000
# API 13.18 Text Mining Targeted Association API: 54 hits
# API 13.19: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:25805" AND association.edge_label:negatively_regulates_entity_to_entity&size=1000
# API 13.19 Text Mining Targeted Association API: 139 hits
# API 1.15: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:134730
# API 1.15 Automat CORD19 Scibite API: 0 hits
# API 1.16: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:3638
# API 1.16 Automat CORD19 Scibite API: 2 hits
# API 1.17: https://automat.renci.org/cord19-scibite/chemical_substance/gene/CHEBI:132943
# API 1.17 Automat CORD19 Scibite API: 0 hits
# API 18.15: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:3638
# API 18.15 Automat CHEMBIO API: 0 hits
# API 18.16: https://automat.renci.org/chembio/chemical_substance/gene/CHEBI:132943
# API 18.16 Automat CHEMBIO API: 0 hits
# API 19.15: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:132943
# API 19.15 Automat HMDB API: 0 hits
# API 5.15: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:132943
# API 5.15 Automat PHAROS API: 0 hits
# API 19.16: https://automat.renci.org/hmdb/chemical_substance/gene/CHEBI:3638
# API 19.16 Automat HMDB API: 9 hits
# API 5.16: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:3638
# API 5.16 Automat PHAROS API: 2 hits
# API 2.15: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:134730
# API 2.15 Automat CORD19 Scigraph API: 0 hits
# API 5.17: https://automat.renci.org/pharos/chemical_substance/gene/CHEBI:134730
# API 5.17 Automat PHAROS API: 0 hits
# API 2.16: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:3638
# API 2.16 Automat CORD19 Scigraph API: 9 hits
# API 2.17: https://automat.renci.org/cord19-scigraph/chemical_substance/gene/CHEBI:132943
# API 2.17 Automat CORD19 Scigraph API: 11 hits
# API 7.15: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3574/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.15: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3439/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.15 BioLink API: 35 hits
# API 7.16 BioLink API: 71 hits
# API 7.17: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:92521/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.17: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5972/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.17 BioLink API: 33 hits
# API 7.18 BioLink API: 57 hits
# API 7.19: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3553/interactions?direct=True&rows=200&unselect_evidence=True
# API 7.19 BioLink API: 155 hits
# API 13.20: https://biothings.ncats.io/text_mining_targeted_association/query?fields=object.NCBIgene,association.evidence.publications&q=subject.CHEBI:"CHEBI:57947" AND association.edge_label:negatively_regulates_entity_to_entity&size=1000
# API 13.20 Text Mining Targeted Association API: 0 hits
# ...
# API 6.263 Automat PHAROS API: 3 hits
# API 1.261: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:4851
# API 1.261 Automat CORD19 Scibite API: 6 hits
# API 6.264: https://automat.renci.org/pharos/gene/disease/NCBIGene:5743
# API 6.264 Automat PHAROS API: 3 hits
# API 1.262: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:7040
# API 1.262: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:5290
# API 1.262 Automat CORD19 Scibite API: 9 hits
# API 1.263: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:5743
# API 1.263 Automat CORD19 Scibite API: 25 hits
# API 3.260: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:7040
# API 3.260 Automat CORD19 Scigraph API: 0 hits
# API 3.261: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:4851
# API 3.261 Automat CORD19 Scigraph API: 4 hits
# API 3.262: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:8878
# API 3.262 Automat CORD19 Scigraph API: 1 hits
# API 3.263: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:5743
# API 3.263 Automat CORD19 Scigraph API: 0 hits
# API 3.264: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:5290
# API 3.264 Automat CORD19 Scigraph API: 1 hits
# API 1.264 Automat CORD19 Scibite API: 39 hits
# API 8.261: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:4851/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.261 BioLink API: 74 hits
# API 8.262: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:8878/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.262 BioLink API: 132 hits
# API 8.263: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5290/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.263: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7040/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.263 BioLink API: 199 hits
# API 8.264 BioLink API: 103 hits
# API 8.265: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7098/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.265 BioLink API: 0 hits
# API 6.265: https://automat.renci.org/pharos/gene/disease/NCBIGene:8795
# API 6.265 Automat PHAROS API: 1 hits
# API 6.266: https://automat.renci.org/pharos/gene/disease/NCBIGene:8600
# API 6.266 Automat PHAROS API: 2 hits
# API 8.266: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:8795/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.266 BioLink API: 1 hits
# API 6.267: https://automat.renci.org/pharos/gene/disease/NCBIGene:7098
# API 6.267 Automat PHAROS API: 2 hits
# API 6.268: https://automat.renci.org/pharos/gene/disease/NCBIGene:1509
# API 6.268 Automat PHAROS API: 3 hits
# API 6.269: https://automat.renci.org/pharos/gene/disease/NCBIGene:7132
# API 6.269 Automat PHAROS API: 2 hits
# API 1.265: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:8795
# API 1.265 Automat CORD19 Scibite API: 2 hits
# API 1.266: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:8600
# API 1.266 Automat CORD19 Scibite API: 9 hits
# API 3.265: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:7132
# API 3.265 Automat CORD19 Scigraph API: 0 hits
# API 1.267: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:1509
# API 1.267 Automat CORD19 Scibite API: 6 hits
# API 1.268: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:7098
# API 1.268 Automat CORD19 Scibite API: 10 hits
# API 1.269: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:7132
# API 1.269 Automat CORD19 Scibite API: 9 hits
# API 3.266: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:8600
# API 3.266 Automat CORD19 Scigraph API: 0 hits
# API 3.267: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:8795
# API 3.267 Automat CORD19 Scigraph API: 0 hits
# API 3.268: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:1509
# API 3.268 Automat CORD19 Scigraph API: 0 hits
# API 3.269: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:7098
# API 3.269 Automat CORD19 Scigraph API: 25 hits
# API 8.267: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7132/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.267 BioLink API: 45 hits
# API 8.268: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1509/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.268 BioLink API: 23 hits
# API 8.269: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:8600/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.269 BioLink API: 60 hits
# API 1.270: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:10598
# API 1.270 Automat CORD19 Scibite API: 0 hits
# API 6.270: https://automat.renci.org/pharos/gene/disease/NCBIGene:26073
# API 6.270 Automat PHAROS API: 0 hits
# API 1.271: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:3133
# API 1.271 Automat CORD19 Scibite API: 3 hits
# API 1.272: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:1398
# API 1.272 Automat CORD19 Scibite API: 0 hits
# API 1.273: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:26073
# API 1.273 Automat CORD19 Scibite API: 0 hits
# API 6.271: https://automat.renci.org/pharos/gene/disease/NCBIGene:1398
# API 6.271 Automat PHAROS API: 1 hits
# API 3.270: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:1398
# API 3.270 Automat CORD19 Scigraph API: 0 hits
# API 1.274: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:1442
# API 1.274 Automat CORD19 Scibite API: 0 hits
# API 6.272: https://automat.renci.org/pharos/gene/disease/NCBIGene:3133
# API 6.272 Automat PHAROS API: 1 hits
# API 3.271: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:10598
# API 3.271 Automat CORD19 Scigraph API: 0 hits
# API 6.273: https://automat.renci.org/pharos/gene/disease/NCBIGene:1442
# API 6.273 Automat PHAROS API: 5 hits
# API 6.274: https://automat.renci.org/pharos/gene/disease/NCBIGene:10598
# API 6.274 Automat PHAROS API: 2 hits
# API 3.272: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:3133
# API 3.272 Automat CORD19 Scigraph API: 0 hits
# API 3.273: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:26073
# API 3.273 Automat CORD19 Scigraph API: 0 hits
# API 3.274: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:1442
# API 3.274 Automat CORD19 Scigraph API: 0 hits
# API 8.270: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:10598/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.270 BioLink API: 0 hits
# API 8.271: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1398/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.271 BioLink API: 0 hits
# API 8.272: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:26073/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.272 BioLink API: 0 hits
# API 8.273: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3133/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.273 BioLink API: 0 hits
# API 8.274: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:1442/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.274 BioLink API: 0 hits
# API 8.275: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3661/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.275 BioLink API: 0 hits
# API 8.276: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3497/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.276 BioLink API: 0 hits
# API 8.277: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3700/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.277 BioLink API: 0 hits
# API 8.278: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3456/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.278 BioLink API: 0 hits
# API 6.275: https://automat.renci.org/pharos/gene/disease/NCBIGene:3497
# API 6.275 Automat PHAROS API: 0 hits
# API 6.276: https://automat.renci.org/pharos/gene/disease/NCBIGene:3661
# API 6.276 Automat PHAROS API: 3 hits
# API 6.277: https://automat.renci.org/pharos/gene/disease/NCBIGene:3700
# API 6.277 Automat PHAROS API: 4 hits
# API 6.278: https://automat.renci.org/pharos/gene/disease/NCBIGene:3559
# API 6.278 Automat PHAROS API: 15 hits
# API 6.279: https://automat.renci.org/pharos/gene/disease/NCBIGene:3456
# API 6.279 Automat PHAROS API: 4 hits
# API 1.275: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:3700
# API 1.275 Automat CORD19 Scibite API: 1 hits
# API 3.275: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:3497
# API 3.275 Automat CORD19 Scigraph API: 0 hits
# API 3.276: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:3559
# API 3.276 Automat CORD19 Scigraph API: 0 hits
# API 1.276: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:3456
# API 1.276 Automat CORD19 Scibite API: 12 hits
# API 3.277: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:3700
# API 3.277 Automat CORD19 Scigraph API: 0 hits
# API 3.278: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:3456
# API 3.278 Automat CORD19 Scigraph API: 1 hits
# API 1.277: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:3559
# API 1.277 Automat CORD19 Scibite API: 20 hits
# API 3.279: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:3661
# API 3.279 Automat CORD19 Scigraph API: 26 hits
# API 1.278: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:3661
# API 1.278 Automat CORD19 Scibite API: 14 hits
# API 1.279: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:3497
# API 1.279 Automat CORD19 Scibite API: 34 hits
# API 8.279: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3559/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.279 BioLink API: 19 hits
# API 8.280: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6962/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.280 BioLink API: 0 hits
# API 1.280: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:6776
# API 1.280 Automat CORD19 Scibite API: 3 hits
# API 8.281: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6776/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.281 BioLink API: 0 hits
# API 1.281: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:6962
# API 1.281 Automat CORD19 Scibite API: 0 hits
# API 1.282: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:5781
# API 1.282 Automat CORD19 Scibite API: 1 hits
# API 1.283: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:6778
# API 1.283 Automat CORD19 Scibite API: 5 hits
# API 6.280: https://automat.renci.org/pharos/gene/disease/NCBIGene:6776
# API 6.280 Automat PHAROS API: 1 hits
# API 6.281: https://automat.renci.org/pharos/gene/disease/NCBIGene:5788
# API 6.281 Automat PHAROS API: 1 hits
# API 6.282: https://automat.renci.org/pharos/gene/disease/NCBIGene:6962
# API 6.282 Automat PHAROS API: 0 hits
# API 6.283: https://automat.renci.org/pharos/gene/disease/NCBIGene:6778
# API 6.283 Automat PHAROS API: 1 hits
# API 1.284: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:5788
# API 1.284 Automat CORD19 Scibite API: 6 hits
# API 6.284: https://automat.renci.org/pharos/gene/disease/NCBIGene:5781
# API 6.284 Automat PHAROS API: 4 hits
# API 3.280: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:6776
# API 3.280 Automat CORD19 Scigraph API: 0 hits
# API 3.281: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:6962
# API 3.281 Automat CORD19 Scigraph API: 0 hits
# API 3.282: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:5788
# API 3.282 Automat CORD19 Scigraph API: 0 hits
# API 3.283: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:6778
# API 3.283 Automat CORD19 Scigraph API: 1 hits
# API 3.284: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:5781
# API 3.284 Automat CORD19 Scigraph API: 0 hits
# API 8.282: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5788/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.282 BioLink API: 12 hits
# API 8.283: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6778/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.283 BioLink API: 1 hits
# API 8.284: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5781/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.284 BioLink API: 146 hits
# API 1.285: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:6857
# API 1.285 Automat CORD19 Scibite API: 0 hits
# API 1.286: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:3578
# API 1.286 Automat CORD19 Scibite API: 3 hits
# API 1.287: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:6850
# API 1.287 Automat CORD19 Scibite API: 3 hits
# API 3.285: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:3308
# API 3.285 Automat CORD19 Scigraph API: 0 hits
# API 1.288: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:5291
# API 1.288 Automat CORD19 Scibite API: 0 hits
# API 3.286: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:6857
# API 3.286 Automat CORD19 Scigraph API: 0 hits
# API 1.289: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:3308
# API 1.289 Automat CORD19 Scibite API: 0 hits
# API 6.285: https://automat.renci.org/pharos/gene/disease/NCBIGene:3578
# API 6.285 Automat PHAROS API: 2 hits
# API 6.286: https://automat.renci.org/pharos/gene/disease/NCBIGene:6857
# API 6.286 Automat PHAROS API: 1 hits
# API 6.287: https://automat.renci.org/pharos/gene/disease/NCBIGene:6850
# API 6.287 Automat PHAROS API: 1 hits
# API 3.287: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:5291
# API 3.287 Automat CORD19 Scigraph API: 0 hits
# API 3.288: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:3578
# API 3.288 Automat CORD19 Scigraph API: 0 hits
# API 6.288: https://automat.renci.org/pharos/gene/disease/NCBIGene:3308
# API 6.288 Automat PHAROS API: 1 hits
# API 6.289: https://automat.renci.org/pharos/gene/disease/NCBIGene:5291
# API 6.289 Automat PHAROS API: 0 hits
# API 3.289: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:6850
# API 3.289 Automat CORD19 Scigraph API: 1 hits
# API 8.285: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3578/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.285 BioLink API: 0 hits
# API 8.286: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:3308/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.286 BioLink API: 0 hits
# API 8.287: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6850/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.287 BioLink API: 0 hits
# API 8.288: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:5291/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.288 BioLink API: 0 hits
# API 8.289: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:6857/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.289 BioLink API: 66 hits
# API 8.290: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:27352/phenotypes?direct=True&rows=200&unselect_evidence=True
# API 8.290 BioLink API: 0 hits
# API 6.290: https://automat.renci.org/pharos/gene/disease/NCBIGene:27352
# API 6.290 Automat PHAROS API: 1 hits
# API 1.290: https://automat.renci.org/cord19-scibite/gene/disease/NCBIGene:27352
# API 1.290 Automat CORD19 Scibite API: 1 hits
# API 3.290: https://automat.renci.org/cord19-scigraph/gene/disease/NCBIGene:27352
# API 3.290 Automat CORD19 Scigraph API: 0 hits
#
# BTE starts to perform id-to-object translation.
#
# After id-to-object translation, BTE retrieved 16494 unique output nodes.
#
#
# Number of output edges sent to NGD score annotation is 179628. Number of output edges annotated with NGD score is 30156
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
# In the #1 query, BTE found 69 unique nodes.
# In the #2 query, BTE found 240 unique nodes.
# In the #3 query, BTE found 16494 unique nodes.

# %%
df2 = pd2.display_table_view()
df2.shape
# Out:
# (8353054, 27)

# %%
# filter gene -> symptoms table to only include rows where symptoms match disease symptoms
indices_with_symptom_outputs = [i for i, val in enumerate([x.upper() for x in list(df2['output_label'])]) if val in disease_symptoms]
indirect_relevant_genes_to_symptoms_df = df2.iloc[indices_with_symptom_outputs]
indirect_relevant_genes_to_symptoms_df.shape

# %%
list(dict.fromkeys(list(indirect_relevant_genes_to_symptoms_df['node2_label'])))

# %%
indirect_genes = 	list(indirect_relevant_genes_to_symptoms_df["node2_label"])
indirect_gene_dict = {x:indirect_genes.count(x) for x in indirect_genes}
indirect_gene_dict = dict(sorted(indirect_gene_dict.items(), key=lambda x: x[1], reverse=True)[:100])
indirect_gene_dict

# %% [markdown]
# ## Top Genes -> Pathways

# %%
# get gene inputs through hint module
gene_inputs = []
gene_names = list(direct_gene_dict.keys()) + list(indirect_gene_dict.keys())
gene_names = [x for x in gene_names if 'UMLS' not in x ]
gene_names = list(dict.fromkeys(gene_names))
gene_names
for gene in gene_names: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        gene_inputs.append(gene_input)
    except: 
        print(gene + ' Failed')

# print(gene_inputs)

# %%
# pd3 = Predict(
#     input_objs=gene_inputs,
#     intermediate_nodes=[None], 
#     output_types =['Pathway'], 
#     config={"expand": False}
# )
# pd3.connect(verbose=True)

# %%
# df3 = pd3.display_table_view()
# df3.shape

# %%
# predict_many funciton will be used to run many BTE queries and return results as a single table
def predict_many(input_object_list, output_type_list, intermediate_node_list = ''):
    df_list = []
    for input_object in input_object_list: 
        for output_type in output_type_list: 
            if(len(intermediate_node_list) > 0):
                for inter in intermediate_node_list:
                    try: 
                        print("Running: " + input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type )
                        fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        rows = df.shape[0]
                        if(rows > 0):
                            df_list.append(df)
                    except:
                        print(input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type + ' FAILED')
            else:
                try:
                    print("Running: " + input_object['name'] + ' --> output type ' + output_type )
                    fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=None)
                    fc.connect(verbose=False)
                    df = fc.display_table_view()
                    rows = df.shape[0]
                    if(rows > 0):
                        df_list.append(df)
                except:
                    print(input_object['name'] + ' --> output type ' + output_type + ' FAILED')

    if(len(df_list) > 0):
        return pandas.concat(df_list)
    else:
        return None

# %%
gene_to_pathways = predict_many(gene_inputs, ['Pathway'])
list(dict.fromkeys(list(gene_to_pathways["output_name"])))

# %%
# pathways
gene_to_pathway_results = {}
gene_to_pathway_genes = list(gene_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'pathway_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_pathways.iterrows():
    gene_to_pathway_results[row['output_name']]['pathway_count'] = gene_to_pathway_results[row['output_name']]['pathway_count'] + 1
    gene_to_pathway_results[row['output_name']]['genes_related'].append(row['input'])
    

gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['pathway_count'], reverse = True))

    
# gene_to_pathway_results
pandas.DataFrame.from_dict(gene_to_pathway_results, orient='index').iloc[0:50]

# %% [markdown]
# ## Genes --> Bioprocesses

# %%
# bioprocesss
gene_to_bioprocesses = predict_many(gene_inputs, ['BiologicalProcess'])
gene_to_bioprocess_results = {}
gene_to_bioprocess_genes = list(gene_to_bioprocesses["output_name"]) # create list of genes
gene_to_bioprocess_genes = list(dict.fromkeys(gene_to_bioprocess_genes))  # remove duplicates

for gene in gene_to_bioprocess_genes: 
    gene_to_bioprocess_results[gene] = {
        'bioprocess_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_bioprocesses.iterrows():
    gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] = gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] + 1
    gene_to_bioprocess_results[row['output_name']]['genes_related'].append(row['input'])

# %%
gene_to_bioprocess_results = dict(sorted(gene_to_bioprocess_results.items(), key = lambda x: x[1]['bioprocess_count'], reverse = True))

# %%
counter = 0 
for key in gene_to_bioprocess_results.keys(): 
    if counter < 100: 
        if(('C0' in key) or ('C1' in key)): 
            try: 
                name = ht.query(key)['BiologicalProcess'][0]['name']
                gene_to_bioprocess_results[name] = gene_to_bioprocess_results[key]
                del gene_to_bioprocess_results[key]
            except: 
                pass
    counter = counter + 1

# %%
# gene_to_bioprocess_results
pandas.DataFrame.from_dict(gene_to_bioprocess_results, orient='index').iloc[0:50]
